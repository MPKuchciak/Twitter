# %% [markdown]
# # Data cleaning

# %% [markdown]
# In this file, we cleaned the downloaded data:
# The main steps include:
# 1. Adding party affiliation to tweet rows
# 2. Deleting unnecessary downloaded Retweets.
# 3. Deleting links and mentions from the tweets text and saving them to separate columns
# 4. Expanding the column of public metrics
# 5. Encoding emojis in a unified format
# 6. Translating tweets using Google Translate in Google Sheets
# 7. Saving all downloaded tweets to one file

# %% [markdown]
# ### 1.  Used libraries

# %%
import os
import pandas as pd
import re
import emoji

# %% [markdown]
# ### 2. Reading JSON files and transforming them into party-specific pickle files

# %%
base_input_path = 'data/tweets_data_final'
subfolders = ['Konfederacja', 'NL', 'PIS', 'PO', 'PL2050', 'PSL']
output_folder = 'data/tweets_data_combined'

os.makedirs(output_folder, exist_ok=True)

for subfolder in subfolders:
    folder_path = os.path.join(base_input_path, subfolder)
    dataframes = []
    
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            politician = filename.split("_tweets.json")[0]
            try:
                df = pd.read_json(file_path)  
                df["username"] = politician  
                df["party"] = subfolder
                print(f"Read {len(df)} rows from {file_path}")  
                dataframes.append(df)
            except ValueError as e:
                print(f"Error reading {file_path}: {e}")
    
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        
        output_file_path = os.path.join(output_folder, f'{subfolder}_combined.pkl')
        combined_df.to_pickle(output_file_path) 
        
        print(f"Saved {subfolder} combined data to {output_file_path}")

print("Processing complete!")
# Out:
# Read 320 rows from data/tweets_data_final/Konfederacja/placzekgrzegorz_2024-04-16_2024-10-15.json
# Read 597 rows from data/tweets_data_final/Konfederacja/MichalWawer_2023-10-16_2024-10-15.json
# Read 1318 rows from data/tweets_data_final/Konfederacja/KonradBerkowicz_2024-04-16_2024-10-15_vol1 (1).json
# Read 950 rows from data/tweets_data_final/Konfederacja/Wlodek_Skalik_2023-10-16_2024-10-15.json
# Read 721 rows from data/tweets_data_final/Konfederacja/SlawomirMentzen_2023-10-16_2024-10-15.json
# Read 889 rows from data/tweets_data_final/Konfederacja/GrzegorzBraun__2023-10-16_2024-10-15.json
# Read 175 rows from data/tweets_data_final/Konfederacja/TudujKrzysztof_2023-10-16_2024-10-15.json
# Read 964 rows from data/tweets_data_final/Konfederacja/bartlomiejpejo_2023-10-16_2024-10-15.json
# Read 421 rows from data/tweets_data_final/Konfederacja/placzekgrzegorz_2023-10-16_2024-04-15.json
# Read 772 rows from data/tweets_data_final/Konfederacja/MarSypniewski_2023-10-16_2024-10-15.json
# Read 289 rows from data/tweets_data_final/Konfederacja/KonradBerkowicz_2023-10-15_2024-04-16_vol2 (1).json
# Read 11 rows from data/tweets_data_final/Konfederacja/Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json
# Read 750 rows from data/tweets_data_final/Konfederacja/WTumanowicz_2023-10-16_2024-10-15.json
# Saved Konfederacja combined data to data/tweets_data_combined/Konfederacja_combined.pkl
# Read 457 rows from data/tweets_data_final/NL/RobertBiedron_2023-10-16_2024-10-15.json
# Read 247 rows from data/tweets_data_final/NL/MoskwaWodnicka_2023-10-16_2024-10-15 (1).json
# Read 575 rows from data/tweets_data_final/NL/poselTTrela_2024-04-16_2024-10-15.json
# Read 178 rows from data/tweets_data_final/NL/KGawkowski_2023-10-16_2024-10-15.json
# Read 481 rows from data/tweets_data_final/NL/AnitaKDZG_2023-10-16_2024-10-15 (1).json
# Read 787 rows from data/tweets_data_final/NL/WandaNowicka_2023-10-16_2024-10-15 (1).json
# Read 142 rows from data/tweets_data_final/NL/wieczorekdarek_2023-10-16_2024-10-15 (1).json
# Read 537 rows from data/tweets_data_final/NL/PaulinaPW2024_2023-10-16_2024-10-15 (1).json
# Read 207 rows from data/tweets_data_final/NL/AndrzejSzejna_2023-10-16_2024-10-15 (1).json
# Read 907 rows from data/tweets_data_final/NL/poselTTrela_2023-10-16_2024-04-15.json
# Read 73 rows from data/tweets_data_final/NL/wlodekczarzasty_2023-10-16_2024-10-15.json
# Read 1128 rows from data/tweets_data_final/NL/MarcinKulasek_2023-10-16_2024-10-15.json
# Read 693 rows from data/tweets_data_final/NL/K_Smiszek_2023-10-16_2024-10-15 (1).json
# Read 0 rows from data/tweets_data_final/NL/DyduchMarek_2023-10-16_2024-10-15.json
# Read 103 rows from data/tweets_data_final/NL/JoankaSW_2023-10-16_2024-10-15 (1).json
# Saved NL combined data to data/tweets_data_combined/NL_combined.pkl
# Read 249 rows from data/tweets_data_final/PIS/mblaszczak_2023-10-16_2024-10-15 (1).json
# Read 647 rows from data/tweets_data_final/PIS/MorawieckiM_2023-10-16_2024-10-15.json
# Read 35 rows from data/tweets_data_final/PIS/Kowalczyk_H_2023-10-16_2024-10-15.json
# Read 77 rows from data/tweets_data_final/PIS/elzbietawitek_2023-10-16_2024-10-15.json
# Read 556 rows from data/tweets_data_final/PIS/BeataSzydlo_2023-10-16_2024-10-15.json
# Read 1025 rows from data/tweets_data_final/PIS/PatrykJaki_2023-10-16_2024-10-15.json
# Read 782 rows from data/tweets_data_final/PIS/mwojcik__2023-10-16_2024-10-15.json
# Read 189 rows from data/tweets_data_final/PIS/Kaminski_M__2023-10-16_2024-10-15.json
# Read 236 rows from data/tweets_data_final/PIS/Macierewicz_A_2023-10-16_2024-10-15.json
# Saved PIS combined data to data/tweets_data_combined/PIS_combined.pkl
# Read 814 rows from data/tweets_data_final/PO/trzaskowski__2023-10-16_2024-10-15 (1).json
# Read 165 rows from data/tweets_data_final/PO/EwaKopacz_2023-10-16_2024-10-15.json
# Read 173 rows from data/tweets_data_final/PO/Leszczyna_2024-04-01_2024-10-15.json
# Read 64 rows from data/tweets_data_final/PO/M_K_Blonska_2024-04-01_2024-10-15.json
# Read 49 rows from data/tweets_data_final/PO/bbudka_2024-04-01_2024-10-15.json
# Read 356 rows from data/tweets_data_final/PO/Konwinski_PO_2023-10-16_2024-10-15.json
# Read 456 rows from data/tweets_data_final/PO/OklaDrewnowicz_2023-10-16_2024-10-15.json
# Read 269 rows from data/tweets_data_final/PO/CTomczyk_2023-10-16_2024-10-15_GUWNOMAMYZNIMPROBLEM (1).json
# Read 118 rows from data/tweets_data_final/PO/Leszczyna_2023-10-16_2023-12-31.json
# Read 112 rows from data/tweets_data_final/PO/Leszczyna_2024-01-01_2024-03-31.json
# Read 45 rows from data/tweets_data_final/PO/bbudka_2023-10-16_2024-03-31.json
# Read 882 rows from data/tweets_data_final/PO/MKierwinski_2023-10-16_2024-10-15.json
# Read 409 rows from data/tweets_data_final/PO/DorotaNiedziela_2023-10-16_2024-10-15.json
# Read 62 rows from data/tweets_data_final/PO/M_K_Blonska_2023-10-16_2024-03-31.json
# Read 102 rows from data/tweets_data_final/PO/JanGrabiec_2023-10-16_2024-10-15.json
# Read 338 rows from data/tweets_data_final/PO/donaldtusk_2023-10-16_2024-10-15.json
# Saved PO combined data to data/tweets_data_combined/PO_combined.pkl
# Read 675 rows from data/tweets_data_final/PL2050/SlizPawel_2023-10-16_2024-10-15.json
# Read 226 rows from data/tweets_data_final/PL2050/Kpelczynska_2023-10-16_2024-10-15.json
# Read 73 rows from data/tweets_data_final/PL2050/LukaszOsmalak_2023-10-16_2024-10-15.json
# Read 41 rows from data/tweets_data_final/PL2050/AgaBaranowskaPL_2023-10-16_2024-10-15.json
# Read 389 rows from data/tweets_data_final/PL2050/hennigkloska_2023-10-16_2024-10-15 (1).json
# Read 175 rows from data/tweets_data_final/PL2050/ZalewskiPawel_2023-10-16_2024-10-15.json
# Read 319 rows from data/tweets_data_final/PL2050/ZywnoMaciej_2023-10-16_2024-10-15 (1).json
# Read 8 rows from data/tweets_data_final/PL2050/joannamucha_2023-10-16_2024-10-15 (1).json
# Read 167 rows from data/tweets_data_final/PL2050/szymon_holownia_2023-10-16_2024-10-15.json
# Read 29 rows from data/tweets_data_final/PL2050/aga_buczynska_2023-10-16_2024-10-15.json
# Saved PL2050 combined data to data/tweets_data_combined/PL2050_combined.pkl
# Read 115 rows from data/tweets_data_final/PSL/GrzybAndrzej_2023-10-16_2024-10-15.json
# Read 411 rows from data/tweets_data_final/PSL/PZgorzelskiP_2023-10-16_2024-10-15.json
# Read 409 rows from data/tweets_data_final/PSL/KosiniakKamysz_2023-10-16_2024-10-15.json
# Read 146 rows from data/tweets_data_final/PSL/Paslawska_2023-10-16_2024-10-15.json
# Read 19 rows from data/tweets_data_final/PSL/Hetman_K_2023-10-16_2024-10-15.json
# Read 192 rows from data/tweets_data_final/PSL/JarubasAdam_2023-10-16_2024-10-15.json
# Read 274 rows from data/tweets_data_final/PSL/DariuszKlimczak_2023-10-16_2024-10-15.json
# Read 107 rows from data/tweets_data_final/PSL/StefanKrajewski_2023-10-16_2024-10-15.json
# Saved PSL combined data to data/tweets_data_combined/PSL_combined.pkl
# Processing complete!

# %% [markdown]
# ### 3. Data cleaning

# %%
df_konf = pd.read_pickle(os.path.join(output_folder, 'Konfederacja_combined.pkl'))
df_NL = pd.read_pickle(os.path.join(output_folder, 'NL_combined.pkl'))
df_PIS = pd.read_pickle(os.path.join(output_folder, 'PIS_combined.pkl'))
df_PO = pd.read_pickle(os.path.join(output_folder, 'PO_combined.pkl'))
df_PL2050 = pd.read_pickle(os.path.join(output_folder, 'PL2050_combined.pkl'))
df_PSL = pd.read_pickle(os.path.join(output_folder, 'PSL_combined.pkl'))

# %%
df_konf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8177 entries, 0 to 8176
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          8177 non-null   object
#  1   reply_settings          8177 non-null   object
#  2   entities                7489 non-null   object
#  3   created_at              8177 non-null   datetime64[ns, UTC]
#  4   attachments             4073 non-null   object
#  5   edit_controls           8177 non-null   object
#  6   author_id               8177 non-null   int64
#  7   edit_history_tweet_ids  8177 non-null   object
#  8   lang                    8177 non-null   object
#  9   possibly_sensitive      8177 non-null   bool
#  10  id                      8177 non-null   int64
#  11  conversation_id         8177 non-null   int64
#  12  text                    8177 non-null   object
#  13  category                8177 non-null   object
#  14  context_annotations     986 non-null    object
#  15  in_reply_to_user_id     1949 non-null   float64
#  16  referenced_tweets       2848 non-null   object
#  17  username                8177 non-null   object
#  18  party                   8177 non-null   object
#  19  geo                     138 non-null    object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(3), object(14)
# memory usage: 1.2+ MB

# %%
# Merge all dataframes into one
df = pd.concat([df_konf, df_NL, df_PIS, df_PO, df_PL2050, df_PSL], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26677 entries, 0 to 26676
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          26677 non-null  object
#  1   reply_settings          26677 non-null  object
#  2   entities                23437 non-null  object
#  3   created_at              26677 non-null  datetime64[ns, UTC]
#  4   attachments             11931 non-null  object
#  5   edit_controls           26661 non-null  object
#  6   author_id               26677 non-null  float64
#  7   edit_history_tweet_ids  26661 non-null  object
#  8   lang                    26677 non-null  object
#  9   possibly_sensitive      26661 non-null  object
#  10  id                      26661 non-null  float64
#  11  conversation_id         26661 non-null  float64
#  12  text                    26677 non-null  object
#  13  category                26677 non-null  object
#  14  context_annotations     3335 non-null   object
#  15  in_reply_to_user_id     5743 non-null   float64
#  16  referenced_tweets       8896 non-null   object
#  17  username                26677 non-null  object
#  18  party                   26677 non-null  object
#  19  geo                     668 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 4.1+ MB

# %%
pd.options.display.float_format = '{:.0f}'.format
df['id'] = df['id'].fillna(0).astype('int64')
df['id']
# Out:
# 0        1846086999964283136
# 1        1845748090461966592
# 2        1845366606823657984
# 3        1845006197847360000
# 4        1844633149784891648
#                 ...
# 26672    1717638951333245440
# 26673    1717063007988052224
# 26674    1716417809469538560
# 26675    1714372612611060224
# 26676    1714372612611060224
# Name: id, Length: 26677, dtype: int64

# %%
df['id'].nunique()
# Out:
# 26548

# %% [markdown]
# We need to remove duplicate tweets because our custom downloading loop occasionally downloads the same tweet two times to ensure completeness.

# %%
# Remove duplicates from the dataframe based on specific columns
df.drop_duplicates(subset=['id'], inplace=True)

# %%
df.head()
# Out:
#                                       public_metrics reply_settings  \
# 0  {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1  {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2  {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3  {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4  {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
#
#                                             entities  \
# 0  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1  {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
#
#                  created_at  \
# 0 2024-10-15 07:13:34+00:00
# 1 2024-10-14 08:46:51+00:00
# 2 2024-10-13 07:30:58+00:00
# 3 2024-10-12 07:38:50+00:00
# 4 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#                     id     conversation_id  \
# 0  1846086999964283136 1846086999964283136
# 1  1845748090461966592 1845748090461966592
# 2  1845366606823657984 1845366606823657984
# 3  1845006197847360000 1845006197847360000
# 4  1844633149784891648 1844633149784891648
#
#                                                 text  category  \
# 0  ❌ Rząd polski zamierza budować w Polsce 49 Cen...  Original
# 1  ❌ Szambo wybija i robi się coraz ciekawiej. Na...  Original
# 2  ❌ NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SPOS...  Original
# 3  🆘  Firma farmaceutyczna GSK zapłaci ponad 2 ml...  Original
# 4  ❌ O CO TUTAJ CHODZI? W październiku 2024 r. sz...  Original
#
#                                  context_annotations  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   referenced_tweets                                    username         party  \
# 0               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 1               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 2               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 3               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 4               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
#
#    geo
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %% [markdown]
# We need to delete retweets because they are wrongly provided by the X API. We want to analyze only original tweets, replies, and quotes.

# %%
df = df[df['category'] != 'Retweet']

# %%
# Update the 'username' column to keep only the string until '_2'
df['username'] = df['username'].str.split('_2').str[0]

# %%
category_summary = df['category'].value_counts()
print(category_summary)
total_tweets = category_summary.sum()
print(f"Total tweets: {total_tweets}")
# Out:
# category
# Original    17595
# Reply        5641
# Quote        2826
# Name: count, dtype: int64
# Total tweets: 26062

# %%
# Ensure the created_at column is in datetime format
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.head()
# Out:
#                                       public_metrics reply_settings  \
# 0  {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1  {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2  {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3  {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4  {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
#
#                                             entities  \
# 0  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1  {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
#
#                  created_at  \
# 0 2024-10-15 07:13:34+00:00
# 1 2024-10-14 08:46:51+00:00
# 2 2024-10-13 07:30:58+00:00
# 3 2024-10-12 07:38:50+00:00
# 4 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#                     id     conversation_id  \
# 0  1846086999964283136 1846086999964283136
# 1  1845748090461966592 1845748090461966592
# 2  1845366606823657984 1845366606823657984
# 3  1845006197847360000 1845006197847360000
# 4  1844633149784891648 1844633149784891648
#
#                                                 text  category  \
# 0  ❌ Rząd polski zamierza budować w Polsce 49 Cen...  Original
# 1  ❌ Szambo wybija i robi się coraz ciekawiej. Na...  Original
# 2  ❌ NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SPOS...  Original
# 3  🆘  Firma farmaceutyczna GSK zapłaci ponad 2 ml...  Original
# 4  ❌ O CO TUTAJ CHODZI? W październiku 2024 r. sz...  Original
#
#                                  context_annotations  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   referenced_tweets         username         party  geo
# 0               NaN  placzekgrzegorz  Konfederacja  NaN
# 1               NaN  placzekgrzegorz  Konfederacja  NaN
# 2               NaN  placzekgrzegorz  Konfederacja  NaN
# 3               NaN  placzekgrzegorz  Konfederacja  NaN
# 4               NaN  placzekgrzegorz  Konfederacja  NaN

# %%
print(df.loc[1, 'text'])
# Out:
# ❌ Szambo wybija i robi się coraz ciekawiej. Na światło dzienne wychodzą bowiem coraz to nowe fakty. Otóż wytyczne funkcjonowania 49 Centrów Integracji Cudzoziemców (CIC) przewidują dla cudzoziemców w całej Polsce między innymi… zatrudnianie OSOBISTYCH ASYSTENTÓW w urzędach,… https://t.co/OZyTSwcMAb

# %%
def add_space_around_emojis(text):
    return ''.join(f' {char} ' if char in emoji.EMOJI_DATA or re.match(r'[\U0001F1E6-\U0001F1FF]', char) else char for char in text)

df['text'] = df['text'].apply(add_space_around_emojis)

def clean_text(text):
    mentions = re.findall(r'@\w+', text)
    text = re.sub(r'@\w+', '', text)
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)
    hashtags = re.findall(r'#\w+', text)
    text = re.sub(r'(?<!\s)([\U0001F600-\U0001F64F])', r' \1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F])(?!\s)', r'\1 ', text)
    return [text, mentions, links, hashtags]

df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)

# %%
df.head()
# Out:
#                                       public_metrics reply_settings  \
# 0  {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1  {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2  {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3  {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4  {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
#
#                                             entities  \
# 0  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1  {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
#
#                  created_at  \
# 0 2024-10-15 07:13:34+00:00
# 1 2024-10-14 08:46:51+00:00
# 2 2024-10-13 07:30:58+00:00
# 3 2024-10-12 07:38:50+00:00
# 4 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  ...  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False  ...
# 1  [1845747336862961872, 1845748090461966651]   pl              False  ...
# 2                       [1845366606823657982]   pl              False  ...
# 3                       [1845006197847359885]   pl              False  ...
# 4                       [1844633149784891665]   pl              False  ...
#
#                                  context_annotations  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   referenced_tweets         username         party  geo  \
# 0               NaN  placzekgrzegorz  Konfederacja  NaN
# 1               NaN  placzekgrzegorz  Konfederacja  NaN
# 2               NaN  placzekgrzegorz  Konfederacja  NaN
# 3               NaN  placzekgrzegorz  Konfederacja  NaN
# 4               NaN  placzekgrzegorz  Konfederacja  NaN
#
#                                           text_clean  \
# 0   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                 mentions  \
# 0                                     []
# 1                                     []
# 2                          [@donaldtusk]
# 3                                     []
# 4  [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
#
#                                                links          hashtags
# 0  [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                          [https://t.co/OZyTSwcMAb]                []
# 2                          [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                          [https://t.co/cwusG1221F]                []
# 4                          [https://t.co/RkylDcUHbo]                []
#
# [5 rows x 24 columns]

# %%
df.drop(columns=['entities'], inplace=True)

# %%
df['retweet_count'] = df['public_metrics'].apply(lambda x: x['retweet_count'])
df['reply_count'] = df['public_metrics'].apply(lambda x: x['reply_count'])
df['like_count'] = df['public_metrics'].apply(lambda x: x['like_count'])
df['quote_count'] = df['public_metrics'].apply(lambda x: x['quote_count'])
df['impression_count'] = df['public_metrics'].apply(lambda x: x['impression_count'])

df.drop(columns=['public_metrics'], inplace=True)

# %%
df
# Out:
#       reply_settings                created_at  \
# 0           everyone 2024-10-15 07:13:34+00:00
# 1           everyone 2024-10-14 08:46:51+00:00
# 2           everyone 2024-10-13 07:30:58+00:00
# 3           everyone 2024-10-12 07:38:50+00:00
# 4           everyone 2024-10-11 06:56:29+00:00
# ...              ...                       ...
# 26671       everyone 2023-10-27 04:07:40+00:00
# 26672       everyone 2023-10-26 20:26:52+00:00
# 26673       everyone 2023-10-25 06:18:17+00:00
# 26674       everyone 2023-10-23 11:34:29+00:00
# 26675       everyone 2023-10-17 20:07:37+00:00
#
#                                              attachments  \
# 0      {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 26671                                                NaN
# 26672          {'media_keys': ['3_1717638945809252352']}
# 26673                                                NaN
# 26674          {'media_keys': ['7_1716417715710156800']}
# 26675          {'media_keys': ['7_1714372479076954113']}
#
#                                            edit_controls           author_id  \
# 0      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# ...                                                  ...                 ...
# 26671  {'edits_remaining': 5, 'is_edit_eligible': Fal...          1201875318
# 26672  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
# 26673  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
# 26674  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
# 26675  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
#
#                            edit_history_tweet_ids lang possibly_sensitive  \
# 0      [1846086770229694583, 1846086999964283214]   pl              False
# 1      [1845747336862961872, 1845748090461966651]   pl              False
# 2                           [1845366606823657982]   pl              False
# 3                           [1845006197847359885]   pl              False
# 4                           [1844633149784891665]   pl              False
# ...                                           ...  ...                ...
# 26671                       [1717754912929435789]   pl                  0
# 26672                       [1717638951333245364]   pl                  0
# 26673                       [1717063007988052299]   pl                  0
# 26674                       [1716417809469538514]   pl                  0
# 26675                       [1714372612611060222]   pl                  0
#
#                         id     conversation_id  ...  \
# 0      1846086999964283136 1846086999964283136  ...
# 1      1845748090461966592 1845748090461966592  ...
# 2      1845366606823657984 1845366606823657984  ...
# 3      1845006197847360000 1845006197847360000  ...
# 4      1844633149784891648 1844633149784891648  ...
# ...                    ...                 ...  ...
# 26671  1717754912929435904 1717638951333245440  ...
# 26672  1717638951333245440 1717638951333245440  ...
# 26673  1717063007988052224 1717063007988052224  ...
# 26674  1716417809469538560 1716417809469538560  ...
# 26675  1714372612611060224 1714372612611060224  ...
#
#                                     geo  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 26671  {'place_id': '47c001064da7125c'}
# 26672                               NaN
# 26673  {'place_id': '47c001064da7125c'}
# 26674  {'place_id': '535f0c2de0121451'}
# 26675  {'place_id': '47c001064da7125c'}
#
#                                               text_clean  \
# 0       ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1       ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2       ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3       🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4       ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
# ...                                                  ...
# 26671   Gdyby coś się zmieniło, jestem do dyspozycji ...
# 26672  Zaświadczenie o wyborze na Posła na Sejm RP  🇵...
# 26673  Ceny paliw na stacjach Orlen rosną w szybkim t...
# 26674  Taki mandat to ja rozumiem 😃 \nDziękuję za każ...
# 26675  Wszystkim Wam serdecznie dziekuję. Za wsparcie...
#
#                                     mentions  \
# 0                                         []
# 1                                         []
# 2                              [@donaldtusk]
# 3                                         []
# 4      [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
# ...                                      ...
# 26671                     [@Speranza7Andrea]
# 26672                                     []
# 26673                                     []
# 26674                                     []
# 26675                                     []
#
#                                                    links          hashtags  \
# 0      [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                              [https://t.co/OZyTSwcMAb]                []
# 2                              [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                              [https://t.co/cwusG1221F]                []
# 4                              [https://t.co/RkylDcUHbo]                []
# ...                                                  ...               ...
# 26671                                                 []                []
# 26672                          [https://t.co/Dl8oj3iPCW]                []
# 26673                                                 []                []
# 26674                          [https://t.co/de5flsSkCd]                []
# 26675                          [https://t.co/bPgETFklrW]                []
#
#       retweet_count reply_count like_count quote_count impression_count
# 0               230          61        644           7            11648
# 1              1301         169       3845          57           146584
# 2               682         145       2061          28           100757
# 3               271          56        989           8            30769
# 4               214          56        678           9            17432
# ...             ...         ...        ...         ...              ...
# 26671             0           1          1           0               53
# 26672             9          13         91           0             3191
# 26673            17          11         39           2             1977
# 26674            38          14        177           6            28476
# 26675            10           6         48           0             6604
#
# [26062 rows x 27 columns]

# %%
df['id'] = df['id'].astype('int64')

# %%
df_clean_text = df[['id', 'text_clean']]

# %%
df_clean_text = df_clean_text[df_clean_text['text_clean'].notna() & df_clean_text['text_clean'].str.strip().ne('')]

# Reset index if needed
df_clean_text = df_clean_text.reset_index(drop=True)

# %%
df_clean_text.to_csv('data_for_translation.csv', index=False)

# %%
df_en_text = pd.read_csv('tweets_translation/text_clean_en1.csv')
df_en_text.head()
# Out:
#                     id                                         text_clean  \
# 0  1846086999964283136   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1  1845748090461966592   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2  1845366606823657984   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3  1845006197847360000   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4  1844633149784891648   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                        text_clean_en
# 0   ❌ The Polish government intends to build 49 F...
# 1   ❌ The cesspool is breaking out and it's getti...
# 2   ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3   🆘 The pharmaceutical company GSK will pay ove...
# 4   ❌ WHAT IS GOING ON HERE? In October 2024, her...

# %%
#df_en_text["id"] = df_en_text["id"].apply(lambda x: int(float(x.replace(',', ''))))

# %%
if 'text_clean_en' in df_en_text.columns:
    # Ensure 'id' is the same type in both DataFrames
    df['id'] = df['id'].astype(str)
    df_en_text['id'] = df_en_text['id'].astype(str)

    # Perform the merge
    df = df.merge(df_en_text[['id', 'text_clean_en']], on='id', how='left')

    display(df.head())
else:
    print("Column 'text_clean_en' does not exist in df_en_text")
# Out:
#   reply_settings                created_at  \
# 0       everyone 2024-10-15 07:13:34+00:00
# 1       everyone 2024-10-14 08:46:51+00:00
# 2       everyone 2024-10-13 07:30:58+00:00
# 3       everyone 2024-10-12 07:38:50+00:00
# 4       everyone 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#                     id     conversation_id  ...  \
# 0  1846086999964283136 1846086999964283136  ...
# 1  1845748090461966592 1845748090461966592  ...
# 2  1845366606823657984 1845366606823657984  ...
# 3  1845006197847360000 1845006197847360000  ...
# 4  1844633149784891648 1844633149784891648  ...
#
#                                           text_clean  \
# 0   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                 mentions  \
# 0                                     []
# 1                                     []
# 2                          [@donaldtusk]
# 3                                     []
# 4  [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
#
#                                                links          hashtags  \
# 0  [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                          [https://t.co/OZyTSwcMAb]                []
# 2                          [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                          [https://t.co/cwusG1221F]                []
# 4                          [https://t.co/RkylDcUHbo]                []
#
#   retweet_count reply_count like_count quote_count impression_count  \
# 0           230          61        644           7            11648
# 1          1301         169       3845          57           146584
# 2           682         145       2061          28           100757
# 3           271          56        989           8            30769
# 4           214          56        678           9            17432
#
#                                        text_clean_en
# 0   ❌ The Polish government intends to build 49 F...
# 1   ❌ The cesspool is breaking out and it's getti...
# 2   ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3   🆘 The pharmaceutical company GSK will pay ove...
# 4   ❌ WHAT IS GOING ON HERE? In October 2024, her...
#
# [5 rows x 28 columns]

# %%
# Replace '#VALUE!' with NaN in 'text_clean_en' column
#df['text_clean_en'] = df['text_clean_en'].replace('#VALUE!', pd.NA)

# %%
df['text_clean_en_demojized'] = df['text_clean_en'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)

df[['text_clean_en', 'text_clean_en_demojized']].head()
# Out:
#                                        text_clean_en  \
# 0   ❌ The Polish government intends to build 49 F...
# 1   ❌ The cesspool is breaking out and it's getti...
# 2   ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3   🆘 The pharmaceutical company GSK will pay ove...
# 4   ❌ WHAT IS GOING ON HERE? In October 2024, her...
#
#                              text_clean_en_demojized
# 0   :cross_mark: The Polish government intends to...
# 1   :cross_mark: The cesspool is breaking out and...
# 2   :cross_mark: I DON'T UNDERSTAND HOW YOU CAN H...
# 3   :SOS_button: The pharmaceutical company GSK w...
# 4   :cross_mark: WHAT IS GOING ON HERE? In Octobe...

# %%
df
# Out:
#       reply_settings                created_at  \
# 0           everyone 2024-10-15 07:13:34+00:00
# 1           everyone 2024-10-14 08:46:51+00:00
# 2           everyone 2024-10-13 07:30:58+00:00
# 3           everyone 2024-10-12 07:38:50+00:00
# 4           everyone 2024-10-11 06:56:29+00:00
# ...              ...                       ...
# 26057       everyone 2023-10-27 04:07:40+00:00
# 26058       everyone 2023-10-26 20:26:52+00:00
# 26059       everyone 2023-10-25 06:18:17+00:00
# 26060       everyone 2023-10-23 11:34:29+00:00
# 26061       everyone 2023-10-17 20:07:37+00:00
#
#                                              attachments  \
# 0      {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 26057                                                NaN
# 26058          {'media_keys': ['3_1717638945809252352']}
# 26059                                                NaN
# 26060          {'media_keys': ['7_1716417715710156800']}
# 26061          {'media_keys': ['7_1714372479076954113']}
#
#                                            edit_controls           author_id  \
# 0      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# ...                                                  ...                 ...
# 26057  {'edits_remaining': 5, 'is_edit_eligible': Fal...          1201875318
# 26058  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
# 26059  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
# 26060  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
# 26061  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1201875318
#
#                            edit_history_tweet_ids lang possibly_sensitive  \
# 0      [1846086770229694583, 1846086999964283214]   pl              False
# 1      [1845747336862961872, 1845748090461966651]   pl              False
# 2                           [1845366606823657982]   pl              False
# 3                           [1845006197847359885]   pl              False
# 4                           [1844633149784891665]   pl              False
# ...                                           ...  ...                ...
# 26057                       [1717754912929435789]   pl                  0
# 26058                       [1717638951333245364]   pl                  0
# 26059                       [1717063007988052299]   pl                  0
# 26060                       [1716417809469538514]   pl                  0
# 26061                       [1714372612611060222]   pl                  0
#
#                         id     conversation_id  ...  \
# 0      1846086999964283136 1846086999964283136  ...
# 1      1845748090461966592 1845748090461966592  ...
# 2      1845366606823657984 1845366606823657984  ...
# 3      1845006197847360000 1845006197847360000  ...
# 4      1844633149784891648 1844633149784891648  ...
# ...                    ...                 ...  ...
# 26057  1717754912929435904 1717638951333245440  ...
# 26058  1717638951333245440 1717638951333245440  ...
# 26059  1717063007988052224 1717063007988052224  ...
# 26060  1716417809469538560 1716417809469538560  ...
# 26061  1714372612611060224 1714372612611060224  ...
#
#                                     mentions  \
# 0                                         []
# 1                                         []
# 2                              [@donaldtusk]
# 3                                         []
# 4      [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
# ...                                      ...
# 26057                     [@Speranza7Andrea]
# 26058                                     []
# 26059                                     []
# 26060                                     []
# 26061                                     []
#
#                                                    links          hashtags  \
# 0      [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                              [https://t.co/OZyTSwcMAb]                []
# 2                              [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                              [https://t.co/cwusG1221F]                []
# 4                              [https://t.co/RkylDcUHbo]                []
# ...                                                  ...               ...
# 26057                                                 []                []
# 26058                          [https://t.co/Dl8oj3iPCW]                []
# 26059                                                 []                []
# 26060                          [https://t.co/de5flsSkCd]                []
# 26061                          [https://t.co/bPgETFklrW]                []
#
#        retweet_count reply_count like_count quote_count impression_count  \
# 0                230          61        644           7            11648
# 1               1301         169       3845          57           146584
# 2                682         145       2061          28           100757
# 3                271          56        989           8            30769
# 4                214          56        678           9            17432
# ...              ...         ...        ...         ...              ...
# 26057              0           1          1           0               53
# 26058              9          13         91           0             3191
# 26059             17          11         39           2             1977
# 26060             38          14        177           6            28476
# 26061             10           6         48           0             6604
#
#                                            text_clean_en  \
# 0       ❌ The Polish government intends to build 49 F...
# 1       ❌ The cesspool is breaking out and it's getti...
# 2       ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3       🆘 The pharmaceutical company GSK will pay ove...
# 4       ❌ WHAT IS GOING ON HERE? In October 2024, her...
# ...                                                  ...
# 26057    If anything changes, I am at your disposal 😄 👍
# 26058  I also have a certificate of election as a Mem...
# 26059  Fuel prices at Orlen stations are rising rapid...
# 26060  I understand this mandate 😃 \nThank you for ev...
# 26061  Thank you all very much. For your support, for...
#
#                                  text_clean_en_demojized
# 0       :cross_mark: The Polish government intends to...
# 1       :cross_mark: The cesspool is breaking out and...
# 2       :cross_mark: I DON'T UNDERSTAND HOW YOU CAN H...
# 3       :SOS_button: The pharmaceutical company GSK w...
# 4       :cross_mark: WHAT IS GOING ON HERE? In Octobe...
# ...                                                  ...
# 26057   If anything changes, I am at your disposal :g...
# 26058  I also have a certificate of election as a Mem...
# 26059  Fuel prices at Orlen stations are rising rapid...
# 26060  I understand this mandate :grinning_face_with_...
# 26061  Thank you all very much. For your support, for...
#
# [26062 rows x 29 columns]

# %%
df['possibly_sensitive'] = df['possibly_sensitive'].astype(bool)

# %%
unique_usernames = df['username'].unique()
print(unique_usernames)
# Out:
# ['placzekgrzegorz' 'MichalWawer' 'KonradBerkowicz' 'Wlodek_Skalik'
#  'SlawomirMentzen' 'GrzegorzBraun_' 'TudujKrzysztof' 'bartlomiejpejo'
#  'MarSypniewski' 'Iwaszkiewicz_RJ' 'WTumanowicz' 'RobertBiedron'
#  'MoskwaWodnicka' 'poselTTrela' 'KGawkowski' 'AnitaKDZG' 'WandaNowicka'
#  'wieczorekdarek' 'PaulinaPW2024' 'AndrzejSzejna' 'wlodekczarzasty'
#  'MarcinKulasek' 'K_Smiszek' 'JoankaSW' 'mblaszczak' 'MorawieckiM'
#  'Kowalczyk_H' 'elzbietawitek' 'BeataSzydlo' 'PatrykJaki' 'mwojcik_'
#  'Kaminski_M_' 'Macierewicz_A' 'trzaskowski_' 'EwaKopacz' 'Leszczyna'
#  'M_K_Blonska' 'bbudka' 'Konwinski_PO' 'OklaDrewnowicz' 'CTomczyk'
#  'MKierwinski' 'DorotaNiedziela' 'JanGrabiec' 'donaldtusk' 'SlizPawel'
#  'Kpelczynska' 'LukaszOsmalak' 'AgaBaranowskaPL' 'hennigkloska'
#  'ZalewskiPawel' 'ZywnoMaciej' 'joannamucha' 'szymon_holownia'
#  'aga_buczynska' 'GrzybAndrzej' 'PZgorzelskiP' 'KosiniakKamysz'
#  'Paslawska' 'Hetman_K' 'JarubasAdam' 'DariuszKlimczak' 'StefanKrajewski']

# %%
username_to_realname = {
    'bartlomiejpejo': 'Bartłomiej Pejo',
    'MichalWawer': 'Michał Wawer',
    'SlawomirMentzen': 'Sławomir Mentzen',
    'GrzegorzBraun_': 'Grzegorz Braun',
    'placzekgrzegorz': 'Grzegorz Placzek',
    'Wlodek_Skalik': 'Włodzimierz Skalik',  
    'KonradBerkowicz': 'Konrad Berkowicz',
    'RobertBiedron': 'Robert Biedroń',
    'PatrykJaki': 'Patryk Jaki',
    'Kpelczynska': 'Katarzyna Pełczyńska',
    'OklaDrewnowicz': 'Agnieszka Okła-Drewnowicz',
    'KosiniakKamysz': 'Władysław Kosiniak-Kamysz',
    'mwojcik_': 'Michał Wójcik',
    'MorawieckiM': 'Mateusz Morawiecki',
    'BeataSzydlo': 'Beata Szydło',
    'WTumanowicz': 'Witold Tumanowicz',
    'KGawkowski': 'Krzysztof Gawkowski',
    'wlodekczarzasty': 'Włodzimierz Czarzasty',
    'Kaminski_M_': 'Mariusz Kamiński',
    'Macierewicz_A': 'Antoni Macierewicz',
    'elzbietawitek': 'Elżbieta Witek',
    'aga_buczynska': 'Agnieszka Buczyńska',
    'szymon_holownia': 'Szymon Hołownia',
    'DorotaNiedziela': 'Dorota Niedziela',
    'EwaKopacz': 'Ewa Kopacz',
    'Leszczyna': 'Izabela Leszczyna',
    'M_K_Blonska': 'Małgorzata Kidawa-Błońska',
    'bbudka': 'Borys Budka',
    'donaldtusk': 'Donald Tusk',
    'DariuszKlimczak': 'Dariusz Klimczak',
    'GrzybAndrzej': 'Andrzej Grzyb',
    'Hetman_K': 'Krzysztof Hetman',
    'JarubasAdam': 'Adam Jarubas',
    'Paslawska': 'Urszula Pasławska',
    'TudujKrzysztof': 'Krzysztof Tuduj',
    'ZalewskiPawel': 'Paweł Zalewski',
    'Iwaszkiewicz_RJ': 'Ryszard Iwaszkiewicz',
    'MarSypniewski': 'Marcin Sypniewski',
    'PaulinaPW2024': 'Paulina Piechna-Więckiewicz',
    'AndrzejSzejna': 'Andrzej Szejna',
    'MarcinKulasek': 'Marcin Kulasek',
    'K_Smiszek': 'Krzysztof Śmiszek',
    'JoankaSW': 'Joanna Scheuring-Wielgus',
    'mblaszczak': 'Mariusz Błaszczak',
    'Kowalczyk_H': 'Henryk Kowalczyk',
    'trzaskowski_': 'Rafał Trzaskowski',
    'Konwinski_PO': 'Zbigniew Konwiński',
    'CTomczyk': 'Cezary Tomczyk',
    'MKierwinski': 'Marcin Kierwiński',
    'JanGrabiec': 'Jan Grabiec',
    'SlizPawel': 'Paweł Śliz',
    'LukaszOsmalak': 'Łukasz Osmalak',
    'AgaBaranowskaPL': 'Agnieszka Baranowska',
    'hennigkloska': 'Paulina Hennig-Kloska',
    'ZywnoMaciej': 'Maciej Żywno',
    'joannamucha': 'Joanna Mucha',
    'PZgorzelskiP': 'Piotr Zgorzelski',
    'StefanKrajewski': 'Stefan Krajewski',
    'wieczorekdarek': 'Dariusz Wieczorek',
    'WandaNowicka': 'Wanda Nowicka',
    'AnitaKDZG': 'Anita Kucharska-Dziedzic',
    'poselTTrela': 'Tomasz Trela',
    'MoskwaWodnicka': 'Hanna Zdanowska'
}

# Add the 'name' column to the DataFrame
df['name'] = df['username'].map(username_to_realname)

# %%
# Delete next line sign from the 'text_clean_en' column
df['text_clean_en'] = df['text_clean_en'].str.replace('\n', ' ')

# %%
# Save the DataFrame to a Parquet file
df.to_parquet('cleaned_data/df_combined.parquet', index=False)

# %% [markdown]
# # Data cleaning

# %% [markdown]
# In this file, we cleaned the downloaded data:
# The main steps include:
# 1. Adding party affiliation to tweet rows
# 2. Deleting links and mentions from the tweets text and saving them to separate columns
# 3. Expanding the column of public metrics
# 4. Encoding emojis in a unified format
# 5. Translating tweets using Google Translate in Google Sheets
# 6. Saving all downloaded tweets to one file

# %% [markdown]
# ### 1.  Used libraries

# %%
import os
import pandas as pd
import re
import emoji

# %% [markdown]
# ### 2. Reading JSON files and transforming them into party-specific pickle files

# %%
base_input_path = 'data/tweets_data_final'
subfolders = ['Konfederacja', 'NL', 'PIS', 'PO', 'PL2050', 'PSL']
output_folder = 'data/tweets_data_combined'

os.makedirs(output_folder, exist_ok=True)

for subfolder in subfolders:
    folder_path = os.path.join(base_input_path, subfolder)
    dataframes = []
    
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            politician = filename.split("_tweets.json")[0]
            try:
                df = pd.read_json(file_path)  
                df["username"] = politician  
                df["party"] = subfolder
                print(f"Read {len(df)} rows from {file_path}")  
                dataframes.append(df)
            except ValueError as e:
                print(f"Error reading {file_path}: {e}")
    
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        
        output_file_path = os.path.join(output_folder, f'{subfolder}_combined.pkl')
        combined_df.to_pickle(output_file_path) 
        
        print(f"Saved {subfolder} combined data to {output_file_path}")

print("Processing complete!")
# Out:
# Read 964 rows from data/tweets_data_final\Konfederacja\bartlomiejpejo_2023-10-16_2024-10-15.json
# Read 721 rows from data/tweets_data_final\Konfederacja\SlawomirMentzen_2023-10-16_2024-10-15.json
# Read 175 rows from data/tweets_data_final\Konfederacja\TudujKrzysztof_2023-10-16_2024-10-15.json
# Read 950 rows from data/tweets_data_final\Konfederacja\Wlodek_Skalik_2023-10-16_2024-10-15.json
# Read 750 rows from data/tweets_data_final\Konfederacja\WTumanowicz_2023-10-16_2024-10-15.json
# Saved Konfederacja combined data to data/tweets_data_combined\Konfederacja_combined.pkl
# Read 0 rows from data/tweets_data_final\NL\DyduchMarek_2023-10-16_2024-10-15.json
# Read 178 rows from data/tweets_data_final\NL\KGawkowski_2023-10-16_2024-10-15.json
# Read 457 rows from data/tweets_data_final\NL\RobertBiedron_2023-10-16_2024-10-15.json
# Read 73 rows from data/tweets_data_final\NL\wlodekczarzasty_2023-10-16_2024-10-15.json
# Saved NL combined data to data/tweets_data_combined\NL_combined.pkl
# Read 556 rows from data/tweets_data_final\PIS\BeataSzydlo_2023-10-16_2024-10-15.json
# Read 77 rows from data/tweets_data_final\PIS\elzbietawitek_2023-10-16_2024-10-15.json
# Read 189 rows from data/tweets_data_final\PIS\Kaminski_M__2023-10-16_2024-10-15.json
# Read 236 rows from data/tweets_data_final\PIS\Macierewicz_A_2023-10-16_2024-10-15.json
# Read 647 rows from data/tweets_data_final\PIS\MorawieckiM_2023-10-16_2024-10-15.json
# Read 782 rows from data/tweets_data_final\PIS\mwojcik__2023-10-16_2024-10-15.json
# Read 1025 rows from data/tweets_data_final\PIS\PatrykJaki_2023-10-16_2024-10-15.json
# Saved PIS combined data to data/tweets_data_combined\PIS_combined.pkl
# Read 45 rows from data/tweets_data_final\PO\bbudka_2023-10-16_2024-03-31.json
# Read 49 rows from data/tweets_data_final\PO\bbudka_2024-04-01_2024-10-15.json
# Read 338 rows from data/tweets_data_final\PO\donaldtusk_2023-10-16_2024-10-15.json
# Read 409 rows from data/tweets_data_final\PO\DorotaNiedziela_2023-10-16_2024-10-15.json
# Read 165 rows from data/tweets_data_final\PO\EwaKopacz_2023-10-16_2024-10-15.json
# Read 118 rows from data/tweets_data_final\PO\Leszczyna_2023-10-16_2023-12-31.json
# Read 112 rows from data/tweets_data_final\PO\Leszczyna_2024-01-01_2024-03-31.json
# Read 173 rows from data/tweets_data_final\PO\Leszczyna_2024-04-01_2024-10-15.json
# Read 62 rows from data/tweets_data_final\PO\M_K_Blonska_2023-10-16_2024-03-31.json
# Read 64 rows from data/tweets_data_final\PO\M_K_Blonska_2024-04-01_2024-10-15.json
# Read 456 rows from data/tweets_data_final\PO\OklaDrewnowicz_2023-10-16_2024-10-15.json
# Saved PO combined data to data/tweets_data_combined\PO_combined.pkl
# Read 29 rows from data/tweets_data_final\PL2050\aga_buczynska_2023-10-16_2024-10-15.json
# Read 226 rows from data/tweets_data_final\PL2050\Kpelczynska_2023-10-16_2024-10-15.json
# Read 167 rows from data/tweets_data_final\PL2050\szymon_holownia_2023-10-16_2024-10-15.json
# Read 175 rows from data/tweets_data_final\PL2050\ZalewskiPawel_2023-10-16_2024-10-15.json
# Saved PL2050 combined data to data/tweets_data_combined\PL2050_combined.pkl
# Read 274 rows from data/tweets_data_final\PSL\DariuszKlimczak_2023-10-16_2024-10-15.json
# Read 115 rows from data/tweets_data_final\PSL\GrzybAndrzej_2023-10-16_2024-10-15.json
# Read 19 rows from data/tweets_data_final\PSL\Hetman_K_2023-10-16_2024-10-15.json
# Read 192 rows from data/tweets_data_final\PSL\JarubasAdam_2023-10-16_2024-10-15.json
# Read 409 rows from data/tweets_data_final\PSL\KosiniakKamysz_2023-10-16_2024-10-15.json
# Read 146 rows from data/tweets_data_final\PSL\Paslawska_2023-10-16_2024-10-15.json
# Saved PSL combined data to data/tweets_data_combined\PSL_combined.pkl
# Processing complete!

# %%
df_konf = pd.read_pickle(os.path.join(output_folder, 'Konfederacja_combined.pkl'))
df_NL = pd.read_pickle(os.path.join(output_folder, 'NL_combined.pkl'))
df_PIS = pd.read_pickle(os.path.join(output_folder, 'PIS_combined.pkl'))
df_PO = pd.read_pickle(os.path.join(output_folder, 'PO_combined.pkl'))
df_PL2050 = pd.read_pickle(os.path.join(output_folder, 'PL2050_combined.pkl'))
df_PSL = pd.read_pickle(os.path.join(output_folder, 'PSL_combined.pkl'))

# %%
df_konf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3560 entries, 0 to 3559
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          3560 non-null   object
#  1   in_reply_to_user_id     726 non-null    float64
#  2   reply_settings          3560 non-null   object
#  3   author_id               3560 non-null   int64
#  4   context_annotations     365 non-null    object
#  5   id                      3560 non-null   int64
#  6   text                    3560 non-null   object
#  7   edit_controls           3560 non-null   object
#  8   referenced_tweets       1055 non-null   object
#  9   created_at              3560 non-null   datetime64[ns, UTC]
#  10  edit_history_tweet_ids  3560 non-null   object
#  11  lang                    3560 non-null   object
#  12  conversation_id         3560 non-null   int64
#  13  entities                3281 non-null   object
#  14  possibly_sensitive      3560 non-null   bool
#  15  category                3560 non-null   object
#  16  attachments             2091 non-null   object
#  17  geo                     137 non-null    object
#  18  username                3560 non-null   object
#  19  party                   3560 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(3), object(14)
# memory usage: 532.0+ KB

# %%
# Merge all dataframes into one
df = pd.concat([df_konf, df_NL, df_PIS, df_PO, df_PL2050, df_PSL], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11523 entries, 0 to 11522
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          11523 non-null  object
#  1   in_reply_to_user_id     1888 non-null   float64
#  2   reply_settings          11523 non-null  object
#  3   author_id               11523 non-null  float64
#  4   context_annotations     1636 non-null   object
#  5   id                      11507 non-null  float64
#  6   text                    11523 non-null  object
#  7   edit_controls           11507 non-null  object
#  8   referenced_tweets       3210 non-null   object
#  9   created_at              11523 non-null  datetime64[ns, UTC]
#  10  edit_history_tweet_ids  11507 non-null  object
#  11  lang                    11523 non-null  object
#  12  conversation_id         11507 non-null  float64
#  13  entities                9861 non-null   object
#  14  possibly_sensitive      11507 non-null  object
#  15  category                11523 non-null  object
#  16  attachments             5551 non-null   object
#  17  geo                     335 non-null    object
#  18  username                11523 non-null  object
#  19  party                   11523 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 1.8+ MB

# %%
pd.options.display.float_format = '{:.0f}'.format
df['id'] = df['id'].fillna(0).astype('int64')
df['id']
# Out:
# 0        1846277256509116672
# 1        1846222583898784000
# 2        1846161400328028160
# 3        1846091824101769472
# 4        1846075343188144128
#                 ...
# 11518    1714531739610075392
# 11519    1714523500176637952
# 11520    1714186262041510400
# 11521    1713833158838276096
# 11522    1713833158838276096
# Name: id, Length: 11523, dtype: int64

# %%
df['id'].nunique()
# Out:
# 11461

# %% [markdown]
# We need to remove duplicate tweets because our custom downloading loop occasionally downloads the same tweet two times to ensure completeness.

# %%
# Remove duplicates from the dataframe based on specific columns
df.drop_duplicates(subset=['id'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11461 entries, 0 to 11521
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          11461 non-null  object
#  1   in_reply_to_user_id     1878 non-null   float64
#  2   reply_settings          11461 non-null  object
#  3   author_id               11461 non-null  float64
#  4   context_annotations     1630 non-null   object
#  5   id                      11461 non-null  int64
#  6   text                    11461 non-null  object
#  7   edit_controls           11460 non-null  object
#  8   referenced_tweets       3195 non-null   object
#  9   created_at              11461 non-null  datetime64[ns, UTC]
#  10  edit_history_tweet_ids  11460 non-null  object
#  11  lang                    11461 non-null  object
#  12  conversation_id         11460 non-null  float64
#  13  entities                9821 non-null   object
#  14  possibly_sensitive      11460 non-null  object
#  15  category                11461 non-null  object
#  16  attachments             5533 non-null   object
#  17  geo                     332 non-null    object
#  18  username                11461 non-null  object
#  19  party                   11461 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(3), int64(1), object(15)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#                                       public_metrics  in_reply_to_user_id  \
# 0  {'retweet_count': 3, 'reply_count': 1, 'like_c...            375146901
# 1  {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2  {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3  {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4  {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
#
#   reply_settings  author_id  \
# 0       everyone 1182211615
# 1       everyone 1182211615
# 2       everyone 1182211615
# 3       everyone 1182211615
# 4       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  ❌Mamy rok po wyborach, a Polska pogrąża się w ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11 🇵🇱 https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids lang     conversation_id  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]   pl 1846091776269963776
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]   pl 1846222583898784000
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]   pl 1846161400328028160
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]   pl 1846091824101769472
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  qme 1846075343188144128
#
#                                             entities possibly_sensitive  \
# 0  {'mentions': [{'start': 0, 'end': 11, 'usernam...              False
# 1  {'urls': [{'start': 100, 'end': 123, 'url': 'h...              False
# 2  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 4  {'hashtags': [{'start': 0, 'end': 6, 'tag': 'I...              False
#
#    category                                 attachments  geo  \
# 0     Reply                                         NaN  NaN
# 1  Original  {'media_keys': ['13_1846222491456282626']}  NaN
# 2  Original   {'media_keys': ['3_1846148786910810112']}  NaN
# 3  Original   {'media_keys': ['3_1846091818959597568']}  NaN
# 4  Original  {'media_keys': ['13_1846075276687478784']}  NaN
#
#                                     username         party
# 0  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 2  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 3  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 4  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja

# %%
# Update the 'username' column to keep only the string until '_2'
df['username'] = df['username'].str.split('_2').str[0]

# %%
category_summary = df['category'].value_counts()
print(category_summary)
total_tweets = category_summary.sum()
print(f"Total tweets: {total_tweets}")
# Out:
# category
# Original    8235
# Reply       1852
# Quote       1370
# Retweet        4
# Name: count, dtype: int64
# Total tweets: 11461

# %%
# Ensure the created_at column is in datetime format
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.head()
# Out:
#                                       public_metrics  in_reply_to_user_id  \
# 0  {'retweet_count': 3, 'reply_count': 1, 'like_c...            375146901
# 1  {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2  {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3  {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4  {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
#
#   reply_settings  author_id  \
# 0       everyone 1182211615
# 1       everyone 1182211615
# 2       everyone 1182211615
# 3       everyone 1182211615
# 4       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  ❌Mamy rok po wyborach, a Polska pogrąża się w ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11 🇵🇱 https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids lang     conversation_id  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]   pl 1846091776269963776
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]   pl 1846222583898784000
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]   pl 1846161400328028160
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]   pl 1846091824101769472
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  qme 1846075343188144128
#
#                                             entities possibly_sensitive  \
# 0  {'mentions': [{'start': 0, 'end': 11, 'usernam...              False
# 1  {'urls': [{'start': 100, 'end': 123, 'url': 'h...              False
# 2  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 4  {'hashtags': [{'start': 0, 'end': 6, 'tag': 'I...              False
#
#    category                                 attachments  geo        username  \
# 0     Reply                                         NaN  NaN  bartlomiejpejo
# 1  Original  {'media_keys': ['13_1846222491456282626']}  NaN  bartlomiejpejo
# 2  Original   {'media_keys': ['3_1846148786910810112']}  NaN  bartlomiejpejo
# 3  Original   {'media_keys': ['3_1846091818959597568']}  NaN  bartlomiejpejo
# 4  Original  {'media_keys': ['13_1846075276687478784']}  NaN  bartlomiejpejo
#
#           party
# 0  Konfederacja
# 1  Konfederacja
# 2  Konfederacja
# 3  Konfederacja
# 4  Konfederacja

# %%
print(df.loc[1, 'text'])
# Out:
# Rok po wyborach trzeba powiedzieć jedno - nie na takie państwo Donald Tusk umawiał się z wyborcami! https://t.co/4Jh5Ni6sgr

# %%
def add_space_around_emojis(text):
    return ''.join(f' {char} ' if char in emoji.EMOJI_DATA or re.match(r'[\U0001F1E6-\U0001F1FF]', char) else char for char in text)

df['text'] = df['text'].apply(add_space_around_emojis)

def clean_text(text):
    # Remove mentions and links
    mentions = re.findall(r'@\w+', text)
    text = re.sub(r'@\w+', '', text)
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)
    hashtags = re.findall(r'#\w+', text)
    # Ensure there is a space before and after each emoji
    text = re.sub(r'(?<!\s)([\U0001F600-\U0001F64F])', r' \1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F])(?!\s)', r'\1 ', text)
    return [text, mentions, links, hashtags]

df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)

# %%
df.head()
# Out:
#                                       public_metrics  in_reply_to_user_id  \
# 0  {'retweet_count': 3, 'reply_count': 1, 'like_c...            375146901
# 1  {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2  {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3  {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4  {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
#
#   reply_settings  author_id  \
# 0       everyone 1182211615
# 1       everyone 1182211615
# 2       everyone 1182211615
# 3       everyone 1182211615
# 4       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4              #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at  ... possibly_sensitive  category  \
# 0 2024-10-15 19:49:34+00:00  ...              False     Reply
# 1 2024-10-15 16:12:19+00:00  ...              False  Original
# 2 2024-10-15 12:09:12+00:00  ...              False  Original
# 3 2024-10-15 07:32:44+00:00  ...              False  Original
# 4 2024-10-15 06:27:14+00:00  ...              False  Original
#
#                                   attachments  geo        username  \
# 0                                         NaN  NaN  bartlomiejpejo
# 1  {'media_keys': ['13_1846222491456282626']}  NaN  bartlomiejpejo
# 2   {'media_keys': ['3_1846148786910810112']}  NaN  bartlomiejpejo
# 3   {'media_keys': ['3_1846091818959597568']}  NaN  bartlomiejpejo
# 4  {'media_keys': ['13_1846075276687478784']}  NaN  bartlomiejpejo
#
#           party                                         text_clean  \
# 0  Konfederacja   Niezrealizowanie większości ze "100 konkretów...
# 1  Konfederacja  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  Konfederacja   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Konfederacja  Mija rok od wyborów parlamentarnych. W kampani...
# 4  Konfederacja                                     #Idę11  🇵  🇱
#
#         mentions                                              links  hashtags
# 0  [@donaldtusk]                                                 []        []
# 1             []                          [https://t.co/4Jh5Ni6sgr]        []
# 2             []  [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...        []
# 3             []  [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...        []
# 4             []                          [https://t.co/KiCe5ATOpX]  [#Idę11]
#
# [5 rows x 24 columns]

# %%
df.drop(columns=['entities'], inplace=True)

# %%
# Extract public metrics into separate columns
df['retweet_count'] = df['public_metrics'].apply(lambda x: x['retweet_count'])
df['reply_count'] = df['public_metrics'].apply(lambda x: x['reply_count'])
df['like_count'] = df['public_metrics'].apply(lambda x: x['like_count'])
df['quote_count'] = df['public_metrics'].apply(lambda x: x['quote_count'])
df['impression_count'] = df['public_metrics'].apply(lambda x: x['impression_count'])

# Delete the 'public_metrics' column
df.drop(columns=['public_metrics'], inplace=True)

# %%
df
# Out:
#        in_reply_to_user_id reply_settings  author_id  \
# 0                375146901       everyone 1182211615
# 1                      NaN       everyone 1182211615
# 2                      NaN       everyone 1182211615
# 3                      NaN       everyone 1182211615
# 4                      NaN       everyone 1182211615
# ...                    ...            ...        ...
# 11517  1557599378285666304       everyone  163197547
# 11518                  NaN       everyone  163197547
# 11519                  NaN       everyone  163197547
# 11520                  NaN       everyone  163197547
# 11521                  NaN       everyone  163197547
#
#                                      context_annotations                   id  \
# 0      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                    NaN  1846161400328028160
# 3                                                    NaN  1846091824101769472
# 4                                                    NaN  1846075343188144128
# ...                                                  ...                  ...
# 11517                                                NaN  1714536050096296192
# 11518                                                NaN  1714531739610075392
# 11519  [{'domain': {'id': '47', 'name': 'Brand', 'des...  1714523500176637952
# 11520                                                NaN  1714186262041510400
# 11521                                                NaN  1713833158838276096
#
#                                                     text  \
# 0      @donaldtusk Niezrealizowanie większości ze "10...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                                                  ...
# 11517  @Marek83406343 @tvn24rozmowa @KonradPiasecki @...
# 11518  Będę namawiała kolegów z opozycji do skorzysta...
# 11519  Budżet państwa musi być uchwalony do końca sty...
# 11520  Dziękuję z całego serca &lt;3 #DobraGospodyni ...
# 11521  #TrzeciaDroga na trzecim miejscu z 17 proc. gł...
#
#                                            edit_controls  \
# 0      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 11517  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 11518  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11519  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11520  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11521  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 0      [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11517  [{'type': 'replied_to', 'id': '171452430045820...
# 11518                                                NaN
# 11519                                                NaN
# 11520                                                NaN
# 11521                                                NaN
#
#                      created_at edit_history_tweet_ids  ...         party  \
# 0     2024-10-15 19:49:34+00:00  [1846277256509116623]  ...  Konfederacja
# 1     2024-10-15 16:12:19+00:00  [1846222583898784025]  ...  Konfederacja
# 2     2024-10-15 12:09:12+00:00  [1846161400328028272]  ...  Konfederacja
# 3     2024-10-15 07:32:44+00:00  [1846091824101769490]  ...  Konfederacja
# 4     2024-10-15 06:27:14+00:00  [1846075343188144153]  ...  Konfederacja
# ...                         ...                    ...  ...           ...
# 11517 2023-10-18 06:57:03+00:00  [1714536050096296256]  ...           PSL
# 11518 2023-10-18 06:39:55+00:00  [1714531739610075435]  ...           PSL
# 11519 2023-10-18 06:07:11+00:00  [1714523500176638070]  ...           PSL
# 11520 2023-10-17 07:47:07+00:00  [1714186262041510351]  ...           PSL
# 11521 2023-10-16 08:24:01+00:00  [1713833158838276198]  ...           PSL
#
#                                               text_clean  \
# 0       Niezrealizowanie większości ze "100 konkretów...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                                         #Idę11  🇵  🇱
# ...                                                  ...
# 11517      W  są ludzie o różnych o światopoglądach i...
# 11518  Będę namawiała kolegów z opozycji do skorzysta...
# 11519  Budżet państwa musi być uchwalony do końca sty...
# 11520    Dziękuję z całego serca &lt;3 #DobraGospodyni
# 11521  #TrzeciaDroga na trzecim miejscu z 17 proc. gł...
#
#                                                 mentions  \
# 0                                          [@donaldtusk]
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 11517  [@Marek83406343, @tvn24rozmowa, @KonradPiaseck...
# 11518              [@Paslawska, @tvn24rozmowa, @nowePSL]
# 11519                  [@paslawska, @tvn24rozmowa, @now]
# 11520                                         [@nowePSL]
# 11521              [@Paslawska, @RadioOlsztyn, @nowePSL]
#
#                                                    links           hashtags  \
# 0                                                     []                 []
# 1                              [https://t.co/4Jh5Ni6sgr]                 []
# 2      [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...                 []
# 3      [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...                 []
# 4                              [https://t.co/KiCe5ATOpX]           [#Idę11]
# ...                                                  ...                ...
# 11517                                                 []                 []
# 11518                                                 []             [#PiS]
# 11519                          [https://t.co/BzsRxbPYv4]                 []
# 11520                          [https://t.co/cpxQaIsGty]  [#DobraGospodyni]
# 11521                          [https://t.co/ubTk0gaI8c]    [#TrzeciaDroga]
#
#       retweet_count reply_count like_count quote_count impression_count
# 0                 3           1         33           0             1555
# 1                 9           2         72           0             3031
# 2                 4           3         33           2             8636
# 3                 6           2         38           0             2441
# 4                45          18        616           2             8634
# ...             ...         ...        ...         ...              ...
# 11517             0           0          1           0               22
# 11518             6           1         33           0              806
# 11519             6           3         16           0              660
# 11520            15          13        122           0             4535
# 11521            12           9         52           1             4434
#
# [11461 rows x 27 columns]

# %%
# Change the type of 'id' column to float
df['id'] = df['id'].astype('int64')

# %%
# Create a new dataframe with 'id' and 'text_clean' columns
df_clean_text = df[['id', 'text_clean']]

# Export the dataframe to a CSV file
df_clean_text.to_csv('data_for_translation.csv', index=False)

# %%
# Read the clean_text_data.csv file into a DataFrame
df_en_text = pd.read_csv('tweets_translation/translated_tweets.csv')

# Display the first few rows of the DataFrame
df_en_text.head()
# Out:
#                     id                                         text_clean  \
# 0  1846277256509116672   Niezrealizowanie większości ze "100 konkretów...
# 1  1846222583898784000  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  1846161400328028160   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  1846091824101769472  Mija rok od wyborów parlamentarnych. W kampani...
# 4  1846075343188144128                                       #Idę11  🇵  🇱
#
#                                        text_clean_en
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   ❌ We are a year after the elections, and Pola...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱

# %%
df_en_text["id"] = df_en_text["id"].apply(lambda x: int(float(x.replace(',', ''))))

# %%
# Ensure the 'text_clean_en' column exists in df_clean_text
if 'text_clean_en' in df_en_text.columns:
    df = df.merge(df_en_text[['id', 'text_clean_en']], on='id', how='left')

    # Display the first few rows of the updated dataframe to verify the merge
    display(df.head())
else:
    print("Column 'text_clean_en' does not exist in df_clean_text")
# Out:
#    in_reply_to_user_id reply_settings  author_id  \
# 0            375146901       everyone 1182211615
# 1                  NaN       everyone 1182211615
# 2                  NaN       everyone 1182211615
# 3                  NaN       everyone 1182211615
# 4                  NaN       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4              #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids  ...  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]  ...
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]  ...
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]  ...
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]  ...
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  ...
#
#                                           text_clean       mentions  \
# 0   Niezrealizowanie większości ze "100 konkretów...  [@donaldtusk]
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...             []
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...             []
# 3  Mija rok od wyborów parlamentarnych. W kampani...             []
# 4                                     #Idę11  🇵  🇱               []
#
#                                                links  hashtags retweet_count  \
# 0                                                 []        []             3
# 1                          [https://t.co/4Jh5Ni6sgr]        []             9
# 2  [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...        []             4
# 3  [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...        []             6
# 4                          [https://t.co/KiCe5ATOpX]  [#Idę11]            45
#
#   reply_count like_count quote_count impression_count  \
# 0           1         33           0             1555
# 1           2         72           0             3031
# 2           3         33           2             8636
# 3           2         38           0             2441
# 4          18        616           2             8634
#
#                                        text_clean_en
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   ❌ We are a year after the elections, and Pola...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱
#
# [5 rows x 28 columns]

# %%
# Replace '#VALUE!' with NaN in 'text_clean_en' column
df['text_clean_en'] = df['text_clean_en'].replace('#VALUE!', pd.NA)

# %%
df['text_clean_en_demojized'] = df['text_clean_en'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)

df[['text_clean_en', 'text_clean_en_demojized']].head()
# Out:
#                                        text_clean_en  \
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   ❌ We are a year after the elections, and Pola...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱
#
#                              text_clean_en_demojized
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   :cross_mark: We are a year after the election...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱

# %%
df
# Out:
#        in_reply_to_user_id reply_settings  author_id  \
# 0                375146901       everyone 1182211615
# 1                      NaN       everyone 1182211615
# 2                      NaN       everyone 1182211615
# 3                      NaN       everyone 1182211615
# 4                      NaN       everyone 1182211615
# ...                    ...            ...        ...
# 11456  1557599378285666304       everyone  163197547
# 11457                  NaN       everyone  163197547
# 11458                  NaN       everyone  163197547
# 11459                  NaN       everyone  163197547
# 11460                  NaN       everyone  163197547
#
#                                      context_annotations                   id  \
# 0      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                    NaN  1846161400328028160
# 3                                                    NaN  1846091824101769472
# 4                                                    NaN  1846075343188144128
# ...                                                  ...                  ...
# 11456                                                NaN  1714536050096296192
# 11457                                                NaN  1714531739610075392
# 11458  [{'domain': {'id': '47', 'name': 'Brand', 'des...  1714523500176637952
# 11459                                                NaN  1714186262041510400
# 11460                                                NaN  1713833158838276096
#
#                                                     text  \
# 0      @donaldtusk Niezrealizowanie większości ze "10...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                                                  ...
# 11456  @Marek83406343 @tvn24rozmowa @KonradPiasecki @...
# 11457  Będę namawiała kolegów z opozycji do skorzysta...
# 11458  Budżet państwa musi być uchwalony do końca sty...
# 11459  Dziękuję z całego serca &lt;3 #DobraGospodyni ...
# 11460  #TrzeciaDroga na trzecim miejscu z 17 proc. gł...
#
#                                            edit_controls  \
# 0      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 11456  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 11457  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11458  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11459  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11460  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 0      [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11456  [{'type': 'replied_to', 'id': '171452430045820...
# 11457                                                NaN
# 11458                                                NaN
# 11459                                                NaN
# 11460                                                NaN
#
#                      created_at edit_history_tweet_ids  ...  \
# 0     2024-10-15 19:49:34+00:00  [1846277256509116623]  ...
# 1     2024-10-15 16:12:19+00:00  [1846222583898784025]  ...
# 2     2024-10-15 12:09:12+00:00  [1846161400328028272]  ...
# 3     2024-10-15 07:32:44+00:00  [1846091824101769490]  ...
# 4     2024-10-15 06:27:14+00:00  [1846075343188144153]  ...
# ...                         ...                    ...  ...
# 11456 2023-10-18 06:57:03+00:00  [1714536050096296256]  ...
# 11457 2023-10-18 06:39:55+00:00  [1714531739610075435]  ...
# 11458 2023-10-18 06:07:11+00:00  [1714523500176638070]  ...
# 11459 2023-10-17 07:47:07+00:00  [1714186262041510351]  ...
# 11460 2023-10-16 08:24:01+00:00  [1713833158838276198]  ...
#
#                                                 mentions  \
# 0                                          [@donaldtusk]
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 11456  [@Marek83406343, @tvn24rozmowa, @KonradPiaseck...
# 11457              [@Paslawska, @tvn24rozmowa, @nowePSL]
# 11458                  [@paslawska, @tvn24rozmowa, @now]
# 11459                                         [@nowePSL]
# 11460              [@Paslawska, @RadioOlsztyn, @nowePSL]
#
#                                                    links           hashtags  \
# 0                                                     []                 []
# 1                              [https://t.co/4Jh5Ni6sgr]                 []
# 2      [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...                 []
# 3      [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...                 []
# 4                              [https://t.co/KiCe5ATOpX]           [#Idę11]
# ...                                                  ...                ...
# 11456                                                 []                 []
# 11457                                                 []             [#PiS]
# 11458                          [https://t.co/BzsRxbPYv4]                 []
# 11459                          [https://t.co/cpxQaIsGty]  [#DobraGospodyni]
# 11460                          [https://t.co/ubTk0gaI8c]    [#TrzeciaDroga]
#
#       retweet_count reply_count like_count quote_count impression_count  \
# 0                 3           1         33           0             1555
# 1                 9           2         72           0             3031
# 2                 4           3         33           2             8636
# 3                 6           2         38           0             2441
# 4                45          18        616           2             8634
# ...             ...         ...        ...         ...              ...
# 11456             0           0          1           0               22
# 11457             6           1         33           0              806
# 11458             6           3         16           0              660
# 11459            15          13        122           0             4535
# 11460            12           9         52           1             4434
#
#                                            text_clean_en  \
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       ❌ We are a year after the elections, and Pola...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 11456  There are people with different worldviews and...
# 11457  I will encourage my colleagues from the opposi...
# 11458  The state budget must be adopted by the end of...
# 11459   Thank you with all my heart &lt;3 #GoodHousewife
# 11460  #TrzeciaDroga in third place with 17%. votes i...
#
#                                  text_clean_en_demojized
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       :cross_mark: We are a year after the election...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 11456  There are people with different worldviews and...
# 11457  I will encourage my colleagues from the opposi...
# 11458  The state budget must be adopted by the end of...
# 11459   Thank you with all my heart &lt;3 #GoodHousewife
# 11460  #TrzeciaDroga in third place with 17%. votes i...
#
# [11461 rows x 29 columns]

# %%
# Convert the 'possibly_sensitive' column to boolean, handling non-boolean values
df['possibly_sensitive'] = df['possibly_sensitive'].astype(bool)

# %%
# Save the DataFrame to a Parquet file
df.to_parquet('cleaned_data/df_combined.parquet', index=False)

# %%
import pandas as pd
import json 

def json_to_dataframe(json_file):
    """
    Reads a JSON file containing tweet data and converts it into a DataFrame.

    Parameters:
    json_file (str): Path to the JSON file.

    Returns:
    pd.DataFrame: DataFrame containing the tweet data.
    """
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Normalize JSON into a DataFrame
    df = pd.json_normalize(data)
    return df

# %%
input_file_path = "Arlukowicz_2023-10-16_2024-10-15_tweets.json"

# %%
df = json_to_dataframe(input_file_path)

# %%
df
# Out:
#                      id  possibly_sensitive      conversation_id  \
# 0   1846103375156277250               False  1846103375156277250
# 1   1846069735084921321               False  1846066439872041438
# 2   1845868192758960129               False  1845868192758960129
# 3   1844821048773988690               False  1844821048773988690
# 4   1843983476850385241               False  1843983476850385241
# ..                  ...                 ...                  ...
# 64  1813659448428404856               False  1813659448428404856
# 65  1813657783570726931               False  1813657783570726931
# 66  1813229013583778009               False  1813229013583778009
# 67  1813222571770319130               False  1813222571770319130
# 68  1813184241624093057               False  1813184241624093057
#
#    edit_history_tweet_ids                created_at lang  \
# 0   [1846103375156277250]  2024-10-15T08:18:38.000Z   pl
# 1   [1846069735084921321]  2024-10-15T06:04:57.000Z   pl
# 2   [1845868192758960129]  2024-10-14T16:44:06.000Z   pl
# 3   [1844821048773988690]  2024-10-11T19:23:07.000Z   pl
# 4   [1843983476850385241]  2024-10-09T11:54:55.000Z   en
# ..                    ...                       ...  ...
# 64  [1813659448428404856]  2024-07-17T19:38:03.000Z   pl
# 65  [1813657783570726931]  2024-07-17T19:31:26.000Z   pl
# 66  [1813229013583778009]  2024-07-16T15:07:39.000Z   pl
# 67  [1813222571770319130]  2024-07-16T14:42:03.000Z   pl
# 68  [1813184241624093057]  2024-07-16T12:09:45.000Z   ca
#
#                                                  text  author_id  \
# 0   15 października. To był nasz wspólny dzień! Pr...  101561338
# 1   @nat_dziedzic @RadioRebeliant Pozdrawiam i dzi...  101561338
# 2   O polityce migracyjnej i rocznicy Koalicji jut...  101561338
# 3   Pan Prezydent w Sądzie Najwyższym. Warto. Tak,...  101561338
# 4   First meeting with future Commissioner for Fis...  101561338
# ..                                                ...        ...
# 64  Poseł Romanowski. W 2024 w Radzie Europy odbył...  101561338
# 65  Poseł Romanowski. Nie jest członkiem Zgromadze...  101561338
# 66  Ale że tak z Niemcami z AFD? Nasi “bogobojni i...  101561338
# 67  A więc ruszamy do pracy! Ten Parlament Europej...  101561338
# 68  Roberta! @EP_President @RobertaMetsola \nCongr...  101561338
#
#    reply_settings  category  ... public_metrics.like_count  \
# 0        everyone  Original  ...                      1202
# 1        everyone     Reply  ...                         7
# 2        everyone  Original  ...                        67
# 3        everyone  Original  ...                       459
# 4        everyone  Original  ...                        22
# ..            ...       ...  ...                       ...
# 64       everyone  Original  ...                       566
# 65       everyone  Original  ...                       857
# 66       everyone     Quote  ...                       778
# 67       everyone  Original  ...                       350
# 68       everyone  Original  ...                       238
#
#    public_metrics.quote_count  public_metrics.bookmark_count  \
# 0                          14                              7
# 1                           0                              0
# 2                           1                              0
# 3                           2                              1
# 4                           0                              0
# ..                        ...                            ...
# 64                          1                              7
# 65                          5                              6
# 66                          1                              2
# 67                          4                              0
# 68                          2                              1
#
#     public_metrics.impression_count  \
# 0                             19459
# 1                               165
# 2                              5624
# 3                             13190
# 4                              1614
# ..                              ...
# 64                            15407
# 65                            18854
# 66                            15580
# 67                            13727
# 68                             5699
#
#                                     referenced_tweets  in_reply_to_user_id  \
# 0                                                 NaN                  NaN
# 1   [{'type': 'replied_to', 'id': '184606769186331...   890595110685114369
# 2                                                 NaN                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# ..                                                ...                  ...
# 64                                                NaN                  NaN
# 65                                                NaN                  NaN
# 66  [{'type': 'quoted', 'id': '1813137455656100306'}]                  NaN
# 67                                                NaN                  NaN
# 68                                                NaN                  NaN
#
#                                     entities.mentions  \
# 0                                                 NaN
# 1   [{'start': 0, 'end': 13, 'username': 'nat_dzie...
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'start': 54, 'end': 66, 'username': 'CostasK...
# ..                                                ...
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67  [{'start': 152, 'end': 164, 'username': 'Europ...
# 68  [{'start': 9, 'end': 22, 'username': 'EP_Presi...
#
#                                entities.hashtags  \
# 0                                            NaN
# 1                                            NaN
# 2   [{'start': 73, 'end': 81, 'tag': 'SuperFm'}]
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 64                                           NaN
# 65                                           NaN
# 66                                           NaN
# 67                                           NaN
# 68                                           NaN
#
#                                   context_annotations  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'domain': {'id': '46', 'name': 'Business Tax...
# ..                                                ...
# 64                                                NaN
# 65                                                NaN
# 66  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 67  [{'domain': {'id': '88', 'name': 'Political Bo...
# 68  [{'domain': {'id': '88', 'name': 'Political Bo...
#
#                                  entities.annotations
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'start': 202, 'end': 216, 'probability': 0.7...
# ..                                                ...
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
#
# [69 rows x 27 columns]

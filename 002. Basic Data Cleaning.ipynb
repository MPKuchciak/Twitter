# %% [markdown]
# # Data cleaning

# %% [markdown]
# In this file, we cleaned the downloaded data:
# The main steps include:
# 1. Adding party affiliation to tweet rows
# 2. Deleting unnecessary downloaded Retweets.
# 3. Deleting links and mentions from the tweets text and saving them to separate columns
# 4. Expanding the column of public metrics
# 5. Encoding emojis in a unified format
# 6. Translating tweets using Google Translate in Google Sheets
# 7. Saving all downloaded tweets to one file

# %% [markdown]
# ### 1.  Used libraries

# %%
import os
import pandas as pd
import re
import emoji

# %% [markdown]
# ### 2. Reading JSON files and transforming them into party-specific pickle files

# %%
base_input_paths = ['data/PoWyborach', 'data/tweets_data_2022']
subfolders = ['Konfederacja', 'NL', 'PIS', 'PO', 'PL2050', 'PSL']
output_folder = 'data/tweets_data_combined'

for subfolder in subfolders:
    dataframes = []
    for base_input_path in base_input_paths:
        folder_path = os.path.join(base_input_path, subfolder)
        for filename in os.listdir(folder_path):
            if filename.endswith('.json'):
                file_path = os.path.join(folder_path, filename)
                politician = filename.split("_tweets.json")[0]
                try:
                    df = pd.read_json(file_path)  
                    df["username"] = politician  
                    df["party"] = subfolder
                    print(f"Read {len(df)} rows from {file_path}")  
                    dataframes.append(df)
                except ValueError as e:
                    print(f"Error reading {file_path}: {e}")
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        
        output_file_path = os.path.join(output_folder, f'{subfolder}_combined.pkl')
        combined_df.to_pickle(output_file_path) 
        
        print(f"Saved {subfolder} combined data to {output_file_path}")

print("Processing complete!")
# Out:
# Read 964 rows from data/PoWyborach\Konfederacja\bartlomiejpejo_2023-10-16_2024-10-15.json
# Read 889 rows from data/PoWyborach\Konfederacja\GrzegorzBraun__2023-10-16_2024-10-15.json
# Read 11 rows from data/PoWyborach\Konfederacja\Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json
# Read 289 rows from data/PoWyborach\Konfederacja\KonradBerkowicz_2023-10-15_2024-04-16_vol2 (1).json
# Read 1318 rows from data/PoWyborach\Konfederacja\KonradBerkowicz_2024-04-16_2024-10-15_vol1 (1).json
# Read 772 rows from data/PoWyborach\Konfederacja\MarSypniewski_2023-10-16_2024-10-15.json
# Read 597 rows from data/PoWyborach\Konfederacja\MichalWawer_2023-10-16_2024-10-15.json
# Read 421 rows from data/PoWyborach\Konfederacja\placzekgrzegorz_2023-10-16_2024-04-15.json
# Read 320 rows from data/PoWyborach\Konfederacja\placzekgrzegorz_2024-04-16_2024-10-15.json
# Read 721 rows from data/PoWyborach\Konfederacja\SlawomirMentzen_2023-10-16_2024-10-15.json
# Read 175 rows from data/PoWyborach\Konfederacja\TudujKrzysztof_2023-10-16_2024-10-15.json
# Read 950 rows from data/PoWyborach\Konfederacja\Wlodek_Skalik_2023-10-16_2024-10-15.json
# Read 750 rows from data/PoWyborach\Konfederacja\WTumanowicz_2023-10-16_2024-10-15.json
# Read 595 rows from data/tweets_data_2022\Konfederacja\bartlomiejpejo_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\Konfederacja\GrzegorzBraun__2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\Konfederacja\JkmMikke_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\Konfederacja\KonradBerkowicz_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\Konfederacja\krzysztofbosak_2022-10-16_2023-10-15.json
# Read 758 rows from data/tweets_data_2022\Konfederacja\MarSypniewski_2022-10-16_2023-10-15.json
# Read 248 rows from data/tweets_data_2022\Konfederacja\MichalWawer_2022-10-16_2023-10-15.json
# Read 592 rows from data/tweets_data_2022\Konfederacja\placzekgrzegorz_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\Konfederacja\RJ_Iwaszkiewicz_2022-10-16_2023-10-15.json
# Read 789 rows from data/tweets_data_2022\Konfederacja\SlawomirMentzen_2022-10-16_2023-10-15.json
# Read 213 rows from data/tweets_data_2022\Konfederacja\TudujKrzysztof_2022-10-16_2023-10-15.json
# Read 585 rows from data/tweets_data_2022\Konfederacja\Wlodek_Skalik_2022-10-16_2023-10-15.json
# Read 694 rows from data/tweets_data_2022\Konfederacja\WTumanowicz_2022-10-16_2023-10-15.json
# Saved Konfederacja combined data to data/tweets_data_combined\Konfederacja_combined.pkl
# Read 207 rows from data/PoWyborach\NL\AndrzejSzejna_2023-10-16_2024-10-15 (1).json
# Read 481 rows from data/PoWyborach\NL\AnitaKDZG_2023-10-16_2024-10-15 (1).json
# Read 0 rows from data/PoWyborach\NL\DyduchMarek_2023-10-16_2024-10-15.json
# Read 103 rows from data/PoWyborach\NL\JoankaSW_2023-10-16_2024-10-15 (1).json
# Read 178 rows from data/PoWyborach\NL\KGawkowski_2023-10-16_2024-10-15.json
# Read 693 rows from data/PoWyborach\NL\K_Smiszek_2023-10-16_2024-10-15 (1).json
# Read 1128 rows from data/PoWyborach\NL\MarcinKulasek_2023-10-16_2024-10-15.json
# Read 247 rows from data/PoWyborach\NL\MoskwaWodnicka_2023-10-16_2024-10-15 (1).json
# Read 537 rows from data/PoWyborach\NL\PaulinaPW2024_2023-10-16_2024-10-15 (1).json
# Read 907 rows from data/PoWyborach\NL\poselTTrela_2023-10-16_2024-04-15.json
# Read 575 rows from data/PoWyborach\NL\poselTTrela_2024-04-16_2024-10-15.json
# Read 457 rows from data/PoWyborach\NL\RobertBiedron_2023-10-16_2024-10-15.json
# Read 787 rows from data/PoWyborach\NL\WandaNowicka_2023-10-16_2024-10-15 (1).json
# Read 142 rows from data/PoWyborach\NL\wieczorekdarek_2023-10-16_2024-10-15 (1).json
# Read 73 rows from data/PoWyborach\NL\wlodekczarzasty_2023-10-16_2024-10-15.json
# Read 184 rows from data/tweets_data_2022\NL\AndrzejSzejna_2022-10-16_2023-10-15.json
# Read 889 rows from data/tweets_data_2022\NL\AnitaKDZG_2022-10-16_2023-10-15.json
# Read 91 rows from data/tweets_data_2022\NL\Arek_Iwaniak_2022-10-16_2023-10-15.json
# Read 598 rows from data/tweets_data_2022\NL\B_Maciejewska_2022-10-16_2023-10-15.json
# Read 379 rows from data/tweets_data_2022\NL\JoankaSW_2022-10-16_2023-10-15.json
# Read 227 rows from data/tweets_data_2022\NL\KGawkowski_2022-10-16_2023-10-15.json
# Read 1073 rows from data/tweets_data_2022\NL\K_Smiszek_2022-10-16_2023-10-15.json
# Read 1010 rows from data/tweets_data_2022\NL\MarcinKulasek_2022-10-16_2023-10-15.json
# Read 204 rows from data/tweets_data_2022\NL\MoskwaWodnicka_2022-10-16_2023-10-15.json
# Read 526 rows from data/tweets_data_2022\NL\PaulinaPW2024_2022-10-16_2023-10-15.json
# Read 293 rows from data/tweets_data_2022\NL\RobertBiedron_2022-10-16_2023-10-15.json
# Read 859 rows from data/tweets_data_2022\NL\WandaNowicka_2022-10-16_2023-10-15.json
# Read 265 rows from data/tweets_data_2022\NL\wieczorekdarek_2022-10-16_2023-10-15.json
# Read 318 rows from data/tweets_data_2022\NL\wlodekczarzasty_2022-10-16_2023-10-15.json
# Saved NL combined data to data/tweets_data_combined\NL_combined.pkl
# Read 556 rows from data/PoWyborach\PIS\BeataSzydlo_2023-10-16_2024-10-15.json
# Read 77 rows from data/PoWyborach\PIS\elzbietawitek_2023-10-16_2024-10-15.json
# Read 189 rows from data/PoWyborach\PIS\Kaminski_M__2023-10-16_2024-10-15.json
# Read 35 rows from data/PoWyborach\PIS\Kowalczyk_H_2023-10-16_2024-10-15.json
# Read 236 rows from data/PoWyborach\PIS\Macierewicz_A_2023-10-16_2024-10-15.json
# Read 249 rows from data/PoWyborach\PIS\mblaszczak_2023-10-16_2024-10-15 (1).json
# Read 647 rows from data/PoWyborach\PIS\MorawieckiM_2023-10-16_2024-10-15.json
# Read 782 rows from data/PoWyborach\PIS\mwojcik__2023-10-16_2024-10-15.json
# Read 1025 rows from data/PoWyborach\PIS\PatrykJaki_2023-10-16_2024-10-15.json
# Read 0 rows from data/tweets_data_2022\PIS\AC_Sobol_2022-10-16_2023-10-15.json
# Read 333 rows from data/tweets_data_2022\PIS\BeataSzydlo_2022-10-16_2023-10-15.json
# Read 61 rows from data/tweets_data_2022\PIS\elzbietawitek_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\PIS\jbrudzinski_2022-10-16_2023-10-15.json
# Read 140 rows from data/tweets_data_2022\PIS\Kaminski_M__2022-10-16_2023-10-15.json
# Read 237 rows from data/tweets_data_2022\PIS\Kowalczyk_H_2022-10-16_2023-10-15.json
# Read 391 rows from data/tweets_data_2022\PIS\Macierewicz_A_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\PIS\mblaszczak_2022-10-16_2023-10-15.json
# Read 614 rows from data/tweets_data_2022\PIS\MorawieckiM_2022-10-16_2023-10-15.json
# Read 268 rows from data/tweets_data_2022\PIS\mwojcik__2022-10-16_2023-10-15.json
# Read 769 rows from data/tweets_data_2022\PIS\PatrykJaki_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\PIS\PMilowanski_2022-10-16_2023-10-15.json
# Saved PIS combined data to data/tweets_data_combined\PIS_combined.pkl
# Read 45 rows from data/PoWyborach\PO\bbudka_2023-10-16_2024-03-31.json
# Read 49 rows from data/PoWyborach\PO\bbudka_2024-04-01_2024-10-15.json
# Read 269 rows from data/PoWyborach\PO\CTomczyk_2023-10-16_2024-10-15_GUWNOMAMYZNIMPROBLEM (1).json
# Read 338 rows from data/PoWyborach\PO\donaldtusk_2023-10-16_2024-10-15.json
# Read 409 rows from data/PoWyborach\PO\DorotaNiedziela_2023-10-16_2024-10-15.json
# Read 165 rows from data/PoWyborach\PO\EwaKopacz_2023-10-16_2024-10-15.json
# Read 102 rows from data/PoWyborach\PO\JanGrabiec_2023-10-16_2024-10-15.json
# Read 356 rows from data/PoWyborach\PO\Konwinski_PO_2023-10-16_2024-10-15.json
# Read 118 rows from data/PoWyborach\PO\Leszczyna_2023-10-16_2023-12-31.json
# Read 112 rows from data/PoWyborach\PO\Leszczyna_2024-01-01_2024-03-31.json
# Read 173 rows from data/PoWyborach\PO\Leszczyna_2024-04-01_2024-10-15.json
# Read 882 rows from data/PoWyborach\PO\MKierwinski_2023-10-16_2024-10-15.json
# Read 62 rows from data/PoWyborach\PO\M_K_Blonska_2023-10-16_2024-03-31.json
# Read 64 rows from data/PoWyborach\PO\M_K_Blonska_2024-04-01_2024-10-15.json
# Read 456 rows from data/PoWyborach\PO\OklaDrewnowicz_2023-10-16_2024-10-15.json
# Read 814 rows from data/PoWyborach\PO\trzaskowski__2023-10-16_2024-10-15 (1).json
# Read 0 rows from data/tweets_data_2022\PO\Arlukowicz_2022-10-16_2023-10-15.json
# Read 395 rows from data/tweets_data_2022\PO\bbudka_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022\PO\CTomczyk_2022-10-16_2023-10-15.json
# Read 178 rows from data/tweets_data_2022\PO\donaldtusk_2022-10-16_2023-10-15.json
# Read 513 rows from data/tweets_data_2022\PO\DorotaNiedziela_2022-10-16_2023-10-15.json
# Read 76 rows from data/tweets_data_2022\PO\EwaKopacz_2022-10-16_2023-10-15.json
# Read 520 rows from data/tweets_data_2022\PO\JanGrabiec_2022-10-16_2023-10-15.json
# Read 56 rows from data/tweets_data_2022\PO\Konwinski_PO_2022-10-16_2023-10-15.json
# Read 370 rows from data/tweets_data_2022\PO\Leszczyna_2022-10-16_2023-10-15.json
# Read 1081 rows from data/tweets_data_2022\PO\MKierwinski_2022-10-16_2023-10-15.json
# Read 515 rows from data/tweets_data_2022\PO\M_K_Blonska_2022-10-16_2023-10-15.json
# Read 766 rows from data/tweets_data_2022\PO\OklaDrewnowicz_2022-10-16_2023-10-15.json
# Read 264 rows from data/tweets_data_2022\PO\TomaszSiemoniak_2022-10-16_2023-10-15.json
# Read 851 rows from data/tweets_data_2022\PO\trzaskowski__2022-10-16_2023-10-15.json
# Saved PO combined data to data/tweets_data_combined\PO_combined.pkl
# Read 41 rows from data/PoWyborach\PL2050\AgaBaranowskaPL_2023-10-16_2024-10-15.json
# Read 29 rows from data/PoWyborach\PL2050\aga_buczynska_2023-10-16_2024-10-15.json
# Read 389 rows from data/PoWyborach\PL2050\hennigkloska_2023-10-16_2024-10-15 (1).json
# Read 8 rows from data/PoWyborach\PL2050\joannamucha_2023-10-16_2024-10-15 (1).json
# Read 226 rows from data/PoWyborach\PL2050\Kpelczynska_2023-10-16_2024-10-15.json
# Read 73 rows from data/PoWyborach\PL2050\LukaszOsmalak_2023-10-16_2024-10-15.json
# Read 675 rows from data/PoWyborach\PL2050\SlizPawel_2023-10-16_2024-10-15.json
# Read 167 rows from data/PoWyborach\PL2050\szymon_holownia_2023-10-16_2024-10-15.json
# Read 175 rows from data/PoWyborach\PL2050\ZalewskiPawel_2023-10-16_2024-10-15.json
# Read 319 rows from data/PoWyborach\PL2050\ZywnoMaciej_2023-10-16_2024-10-15 (1).json
# Read 14 rows from data/tweets_data_2022\PL2050\AgaBaranowskaPL_2022-10-16_2023-10-15.json
# Read 244 rows from data/tweets_data_2022\PL2050\aga_buczynska_2022-10-16_2023-10-15.json
# Read 652 rows from data/tweets_data_2022\PL2050\hennigkloska_2022-10-16_2023-10-15.json
# Read 26 rows from data/tweets_data_2022\PL2050\JKozlowskiEu_2022-10-16_2023-10-15.json
# Read 51 rows from data/tweets_data_2022\PL2050\joannamucha_2022-10-16_2023-10-15.json
# Read 74 rows from data/tweets_data_2022\PL2050\Kpelczynska_2022-10-16_2023-10-15.json
# Read 127 rows from data/tweets_data_2022\PL2050\LukaszOsmalak_2022-10-16_2023-10-15.json
# Read 554 rows from data/tweets_data_2022\PL2050\michalkobosko_2022-10-16_2023-10-15.json
# Read 564 rows from data/tweets_data_2022\PL2050\SlizPawel_2022-10-16_2023-10-15.json
# Read 339 rows from data/tweets_data_2022\PL2050\szymon_holownia_2022-10-16_2023-10-15.json
# Read 514 rows from data/tweets_data_2022\PL2050\ZalewskiPawel_2022-10-16_2023-10-15.json
# Read 479 rows from data/tweets_data_2022\PL2050\ZywnoMaciej_2022-10-16_2023-10-15.json
# Saved PL2050 combined data to data/tweets_data_combined\PL2050_combined.pkl
# Read 274 rows from data/PoWyborach\PSL\DariuszKlimczak_2023-10-16_2024-10-15.json
# Read 115 rows from data/PoWyborach\PSL\GrzybAndrzej_2023-10-16_2024-10-15.json
# Read 19 rows from data/PoWyborach\PSL\Hetman_K_2023-10-16_2024-10-15.json
# Read 192 rows from data/PoWyborach\PSL\JarubasAdam_2023-10-16_2024-10-15.json
# Read 409 rows from data/PoWyborach\PSL\KosiniakKamysz_2023-10-16_2024-10-15.json
# Read 146 rows from data/PoWyborach\PSL\Paslawska_2023-10-16_2024-10-15.json
# Read 411 rows from data/PoWyborach\PSL\PZgorzelskiP_2023-10-16_2024-10-15.json
# Read 107 rows from data/PoWyborach\PSL\StefanKrajewski_2023-10-16_2024-10-15.json
# Read 288 rows from data/tweets_data_2022\PSL\DariuszKlimczak_2022-10-16_2023-10-15.json
# Read 262 rows from data/tweets_data_2022\PSL\GrzybAndrzej_2022-10-16_2023-10-15.json
# Read 162 rows from data/tweets_data_2022\PSL\Hetman_K_2022-10-16_2023-10-15.json
# Read 280 rows from data/tweets_data_2022\PSL\JarubasAdam_2022-10-16_2023-10-15.json
# Read 400 rows from data/tweets_data_2022\PSL\KosiniakKamysz_2022-10-16_2023-10-15.json
# Read 199 rows from data/tweets_data_2022\PSL\Paslawska_2022-10-16_2023-10-15.json
# Read 774 rows from data/tweets_data_2022\PSL\PZgorzelskiP_2022-10-16_2023-10-15.json
# Read 195 rows from data/tweets_data_2022\PSL\StefanKrajewski_2022-10-16_2023-10-15.json
# Read 124 rows from data/tweets_data_2022\PSL\StruzikAdam_2022-10-16_2023-10-15.json
# Saved PSL combined data to data/tweets_data_combined\PSL_combined.pkl
# Processing complete!

# %% [markdown]
# ### 3. Data cleaning

# %%
df_konfederacja = pd.read_pickle(os.path.join(output_folder, 'Konfederacja_combined.pkl'))
df_NL = pd.read_pickle(os.path.join(output_folder, 'NL_combined.pkl'))
df_PIS = pd.read_pickle(os.path.join(output_folder, 'PIS_combined.pkl'))
df_PO = pd.read_pickle(os.path.join(output_folder, 'PO_combined.pkl'))
df_PL2050 = pd.read_pickle(os.path.join(output_folder, 'PL2050_combined.pkl'))
df_PSL = pd.read_pickle(os.path.join(output_folder, 'PSL_combined.pkl'))

# %%
df_konfederacja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12651 entries, 0 to 12650
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          12651 non-null  object
#  1   in_reply_to_user_id     3078 non-null   float64
#  2   reply_settings          12651 non-null  object
#  3   author_id               12651 non-null  float64
#  4   context_annotations     1334 non-null   object
#  5   id                      12651 non-null  float64
#  6   text                    12651 non-null  object
#  7   edit_controls           12651 non-null  object
#  8   referenced_tweets       4543 non-null   object
#  9   created_at              12651 non-null  datetime64[ns, UTC]
#  10  edit_history_tweet_ids  12651 non-null  object
#  11  lang                    12651 non-null  object
#  12  conversation_id         12651 non-null  float64
#  13  entities                11407 non-null  object
#  14  possibly_sensitive      12651 non-null  object
#  15  category                12651 non-null  object
#  16  attachments             6203 non-null   object
#  17  geo                     295 non-null    object
#  18  username                12651 non-null  object
#  19  party                   12651 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 1.9+ MB

# %%
df_konfederacja.head()
# Out:
#                                       public_metrics  in_reply_to_user_id  \
# 0  {'retweet_count': 3, 'reply_count': 1, 'like_c...          375146901.0
# 1  {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2  {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3  {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4  {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
#
#   reply_settings     author_id  \
# 0       everyone  1.182212e+09
# 1       everyone  1.182212e+09
# 2       everyone  1.182212e+09
# 3       everyone  1.182212e+09
# 4       everyone  1.182212e+09
#
#                                  context_annotations            id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1.846277e+18
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1.846223e+18
# 2                                                NaN  1.846161e+18
# 3                                                NaN  1.846092e+18
# 4                                                NaN  1.846075e+18
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  ❌Mamy rok po wyborach, a Polska pogrąża się w ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11 🇵🇱 https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids lang  conversation_id  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]   pl     1.846092e+18
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]   pl     1.846223e+18
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]   pl     1.846161e+18
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]   pl     1.846092e+18
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  qme     1.846075e+18
#
#                                             entities possibly_sensitive  \
# 0  {'mentions': [{'start': 0, 'end': 11, 'usernam...              False
# 1  {'urls': [{'start': 100, 'end': 123, 'url': 'h...              False
# 2  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 4  {'hashtags': [{'start': 0, 'end': 6, 'tag': 'I...              False
#
#    category                                 attachments  geo  \
# 0     Reply                                         NaN  NaN
# 1  Original  {'media_keys': ['13_1846222491456282626']}  NaN
# 2  Original   {'media_keys': ['3_1846148786910810112']}  NaN
# 3  Original   {'media_keys': ['3_1846091818959597568']}  NaN
# 4  Original  {'media_keys': ['13_1846075276687478784']}  NaN
#
#                                     username         party
# 0  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 2  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 3  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 4  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja

# %%
# Merge all dataframes into one
df = pd.concat([df_konfederacja, df_NL, df_PIS, df_PO, df_PL2050, df_PSL], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52787 entries, 0 to 52786
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          52787 non-null  object
#  1   in_reply_to_user_id     10972 non-null  float64
#  2   reply_settings          52787 non-null  object
#  3   author_id               52787 non-null  float64
#  4   context_annotations     5948 non-null   object
#  5   id                      52771 non-null  float64
#  6   text                    52787 non-null  object
#  7   edit_controls           52771 non-null  object
#  8   referenced_tweets       19691 non-null  object
#  9   created_at              52787 non-null  datetime64[ns, UTC]
#  10  edit_history_tweet_ids  52771 non-null  object
#  11  lang                    52787 non-null  object
#  12  conversation_id         52771 non-null  float64
#  13  entities                46839 non-null  object
#  14  possibly_sensitive      52771 non-null  object
#  15  category                52787 non-null  object
#  16  attachments             22966 non-null  object
#  17  geo                     1459 non-null   object
#  18  username                52787 non-null  object
#  19  party                   52787 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 8.1+ MB

# %%
len(df)
# Out:
# 52787

# %%
pd.options.display.float_format = '{:.0f}'.format
df['id'] = df['id'].fillna(0).astype('int64')
df['id']
# Out:
# 0        1846277256509116672
# 1        1846222583898784000
# 2        1846161400328028160
# 3        1846091824101769472
# 4        1846075343188144128
#                 ...
# 52782    1701274354145780224
# 52783    1701273238263742720
# 52784    1701273238263742720
# 52785    1697128952131661824
# 52786    1697128952131661824
# Name: id, Length: 52787, dtype: int64

# %%
# Get the value counts of 'id'
id_counts = df['id'].value_counts()

# Filter the counts to show only those greater than 1
id_counts_above_1 = id_counts[id_counts > 1]

# Display the counts
print(f"IDs with counts greater than 1:\n{id_counts_above_1}")
# Out:
# IDs with counts greater than 1:
# id
# 0                      16
# 1780108572161945856     3
# 1714215043720442368     2
# 1581668593192034304     2
# 1581702691851763712     2
#                        ..
# 1713961177028415488     2
# 1780346371888833024     2
# 1791793599819993088     2
# 1780346025854603264     2
# 1780345829615636480     2
# Name: count, Length: 229, dtype: int64

# %%
id_counts_above_1.sum()
# Out:
# 473

# %%
# Count unique IDs
non_duplicate_counts = df['id'].nunique()
print(f"Number of unique IDs: {non_duplicate_counts}")

# Count duplicate IDs
duplicate_counts = df['id'].duplicated().sum()
print(f"Number of duplicate IDs: {duplicate_counts}")

# Get the value counts of 'id'
id_counts = df['id'].value_counts()

# Filter the counts to show only those greater than 1
id_counts_above_1 = id_counts[id_counts > 1]

# Sum of counts of IDs that appear more than once
total_duplicate_rows = id_counts_above_1.sum()
print(f"Total number of duplicate rows based on 'id': {total_duplicate_rows}")

# Convert all columns to strings to avoid unhashable types
df_str = df.astype(str)

# Now check for exact duplicate rows across all columns
duplicates_all = df_str[df_str.duplicated(keep=False)]
print(f"Total duplicate rows (exact match across all columns): {duplicates_all.shape[0]}")
duplicates_all
# Out:
# Number of unique IDs: 52543
# Number of duplicate IDs: 244
# Total number of duplicate rows based on 'id': 473
# Total duplicate rows (exact match across all columns): 304
#                                           public_metrics in_reply_to_user_id  \
# 1660   {'retweet_count': 38, 'reply_count': 23, 'like...                 nan
# 1661   {'retweet_count': 38, 'reply_count': 23, 'like...                 nan
# 1743   {'retweet_count': 16, 'reply_count': 0, 'like_...                 nan
# 1744   {'retweet_count': 16, 'reply_count': 0, 'like_...                 nan
# 1862   {'retweet_count': 0, 'reply_count': 0, 'like_c...                 nan
# ...                                                  ...                 ...
# 52744  {'retweet_count': 6, 'reply_count': 0, 'like_c...                 nan
# 52783  {'retweet_count': 41, 'reply_count': 0, 'like_...                 nan
# 52784  {'retweet_count': 41, 'reply_count': 0, 'like_...                 nan
# 52785  {'retweet_count': 12, 'reply_count': 0, 'like_...                 nan
# 52786  {'retweet_count': 12, 'reply_count': 0, 'like_...                 nan
#
#       reply_settings               author_id context_annotations  \
# 1660        everyone  1.1863674835461652e+18                 nan
# 1661        everyone  1.1863674835461652e+18                 nan
# 1743        everyone  1.1863674835461652e+18                 nan
# 1744        everyone  1.1863674835461652e+18                 nan
# 1862        everyone  1.5544839915117036e+18                 nan
# ...              ...                     ...                 ...
# 52744       everyone             961181894.0                 nan
# 52783       everyone             961181894.0                 nan
# 52784       everyone             961181894.0                 nan
# 52785       everyone             961181894.0                 nan
# 52786       everyone             961181894.0                 nan
#
#                         id                                               text  \
# 1660   1768754497738678272                   Skandal👇 https://t.co/XBJRvv3OVR
# 1661   1768754497738678272                   Skandal👇 https://t.co/XBJRvv3OVR
# 1743   1753779932742799616  RT @Roman_Korona: ⏰Zapraszam na doroczny Zlot ...
# 1744   1753779932742799616  RT @Roman_Korona: ⏰Zapraszam na doroczny Zlot ...
# 1862   1762109123800293376  Nie ma takiej obietnicy, której polityk nie ob...
# ...                    ...                                                ...
# 52744  1707867087899705600  RT @JKaminska02: Niezależnie od poglądów warto...
# 52783  1701273238263742720  RT @KosiniakKamysz: Polska wymiera! Miesięczni...
# 52784  1701273238263742720  RT @KosiniakKamysz: Polska wymiera! Miesięczni...
# 52785  1697128952131661824  RT @nowePSL: 💬 Referendum to gra polityczna @p...
# 52786  1697128952131661824  RT @nowePSL: 💬 Referendum to gra polityczna @p...
#
#                                            edit_controls  \
# 1660   {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1661   {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1743   {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1744   {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1862   {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 52744  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52783  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52784  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52785  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52786  {'edits_remaining': 5, 'is_edit_eligible': Fal...
#
#                                        referenced_tweets  \
# 1660   [{'type': 'quoted', 'id': '1768727139937828957'}]
# 1661   [{'type': 'quoted', 'id': '1768727139937828957'}]
# 1743   [{'type': 'retweeted', 'id': '1753770538424504...
# 1744   [{'type': 'retweeted', 'id': '1753770538424504...
# 1862                                                 nan
# ...                                                  ...
# 52744  [{'type': 'retweeted', 'id': '1707772421258813...
# 52783  [{'type': 'retweeted', 'id': '1701264896711709...
# 52784  [{'type': 'retweeted', 'id': '1701264896711709...
# 52785  [{'type': 'retweeted', 'id': '1697126436279128...
# 52786  [{'type': 'retweeted', 'id': '1697126436279128...
#
#                       created_at   edit_history_tweet_ids lang  \
# 1660   2024-03-15 21:41:48+00:00  ['1768754497738678324']   in
# 1661   2024-03-15 21:41:48+00:00  ['1768754497738678324']   in
# 1743   2024-02-03 13:58:14+00:00  ['1753779932742799591']   pl
# 1744   2024-02-03 13:58:14+00:00  ['1753779932742799591']   pl
# 1862   2024-02-26 13:35:28+00:00  ['1762109123800293457']   pl
# ...                          ...                      ...  ...
# 52744  2023-09-29 21:16:59+00:00  ['1707867087899705655']   pl
# 52783  2023-09-11 16:35:22+00:00  ['1701273238263742680']   pl
# 52784  2023-09-11 16:35:22+00:00  ['1701273238263742680']   pl
# 52785  2023-08-31 06:07:27+00:00  ['1697128952131661845']   pl
# 52786  2023-08-31 06:07:27+00:00  ['1697128952131661845']   pl
#
#               conversation_id  \
# 1660   1.7687544977386783e+18
# 1661   1.7687544977386783e+18
# 1743   1.7537799327427996e+18
# 1744   1.7537799327427996e+18
# 1862   1.7621091238002934e+18
# ...                       ...
# 52744  1.7078670878997056e+18
# 52783  1.7012732382637427e+18
# 52784  1.7012732382637427e+18
# 52785  1.6971289521316618e+18
# 52786  1.6971289521316618e+18
#
#                                                 entities possibly_sensitive  \
# 1660   {'urls': [{'start': 9, 'end': 32, 'url': 'http...              False
# 1661   {'urls': [{'start': 9, 'end': 32, 'url': 'http...              False
# 1743   {'mentions': [{'start': 3, 'end': 16, 'usernam...              False
# 1744   {'mentions': [{'start': 3, 'end': 16, 'usernam...              False
# 1862   {'urls': [{'start': 80, 'end': 103, 'url': 'ht...              False
# ...                                                  ...                ...
# 52744  {'mentions': [{'start': 3, 'end': 15, 'usernam...                0.0
# 52783  {'mentions': [{'start': 3, 'end': 18, 'usernam...                0.0
# 52784  {'mentions': [{'start': 3, 'end': 18, 'usernam...                0.0
# 52785  {'mentions': [{'start': 3, 'end': 11, 'usernam...                0.0
# 52786  {'mentions': [{'start': 3, 'end': 11, 'usernam...                0.0
#
#        category                                attachments  geo  \
# 1660      Quote                                        nan  nan
# 1661      Quote                                        nan  nan
# 1743    Retweet                                        nan  nan
# 1744    Retweet                                        nan  nan
# 1862   Original  {'media_keys': ['3_1762109117865304064']}  nan
# ...         ...                                        ...  ...
# 52744   Retweet                                        nan  nan
# 52783   Retweet                                        nan  nan
# 52784   Retweet                                        nan  nan
# 52785   Retweet                                        nan  nan
# 52786   Retweet                                        nan  nan
#
#                                          username         party
# 1660    GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 1661    GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 1743    GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 1744    GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 1862   Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# ...                                           ...           ...
# 52744      StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52783      StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52784      StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52785      StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52786      StruzikAdam_2022-10-16_2023-10-15.json           PSL
#
# [304 rows x 20 columns]

# %% [markdown]
# brief insight into how do these duplicates look like

# %%
df[df['id'].duplicated(keep=False)].sort_values(by='id')
# Out:
#                                           public_metrics  in_reply_to_user_id  \
# 34539  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 48817  {'retweet_count': 2, 'reply_count': 1, 'like_c...                  NaN
# 48818  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34538  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34528  {'retweet_count': 0, 'reply_count': 1, 'like_c...                  NaN
# ...                                                  ...                  ...
# 48525  {'retweet_count': 15, 'reply_count': 2, 'like_...                  NaN
# 32828  {'retweet_count': 568, 'reply_count': 221, 'li...                  NaN
# 32829  {'retweet_count': 567, 'reply_count': 221, 'li...                  NaN
# 27208  {'retweet_count': 141, 'reply_count': 125, 'li...                  NaN
# 27209  {'retweet_count': 141, 'reply_count': 125, 'li...                  NaN
#
#       reply_settings  author_id  \
# 34539       everyone   61552404
# 48817       everyone 1119834276
# 48818       everyone   61552404
# 34538       everyone   61552404
# 34528       everyone   61552404
# ...              ...        ...
# 48525       everyone  964017524
# 32828       everyone   52367150
# 32829       everyone   52367150
# 27208       everyone  138048156
# 27209       everyone  138048156
#
#                                      context_annotations                   id  \
# 34539                                                NaN                    0
# 48817                                                NaN                    0
# 48818                                                NaN                    0
# 34538                                                NaN                    0
# 34528                                                NaN                    0
# ...                                                  ...                  ...
# 48525  [{'domain': {'id': '11', 'name': 'Sport', 'des...  1834508231009325568
# 32828  [{'domain': {'id': '10', 'name': 'Person', 'de...  1836654233296244992
# 32829  [{'domain': {'id': '10', 'name': 'Person', 'de...  1836654233296244992
# 27208                                                NaN  1838584923688444416
# 27209                                                NaN  1838584923688444416
#
#                                                     text  \
# 34539                                  @magosia_10_19 🤛🥰
# 48817                                       Dziękuję 🤝😀🍀
# 48818                 @Maciej_ENZ0 Dziękuję i pozdrawiam
# 34538  @RGrupinski @StGawlowski i ode mnie Rafale, dl...
# 34528                                       @tomekbit ✌️
# ...                                                  ...
# 48525  W ramach roboczego kontaktu z @WodyPolskie ora...
# 32828  Premier @donaldtusk : namierzono człowieka prz...
# 32829  Premier @donaldtusk : namierzono człowieka prz...
# 27208  Potwierdza się to o czym mówiliśmy już od dawn...
# 27209  Potwierdza się to o czym mówiliśmy już od dawn...
#
#                                            edit_controls  \
# 34539                                                NaN
# 48817                                                NaN
# 48818                                                NaN
# 34538                                                NaN
# 34528                                                NaN
# ...                                                  ...
# 48525  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 32828  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 32829  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 27208  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 27209  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 34539                                                NaN
# 48817  [{'type': 'quoted', 'id': '1714320722481615223'}]
# 48818                                                NaN
# 34538                                                NaN
# 34528                                                NaN
# ...                                                  ...
# 48525                                                NaN
# 32828                                                NaN
# 32829                                                NaN
# 27208  [{'type': 'quoted', 'id': '1838307356918071625'}]
# 27209  [{'type': 'quoted', 'id': '1838307356918071625'}]
#
#                      created_at edit_history_tweet_ids lang  \
# 34539 2023-10-16 23:17:00+00:00                    NaN   pl
# 48817 2024-10-17 18:49:00+00:00                    NaN   pl
# 48818 2023-10-18 12:46:00+00:00                    NaN   pl
# 34538 2023-10-16 23:15:00+00:00                    NaN   pl
# 34528 2023-10-16 00:00:00+00:00                    NaN   pl
# ...                         ...                    ...  ...
# 48525 2024-09-13 08:23:40+00:00  [1834508231009325542]   pl
# 32828 2024-09-19 06:31:07+00:00  [1836654233296244914]   pl
# 32829 2024-09-19 06:31:07+00:00  [1836654233296244914]   pl
# 27208 2024-09-24 14:22:59+00:00  [1838584923688444342]   pl
# 27209 2024-09-24 14:22:59+00:00  [1838584923688444342]   pl
#
#           conversation_id                                           entities  \
# 34539                 NaN                                                NaN
# 48817                 NaN                                                NaN
# 48818                 NaN                                                NaN
# 34538                 NaN                                                NaN
# 34528                 NaN                                                NaN
# ...                   ...                                                ...
# 48525 1834508231009325568  {'mentions': [{'start': 30, 'end': 42, 'userna...
# 32828 1836654233296244992  {'mentions': [{'start': 8, 'end': 19, 'usernam...
# 32829 1836654233296244992  {'mentions': [{'start': 8, 'end': 19, 'usernam...
# 27208 1838584923688444416  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 27209 1838584923688444416  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
#
#       possibly_sensitive  category attachments  geo  \
# 34539                NaN     Reply         NaN  NaN
# 48817                NaN     Quote         NaN  NaN
# 48818                NaN     Reply         NaN  NaN
# 34538                NaN     Reply         NaN  NaN
# 34528                NaN     Reply         NaN  NaN
# ...                  ...       ...         ...  ...
# 48525                  0  Original         NaN  NaN
# 32828              False  Original         NaN  NaN
# 32829              False  Original         NaN  NaN
# 27208              False     Quote         NaN  NaN
# 27209              False     Quote         NaN  NaN
#
#                                                 username party
# 34539               Leszczyna_2023-10-16_2023-12-31.json    PO
# 48817            GrzybAndrzej_2023-10-16_2024-10-15.json   PSL
# 48818            GrzybAndrzej_2023-10-16_2024-10-15.json   PSL
# 34538               Leszczyna_2023-10-16_2023-12-31.json    PO
# 34528               Leszczyna_2023-10-16_2023-12-31.json    PO
# ...                                                  ...   ...
# 48525         DariuszKlimczak_2023-10-16_2024-10-15.json   PSL
# 32828  CTomczyk_2023-10-16_2024-10-15_GUWNOMAMYZNIMPR...    PO
# 32829  CTomczyk_2023-10-16_2024-10-15_GUWNOMAMYZNIMPR...    PO
# 27208          mblaszczak_2023-10-16_2024-10-15 (1).json   PIS
# 27209          mblaszczak_2023-10-16_2024-10-15 (1).json   PIS
#
# [473 rows x 20 columns]

# %%
for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, dict)).any():
        print(f"Column '{col}' contains dictionaries.")
    elif df[col].apply(lambda x: isinstance(x, list)).any():
        print(f"Column '{col}' contains lists.")
# Out:
# Column 'public_metrics' contains dictionaries.
# Column 'context_annotations' contains lists.
# Column 'edit_controls' contains dictionaries.
# Column 'referenced_tweets' contains lists.
# Column 'edit_history_tweet_ids' contains lists.
# Column 'entities' contains dictionaries.
# Column 'attachments' contains dictionaries.
# Column 'geo' contains dictionaries.

# %%
# Get all duplicate IDs
duplicate_ids = df[df['id'].duplicated(keep=False)]

# Exclude columns with unhashable (dict-like) values
columns_to_exclude = ['edit_controls', 'public_metrics', 'attachments', 'entities', 'geo', 'edit_history_tweet_ids', 'context_annotations','referenced_tweets']
valid_columns = [col for col in df.columns if col not in columns_to_exclude]

# Find differences across valid columns
diff_summary = duplicate_ids[valid_columns].groupby('id').nunique()

# Show columns where duplicates have different values
diff_summary = diff_summary[(diff_summary > 1).any(axis=1)]

# %%
diff_summary
# Out:
#                      in_reply_to_user_id  reply_settings  author_id  text  \
# id
# 0                                      0               1          2    16
# 1780108572161945856                    0               1          1     1
# 1780146130551996672                    1               1          1     1
# 1780171152914034944                    1               1          1     1
# 1780244011212485120                    0               1          1     1
# 1780309557610258688                    0               1          1     1
# 1780345695163047936                    1               1          1     1
# 1780345829615636480                    1               1          1     1
# 1780346025854603264                    1               1          1     1
# 1780346371888833024                    1               1          1     1
#
#                      created_at  lang  conversation_id  possibly_sensitive  \
# id
# 0                             9     1                0                   0
# 1780108572161945856           1     1                1                   1
# 1780146130551996672           1     1                1                   1
# 1780171152914034944           1     1                1                   1
# 1780244011212485120           1     1                1                   1
# 1780309557610258688           1     1                1                   1
# 1780345695163047936           1     1                1                   1
# 1780345829615636480           1     1                1                   1
# 1780346025854603264           1     1                1                   1
# 1780346371888833024           1     1                1                   1
#
#                      category  username  party
# id
# 0                           2         2      2
# 1780108572161945856         1         2      1
# 1780146130551996672         1         2      1
# 1780171152914034944         1         2      1
# 1780244011212485120         1         2      1
# 1780309557610258688         1         2      1
# 1780345695163047936         1         2      1
# 1780345829615636480         1         2      1
# 1780346025854603264         1         2      1
# 1780346371888833024         1         2      1

# %%
duplicates = df[df.duplicated(subset=['id'], keep=False)]
duplicates
# Out:
#                                           public_metrics  in_reply_to_user_id  \
# 962    {'retweet_count': 15, 'reply_count': 28, 'like...                  NaN
# 963    {'retweet_count': 15, 'reply_count': 28, 'like...                  NaN
# 1660   {'retweet_count': 38, 'reply_count': 23, 'like...                  NaN
# 1661   {'retweet_count': 38, 'reply_count': 23, 'like...                  NaN
# 1743   {'retweet_count': 16, 'reply_count': 0, 'like_...                  NaN
# ...                                                  ...                  ...
# 52744  {'retweet_count': 6, 'reply_count': 0, 'like_c...                  NaN
# 52783  {'retweet_count': 41, 'reply_count': 0, 'like_...                  NaN
# 52784  {'retweet_count': 41, 'reply_count': 0, 'like_...                  NaN
# 52785  {'retweet_count': 12, 'reply_count': 0, 'like_...                  NaN
# 52786  {'retweet_count': 12, 'reply_count': 0, 'like_...                  NaN
#
#       reply_settings           author_id context_annotations  \
# 962         everyone          1182211615                 NaN
# 963         everyone          1182211615                 NaN
# 1660        everyone 1186367483546165248                 NaN
# 1661        everyone 1186367483546165248                 NaN
# 1743        everyone 1186367483546165248                 NaN
# ...              ...                 ...                 ...
# 52744       everyone           961181894                 NaN
# 52783       everyone           961181894                 NaN
# 52784       everyone           961181894                 NaN
# 52785       everyone           961181894                 NaN
# 52786       everyone           961181894                 NaN
#
#                         id                                               text  \
# 962    1714195119706890496  Serdeczne dzięki za każdy głos. 🤝\nDla mnie to...
# 963    1714195119706890496  Serdeczne dzięki za każdy głos. 🤝\nDla mnie to...
# 1660   1768754497738678272                   Skandal👇 https://t.co/XBJRvv3OVR
# 1661   1768754497738678272                   Skandal👇 https://t.co/XBJRvv3OVR
# 1743   1753779932742799616  RT @Roman_Korona: ⏰Zapraszam na doroczny Zlot ...
# ...                    ...                                                ...
# 52744  1707867087899705600  RT @JKaminska02: Niezależnie od poglądów warto...
# 52783  1701273238263742720  RT @KosiniakKamysz: Polska wymiera! Miesięczni...
# 52784  1701273238263742720  RT @KosiniakKamysz: Polska wymiera! Miesięczni...
# 52785  1697128952131661824  RT @nowePSL: 💬 Referendum to gra polityczna @p...
# 52786  1697128952131661824  RT @nowePSL: 💬 Referendum to gra polityczna @p...
#
#                                            edit_controls  \
# 962    {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 963    {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1660   {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1661   {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1743   {'edits_remaining': 5, 'is_edit_eligible': Fal...
# ...                                                  ...
# 52744  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52783  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52784  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52785  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52786  {'edits_remaining': 5, 'is_edit_eligible': Fal...
#
#                                        referenced_tweets  \
# 962                                                  NaN
# 963                                                  NaN
# 1660   [{'type': 'quoted', 'id': '1768727139937828957'}]
# 1661   [{'type': 'quoted', 'id': '1768727139937828957'}]
# 1743   [{'type': 'retweeted', 'id': '1753770538424504...
# ...                                                  ...
# 52744  [{'type': 'retweeted', 'id': '1707772421258813...
# 52783  [{'type': 'retweeted', 'id': '1701264896711709...
# 52784  [{'type': 'retweeted', 'id': '1701264896711709...
# 52785  [{'type': 'retweeted', 'id': '1697126436279128...
# 52786  [{'type': 'retweeted', 'id': '1697126436279128...
#
#                      created_at edit_history_tweet_ids lang  \
# 962   2023-10-17 08:22:19+00:00  [1714195119706890463]   pl
# 963   2023-10-17 08:22:19+00:00  [1714195119706890463]   pl
# 1660  2024-03-15 21:41:48+00:00  [1768754497738678324]   in
# 1661  2024-03-15 21:41:48+00:00  [1768754497738678324]   in
# 1743  2024-02-03 13:58:14+00:00  [1753779932742799591]   pl
# ...                         ...                    ...  ...
# 52744 2023-09-29 21:16:59+00:00  [1707867087899705655]   pl
# 52783 2023-09-11 16:35:22+00:00  [1701273238263742680]   pl
# 52784 2023-09-11 16:35:22+00:00  [1701273238263742680]   pl
# 52785 2023-08-31 06:07:27+00:00  [1697128952131661845]   pl
# 52786 2023-08-31 06:07:27+00:00  [1697128952131661845]   pl
#
#           conversation_id                                           entities  \
# 962   1714195119706890496  {'hashtags': [{'start': 251, 'end': 264, 'tag'...
# 963   1714195119706890496  {'urls': [{'start': 275, 'end': 298, 'url': 'h...
# 1660  1768754497738678272  {'urls': [{'start': 9, 'end': 32, 'url': 'http...
# 1661  1768754497738678272  {'urls': [{'start': 9, 'end': 32, 'url': 'http...
# 1743  1753779932742799616  {'mentions': [{'start': 3, 'end': 16, 'usernam...
# ...                   ...                                                ...
# 52744 1707867087899705600  {'mentions': [{'start': 3, 'end': 15, 'usernam...
# 52783 1701273238263742720  {'mentions': [{'start': 3, 'end': 18, 'usernam...
# 52784 1701273238263742720  {'mentions': [{'start': 3, 'end': 18, 'usernam...
# 52785 1697128952131661824  {'mentions': [{'start': 3, 'end': 11, 'usernam...
# 52786 1697128952131661824  {'mentions': [{'start': 3, 'end': 11, 'usernam...
#
#       possibly_sensitive  category                                attachments  \
# 962                False  Original  {'media_keys': ['3_1714195114472431617']}
# 963                False  Original  {'media_keys': ['3_1714195114472431617']}
# 1660               False     Quote                                        NaN
# 1661               False     Quote                                        NaN
# 1743               False   Retweet                                        NaN
# ...                  ...       ...                                        ...
# 52744                  0   Retweet                                        NaN
# 52783                  0   Retweet                                        NaN
# 52784                  0   Retweet                                        NaN
# 52785                  0   Retweet                                        NaN
# 52786                  0   Retweet                                        NaN
#
#                                     geo  \
# 962    {'place_id': '535f0c2de0121451'}
# 963    {'place_id': '535f0c2de0121451'}
# 1660                                NaN
# 1661                                NaN
# 1743                                NaN
# ...                                 ...
# 52744                               NaN
# 52783                               NaN
# 52784                               NaN
# 52785                               NaN
# 52786                               NaN
#
#                                         username         party
# 962    bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 963    bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1660   GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 1661   GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 1743   GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# ...                                          ...           ...
# 52744     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52783     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52784     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52785     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52786     StruzikAdam_2022-10-16_2023-10-15.json           PSL
#
# [473 rows x 20 columns]

# %%
duplicate_text_count = df['text'].duplicated().sum()
print(f"Number of duplicate Text Entries: {duplicate_text_count}")
# Out:
# Number of duplicate Text Entries: 320

# %%
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]
print(f"Rows where BOTH `id` and `text` are duplicated: {len(duplicate_id_text_rows)}")
# Out:
# Rows where BOTH `id` and `text` are duplicated: 457

# %%
# Count occurrences of each ID
id_counts = df['id'].value_counts()
print("Distribution of duplicate IDs:")
print(id_counts.value_counts().sort_index())

# Count occurrences of each text
text_counts = df['text'].value_counts()
print("\nDistribution of duplicate Text Entries:")
print(text_counts.value_counts().sort_index())
# Out:
# Distribution of duplicate IDs:
# count
# 1     52314
# 2       227
# 3         1
# 16        1
# Name: count, dtype: int64
#
# Distribution of duplicate Text Entries:
# count
# 1    52164
# 2      291
# 3        9
# 4        2
# 6        1
# Name: count, dtype: int64

# %%
# Get all duplicate ID rows
duplicate_id_rows = df[df.duplicated(subset=['id'], keep=False)]

# Get all duplicate Text rows
duplicate_text_rows = df[df.duplicated(subset=['text'], keep=False)]

# Get rows where both ID and Text are duplicated
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]

# Compare overlaps
print(f"Rows where ID is duplicated: {len(duplicate_id_rows)}")
print(f"Rows where Text is duplicated: {len(duplicate_text_rows)}")
print(f"Rows where BOTH ID and Text are duplicated: {len(duplicate_id_text_rows)}")

# Find duplicate IDs that are NOT in the text duplicate set
id_not_in_text = duplicate_id_rows[~duplicate_id_rows['id'].isin(duplicate_text_rows['id'])]
print(f"\nDuplicate IDs NOT duplicated in Text: {len(id_not_in_text)}")

# Find duplicate Texts that are NOT in the ID duplicate set
text_not_in_id = duplicate_text_rows[~duplicate_text_rows['text'].isin(duplicate_id_rows['text'])]
print(f"Duplicate Texts NOT duplicated in ID: {len(text_not_in_id)}")
# Out:
# Rows where ID is duplicated: 473
# Rows where Text is duplicated: 623
# Rows where BOTH ID and Text are duplicated: 457
#
# Duplicate IDs NOT duplicated in Text: 16
# Duplicate Texts NOT duplicated in ID: 165

# %%
empty_id_rows = df[df['id'].isna()]
print(f"Rows where `id` is empty (NaN): {len(empty_id_rows)}")
#empty_id_rows

zero_id_rows = df[df['id'] == 0]
print(f"Rows where `id` is 0: {len(zero_id_rows)}")
zero_id_rows
# Out:
# Rows where `id` is empty (NaN): 0
# Rows where `id` is 0: 16
#                                           public_metrics  in_reply_to_user_id  \
# 34528  {'retweet_count': 0, 'reply_count': 1, 'like_c...                  NaN
# 34529  {'retweet_count': 0, 'reply_count': 2, 'like_c...                  NaN
# 34530  {'retweet_count': 0, 'reply_count': 1, 'like_c...                  NaN
# 34531  {'retweet_count': 1, 'reply_count': 1, 'like_c...                  NaN
# 34532  {'retweet_count': 1, 'reply_count': 0, 'like_c...                  NaN
# 34533  {'retweet_count': 0, 'reply_count': 1, 'like_c...                  NaN
# 34534  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34535  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34536  {'retweet_count': 18, 'reply_count': 31, 'like...                  NaN
# 34537  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34538  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34539  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34540  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 34541  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
# 48817  {'retweet_count': 2, 'reply_count': 1, 'like_c...                  NaN
# 48818  {'retweet_count': 0, 'reply_count': 0, 'like_c...                  NaN
#
#       reply_settings  author_id context_annotations  id  \
# 34528       everyone   61552404                 NaN   0
# 34529       everyone   61552404                 NaN   0
# 34530       everyone   61552404                 NaN   0
# 34531       everyone   61552404                 NaN   0
# 34532       everyone   61552404                 NaN   0
# 34533       everyone   61552404                 NaN   0
# 34534       everyone   61552404                 NaN   0
# 34535       everyone   61552404                 NaN   0
# 34536       everyone   61552404                 NaN   0
# 34537       everyone   61552404                 NaN   0
# 34538       everyone   61552404                 NaN   0
# 34539       everyone   61552404                 NaN   0
# 34540       everyone   61552404                 NaN   0
# 34541       everyone   61552404                 NaN   0
# 48817       everyone 1119834276                 NaN   0
# 48818       everyone   61552404                 NaN   0
#
#                                                     text edit_controls  \
# 34528                                       @tomekbit ✌️           NaN
# 34529  @MaciejGdynia Maćku, czekam na oficjalne wynik...           NaN
# 34530      @MCichonAlicja Alu, czekamy jeszcze na wynik?           NaN
# 34531                                        @REL_76 🥰🥰🥰           NaN
# 34532                                      @Gidziela 🥰✌️           NaN
# 34533                              @WHaptar Gratulacje👏🥂           NaN
# 34534                       @KapenGenezyp Dziękuję❤️❤️❤️           NaN
# 34535                                     @jasinska_e ❤️           NaN
# 34536                            @BMikolajewska odpowie💪           NaN
# 34537                    @DorotaNiedziela ja Tobie też❣️           NaN
# 34538  @RGrupinski @StGawlowski i ode mnie Rafale, dl...           NaN
# 34539                                  @magosia_10_19 🤛🥰           NaN
# 34540                          @3Fritz1 @BMikolajewska 🫡           NaN
# 34541      @BernadettaK2 @otoWojciech @BMikolajewska 😂😂😂           NaN
# 48817                                       Dziękuję 🤝😀🍀           NaN
# 48818                 @Maciej_ENZ0 Dziękuję i pozdrawiam           NaN
#
#                                        referenced_tweets  \
# 34528                                                NaN
# 34529                                                NaN
# 34530                                                NaN
# 34531                                                NaN
# 34532                                                NaN
# 34533                                                NaN
# 34534                                                NaN
# 34535                                                NaN
# 34536                                                NaN
# 34537                                                NaN
# 34538                                                NaN
# 34539                                                NaN
# 34540                                                NaN
# 34541                                                NaN
# 48817  [{'type': 'quoted', 'id': '1714320722481615223'}]
# 48818                                                NaN
#
#                      created_at edit_history_tweet_ids lang  conversation_id  \
# 34528 2023-10-16 00:00:00+00:00                    NaN   pl              NaN
# 34529 2023-10-16 00:00:00+00:00                    NaN   pl              NaN
# 34530 2023-10-16 00:00:00+00:00                    NaN   pl              NaN
# 34531 2023-10-16 00:00:00+00:00                    NaN   pl              NaN
# 34532 2023-10-16 00:00:00+00:00                    NaN   pl              NaN
# 34533 2023-10-16 00:00:00+00:00                    NaN   pl              NaN
# 34534 2023-10-16 00:00:00+00:00                    NaN   pl              NaN
# 34535 2023-10-16 21:57:00+00:00                    NaN   pl              NaN
# 34536 2023-10-16 22:27:00+00:00                    NaN   pl              NaN
# 34537 2023-10-16 22:41:00+00:00                    NaN   pl              NaN
# 34538 2023-10-16 23:15:00+00:00                    NaN   pl              NaN
# 34539 2023-10-16 23:17:00+00:00                    NaN   pl              NaN
# 34540 2023-10-16 23:18:00+00:00                    NaN   pl              NaN
# 34541 2023-10-16 23:18:00+00:00                    NaN   pl              NaN
# 48817 2024-10-17 18:49:00+00:00                    NaN   pl              NaN
# 48818 2023-10-18 12:46:00+00:00                    NaN   pl              NaN
#
#       entities possibly_sensitive category attachments  geo  \
# 34528      NaN                NaN    Reply         NaN  NaN
# 34529      NaN                NaN    Reply         NaN  NaN
# 34530      NaN                NaN    Reply         NaN  NaN
# 34531      NaN                NaN    Reply         NaN  NaN
# 34532      NaN                NaN    Reply         NaN  NaN
# 34533      NaN                NaN    Reply         NaN  NaN
# 34534      NaN                NaN    Reply         NaN  NaN
# 34535      NaN                NaN    Reply         NaN  NaN
# 34536      NaN                NaN    Reply         NaN  NaN
# 34537      NaN                NaN    Reply         NaN  NaN
# 34538      NaN                NaN    Reply         NaN  NaN
# 34539      NaN                NaN    Reply         NaN  NaN
# 34540      NaN                NaN    Reply         NaN  NaN
# 34541      NaN                NaN    Reply         NaN  NaN
# 48817      NaN                NaN    Quote         NaN  NaN
# 48818      NaN                NaN    Reply         NaN  NaN
#
#                                       username party
# 34528     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34529     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34530     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34531     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34532     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34533     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34534     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34535     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34536     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34537     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34538     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34539     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34540     Leszczyna_2023-10-16_2023-12-31.json    PO
# 34541     Leszczyna_2023-10-16_2023-12-31.json    PO
# 48817  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL
# 48818  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL

# %%
tweets_by_author = df[df['author_id'] == 61552404.0].sort_values(by='created_at')
display(tweets_by_author)
# Out:
#                                           public_metrics  in_reply_to_user_id  \
# 39211  {'retweet_count': 482, 'reply_count': 0, 'like...                  NaN
# 39212  {'retweet_count': 482, 'reply_count': 0, 'like...                  NaN
# 39210  {'retweet_count': 376, 'reply_count': 0, 'like...                  NaN
# 39209  {'retweet_count': 144, 'reply_count': 0, 'like...                  NaN
# 39208  {'retweet_count': 167, 'reply_count': 0, 'like...                  NaN
# ...                                                  ...                  ...
# 34658  {'retweet_count': 0, 'reply_count': 2, 'like_c...   713836895495696384
# 34657  {'retweet_count': 0, 'reply_count': 2, 'like_c...  1439610920175558656
# 34656  {'retweet_count': 47, 'reply_count': 116, 'lik...                  NaN
# 34655  {'retweet_count': 0, 'reply_count': 5, 'like_c...  1217929501063155712
# 34654  {'retweet_count': 124, 'reply_count': 85, 'lik...                  NaN
#
#       reply_settings  author_id  \
# 39211       everyone   61552404
# 39212       everyone   61552404
# 39210       everyone   61552404
# 39209       everyone   61552404
# 39208       everyone   61552404
# ...              ...        ...
# 34658       everyone   61552404
# 34657       everyone   61552404
# 34656       everyone   61552404
# 34655       everyone   61552404
# 34654       everyone   61552404
#
#                                      context_annotations                   id  \
# 39211  [{'domain': {'id': '10', 'name': 'Person', 'de...  1700530175337738496
# 39212  [{'domain': {'id': '10', 'name': 'Person', 'de...  1700530175337738496
# 39210                                                NaN  1700530281784971520
# 39209  [{'domain': {'id': '10', 'name': 'Person', 'de...  1700530331500085760
# 39208  [{'domain': {'id': '10', 'name': 'Person', 'de...  1700530402610364672
# ...                                                  ...                  ...
# 34658                                                NaN  1842513925612372224
# 34657                                                NaN  1842515633826627840
# 34656                                                NaN  1844253674584916224
# 34655                                                NaN  1844411831844036864
# 34654                                                NaN  1846249201925345280
#
#                                                     text  \
# 39211  RT @Platforma_org: 💬 Przewodniczący @donaldtus...
# 39212  RT @Platforma_org: 💬 Przewodniczący @donaldtus...
# 39210  RT @MariaLe85219860: B U M‼️\n\nDuda, Ziobro, ...
# 39209  RT @Platforma_org: 💬 Przewodniczący @donaldtus...
# 39208  RT @Platforma_org: 💬 Przewodniczący @donaldtus...
# ...                                                  ...
# 34658  @arekpisarski @MZ_GOV_PL @NFZ_GOV_PL tak, @Rze...
# 34657  @ewa_esse @MZ_GOV_PL od 15. października, ale ...
# 34656  Ustawa o wychowaniu w trzeźwości trafi dopiero...
# 34655  @Mariusz32382943 nad zmianami systemowymi prac...
# 34654  #15października - Święto bezimiennych Bohatere...
#
#                                            edit_controls  \
# 39211  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 39212  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 39210  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 39209  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 39208  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# ...                                                  ...
# 34658  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 34657  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 34656  {'edits_remaining': 4, 'is_edit_eligible': Tru...
# 34655  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 34654  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 39211  [{'type': 'retweeted', 'id': '1700489605026340...
# 39212  [{'type': 'retweeted', 'id': '1700489605026340...
# 39210  [{'type': 'retweeted', 'id': '1700475689600696...
# 39209  [{'type': 'retweeted', 'id': '1700482994564186...
# 39208  [{'type': 'retweeted', 'id': '1700463357575221...
# ...                                                  ...
# 34658  [{'type': 'replied_to', 'id': '184214897941436...
# 34657  [{'type': 'replied_to', 'id': '184216083786941...
# 34656  [{'type': 'quoted', 'id': '1844091771900526777'}]
# 34655  [{'type': 'replied_to', 'id': '184427203001280...
# 34654                                                NaN
#
#                      created_at                      edit_history_tweet_ids  \
# 39211 2023-09-09 15:22:42+00:00                       [1700530175337738371]
# 39212 2023-09-09 15:22:42+00:00                       [1700530175337738371]
# 39210 2023-09-09 15:23:08+00:00                       [1700530281784971545]
# 39209 2023-09-09 15:23:20+00:00                       [1700530331500085744]
# 39208 2023-09-09 15:23:36+00:00                       [1700530402610364779]
# ...                         ...                                         ...
# 34658 2024-10-05 10:35:26+00:00                       [1842513925612372262]
# 34657 2024-10-05 10:42:14+00:00                       [1842515633826627766]
# 34656 2024-10-10 05:48:35+00:00  [1844253222103380157, 1844253674584916327]
# 34655 2024-10-10 16:17:02+00:00                       [1844411831844036750]
# 34654 2024-10-15 17:58:06+00:00                       [1846249201925345310]
#
#       lang     conversation_id  \
# 39211   pl 1700530175337738496
# 39212   pl 1700530175337738496
# 39210   pl 1700530281784971520
# 39209   pl 1700530331500085760
# 39208   pl 1700530402610364672
# ...    ...                 ...
# 34658   pl 1842146757360169472
# 34657   pl 1842146757360169472
# 34656   pl 1844253674584916224
# 34655   pl 1844253674584916224
# 34654   pl 1846249201925345280
#
#                                                 entities possibly_sensitive  \
# 39211  {'mentions': [{'start': 3, 'end': 17, 'usernam...              False
# 39212  {'mentions': [{'start': 3, 'end': 17, 'usernam...              False
# 39210  {'hashtags': [{'start': 114, 'end': 127, 'tag'...              False
# 39209  {'mentions': [{'start': 3, 'end': 17, 'usernam...              False
# 39208  {'mentions': [{'start': 3, 'end': 17, 'usernam...              False
# ...                                                  ...                ...
# 34658  {'urls': [{'start': 85, 'end': 108, 'url': 'ht...              False
# 34657  {'urls': [{'start': 303, 'end': 326, 'url': 'h...              False
# 34656  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 34655  {'urls': [{'start': 296, 'end': 319, 'url': 'h...              False
# 34654  {'urls': [{'start': 279, 'end': 302, 'url': 'h...              False
#
#        category                                 attachments  geo  \
# 39211   Retweet                                         NaN  NaN
# 39212   Retweet                                         NaN  NaN
# 39210   Retweet                                         NaN  NaN
# 39209   Retweet                                         NaN  NaN
# 39208   Retweet                                         NaN  NaN
# ...         ...                                         ...  ...
# 34658     Reply                                         NaN  NaN
# 34657     Reply                                         NaN  NaN
# 34656     Quote                                         NaN  NaN
# 34655     Reply                                         NaN  NaN
# 34654  Original  {'media_keys': ['13_1846249130529538048']}  NaN
#
#                                    username party
# 39211  Leszczyna_2022-10-16_2023-10-15.json    PO
# 39212  Leszczyna_2022-10-16_2023-10-15.json    PO
# 39210  Leszczyna_2022-10-16_2023-10-15.json    PO
# 39209  Leszczyna_2022-10-16_2023-10-15.json    PO
# 39208  Leszczyna_2022-10-16_2023-10-15.json    PO
# ...                                     ...   ...
# 34658  Leszczyna_2024-04-01_2024-10-15.json    PO
# 34657  Leszczyna_2024-04-01_2024-10-15.json    PO
# 34656  Leszczyna_2024-04-01_2024-10-15.json    PO
# 34655  Leszczyna_2024-04-01_2024-10-15.json    PO
# 34654  Leszczyna_2024-04-01_2024-10-15.json    PO
#
# [774 rows x 20 columns]

# %% [markdown]
# id 0 of a tweet may mean, that the tweet was, changed, deleted, or that it is not a tweet but something else and was wrongly categorized as one

# %% [markdown]
# We need to remove duplicate tweets + delete the tweets that were 0; because our custom downloading loop occasionally downloads the same tweet two times to ensure completeness.

# %%
import pandas as pd
import numpy as np

# 1) Copy the original DataFrame before cleaning
df_before = df.copy()

# 2) Get the initial size
initial_size = len(df_before)
print(f"Initial number of tweets: {initial_size}")

# 3) Check and report issues with the 'id' column
print("\n--- ID QUALITY CHECK ---")

# Convert id to string for consistent checking
df_before['id'] = df_before['id'].astype(str)

# Check for various problems
missing_ids = df_before['id'].isna()
empty_ids = df_before['id'] == ''
zero_ids = df_before['id'] == '0'
very_short_ids = df_before['id'].str.len() < 5  # Twitter IDs are typically longer

# Report on ID issues
print(f"Missing IDs (NaN): {missing_ids.sum()} ({missing_ids.mean():.2%})")
print(f"Empty IDs: {empty_ids.sum()} ({empty_ids.mean():.2%})")
print(f"Zero IDs ('0'): {zero_ids.sum()} ({zero_ids.mean():.2%})")
print(f"Very short IDs (< 5 chars): {very_short_ids.sum()} ({very_short_ids.mean():.2%})")

# Create a mask for all problematic IDs
problematic_ids_mask = missing_ids | empty_ids | zero_ids | very_short_ids

# Report total problematic IDs
print(f"Total problematic IDs: {problematic_ids_mask.sum()} ({problematic_ids_mask.mean():.2%})")

# 4) First filter out problematic IDs from the original dataset
df_no_problems = df_before[~problematic_ids_mask].copy()
problematic_removed = initial_size - len(df_no_problems)

# 5) Then remove duplicates from the dataset without problematic IDs
df_after = df_no_problems.drop_duplicates(subset=['id'])
duplicates_removed = len(df_no_problems) - len(df_after)

# 6) Calculate removed counts and percentages
remaining_final = len(df_after)
total_removed = initial_size - remaining_final

duplicate_percentage = (duplicates_removed / initial_size) * 100
problematic_percentage = (problematic_removed / initial_size) * 100
total_removed_percentage = (total_removed / initial_size) * 100
remaining_percentage = (remaining_final / initial_size) * 100

# 7) Print comprehensive results
print("\n--- CLEANING SUMMARY ---")
print(f"Initial tweets: {initial_size}")
print(f"Problematic ID tweets removed: {problematic_removed} ({problematic_percentage:.2f}%)")
print(f"Duplicate tweets removed: {duplicates_removed} ({duplicate_percentage:.2f}%)")
print(f"Total tweets removed: {total_removed} ({total_removed_percentage:.2f}%)")
print(f"Tweets remaining: {remaining_final} ({remaining_percentage:.2f}%)")

# 8) Show sample of problematic IDs
if problematic_ids_mask.sum() > 0:
    print("\nSample of problematic IDs:")
    sample_problematic = df_before[problematic_ids_mask].head(5)
    for i, (idx, row) in enumerate(sample_problematic.iterrows()):
        print(f"  {i+1}. ID: '{row['id']}', Text: '{row['text'][:50]}...'")

# 9) Identify the actual duplicate IDs from the data without problematic IDs
duplicate_ids = df_no_problems[df_no_problems.duplicated(subset=['id'], keep='first')]['id'].unique().tolist()
print(f"\nNumber of unique duplicate IDs: {len(duplicate_ids)}")
if duplicate_ids:
    print("Sample of duplicate IDs (first 5):")
    for i, dup_id in enumerate(duplicate_ids[:5]):
        print(f"  {i+1}. {dup_id}")
else:
    print("No duplicates found")

# 10) Keep df_after as the new df
df = df_after
print(f"\nFinal clean dataframe shape: {df.shape}")

# 11) Verify no problematic IDs remain
if (df['id'] == '0').sum() > 0 or df['id'].isna().sum() > 0 or (df['id'] == '').sum() > 0 or (df['id'].str.len() < 5).sum() > 0:
    print("WARNING: Some problematic IDs still remain in the cleaned dataframe")
else:
    print("SUCCESS: All problematic IDs have been removed")
# Out:
# Initial number of tweets: 52787
#
# --- ID QUALITY CHECK ---
# Missing IDs (NaN): 0 (0.00%)
# Empty IDs: 0 (0.00%)
# Zero IDs ('0'): 16 (0.03%)
# Very short IDs (< 5 chars): 16 (0.03%)
# Total problematic IDs: 16 (0.03%)
#
# --- CLEANING SUMMARY ---
# Initial tweets: 52787
# Problematic ID tweets removed: 16 (0.03%)
# Duplicate tweets removed: 229 (0.43%)
# Total tweets removed: 245 (0.46%)
# Tweets remaining: 52542 (99.54%)
#
# Sample of problematic IDs:
#   1. ID: '0', Text: '@tomekbit ✌️...'
#   2. ID: '0', Text: '@MaciejGdynia Maćku, czekam na oficjalne wyniki, ż...'
#   3. ID: '0', Text: '@MCichonAlicja Alu, czekamy jeszcze na wynik?...'
#   4. ID: '0', Text: '@REL_76 🥰🥰🥰...'
#   5. ID: '0', Text: '@Gidziela 🥰✌️...'
#
# Number of unique duplicate IDs: 228
# Sample of duplicate IDs (first 5):
#   1. 1714195119706890496
#   2. 1768754497738678272
#   3. 1753779932742799616
#   4. 1736748164722385408
#   5. 1762109123800293376
#
# Final clean dataframe shape: (52542, 20)
# SUCCESS: All problematic IDs have been removed

# %%
# 1) How many total rows have a duplicate 'id' (including the first occurrence)?
total_dup_rows = df.duplicated(subset=['id'], keep=False).sum()
print(f"Total rows that share a duplicate ID (including the first occurrence): {total_dup_rows}")

# 2) How many rows are "extra" duplicates beyond the first?
extra_dup_rows = df.duplicated(subset=['id'], keep='first').sum()
print(f"Number of extra duplicates beyond the first occurrence: {extra_dup_rows}")

# 3) How many unique IDs appear more than once?
duplicate_ids = df[df.duplicated(subset=['id'], keep=False)]['id'].unique()
num_duplicate_ids = len(duplicate_ids)
print(f"Number of unique IDs that are duplicated: {num_duplicate_ids}")
# Out:
# Total rows that share a duplicate ID (including the first occurrence): 0
# Number of extra duplicates beyond the first occurrence: 0
# Number of unique IDs that are duplicated: 0

# %%
df.head()
# Out:
#                                       public_metrics  in_reply_to_user_id  \
# 0  {'retweet_count': 3, 'reply_count': 1, 'like_c...            375146901
# 1  {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2  {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3  {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4  {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
#
#   reply_settings  author_id  \
# 0       everyone 1182211615
# 1       everyone 1182211615
# 2       everyone 1182211615
# 3       everyone 1182211615
# 4       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  ❌Mamy rok po wyborach, a Polska pogrąża się w ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11 🇵🇱 https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids lang     conversation_id  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]   pl 1846091776269963776
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]   pl 1846222583898784000
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]   pl 1846161400328028160
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]   pl 1846091824101769472
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  qme 1846075343188144128
#
#                                             entities possibly_sensitive  \
# 0  {'mentions': [{'start': 0, 'end': 11, 'usernam...              False
# 1  {'urls': [{'start': 100, 'end': 123, 'url': 'h...              False
# 2  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 4  {'hashtags': [{'start': 0, 'end': 6, 'tag': 'I...              False
#
#    category                                 attachments  geo  \
# 0     Reply                                         NaN  NaN
# 1  Original  {'media_keys': ['13_1846222491456282626']}  NaN
# 2  Original   {'media_keys': ['3_1846148786910810112']}  NaN
# 3  Original   {'media_keys': ['3_1846091818959597568']}  NaN
# 4  Original  {'media_keys': ['13_1846075276687478784']}  NaN
#
#                                     username         party
# 0  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 2  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 3  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 4  bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja

# %%
# Get the value counts of the 'category' column
category_counts = df['category'].value_counts()

# Display the counts
print(category_counts)

# Get the number of unique categories
unique_category_count = category_counts.count()
print(f"Number of unique categories: {unique_category_count}")
# Out:
# category
# Original    32794
# Reply       10790
# Quote        5478
# Retweet      3480
# Name: count, dtype: int64
# Number of unique categories: 4

# %% [markdown]
# We need to delete retweets because they are wrongly provided by the X API. We want to analyze only original tweets, replies, and quotes.

# %%
df = df[df['category'] != 'Retweet']

# %%
df
# Out:
#                                           public_metrics  in_reply_to_user_id  \
# 0      {'retweet_count': 3, 'reply_count': 1, 'like_c...            375146901
# 1      {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2      {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3      {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4      {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
# ...                                                  ...                  ...
# 52753  {'retweet_count': 9, 'reply_count': 0, 'like_c...                  NaN
# 52774  {'retweet_count': 9, 'reply_count': 0, 'like_c...                  NaN
# 52777  {'retweet_count': 8, 'reply_count': 0, 'like_c...                  NaN
# 52778  {'retweet_count': 8, 'reply_count': 0, 'like_c...                  NaN
# 52779  {'retweet_count': 11, 'reply_count': 2, 'like_...                  NaN
#
#       reply_settings  author_id  \
# 0           everyone 1182211615
# 1           everyone 1182211615
# 2           everyone 1182211615
# 3           everyone 1182211615
# 4           everyone 1182211615
# ...              ...        ...
# 52753       everyone  961181894
# 52774       everyone  961181894
# 52777       everyone  961181894
# 52778       everyone  961181894
# 52779       everyone  961181894
#
#                                      context_annotations                   id  \
# 0      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                    NaN  1846161400328028160
# 3                                                    NaN  1846091824101769472
# 4                                                    NaN  1846075343188144128
# ...                                                  ...                  ...
# 52753                                                NaN  1707719554355380480
# 52774                                                NaN  1704120323023454464
# 52777                                                NaN  1702668459576786944
# 52778                                                NaN  1701960909369868544
# 52779                                                NaN  1701606379709198336
#
#                                                     text  \
# 0      @donaldtusk Niezrealizowanie większości ze "10...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2      ❌Mamy rok po wyborach, a Polska pogrąża się w ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                      #Idę11 🇵🇱 https://t.co/KiCe5ATOpX
# ...                                                  ...
# 52753  Studiujesz na kierunku lekarskim, pielęgniarst...
# 52774  Za nami posiedzenie @SejmikMaz. I kolejne wspa...
# 52777  Płockie Centrum Onkologii gotowe! Już na począ...
# 52778  To jedna z największych inwestycji drogowych @...
# 52779  Powiaty mają 25 lat❗️Na @Zamek_Krolewski odbył...
#
#                                            edit_controls  \
# 0      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 52753  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52774  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52777  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52778  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52779  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 0      [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52753                                                NaN
# 52774                                                NaN
# 52777                                                NaN
# 52778                                                NaN
# 52779                                                NaN
#
#                      created_at edit_history_tweet_ids lang  \
# 0     2024-10-15 19:49:34+00:00  [1846277256509116623]   pl
# 1     2024-10-15 16:12:19+00:00  [1846222583898784025]   pl
# 2     2024-10-15 12:09:12+00:00  [1846161400328028272]   pl
# 3     2024-10-15 07:32:44+00:00  [1846091824101769490]   pl
# 4     2024-10-15 06:27:14+00:00  [1846075343188144153]  qme
# ...                         ...                    ...  ...
# 52753 2023-09-29 11:30:44+00:00  [1707719554355380484]   pl
# 52774 2023-09-19 13:08:40+00:00  [1704120323023454339]   pl
# 52777 2023-09-15 12:59:29+00:00  [1702668459576787064]   pl
# 52778 2023-09-13 14:07:56+00:00  [1701960909369868437]   pl
# 52779 2023-09-12 14:39:09+00:00  [1701606379709198357]   pl
#
#           conversation_id                                           entities  \
# 0     1846091776269963776  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 1     1846222583898784000  {'urls': [{'start': 100, 'end': 123, 'url': 'h...
# 2     1846161400328028160  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 3     1846091824101769472  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4     1846075343188144128  {'hashtags': [{'start': 0, 'end': 6, 'tag': 'I...
# ...                   ...                                                ...
# 52753 1707719554355380480  {'mentions': [{'start': 132, 'end': 142, 'user...
# 52774 1704120323023454464  {'mentions': [{'start': 20, 'end': 30, 'userna...
# 52777 1702668459576786944  {'mentions': [{'start': 210, 'end': 220, 'user...
# 52778 1701960909369868544  {'mentions': [{'start': 45, 'end': 55, 'userna...
# 52779 1701606379709198336  {'mentions': [{'start': 24, 'end': 40, 'userna...
#
#       possibly_sensitive  category  \
# 0                  False     Reply
# 1                  False  Original
# 2                  False  Original
# 3                  False  Original
# 4                  False  Original
# ...                  ...       ...
# 52753                  0  Original
# 52774                  0  Original
# 52777                  0  Original
# 52778                  0  Original
# 52779                  0  Original
#
#                                              attachments  geo  \
# 0                                                    NaN  NaN
# 1             {'media_keys': ['13_1846222491456282626']}  NaN
# 2              {'media_keys': ['3_1846148786910810112']}  NaN
# 3              {'media_keys': ['3_1846091818959597568']}  NaN
# 4             {'media_keys': ['13_1846075276687478784']}  NaN
# ...                                                  ...  ...
# 52753          {'media_keys': ['3_1707719240550166528']}  NaN
# 52774          {'media_keys': ['3_1704118556785254400']}  NaN
# 52777          {'media_keys': ['3_1702668263241498624']}  NaN
# 52778  {'media_keys': ['3_1701960742109429762', '3_17...  NaN
# 52779  {'media_keys': ['3_1701605331858788352', '3_17...  NaN
#
#                                         username         party
# 0      bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1      bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 2      bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 3      bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 4      bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# ...                                          ...           ...
# 52753     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52774     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52777     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52778     StruzikAdam_2022-10-16_2023-10-15.json           PSL
# 52779     StruzikAdam_2022-10-16_2023-10-15.json           PSL
#
# [49062 rows x 20 columns]

# %%
# Update the 'username' column to keep only the string until '_2' -> split to date range

#df['username'] = df['username'].str.split('_2').str[0].copy()
df.loc[:, 'username'] = df['username'].str.split('_2').str[0]

# %%
category_summary = df['category'].value_counts()
print(category_summary)
total_tweets = category_summary.sum()
print(f"Total tweets: {total_tweets}")
# Out:
# category
# Original    32794
# Reply       10790
# Quote        5478
# Name: count, dtype: int64
# Total tweets: 49062

# %%
# Ensure the created_at column is in datetime format

#df['created_at'] = pd.to_datetime(df['created_at'])
df.loc[:, 'created_at'] = pd.to_datetime(df['created_at'])

# %%
df.head()
# Out:
#                                       public_metrics  in_reply_to_user_id  \
# 0  {'retweet_count': 3, 'reply_count': 1, 'like_c...            375146901
# 1  {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2  {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3  {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4  {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
#
#   reply_settings  author_id  \
# 0       everyone 1182211615
# 1       everyone 1182211615
# 2       everyone 1182211615
# 3       everyone 1182211615
# 4       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  ❌Mamy rok po wyborach, a Polska pogrąża się w ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11 🇵🇱 https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids lang     conversation_id  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]   pl 1846091776269963776
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]   pl 1846222583898784000
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]   pl 1846161400328028160
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]   pl 1846091824101769472
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  qme 1846075343188144128
#
#                                             entities possibly_sensitive  \
# 0  {'mentions': [{'start': 0, 'end': 11, 'usernam...              False
# 1  {'urls': [{'start': 100, 'end': 123, 'url': 'h...              False
# 2  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...              False
# 4  {'hashtags': [{'start': 0, 'end': 6, 'tag': 'I...              False
#
#    category                                 attachments  geo        username  \
# 0     Reply                                         NaN  NaN  bartlomiejpejo
# 1  Original  {'media_keys': ['13_1846222491456282626']}  NaN  bartlomiejpejo
# 2  Original   {'media_keys': ['3_1846148786910810112']}  NaN  bartlomiejpejo
# 3  Original   {'media_keys': ['3_1846091818959597568']}  NaN  bartlomiejpejo
# 4  Original  {'media_keys': ['13_1846075276687478784']}  NaN  bartlomiejpejo
#
#           party
# 0  Konfederacja
# 1  Konfederacja
# 2  Konfederacja
# 3  Konfederacja
# 4  Konfederacja

# %%
df.loc[1, 'text']
# Out:
# 'Rok po wyborach trzeba powiedzieć jedno - nie na takie państwo Donald Tusk umawiał się z wyborcami! https://t.co/4Jh5Ni6sgr'

# %% [markdown]
# Emojis handler

# %%
def add_space_around_emojis(text):
    return ''.join(f' {char} ' if char in emoji.EMOJI_DATA or re.match(r'[\U0001F1E6-\U0001F1FF]', char) else char for char in text)

df['text'] = df['text'].apply(add_space_around_emojis)

def clean_text(text):
    mentions = re.findall(r'@\w+', text)
    text = re.sub(r'@\w+', '', text)
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)
    hashtags = re.findall(r'#\w+', text)
    text = re.sub(r'(?<!\s)([\U0001F600-\U0001F64F])', r' \1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F])(?!\s)', r'\1 ', text)
    return [text, mentions, links, hashtags]

df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# Out:
# C:\Users\CarpeDiem\AppData\Local\Temp\ipykernel_13992\331721625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(add_space_around_emojis)
# C:\Users\CarpeDiem\AppData\Local\Temp\ipykernel_13992\331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# C:\Users\CarpeDiem\AppData\Local\Temp\ipykernel_13992\331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# C:\Users\CarpeDiem\AppData\Local\Temp\ipykernel_13992\331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# C:\Users\CarpeDiem\AppData\Local\Temp\ipykernel_13992\331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # Turn off the warning from lack of loc

# %%
df.head()
# Out:
#                                       public_metrics  in_reply_to_user_id  \
# 0  {'retweet_count': 3, 'reply_count': 1, 'like_c...            375146901
# 1  {'retweet_count': 9, 'reply_count': 2, 'like_c...                  NaN
# 2  {'retweet_count': 4, 'reply_count': 3, 'like_c...                  NaN
# 3  {'retweet_count': 6, 'reply_count': 2, 'like_c...                  NaN
# 4  {'retweet_count': 45, 'reply_count': 18, 'like...                  NaN
#
#   reply_settings  author_id  \
# 0       everyone 1182211615
# 1       everyone 1182211615
# 2       everyone 1182211615
# 3       everyone 1182211615
# 4       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4              #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at  ... possibly_sensitive  category  \
# 0 2024-10-15 19:49:34+00:00  ...              False     Reply
# 1 2024-10-15 16:12:19+00:00  ...              False  Original
# 2 2024-10-15 12:09:12+00:00  ...              False  Original
# 3 2024-10-15 07:32:44+00:00  ...              False  Original
# 4 2024-10-15 06:27:14+00:00  ...              False  Original
#
#                                   attachments  geo        username  \
# 0                                         NaN  NaN  bartlomiejpejo
# 1  {'media_keys': ['13_1846222491456282626']}  NaN  bartlomiejpejo
# 2   {'media_keys': ['3_1846148786910810112']}  NaN  bartlomiejpejo
# 3   {'media_keys': ['3_1846091818959597568']}  NaN  bartlomiejpejo
# 4  {'media_keys': ['13_1846075276687478784']}  NaN  bartlomiejpejo
#
#           party                                         text_clean  \
# 0  Konfederacja   Niezrealizowanie większości ze "100 konkretów...
# 1  Konfederacja  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2  Konfederacja   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Konfederacja  Mija rok od wyborów parlamentarnych. W kampani...
# 4  Konfederacja                                     #Idę11  🇵  🇱
#
#         mentions                                              links  hashtags
# 0  [@donaldtusk]                                                 []        []
# 1             []                          [https://t.co/4Jh5Ni6sgr]        []
# 2             []  [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...        []
# 3             []  [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...        []
# 4             []                          [https://t.co/KiCe5ATOpX]  [#Idę11]
#
# [5 rows x 24 columns]

# %%
df.drop(columns=['entities'], inplace=True)

# %%
# Some additioanl numerical data from tweets is extracted and added to the dataframe as new variables, then the original column is dropped
df['retweet_count'] = df['public_metrics'].apply(lambda x: x['retweet_count'])
df['reply_count'] = df['public_metrics'].apply(lambda x: x['reply_count'])
df['like_count'] = df['public_metrics'].apply(lambda x: x['like_count'])
df['quote_count'] = df['public_metrics'].apply(lambda x: x['quote_count'])
df['impression_count'] = df['public_metrics'].apply(lambda x: x['impression_count'])

df.drop(columns=['public_metrics'], inplace=True)

# %%
df
# Out:
#        in_reply_to_user_id reply_settings  author_id  \
# 0                375146901       everyone 1182211615
# 1                      NaN       everyone 1182211615
# 2                      NaN       everyone 1182211615
# 3                      NaN       everyone 1182211615
# 4                      NaN       everyone 1182211615
# ...                    ...            ...        ...
# 52753                  NaN       everyone  961181894
# 52774                  NaN       everyone  961181894
# 52777                  NaN       everyone  961181894
# 52778                  NaN       everyone  961181894
# 52779                  NaN       everyone  961181894
#
#                                      context_annotations                   id  \
# 0      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                    NaN  1846161400328028160
# 3                                                    NaN  1846091824101769472
# 4                                                    NaN  1846075343188144128
# ...                                                  ...                  ...
# 52753                                                NaN  1707719554355380480
# 52774                                                NaN  1704120323023454464
# 52777                                                NaN  1702668459576786944
# 52778                                                NaN  1701960909369868544
# 52779                                                NaN  1701606379709198336
#
#                                                     text  \
# 0      @donaldtusk Niezrealizowanie większości ze "10...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                                                  ...
# 52753  Studiujesz na kierunku lekarskim, pielęgniarst...
# 52774  Za nami posiedzenie @SejmikMaz. I kolejne wspa...
# 52777  Płockie Centrum Onkologii gotowe! Już na począ...
# 52778  To jedna z największych inwestycji drogowych @...
# 52779  Powiaty mają 25 lat ❗ ️Na @Zamek_Krolewski odb...
#
#                                            edit_controls  \
# 0      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 52753  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52774  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52777  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52778  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52779  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 0      [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52753                                                NaN
# 52774                                                NaN
# 52777                                                NaN
# 52778                                                NaN
# 52779                                                NaN
#
#                      created_at edit_history_tweet_ids  ...         party  \
# 0     2024-10-15 19:49:34+00:00  [1846277256509116623]  ...  Konfederacja
# 1     2024-10-15 16:12:19+00:00  [1846222583898784025]  ...  Konfederacja
# 2     2024-10-15 12:09:12+00:00  [1846161400328028272]  ...  Konfederacja
# 3     2024-10-15 07:32:44+00:00  [1846091824101769490]  ...  Konfederacja
# 4     2024-10-15 06:27:14+00:00  [1846075343188144153]  ...  Konfederacja
# ...                         ...                    ...  ...           ...
# 52753 2023-09-29 11:30:44+00:00  [1707719554355380484]  ...           PSL
# 52774 2023-09-19 13:08:40+00:00  [1704120323023454339]  ...           PSL
# 52777 2023-09-15 12:59:29+00:00  [1702668459576787064]  ...           PSL
# 52778 2023-09-13 14:07:56+00:00  [1701960909369868437]  ...           PSL
# 52779 2023-09-12 14:39:09+00:00  [1701606379709198357]  ...           PSL
#
#                                               text_clean            mentions  \
# 0       Niezrealizowanie większości ze "100 konkretów...       [@donaldtusk]
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...                  []
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...                  []
# 3      Mija rok od wyborów parlamentarnych. W kampani...                  []
# 4                                         #Idę11  🇵  🇱                    []
# ...                                                  ...                 ...
# 52753  Studiujesz na kierunku lekarskim, pielęgniarst...        [@SejmikMaz]
# 52774  Za nami posiedzenie . I kolejne wsparcie dla m...        [@SejmikMaz]
# 52777  Płockie Centrum Onkologii gotowe! Już na począ...        [@SejmikMaz]
# 52778  To jedna z największych inwestycji drogowych  ...        [@SejmikMaz]
# 52779  Powiaty mają 25 lat ❗ ️Na  odbyło się dziś jub...  [@Zamek_Krolewski]
#
#                                                    links  hashtags  \
# 0                                                     []        []
# 1                              [https://t.co/4Jh5Ni6sgr]        []
# 2      [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...        []
# 3      [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...        []
# 4                              [https://t.co/KiCe5ATOpX]  [#Idę11]
# ...                                                  ...       ...
# 52753                          [https://t.co/6zats7JXbY]        []
# 52774                          [https://t.co/A7EG9Jzuv1]    [#OSP]
# 52777                          [https://t.co/OALgj7gqxE]        []
# 52778                          [https://t.co/9jWRcVZHXk]    [#634]
# 52779                          [https://t.co/iEAFy9AI2R]        []
#
#       retweet_count reply_count like_count quote_count impression_count
# 0                 3           1         33           0             1555
# 1                 9           2         72           0             3031
# 2                 4           3         33           2             8636
# 3                 6           2         38           0             2441
# 4                45          18        616           2             8634
# ...             ...         ...        ...         ...              ...
# 52753             9           0          6           0             2154
# 52774             9           0         15           0              649
# 52777             8           0         16           0              581
# 52778             8           0         13           0              621
# 52779            11           2         16           0             2444
#
# [49062 rows x 27 columns]

# %%
df.dtypes
# Out:
# in_reply_to_user_id                   float64
# reply_settings                         object
# author_id                             float64
# context_annotations                    object
# id                                     object
# text                                   object
# edit_controls                          object
# referenced_tweets                      object
# created_at                datetime64[ns, UTC]
# edit_history_tweet_ids                 object
# lang                                   object
# conversation_id                       float64
# possibly_sensitive                     object
# category                               object
# attachments                            object
# geo                                    object
# username                               object
# party                                  object
# text_clean                             object
# mentions                               object
# links                                  object
# hashtags                               object
# retweet_count                           int64
# reply_count                             int64
# like_count                              int64
# quote_count                             int64
# impression_count                        int64
# dtype: object

# %%
df.head()
# Out:
#    in_reply_to_user_id reply_settings  author_id  \
# 0            375146901       everyone 1182211615
# 1                  NaN       everyone 1182211615
# 2                  NaN       everyone 1182211615
# 3                  NaN       everyone 1182211615
# 4                  NaN       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4              #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids  ...         party  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]  ...  Konfederacja
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]  ...  Konfederacja
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]  ...  Konfederacja
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]  ...  Konfederacja
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  ...  Konfederacja
#
#                                           text_clean       mentions  \
# 0   Niezrealizowanie większości ze "100 konkretów...  [@donaldtusk]
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...             []
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...             []
# 3  Mija rok od wyborów parlamentarnych. W kampani...             []
# 4                                     #Idę11  🇵  🇱               []
#
#                                                links  hashtags retweet_count  \
# 0                                                 []        []             3
# 1                          [https://t.co/4Jh5Ni6sgr]        []             9
# 2  [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...        []             4
# 3  [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...        []             6
# 4                          [https://t.co/KiCe5ATOpX]  [#Idę11]            45
#
#   reply_count like_count quote_count impression_count
# 0           1         33           0             1555
# 1           2         72           0             3031
# 2           3         33           2             8636
# 3           2         38           0             2441
# 4          18        616           2             8634
#
# [5 rows x 27 columns]

# %%
df.dtypes
# Out:
# in_reply_to_user_id                   float64
# reply_settings                         object
# author_id                             float64
# context_annotations                    object
# id                                     object
# text                                   object
# edit_controls                          object
# referenced_tweets                      object
# created_at                datetime64[ns, UTC]
# edit_history_tweet_ids                 object
# lang                                   object
# conversation_id                       float64
# possibly_sensitive                     object
# category                               object
# attachments                            object
# geo                                    object
# username                               object
# party                                  object
# text_clean                             object
# mentions                               object
# links                                  object
# hashtags                               object
# retweet_count                           int64
# reply_count                             int64
# like_count                              int64
# quote_count                             int64
# impression_count                        int64
# dtype: object

# %%
import pandas as pd

# Step 1: Check for duplicate columns and remove them
if df.columns.duplicated().any():
    print("Duplicate columns found! Removing them...")
    df_no_duplicates = df.loc[:, ~df.columns.duplicated()]  # Keep the first occurrence of each column
else:
    df_no_duplicates = df.copy()

# Step 2: Convert 'id' column to string (if needed)
df_no_duplicates['id'] = df_no_duplicates['id'].astype(str)

# Step 3: Check for missing or empty values in 'text' and 'text_clean'
empty_text = df_no_duplicates[df_no_duplicates['text'].isna() | (df_no_duplicates['text'].astype(str).str.strip() == '')]
empty_text_clean = df_no_duplicates[df_no_duplicates['text_clean'].isna() | (df_no_duplicates['text_clean'].astype(str).str.strip() == '')]

print(f"Rows where 'text' is empty or null: {empty_text.shape[0]}")
print(empty_text[['id', 'text', 'text_clean']].head())

print(f"\nRows where 'text_clean' is empty or null: {empty_text_clean.shape[0]}")
empty_text_clean[['id', 'text', 'text_clean']].head()
# Out:
# Rows where 'text' is empty or null: 0
# Empty DataFrame
# Columns: [id, text, text_clean]
# Index: []
#
# Rows where 'text_clean' is empty or null: 731
#                       id                                               text  \
# 16   1844711276577964544                     @Nowa_Nadzieja_ @KONFEDERACJA_
# 92   1838621761090285568                     @KONFEDERACJA_ @Nowa_Nadzieja_
# 254  1821520992629305600                            https://t.co/H9BQbYjylo
# 595  1768213892272959744  @MPerspektywa @AdamAbramowicz1 https://t.co/bz...
# 786  1733398115917402624                            https://t.co/uXKjbwD1DQ
#
#     text_clean
# 16
# 92
# 254
# 595
# 786

# %%
false_count = (df['text_clean'].str.strip().astype(bool))
print(f"Number of False values: {false_count}")
# Out:
# Number of False values: 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 52753    True
# 52774    True
# 52777    True
# 52778    True
# 52779    True
# Name: text_clean, Length: 49062, dtype: bool

# %%
#Delete empty tweets
df = df[false_count]

# %%
len(df)
# Out:
# 48331

# %% [markdown]
# saving data used for translation

# %%
df_clean_text = df[['id', 'text', 'text_clean']]

df_clean_text.to_csv('data/02.processed/data_for_translation.csv', index=False)
df.to_csv('data/02.processed/whole_dataset_for_translation.csv', index=False)

# %%
len(df)
# Out:
# 48331

# %%
df_clean_text.dtypes
# Out:
# id            object
# text          object
# text_clean    object
# dtype: object

# %% [markdown]
# reading data used for translation

# %%
# Read CSV with ID column as string (text)
df_clean_text = pd.read_csv('Data/02.processed/data_for_translation.csv', dtype={'id': str})

# Verify the column type
print("ID column type:", df_clean_text['id'].dtype)
print("Sample ID:", df_clean_text['id'].iloc[0], "of type", type(df_clean_text['id'].iloc[0]))
# Out:
# ID column type: object
# Sample ID: 1846277256509116672 of type <class 'str'>

# %%
df_clean_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48331 entries, 0 to 48330
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          48331 non-null  object
#  1   text        48331 non-null  object
#  2   text_clean  48331 non-null  object
# dtypes: object(3)
# memory usage: 1.1+ MB

# %%
df_clean_text
# Out:
#                         id                                               text  \
# 0      1846277256509116672  @donaldtusk Niezrealizowanie większości ze "10...
# 1      1846222583898784000  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2      1846161400328028160   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      1846091824101769472  Mija rok od wyborów parlamentarnych. W kampani...
# 4      1846075343188144128              #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                    ...                                                ...
# 48326  1707719554355380480  Studiujesz na kierunku lekarskim, pielęgniarst...
# 48327  1704120323023454464  Za nami posiedzenie @SejmikMaz. I kolejne wspa...
# 48328  1702668459576786944  Płockie Centrum Onkologii gotowe! Już na począ...
# 48329  1701960909369868544  To jedna z największych inwestycji drogowych @...
# 48330  1701606379709198336  Powiaty mają 25 lat ❗ ️Na @Zamek_Krolewski odb...
#
#                                               text_clean
# 0       Niezrealizowanie większości ze "100 konkretów...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                                         #Idę11  🇵  🇱
# ...                                                  ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...
# 48327  Za nami posiedzenie . I kolejne wsparcie dla m...
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...
# 48329  To jedna z największych inwestycji drogowych  ...
# 48330  Powiaty mają 25 lat ❗ ️Na  odbyło się dziś jub...
#
# [48331 rows x 3 columns]

# %%
# Filter rows where 'text_clean' is null OR empty (after stripping whitespace)
null_or_empty_text_clean = df_clean_text[
    df_clean_text['text_clean'].isna() | 
    (df_clean_text['text_clean'].astype(str).str.strip() == '')
]

# Display the number of problematic rows
print(f"Rows where 'text_clean' is null or empty: {null_or_empty_text_clean.shape[0]}")

# Show the affected rows
null_or_empty_text_clean[['id', 'text', 'text_clean']]
# Out:
# Rows where 'text_clean' is null or empty: 0
# Empty DataFrame
# Columns: [id, text, text_clean]
# Index: []

# %%
# 1. Print the total number of rows in df_clean_text
print("Total rows in df_clean_text:", len(df_clean_text))

# 2. Filter out rows where 'text_clean' is null or an empty string (after stripping whitespace)
valid_rows = df_clean_text[
    ~(
        df_clean_text['text_clean'].isna() 
        | (df_clean_text['text_clean'].astype(str).str.strip() == '')
    )
]

# 3. Print the number of those valid (non-empty) rows
print("Rows with non-empty 'text_clean':", len(valid_rows))
# Out:
# Total rows in df_clean_text: 48331
# Rows with non-empty 'text_clean': 48331

# %% [markdown]
# reading translation dataset

# %%
df_en_text = pd.read_excel('data/02.processed/tweets_translation/translated_tweets.xlsx', dtype={'id': str})
df_en_text
# Out:
#                         id                                               text  \
# 0      1846277256509116672  @donaldtusk Niezrealizowanie większości ze "10...
# 1      1846222583898784000  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2      1846161400328028160   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      1846091824101769472  Mija rok od wyborów parlamentarnych. W kampani...
# 4      1846075343188144128              #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                    ...                                                ...
# 48326  1707719554355380480  Studiujesz na kierunku lekarskim, pielęgniarst...
# 48327  1704120323023454464  Za nami posiedzenie @SejmikMaz. I kolejne wspa...
# 48328  1702668459576786944  Płockie Centrum Onkologii gotowe! Już na począ...
# 48329  1701960909369868544  To jedna z największych inwestycji drogowych @...
# 48330  1701606379709198336  Powiaty mają 25 lat ❗ ️Na @Zamek_Krolewski odb...
#
#                                               text_clean  \
# 0       Niezrealizowanie większości ze "100 konkretów...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                                           #Idę11  🇵  🇱
# ...                                                  ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...
# 48327  Za nami posiedzenie . I kolejne wsparcie dla m...
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...
# 48329  To jedna z największych inwestycji drogowych  ...
# 48330  Powiaty mają 25 lat ❗ ️Na  odbyło się dziś jub...
#
#                                            text_clean_en
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       ❌ We are a year after the elections, and Pola...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 48326  Are you studying medicine, nursing or emergenc...
# 48327  The meeting is over. And further support for t...
# 48328  The Płock Oncology Center is ready! It will ac...
# 48329  This is one of the largest road investments  \...
# 48330  The counties are 25 years old ❗ ️The anniversa...
#
# [48331 rows x 4 columns]

# %%
missing_translation_mask = df_en_text['text_clean_en'].isna() | (df_en_text['text_clean_en'].str.strip() == '')
df_en_text[missing_translation_mask]
# Out:
# Empty DataFrame
# Columns: [id, text, text_clean, text_clean_en]
# Index: []

# %% [markdown]
# merging second version of translated dataset with original one

# %%
# Step 1: Make sure IDs are strings
df['id'] = df['id'].astype(str)
df_en_text['id'] = df_en_text['id'].astype(str)

df_en_combined = pd.concat([df_en_text], ignore_index=True)

# Step 3: Drop duplicates by 'id' to keep only the latest 
df_en_combined = df_en_combined.drop_duplicates(subset='id', keep='last')

# Step 4: Merge back into the full dataset to get a unified view
df_merged = df.merge(df_en_text[['id', 'text_clean_en']], on='id')

print(f"Total rows after merge: {len(df_merged)} ")
# Out:
# Total rows after merge: 48331

# %%
# Find the IDs present in df but not in df_merged
missing_ids = df[~df['id'].isin(df_merged['id'])]['id']

# Display the missing rows
missing_rows = df[df['id'].isin(missing_ids)]
print(missing_rows)
# Out:
# Empty DataFrame
# Columns: [in_reply_to_user_id, reply_settings, author_id, context_annotations, id, text, edit_controls, referenced_tweets, created_at, edit_history_tweet_ids, lang, conversation_id, possibly_sensitive, category, attachments, geo, username, party, text_clean, mentions, links, hashtags, retweet_count, reply_count, like_count, quote_count, impression_count]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_merged
# Out:
#        in_reply_to_user_id reply_settings  author_id  \
# 0                375146901       everyone 1182211615
# 1                      NaN       everyone 1182211615
# 2                      NaN       everyone 1182211615
# 3                      NaN       everyone 1182211615
# 4                      NaN       everyone 1182211615
# ...                    ...            ...        ...
# 48326                  NaN       everyone  961181894
# 48327                  NaN       everyone  961181894
# 48328                  NaN       everyone  961181894
# 48329                  NaN       everyone  961181894
# 48330                  NaN       everyone  961181894
#
#                                      context_annotations                   id  \
# 0      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                    NaN  1846161400328028160
# 3                                                    NaN  1846091824101769472
# 4                                                    NaN  1846075343188144128
# ...                                                  ...                  ...
# 48326                                                NaN  1707719554355380480
# 48327                                                NaN  1704120323023454464
# 48328                                                NaN  1702668459576786944
# 48329                                                NaN  1701960909369868544
# 48330                                                NaN  1701606379709198336
#
#                                                     text  \
# 0      @donaldtusk Niezrealizowanie większości ze "10...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                                                  ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...
# 48327  Za nami posiedzenie @SejmikMaz. I kolejne wspa...
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...
# 48329  To jedna z największych inwestycji drogowych @...
# 48330  Powiaty mają 25 lat ❗ ️Na @Zamek_Krolewski odb...
#
#                                            edit_controls  \
# 0      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 48326  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48327  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48328  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48329  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48330  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 0      [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 48326                                                NaN
# 48327                                                NaN
# 48328                                                NaN
# 48329                                                NaN
# 48330                                                NaN
#
#                      created_at edit_history_tweet_ids  ...  \
# 0     2024-10-15 19:49:34+00:00  [1846277256509116623]  ...
# 1     2024-10-15 16:12:19+00:00  [1846222583898784025]  ...
# 2     2024-10-15 12:09:12+00:00  [1846161400328028272]  ...
# 3     2024-10-15 07:32:44+00:00  [1846091824101769490]  ...
# 4     2024-10-15 06:27:14+00:00  [1846075343188144153]  ...
# ...                         ...                    ...  ...
# 48326 2023-09-29 11:30:44+00:00  [1707719554355380484]  ...
# 48327 2023-09-19 13:08:40+00:00  [1704120323023454339]  ...
# 48328 2023-09-15 12:59:29+00:00  [1702668459576787064]  ...
# 48329 2023-09-13 14:07:56+00:00  [1701960909369868437]  ...
# 48330 2023-09-12 14:39:09+00:00  [1701606379709198357]  ...
#
#                                               text_clean            mentions  \
# 0       Niezrealizowanie większości ze "100 konkretów...       [@donaldtusk]
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...                  []
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...                  []
# 3      Mija rok od wyborów parlamentarnych. W kampani...                  []
# 4                                         #Idę11  🇵  🇱                    []
# ...                                                  ...                 ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...        [@SejmikMaz]
# 48327  Za nami posiedzenie . I kolejne wsparcie dla m...        [@SejmikMaz]
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...        [@SejmikMaz]
# 48329  To jedna z największych inwestycji drogowych  ...        [@SejmikMaz]
# 48330  Powiaty mają 25 lat ❗ ️Na  odbyło się dziś jub...  [@Zamek_Krolewski]
#
#                                                    links  hashtags  \
# 0                                                     []        []
# 1                              [https://t.co/4Jh5Ni6sgr]        []
# 2      [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...        []
# 3      [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...        []
# 4                              [https://t.co/KiCe5ATOpX]  [#Idę11]
# ...                                                  ...       ...
# 48326                          [https://t.co/6zats7JXbY]        []
# 48327                          [https://t.co/A7EG9Jzuv1]    [#OSP]
# 48328                          [https://t.co/OALgj7gqxE]        []
# 48329                          [https://t.co/9jWRcVZHXk]    [#634]
# 48330                          [https://t.co/iEAFy9AI2R]        []
#
#       retweet_count reply_count like_count quote_count impression_count  \
# 0                 3           1         33           0             1555
# 1                 9           2         72           0             3031
# 2                 4           3         33           2             8636
# 3                 6           2         38           0             2441
# 4                45          18        616           2             8634
# ...             ...         ...        ...         ...              ...
# 48326             9           0          6           0             2154
# 48327             9           0         15           0              649
# 48328             8           0         16           0              581
# 48329             8           0         13           0              621
# 48330            11           2         16           0             2444
#
#                                            text_clean_en
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       ❌ We are a year after the elections, and Pola...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 48326  Are you studying medicine, nursing or emergenc...
# 48327  The meeting is over. And further support for t...
# 48328  The Płock Oncology Center is ready! It will ac...
# 48329  This is one of the largest road investments  \...
# 48330  The counties are 25 years old ❗ ️The anniversa...
#
# [48331 rows x 28 columns]

# %% [markdown]
# check wether the data went correctly

# %%
df_merged[df_merged["id"]=="1807795860480160000"]
# Out:
#      in_reply_to_user_id reply_settings  author_id context_annotations  \
# 407                  NaN       everyone 1182211615                 NaN
#
#                       id                                               text  \
# 407  1807795860480160000   🇳  🇱  Holenderski klub NAC Breda przygotował ...
#
#                                          edit_controls referenced_tweets  \
# 407  {'edits_remaining': 5, 'is_edit_eligible': Tru...               NaN
#
#                    created_at edit_history_tweet_ids  ...  \
# 407 2024-07-01 15:18:15+00:00  [1807795860480159980]  ...
#
#                                             text_clean  mentions  \
# 407   🇳  🇱  Holenderski klub NAC Breda przygotował ...        []
#
#                                                  links hashtags retweet_count  \
# 407  [https://t.co/WI736ocWQ7, https://t.co/ANX3x4e...       []             5
#
#     reply_count like_count quote_count impression_count  \
# 407           1         24           0              603
#
#                                          text_clean_en
# 407   🇳 🇱 The Dutch club NAC Breda has prepared spe...
#
# [1 rows x 28 columns]

# %%
# Check how many rows still have missing or empty translations
missing_translation_mask = df_merged['text_clean_en'].isna() | (df_merged['text_clean_en'].str.strip() == '')

# Show some of them
df_missing_translation = df_merged[missing_translation_mask]
print(f"Rows without translation: {df_missing_translation.shape[0]}")
display(df_missing_translation[['id', 'text', 'text_clean', 'text_clean_en']].head())
# Out:
# Rows without translation: 0
# Empty DataFrame
# Columns: [id, text, text_clean, text_clean_en]
# Index: []

# %% [markdown]
# removing rows withtout translation due to possessing text that is not being analyzed by our research

# %%
# Remove them
df_clean_translated = df_merged[~missing_translation_mask].copy()

print(f"Remaining rows with proper translation: {df_clean_translated.shape[0]}")
# Out:
# Remaining rows with proper translation: 48331

# %%
df_clean_translated.head()
# Out:
#    in_reply_to_user_id reply_settings  author_id  \
# 0            375146901       everyone 1182211615
# 1                  NaN       everyone 1182211615
# 2                  NaN       everyone 1182211615
# 3                  NaN       everyone 1182211615
# 4                  NaN       everyone 1182211615
#
#                                  context_annotations                   id  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                NaN  1846161400328028160
# 3                                                NaN  1846091824101769472
# 4                                                NaN  1846075343188144128
#
#                                                 text  \
# 0  @donaldtusk Niezrealizowanie większości ze "10...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4              #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  created_at edit_history_tweet_ids  ...  \
# 0 2024-10-15 19:49:34+00:00  [1846277256509116623]  ...
# 1 2024-10-15 16:12:19+00:00  [1846222583898784025]  ...
# 2 2024-10-15 12:09:12+00:00  [1846161400328028272]  ...
# 3 2024-10-15 07:32:44+00:00  [1846091824101769490]  ...
# 4 2024-10-15 06:27:14+00:00  [1846075343188144153]  ...
#
#                                           text_clean       mentions  \
# 0   Niezrealizowanie większości ze "100 konkretów...  [@donaldtusk]
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...             []
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...             []
# 3  Mija rok od wyborów parlamentarnych. W kampani...             []
# 4                                     #Idę11  🇵  🇱               []
#
#                                                links  hashtags retweet_count  \
# 0                                                 []        []             3
# 1                          [https://t.co/4Jh5Ni6sgr]        []             9
# 2  [https://t.co/zFk5QLd1em, https://t.co/bRV4y07...        []             4
# 3  [https://t.co/rtVu3Bh43G, https://t.co/8Q3LME6...        []             6
# 4                          [https://t.co/KiCe5ATOpX]  [#Idę11]            45
#
#   reply_count like_count quote_count impression_count  \
# 0           1         33           0             1555
# 1           2         72           0             3031
# 2           3         33           2             8636
# 3           2         38           0             2441
# 4          18        616           2             8634
#
#                                        text_clean_en
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   ❌ We are a year after the elections, and Pola...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱
#
# [5 rows x 28 columns]

# %%
df_clean_translated.to_csv('data/02.processed/df_clean_translated_further_analalysis.csv', index=False)

# %%
def count_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols & pictographs
        "\U0001F680-\U0001F6FF"  # Transport & map symbols
        "\U0001F700-\U0001F77F"  # Alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric shapes
        "\U0001F800-\U0001F8FF"  # Supplemental arrows
        "\U0001F900-\U0001F9FF"  # Supplemental symbols and pictographs
        "\U0001FA00-\U0001FA6F"  # Chess symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and pictographs extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"  # Enclosed characters
        "]+",
        flags=re.UNICODE,
    )
    return len(emoji_pattern.findall(text))

# %%
# Demojize text columns
df_clean_translated['text_clean_en_demojized'] = df_clean_translated['text_clean_en'].apply(
    lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x
)
df_clean_translated['text_clean_demojized'] = df_clean_translated['text_clean'].apply(
    lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x
)

# Count emojis in original text columns
df_clean_translated['emoji_count_en'] = df_clean_translated['text_clean_en'].apply(
    lambda x: count_emojis(str(x)) if pd.notnull(x) else 0
)
df_clean_translated['emoji_count'] = df_clean_translated['text_clean'].apply(
    lambda x: count_emojis(str(x)) if pd.notnull(x) else 0
)

# %%
# Total number of rows
total_rows = len(df_clean_translated)

# Rows with emojis in 'text_clean_en'
rows_with_emojis_en = df_clean_translated[df_clean_translated['emoji_count_en'] > 0].shape[0]

# Rows with emojis in 'text_clean'
rows_with_emojis = df_clean_translated[df_clean_translated['emoji_count'] > 0].shape[0]

# Display statistics
print(f"Total number of rows: {total_rows}")
print(f"Rows with emojis in 'text_clean_en': {rows_with_emojis_en} ({(rows_with_emojis_en/total_rows)*100:.2f}%)")
print(f"Rows with emojis in 'text_clean': {rows_with_emojis} ({(rows_with_emojis/total_rows)*100:.2f}%)")
# Out:
# Total number of rows: 48331
# Rows with emojis in 'text_clean_en': 17994 (37.23%)
# Rows with emojis in 'text_clean': 18289 (37.84%)

# %%
df_clean_translated[['text_clean_en', 'text_clean_en_demojized', 'emoji_count_en', 'text_clean', 'text_clean_demojized', 'emoji_count']].head()
# Out:
#                                        text_clean_en  \
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   ❌ We are a year after the elections, and Pola...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱
#
#                              text_clean_en_demojized  emoji_count_en  \
# 0   Failure to implement most of the "100 specifi...               0
# 1  A year after the elections, one thing must be ...               0
# 2   :cross_mark: We are a year after the election...               1
# 3  A year has passed since the parliamentary elec...               0
# 4                                   #I'm going11 🇵 🇱               2
#
#                                           text_clean  \
# 0   Niezrealizowanie większości ze "100 konkretów...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                                     #Idę11  🇵  🇱
#
#                                 text_clean_demojized  emoji_count
# 0   Niezrealizowanie większości ze "100 konkretów...            0
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...            0
# 2   :cross_mark: Mamy rok po wyborach, a Polska p...            1
# 3  Mija rok od wyborów parlamentarnych. W kampani...            0
# 4                                     #Idę11  🇵  🇱              2

# %%
# Filter rows
rows_with_emojis_in_text_clean_only = df_clean_translated[
    (df_clean_translated['emoji_count'] > 0) & (df_clean_translated['emoji_count_en'] == 0)
]

# Display the number of such rows
print(f"Number of rows with emojis in 'text_clean' but not in 'text_clean_en': {len(rows_with_emojis_in_text_clean_only)}")

# Display the affected rows
rows_with_emojis_in_text_clean_only[['text_clean', 'text_clean_en']]
# Out:
# Number of rows with emojis in 'text_clean' but not in 'text_clean_en': 295
#                                               text_clean  \
# 453    Mamy Państwo z dykty, a Kosiniak-Kamysz natych...
# 589    Dyrektywa budynkowa przyjęta! Przymusowe remon...
# 686                     Gdzie tu sens, gdzie logika ⁉ ️
# 1251   Ostrzegaliśmy  👇   mądra PRZED a nie dopiero P...
# 1421   W niedzielę zapraszam do Opatowa. Nawet 2 razy...
# ...                                                  ...
# 45723           I 10 razy tyle, co na mieszkalnictwo  🙂
# 45917  Dziś, w Pałacu Prezydenckim odbyła się uroczys...
# 46705  Intensywny tydzień misji Komisji Budżetu PE w ...
# 46895  Dbanie o bezpieczeństwo żywnościowe i ochrona ...
# 47346               Może być  🙂  Dziękuję i ściskam dłoń
#
#                                            text_clean_en
# 453    We are out of business, and Kosiniak-Kamysz sh...
# 589    The Building Directive has been adopted! Compu...
# 686             Where is the sense, where is the logic?
# 1251   We warned you wisely BEFORE and not only AFTER...
# 1421   I invite you to Opatów on Sunday. Even twice :...
# ...                                                  ...
# 45723            And 10 times as much as for housing :)
# 45917  Today, the ceremony of awarding nominations to...
# 46705  An intense week of mission of the EP Budget Co...
# 46895  Taking care of food security and protecting th...
# 47346           Maybe :) Thank you and I shake your hand
#
# [295 rows x 2 columns]

# %%
df_clean_translated['text_clean_en_demojized'] = df_clean_translated['text_clean_en'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)
df_clean_translated['text_clean_demojized'] = df_clean_translated['text_clean'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)

df_clean_translated[['text_clean_en', 'text_clean_en_demojized', 'text_clean', 'text_clean_demojized']].head()
# Out:
#                                        text_clean_en  \
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   ❌ We are a year after the elections, and Pola...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱
#
#                              text_clean_en_demojized  \
# 0   Failure to implement most of the "100 specifi...
# 1  A year after the elections, one thing must be ...
# 2   :cross_mark: We are a year after the election...
# 3  A year has passed since the parliamentary elec...
# 4                                   #I'm going11 🇵 🇱
#
#                                           text_clean  \
# 0   Niezrealizowanie większości ze "100 konkretów...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                                     #Idę11  🇵  🇱
#
#                                 text_clean_demojized
# 0   Niezrealizowanie większości ze "100 konkretów...
# 1  Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2   :cross_mark: Mamy rok po wyborach, a Polska p...
# 3  Mija rok od wyborów parlamentarnych. W kampani...
# 4                                     #Idę11  🇵  🇱

# %%
df_clean_translated['possibly_sensitive'] = df_clean_translated['possibly_sensitive'].astype(bool)

# %%
username_to_realname = {
    'bartlomiejpejo': 'Bartłomiej Pejo',
    'GrzegorzBraun_': 'Grzegorz Braun',
    'Iwaszkiewicz_RJ': 'Robert Iwaszkiewicz',
    'KonradBerkowicz': 'Konrad Berkowicz',
    'MarSypniewski': 'Marek Sypniewski',
    'MichalWawer': 'Michał Wawer',
    'placzekgrzegorz': 'Grzegorz Płaczek',
    'SlawomirMentzen': 'Sławomir Mentzen',
    'TudujKrzysztof': 'Krzysztof Tuduj',
    'Wlodek_Skalik': 'Włodzimierz Skalik',
    'WTumanowicz': 'Witold Tumanowicz',
    'AndrzejSzejna': 'Andrzej Szejna',
    'AnitaKDZG': 'Anita Kucharska-Dziedzic',
    'JoankaSW': 'Joanna Scheuring-Wielgus',
    'KGawkowski': 'Krzysztof Gawkowski',
    'K_Smiszek': 'Krzysztof Śmiszek',
    'MarcinKulasek': 'Marcin Kulasek',
    'MoskwaWodnicka': 'Małgorzata Moskwa-Wodnicka',
    'PaulinaPW2024': 'Paulina Piechna-Więckiewicz',
    'poselTTrela': 'Tomasz Trela',
    'RobertBiedron': 'Robert Biedroń',
    'WandaNowicka': 'Wanda Nowicka',
    'wieczorekdarek': 'Dariusz Wieczorek',
    'wlodekczarzasty': 'Włodzimierz Czarzasty',
    'Arek_Iwaniak': 'Arkadiusz Iwaniak',
    'B_Maciejewska': 'Beata Maciejewska',
    'BeataSzydlo': 'Beata Szydło',
    'elzbietawitek': 'Elżbieta Witek',
    'Kaminski_M_': 'Mariusz Kamiński',
    'Kowalczyk_H': 'Henryk Kowalczyk',
    'Macierewicz_A': 'Antoni Macierewicz',
    'mblaszczak': 'Mariusz Błaszczak',
    'MorawieckiM': 'Mateusz Morawiecki',
    'mwojcik_': 'Michał Wójcik',
    'PatrykJaki': 'Patryk Jaki',
    'bbudka': 'Borys Budka',
    'CTomczyk': 'Cezary Tomczyk',
    'donaldtusk': 'Donald Tusk',
    'DorotaNiedziela': 'Dorota Niedziela',
    'EwaKopacz': 'Ewa Kopacz',
    'JanGrabiec': 'Jan Grabiec',
    'Konwinski_PO': 'Zbigniew Konwiński',
    'Leszczyna': 'Izabela Leszczyna',
    'MKierwinski': 'Marcin Kierwiński',
    'M_K_Blonska': 'Małgorzata Kidawa-Błońska',
    'OklaDrewnowicz': 'Agnieszka Okła-Drewnowicz',
    'trzaskowski_': 'Rafał Trzaskowski',
    'TomaszSiemoniak': 'Tomasz Siemoniak',
    'AgaBaranowskaPL': 'Agnieszka Baranowska',
    'aga_buczynska': 'Agnieszka Buczyńska',
    'hennigkloska': 'Paulina Hennig-Kloska',
    'joannamucha': 'Joanna Mucha',
    'Kpelczynska': 'Katarzyna Pelczyńska',
    'LukaszOsmalak': 'Łukasz Osmałek',
    'SlizPawel': 'Paweł Śliz',
    'szymon_holownia': 'Szymon Hołownia',
    'ZalewskiPawel': 'Paweł Zalewski',
    'ZywnoMaciej': 'Maciej Żywno',
    'JKozlowskiEu': 'Janusz Kozłowski',
    'michalkobosko': 'Michał Kobosko',
    'DariuszKlimczak': 'Dariusz Klimczak',
    'GrzybAndrzej': 'Andrzej Grzyb',
    'Hetman_K': 'Krzysztof Hetman',
    'JarubasAdam': 'Adam Jarubas',
    'KosiniakKamysz': 'Władysław Kosiniak-Kamysz',
    'Paslawska': 'Urszula Pasławska',
    'PZgorzelskiP': 'Piotr Zgorzelski',
    'StefanKrajewski': 'Stefan Krajewski',
    'StruzikAdam': 'Adam Struzik'
}

# Add the 'name' column to the dataframe
df_clean_translated['name'] = df_clean_translated['username'].map(username_to_realname)

# %%
# Delete next line sign from the 'text_clean_en' column
df_clean_translated['text_clean_en'] = df_clean_translated['text_clean_en'].str.replace('\n', ' ')

# %%
# Save the DataFrame to a Parquet file
df_clean_translated.to_parquet('data/03.cleaned/df_combined.parquet', index=False)

# %%
df_clean_translated
# Out:
#        in_reply_to_user_id reply_settings  author_id  \
# 0                375146901       everyone 1182211615
# 1                      NaN       everyone 1182211615
# 2                      NaN       everyone 1182211615
# 3                      NaN       everyone 1182211615
# 4                      NaN       everyone 1182211615
# ...                    ...            ...        ...
# 48326                  NaN       everyone  961181894
# 48327                  NaN       everyone  961181894
# 48328                  NaN       everyone  961181894
# 48329                  NaN       everyone  961181894
# 48330                  NaN       everyone  961181894
#
#                                      context_annotations                   id  \
# 0      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846277256509116672
# 1      [{'domain': {'id': '10', 'name': 'Person', 'de...  1846222583898784000
# 2                                                    NaN  1846161400328028160
# 3                                                    NaN  1846091824101769472
# 4                                                    NaN  1846075343188144128
# ...                                                  ...                  ...
# 48326                                                NaN  1707719554355380480
# 48327                                                NaN  1704120323023454464
# 48328                                                NaN  1702668459576786944
# 48329                                                NaN  1701960909369868544
# 48330                                                NaN  1701606379709198336
#
#                                                     text  \
# 0      @donaldtusk Niezrealizowanie większości ze "10...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                                                  ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...
# 48327  Za nami posiedzenie @SejmikMaz. I kolejne wspa...
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...
# 48329  To jedna z największych inwestycji drogowych @...
# 48330  Powiaty mają 25 lat ❗ ️Na @Zamek_Krolewski odb...
#
#                                            edit_controls  \
# 0      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 48326  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48327  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48328  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48329  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 48330  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                        referenced_tweets  \
# 0      [{'type': 'replied_to', 'id': '184609177626996...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 48326                                                NaN
# 48327                                                NaN
# 48328                                                NaN
# 48329                                                NaN
# 48330                                                NaN
#
#                      created_at edit_history_tweet_ids  ... reply_count  \
# 0     2024-10-15 19:49:34+00:00  [1846277256509116623]  ...           1
# 1     2024-10-15 16:12:19+00:00  [1846222583898784025]  ...           2
# 2     2024-10-15 12:09:12+00:00  [1846161400328028272]  ...           3
# 3     2024-10-15 07:32:44+00:00  [1846091824101769490]  ...           2
# 4     2024-10-15 06:27:14+00:00  [1846075343188144153]  ...          18
# ...                         ...                    ...  ...         ...
# 48326 2023-09-29 11:30:44+00:00  [1707719554355380484]  ...           0
# 48327 2023-09-19 13:08:40+00:00  [1704120323023454339]  ...           0
# 48328 2023-09-15 12:59:29+00:00  [1702668459576787064]  ...           0
# 48329 2023-09-13 14:07:56+00:00  [1701960909369868437]  ...           0
# 48330 2023-09-12 14:39:09+00:00  [1701606379709198357]  ...           2
#
#        like_count  quote_count impression_count  \
# 0              33            0             1555
# 1              72            0             3031
# 2              33            2             8636
# 3              38            0             2441
# 4             616            2             8634
# ...           ...          ...              ...
# 48326           6            0             2154
# 48327          15            0              649
# 48328          16            0              581
# 48329          13            0              621
# 48330          16            0             2444
#
#                                            text_clean_en  \
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       ❌ We are a year after the elections, and Pola...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 48326  Are you studying medicine, nursing or emergenc...
# 48327  The meeting is over. And further support for t...
# 48328  The Płock Oncology Center is ready! It will ac...
# 48329  This is one of the largest road investments   ...
# 48330  The counties are 25 years old ❗ ️The anniversa...
#
#                                  text_clean_en_demojized  \
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       :cross_mark: We are a year after the election...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 48326  Are you studying medicine, nursing or emergenc...
# 48327  The meeting is over. And further support for t...
# 48328  The Płock Oncology Center is ready! It will ac...
# 48329  This is one of the largest road investments  \...
# 48330  The counties are 25 years old :red_exclamation...
#
#                                     text_clean_demojized emoji_count_en  \
# 0       Niezrealizowanie większości ze "100 konkretów...              0
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...              0
# 2       :cross_mark: Mamy rok po wyborach, a Polska p...              1
# 3      Mija rok od wyborów parlamentarnych. W kampani...              0
# 4                                         #Idę11  🇵  🇱                2
# ...                                                  ...            ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...              0
# 48327  Za nami posiedzenie . I kolejne wsparcie dla m...              0
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...              0
# 48329  To jedna z największych inwestycji drogowych  ...              0
# 48330  Powiaty mają 25 lat :red_exclamation_mark: Na ...              3
#
#       emoji_count             name
# 0               0  Bartłomiej Pejo
# 1               0  Bartłomiej Pejo
# 2               1  Bartłomiej Pejo
# 3               0  Bartłomiej Pejo
# 4               2  Bartłomiej Pejo
# ...           ...              ...
# 48326           0     Adam Struzik
# 48327           0     Adam Struzik
# 48328           0     Adam Struzik
# 48329           0     Adam Struzik
# 48330           3     Adam Struzik
#
# [48331 rows x 33 columns]

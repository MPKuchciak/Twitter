# %% [markdown]
# # Data cleaning

# %% [markdown]
# In this file, we cleaned the downloaded data:
# The main steps include:
# 1. Adding party affiliation to tweet rows
# 2. Deleting unnecessary downloaded Retweets.
# 3. Deleting links and mentions from the tweets text and saving them to separate columns
# 4. Expanding the column of public metrics
# 5. Encoding emojis in a unified format
# 6. Translating tweets using Google Translate in Google Sheets
# 7. Saving all downloaded tweets to one file

# %% [markdown]
# ### 1.  Used libraries

# %%
import os
import pandas as pd
import re
import emoji

# %% [markdown]
# ### 2. Reading JSON files and transforming them into party-specific pickle files

# %%
base_input_path = 'data/01.raw/tweets_data_final' # change folder if needed
subfolders = ['Konfederacja', 'NL', 'PiS', 'PO', 'PL2050', 'PSL']
output_folder = 'data/01.raw/tweets_data_combined'

os.makedirs(output_folder, exist_ok=True)

for subfolder in subfolders:
    folder_path = os.path.join(base_input_path, subfolder)
    dataframes = []
    
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            politician = filename.split("_tweets.json")[0]
            try:
                df = pd.read_json(file_path)  
                df["username"] = politician  
                df["party"] = subfolder
                print(f"Read {len(df)} rows from {file_path}")  
                dataframes.append(df)
            except ValueError as e:
                print(f"Error reading {file_path}: {e}")
    
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        
        output_file_path = os.path.join(output_folder, f'{subfolder}_combined.pkl')
        combined_df.to_pickle(output_file_path) 
        
        print(f"Saved {subfolder} combined data to {output_file_path}")

print("Processing complete!")
# Out:
# Read 11 rows from data/01.raw/tweets_data_final\Konfederacja\Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json
# Read 964 rows from data/01.raw/tweets_data_final\Konfederacja\bartlomiejpejo_2023-10-16_2024-10-15.json
# Read 1318 rows from data/01.raw/tweets_data_final\Konfederacja\KonradBerkowicz_2024-04-16_2024-10-15_vol1.json
# Read 597 rows from data/01.raw/tweets_data_final\Konfederacja\MichalWawer_2023-10-16_2024-10-15.json
# Read 772 rows from data/01.raw/tweets_data_final\Konfederacja\MarSypniewski_2023-10-16_2024-10-15.json
# Read 175 rows from data/01.raw/tweets_data_final\Konfederacja\TudujKrzysztof_2023-10-16_2024-10-15.json
# Read 721 rows from data/01.raw/tweets_data_final\Konfederacja\SlawomirMentzen_2023-10-16_2024-10-15.json
# Read 750 rows from data/01.raw/tweets_data_final\Konfederacja\WTumanowicz_2023-10-16_2024-10-15.json
# Read 950 rows from data/01.raw/tweets_data_final\Konfederacja\Wlodek_Skalik_2023-10-16_2024-10-15.json
# Read 289 rows from data/01.raw/tweets_data_final\Konfederacja\KonradBerkowicz_2023-10-15_2024-04-16_vol2.json
# Read 421 rows from data/01.raw/tweets_data_final\Konfederacja\placzekgrzegorz_2023-10-16_2024-04-15.json
# Read 320 rows from data/01.raw/tweets_data_final\Konfederacja\placzekgrzegorz_2024-04-16_2024-10-15.json
# Read 889 rows from data/01.raw/tweets_data_final\Konfederacja\GrzegorzBraun__2023-10-16_2024-10-15.json
# Saved Konfederacja combined data to data/01.raw/tweets_data_combined\Konfederacja_combined.pkl
# Read 0 rows from data/01.raw/tweets_data_final\NL\DyduchMarek_2023-10-16_2024-10-15.json
# Read 207 rows from data/01.raw/tweets_data_final\NL\AndrzejSzejna_2023-10-16_2024-10-15.json
# Read 73 rows from data/01.raw/tweets_data_final\NL\wlodekczarzasty_2023-10-16_2024-10-15.json
# Read 103 rows from data/01.raw/tweets_data_final\NL\JoankaSW_2023-10-16_2024-10-15.json
# Read 142 rows from data/01.raw/tweets_data_final\NL\wieczorekdarek_2023-10-16_2024-10-15.json
# Read 247 rows from data/01.raw/tweets_data_final\NL\MoskwaWodnicka_2023-10-16_2024-10-15.json
# Read 178 rows from data/01.raw/tweets_data_final\NL\KGawkowski_2023-10-16_2024-10-15.json
# Read 537 rows from data/01.raw/tweets_data_final\NL\PaulinaPW2024_2023-10-16_2024-10-15.json
# Read 907 rows from data/01.raw/tweets_data_final\NL\poselTTrela_2023-10-16_2024-04-15.json
# Read 575 rows from data/01.raw/tweets_data_final\NL\poselTTrela_2024-04-16_2024-10-15.json
# Read 787 rows from data/01.raw/tweets_data_final\NL\WandaNowicka_2023-10-16_2024-10-15.json
# Read 457 rows from data/01.raw/tweets_data_final\NL\RobertBiedron_2023-10-16_2024-10-15.json
# Read 481 rows from data/01.raw/tweets_data_final\NL\AnitaKDZG_2023-10-16_2024-10-15.json
# Read 693 rows from data/01.raw/tweets_data_final\NL\K_Smiszek_2023-10-16_2024-10-15.json
# Read 1128 rows from data/01.raw/tweets_data_final\NL\MarcinKulasek_2023-10-16_2024-10-15.json
# Saved NL combined data to data/01.raw/tweets_data_combined\NL_combined.pkl
# Read 189 rows from data/01.raw/tweets_data_final\PiS\Kaminski_M__2023-10-16_2024-10-15.json
# Read 782 rows from data/01.raw/tweets_data_final\PiS\mwojcik__2023-10-16_2024-10-15.json
# Read 556 rows from data/01.raw/tweets_data_final\PiS\BeataSzydlo_2023-10-16_2024-10-15.json
# Read 77 rows from data/01.raw/tweets_data_final\PiS\elzbietawitek_2023-10-16_2024-10-15.json
# Read 35 rows from data/01.raw/tweets_data_final\PiS\Kowalczyk_H_2023-10-16_2024-10-15.json
# Read 647 rows from data/01.raw/tweets_data_final\PiS\MorawieckiM_2023-10-16_2024-10-15.json
# Read 249 rows from data/01.raw/tweets_data_final\PiS\mblaszczak_2023-10-16_2024-10-15.json
# Read 236 rows from data/01.raw/tweets_data_final\PiS\Macierewicz_A_2023-10-16_2024-10-15.json
# Read 1025 rows from data/01.raw/tweets_data_final\PiS\PatrykJaki_2023-10-16_2024-10-15.json
# Saved PiS combined data to data/01.raw/tweets_data_combined\PiS_combined.pkl
# Read 102 rows from data/01.raw/tweets_data_final\PO\JanGrabiec_2023-10-16_2024-10-15.json
# Read 356 rows from data/01.raw/tweets_data_final\PO\Konwinski_PO_2023-10-16_2024-10-15.json
# Read 409 rows from data/01.raw/tweets_data_final\PO\DorotaNiedziela_2023-10-16_2024-10-15.json
# Read 49 rows from data/01.raw/tweets_data_final\PO\bbudka_2024-04-01_2024-10-15.json
# Read 45 rows from data/01.raw/tweets_data_final\PO\bbudka_2023-10-16_2024-03-31.json
# Read 64 rows from data/01.raw/tweets_data_final\PO\M_K_Blonska_2024-04-01_2024-10-15.json
# Read 118 rows from data/01.raw/tweets_data_final\PO\Leszczyna_2023-10-16_2023-12-31.json
# Read 112 rows from data/01.raw/tweets_data_final\PO\Leszczyna_2024-01-01_2024-03-31.json
# Read 62 rows from data/01.raw/tweets_data_final\PO\M_K_Blonska_2023-10-16_2024-03-31.json
# Read 165 rows from data/01.raw/tweets_data_final\PO\EwaKopacz_2023-10-16_2024-10-15.json
# Read 173 rows from data/01.raw/tweets_data_final\PO\Leszczyna_2024-04-01_2024-10-15.json
# Read 882 rows from data/01.raw/tweets_data_final\PO\MKierwinski_2023-10-16_2024-10-15.json
# Read 814 rows from data/01.raw/tweets_data_final\PO\trzaskowski__2023-10-16_2024-10-15.json
# Read 338 rows from data/01.raw/tweets_data_final\PO\donaldtusk_2023-10-16_2024-10-15.json
# Read 456 rows from data/01.raw/tweets_data_final\PO\OklaDrewnowicz_2023-10-16_2024-10-15.json
# Read 269 rows from data/01.raw/tweets_data_final\PO\CTomczyk_2023-10-16_2024-10-15_ERROR.json
# Saved PO combined data to data/01.raw/tweets_data_combined\PO_combined.pkl
# Read 675 rows from data/01.raw/tweets_data_final\PL2050\SlizPawel_2023-10-16_2024-10-15.json
# Read 8 rows from data/01.raw/tweets_data_final\PL2050\joannamucha_2023-10-16_2024-10-15.json
# Read 167 rows from data/01.raw/tweets_data_final\PL2050\szymon_holownia_2023-10-16_2024-10-15.json
# Read 41 rows from data/01.raw/tweets_data_final\PL2050\AgaBaranowskaPL_2023-10-16_2024-10-15.json
# Read 29 rows from data/01.raw/tweets_data_final\PL2050\aga_buczynska_2023-10-16_2024-10-15.json
# Read 73 rows from data/01.raw/tweets_data_final\PL2050\LukaszOsmalak_2023-10-16_2024-10-15.json
# Read 175 rows from data/01.raw/tweets_data_final\PL2050\ZalewskiPawel_2023-10-16_2024-10-15.json
# Read 226 rows from data/01.raw/tweets_data_final\PL2050\Kpelczynska_2023-10-16_2024-10-15.json
# Read 319 rows from data/01.raw/tweets_data_final\PL2050\ZywnoMaciej_2023-10-16_2024-10-15.json
# Read 389 rows from data/01.raw/tweets_data_final\PL2050\hennigkloska_2023-10-16_2024-10-15.json
# Saved PL2050 combined data to data/01.raw/tweets_data_combined\PL2050_combined.pkl
# Read 19 rows from data/01.raw/tweets_data_final\PSL\Hetman_K_2023-10-16_2024-10-15.json
# Read 274 rows from data/01.raw/tweets_data_final\PSL\DariuszKlimczak_2023-10-16_2024-10-15.json
# Read 115 rows from data/01.raw/tweets_data_final\PSL\GrzybAndrzej_2023-10-16_2024-10-15.json
# Read 192 rows from data/01.raw/tweets_data_final\PSL\JarubasAdam_2023-10-16_2024-10-15.json
# Read 146 rows from data/01.raw/tweets_data_final\PSL\Paslawska_2023-10-16_2024-10-15.json
# Read 107 rows from data/01.raw/tweets_data_final\PSL\StefanKrajewski_2023-10-16_2024-10-15.json
# Read 411 rows from data/01.raw/tweets_data_final\PSL\PZgorzelskiP_2023-10-16_2024-10-15.json
# Read 409 rows from data/01.raw/tweets_data_final\PSL\KosiniakKamysz_2023-10-16_2024-10-15.json
# Saved PSL combined data to data/01.raw/tweets_data_combined\PSL_combined.pkl
# Processing complete!

# %% [markdown]
# ### 3. Data cleaning

# %%
df_konf = pd.read_pickle(os.path.join(output_folder, 'Konfederacja_combined.pkl'))
df_NL = pd.read_pickle(os.path.join(output_folder, 'NL_combined.pkl'))
df_PIS = pd.read_pickle(os.path.join(output_folder, 'PIS_combined.pkl'))
df_PO = pd.read_pickle(os.path.join(output_folder, 'PO_combined.pkl'))
df_PL2050 = pd.read_pickle(os.path.join(output_folder, 'PL2050_combined.pkl'))
df_PSL = pd.read_pickle(os.path.join(output_folder, 'PSL_combined.pkl'))

# %%
df_konf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8177 entries, 0 to 8176
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   created_at              8177 non-null   datetime64[ns, UTC]
#  1   text                    8177 non-null   object
#  2   id                      8177 non-null   int64
#  3   author_id               8177 non-null   int64
#  4   edit_controls           8177 non-null   object
#  5   possibly_sensitive      8177 non-null   bool
#  6   reply_settings          8177 non-null   object
#  7   public_metrics          8177 non-null   object
#  8   lang                    8177 non-null   object
#  9   edit_history_tweet_ids  8177 non-null   object
#  10  conversation_id         8177 non-null   int64
#  11  category                8177 non-null   object
#  12  attachments             4073 non-null   object
#  13  entities                7489 non-null   object
#  14  username                8177 non-null   object
#  15  party                   8177 non-null   object
#  16  in_reply_to_user_id     1949 non-null   float64
#  17  context_annotations     986 non-null    object
#  18  referenced_tweets       2848 non-null   object
#  19  geo                     138 non-null    object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(3), object(14)
# memory usage: 1.2+ MB

# %%
df_konf.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#              author_id                                      edit_controls  \
# 0  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#    possibly_sensitive reply_settings  \
# 0               False       everyone
# 1               False       everyone
# 2               False       everyone
# 3               False       everyone
# 4               False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids      conversation_id  category  \
# 0  [1765380709114409272]  1765380709114409216  Original
# 1  [1764245727646044196]  1764245727646044160  Original
# 2  [1763931255521857839]  1763931255521857792  Original
# 3  [1763576337078313201]  1763576337078313216  Original
# 4  [1763173358068281524]  1763173358068281600  Original
#
#                                  attachments  \
# 0                                        NaN
# 1  {'media_keys': ['3_1764245720805040128']}
# 2  {'media_keys': ['7_1763931103151202304']}
# 3  {'media_keys': ['3_1763576329385967617']}
# 4  {'media_keys': ['3_1763173351466401792']}
#
#                                             entities  \
# 0                                                NaN
# 1  {'urls': [{'start': 57, 'end': 80, 'url': 'htt...
# 2  {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 3  {'urls': [{'start': 64, 'end': 87, 'url': 'htt...
# 4  {'urls': [{'start': 128, 'end': 151, 'url': 'h...
#
#                                      username         party  \
# 0  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 1  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 2  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 3  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 4  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
#
#    in_reply_to_user_id context_annotations referenced_tweets  geo
# 0                  NaN                 NaN               NaN  NaN
# 1                  NaN                 NaN               NaN  NaN
# 2                  NaN                 NaN               NaN  NaN
# 3                  NaN                 NaN               NaN  NaN
# 4                  NaN                 NaN               NaN  NaN

# %%
# Merge all dataframes into one
df = pd.concat([df_konf, df_NL, df_PIS, df_PO, df_PL2050, df_PSL], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26677 entries, 0 to 26676
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   created_at              26677 non-null  datetime64[ns, UTC]
#  1   text                    26677 non-null  object
#  2   id                      26661 non-null  float64
#  3   author_id               26677 non-null  float64
#  4   edit_controls           26661 non-null  object
#  5   possibly_sensitive      26661 non-null  object
#  6   reply_settings          26677 non-null  object
#  7   public_metrics          26677 non-null  object
#  8   lang                    26677 non-null  object
#  9   edit_history_tweet_ids  26661 non-null  object
#  10  conversation_id         26661 non-null  float64
#  11  category                26677 non-null  object
#  12  attachments             11931 non-null  object
#  13  entities                23437 non-null  object
#  14  username                26677 non-null  object
#  15  party                   26677 non-null  object
#  16  in_reply_to_user_id     5743 non-null   float64
#  17  context_annotations     3335 non-null   object
#  18  referenced_tweets       8896 non-null   object
#  19  geo                     668 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 4.1+ MB

# %%
len(df)
# Out:
# 26677

# %%
pd.options.display.float_format = '{:.0f}'.format
df['id'] = df['id'].fillna(0).astype('int64')
df['id']
# Out:
# 0        1765380709114409216
# 1        1764245727646044160
# 2        1763931255521857792
# 3        1763576337078313216
# 4        1763173358068281600
#                 ...
# 26672    1715066644018381312
# 26673    1714927388637696256
# 26674    1714675864237924864
# 26675    1714370461507748096
# 26676    1714370461507748096
# Name: id, Length: 26677, dtype: int64

# %%
# Get the value counts of 'id'
id_counts = df['id'].value_counts()

# Filter the counts to show only those greater than 1
id_counts_above_1 = id_counts[id_counts > 1]

# Display the counts
print(f"IDs with counts greater than 1:\n{id_counts_above_1}")
# Out:
# IDs with counts greater than 1:
# id
# 0                      16
# 1780108572161945856     3
# 1780104870302732544     2
# 1734658925658619904     2
# 1713706323672539392     2
#                        ..
# 1806263584877326848     2
# 1778400392470056960     2
# 1714215043720442368     2
# 1713961177028415488     2
# 1734231599116374272     2
# Name: count, Length: 114, dtype: int64

# %%
id_counts_above_1.sum()
# Out:
# 243

# %%
# Count unique IDs
non_duplicate_counts = df['id'].nunique()
print(f"Number of unique IDs: {non_duplicate_counts}")

# Count duplicate IDs
duplicate_counts = df['id'].duplicated().sum()
print(f"Number of duplicate IDs: {duplicate_counts}")

# Get the value counts of 'id'
id_counts = df['id'].value_counts()

# Filter the counts to show only those greater than 1
id_counts_above_1 = id_counts[id_counts > 1]

# Sum of counts of IDs that appear more than once
total_duplicate_rows = id_counts_above_1.sum()
print(f"Total number of duplicate rows based on 'id': {total_duplicate_rows}")

# Convert all columns to strings to avoid unhashable types
df_str = df.astype(str)

# Now check for exact duplicate rows across all columns
duplicates_all = df_str[df_str.duplicated(keep=False)]
print(f"Total duplicate rows (exact match across all columns): {duplicates_all.shape[0]}")
duplicates_all
# Out:
# Number of unique IDs: 26548
# Number of duplicate IDs: 129
# Total number of duplicate rows based on 'id': 243
# Total duplicate rows (exact match across all columns): 130
#                       created_at  \
# 9      2024-02-26 13:35:28+00:00
# 10     2024-02-26 13:35:28+00:00
# 2291   2024-04-16 05:38:51+00:00
# 2292   2024-04-16 05:38:51+00:00
# 2888   2023-10-17 10:47:20+00:00
# ...                          ...
# 25603  2023-10-16 08:28:55+00:00
# 25835  2024-02-19 11:38:01+00:00
# 25836  2024-02-19 11:38:01+00:00
# 25855  2023-10-17 20:07:37+00:00
# 25856  2023-10-17 20:07:37+00:00
#
#                                                     text                   id  \
# 9      Nie ma takiej obietnicy, której polityk nie ob...  1762109123800293376
# 10     Nie ma takiej obietnicy, której polityk nie ob...  1762109123800293376
# 2291   ❗SPOTKANIE CZŁONKÓW I SYMPATYKÓW KLUBU KONFEDE...  1780108572161945856
# 2292   ❗SPOTKANIE CZŁONKÓW I SYMPATYKÓW KLUBU KONFEDE...  1780108572161945856
# 2888   Ponad 43 tysiące wyborców oddało swoje głosy n...  1714231616065708544
# ...                                                  ...                  ...
# 25603  Wiara, determinacja, silne partycypacyjne przy...  1713834394127884544
# 25835  Kontrole @gijhars obejmują wszystkie transport...  1759542851396940288
# 25836  Kontrole @gijhars obejmują wszystkie transport...  1759542851396940288
# 25855  Wszystkim Wam serdecznie dziekuję. Za wsparcie...  1714372612611060224
# 25856  Wszystkim Wam serdecznie dziekuję. Za wsparcie...  1714372612611060224
#
#                     author_id  \
# 9      1.5544839915117036e+18
# 10     1.5544839915117036e+18
# 2291             1420353350.0
# 2292             1420353350.0
# 2888    9.417106438534472e+17
# ...                       ...
# 25603             325592746.0
# 25835            1201875318.0
# 25836            1201875318.0
# 25855            1201875318.0
# 25856            1201875318.0
#
#                                            edit_controls possibly_sensitive  \
# 9      {'edits_remaining': 5, 'is_edit_eligible': Tru...              False
# 10     {'edits_remaining': 5, 'is_edit_eligible': Tru...              False
# 2291   {'edits_remaining': 5, 'is_edit_eligible': Tru...              False
# 2292   {'edits_remaining': 5, 'is_edit_eligible': Tru...              False
# 2888   {'edits_remaining': 5, 'is_edit_eligible': Tru...              False
# ...                                                  ...                ...
# 25603  {'edits_remaining': 5, 'is_edit_eligible': Tru...                0.0
# 25835  {'edits_remaining': 5, 'is_edit_eligible': Tru...                0.0
# 25836  {'edits_remaining': 5, 'is_edit_eligible': Tru...                0.0
# 25855  {'edits_remaining': 5, 'is_edit_eligible': Tru...                0.0
# 25856  {'edits_remaining': 5, 'is_edit_eligible': Tru...                0.0
#
#       reply_settings                                     public_metrics lang  \
# 9           everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 10          everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2291        everyone  {'retweet_count': 5, 'reply_count': 1, 'like_c...   pl
# 2292        everyone  {'retweet_count': 5, 'reply_count': 1, 'like_c...   pl
# 2888        everyone  {'retweet_count': 35, 'reply_count': 111, 'lik...   pl
# ...              ...                                                ...  ...
# 25603       everyone  {'retweet_count': 21, 'reply_count': 3, 'like_...   pl
# 25835       everyone  {'retweet_count': 7, 'reply_count': 2, 'like_c...   pl
# 25836       everyone  {'retweet_count': 7, 'reply_count': 2, 'like_c...   pl
# 25855       everyone  {'retweet_count': 10, 'reply_count': 6, 'like_...   pl
# 25856       everyone  {'retweet_count': 10, 'reply_count': 6, 'like_...   pl
#
#         edit_history_tweet_ids         conversation_id  category  \
# 9      ['1762109123800293457']  1.7621091238002934e+18  Original
# 10     ['1762109123800293457']  1.7621091238002934e+18  Original
# 2291   ['1780108572161945969']  1.7801085721619459e+18  Original
# 2292   ['1780108572161945969']  1.7801085721619459e+18  Original
# 2888   ['1714231616065708419']  1.7142316160657085e+18  Original
# ...                        ...                     ...       ...
# 25603  ['1713834394127884470']  1.7138343941278845e+18     Quote
# 25835  ['1759542851396940198']  1.7595428513969403e+18     Quote
# 25836  ['1759542851396940198']  1.7595428513969403e+18     Quote
# 25855  ['1714372612611060222']  1.7143726126110602e+18  Original
# 25856  ['1714372612611060222']  1.7143726126110602e+18  Original
#
#                                      attachments  \
# 9      {'media_keys': ['3_1762109117865304064']}
# 10     {'media_keys': ['3_1762109117865304064']}
# 2291   {'media_keys': ['3_1780108567447560193']}
# 2292   {'media_keys': ['3_1780108567447560193']}
# 2888   {'media_keys': ['3_1714231608536891392']}
# ...                                          ...
# 25603                                        nan
# 25835                                        nan
# 25836                                        nan
# 25855  {'media_keys': ['7_1714372479076954113']}
# 25856  {'media_keys': ['7_1714372479076954113']}
#
#                                                 entities  \
# 9      {'urls': [{'start': 80, 'end': 103, 'url': 'ht...
# 10     {'urls': [{'start': 80, 'end': 103, 'url': 'ht...
# 2291   {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 2292   {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 2888   {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# ...                                                  ...
# 25603  {'hashtags': [{'start': 78, 'end': 91, 'tag': ...
# 25835  {'urls': [{'start': 249, 'end': 272, 'url': 'h...
# 25836  {'urls': [{'start': 249, 'end': 272, 'url': 'h...
# 25855  {'urls': [{'start': 81, 'end': 104, 'url': 'ht...
# 25856  {'urls': [{'start': 81, 'end': 104, 'url': 'ht...
#
#                                               username         party  \
# 9           Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 10          Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 2291   KonradBerkowicz_2024-04-16_2024-10-15_vol1.json  Konfederacja
# 2292   KonradBerkowicz_2024-04-16_2024-10-15_vol1.json  Konfederacja
# 2888            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# ...                                                ...           ...
# 25603           JarubasAdam_2023-10-16_2024-10-15.json           PSL
# 25835       StefanKrajewski_2023-10-16_2024-10-15.json           PSL
# 25836       StefanKrajewski_2023-10-16_2024-10-15.json           PSL
# 25855       StefanKrajewski_2023-10-16_2024-10-15.json           PSL
# 25856       StefanKrajewski_2023-10-16_2024-10-15.json           PSL
#
#       in_reply_to_user_id                                context_annotations  \
# 9                     nan                                                nan
# 10                    nan                                                nan
# 2291                  nan                                                nan
# 2292                  nan                                                nan
# 2888                  nan  [{'domain': {'id': '47', 'name': 'Brand', 'des...
# ...                   ...                                                ...
# 25603                 nan                                                nan
# 25835                 nan                                                nan
# 25836                 nan                                                nan
# 25855                 nan                                                nan
# 25856                 nan                                                nan
#
#                                        referenced_tweets  \
# 9                                                    nan
# 10                                                   nan
# 2291                                                 nan
# 2292                                                 nan
# 2888                                                 nan
# ...                                                  ...
# 25603  [{'type': 'quoted', 'id': '1713640726922195372'}]
# 25835  [{'type': 'quoted', 'id': '1759533295833096303'}]
# 25836  [{'type': 'quoted', 'id': '1759533295833096303'}]
# 25855                                                nan
# 25856                                                nan
#
#                                     geo
# 9                                   nan
# 10                                  nan
# 2291                                nan
# 2292                                nan
# 2888                                nan
# ...                                 ...
# 25603                               nan
# 25835                               nan
# 25836                               nan
# 25855  {'place_id': '47c001064da7125c'}
# 25856  {'place_id': '47c001064da7125c'}
#
# [130 rows x 20 columns]

# %% [markdown]
# brief insight into how do these duplicates look like

# %%
df[df['id'].duplicated(keep=False)].sort_values(by='id')
# Out:
#                      created_at  \
# 19626 2023-10-16 22:41:00+00:00
# 19621 2023-10-16 00:00:00+00:00
# 19620 2023-10-16 00:00:00+00:00
# 19619 2023-10-16 00:00:00+00:00
# 19624 2023-10-16 21:57:00+00:00
# ...                         ...
# 25119 2024-09-13 08:23:40+00:00
# 22677 2024-09-19 06:31:07+00:00
# 22676 2024-09-19 06:31:07+00:00
# 17012 2024-09-24 14:22:59+00:00
# 17011 2024-09-24 14:22:59+00:00
#
#                                                     text                   id  \
# 19626                    @DorotaNiedziela ja Tobie też❣️                    0
# 19621                                      @Gidziela 🥰✌️                    0
# 19620                                        @REL_76 🥰🥰🥰                    0
# 19619      @MCichonAlicja Alu, czekamy jeszcze na wynik?                    0
# 19624                                     @jasinska_e ❤️                    0
# ...                                                  ...                  ...
# 25119  W ramach roboczego kontaktu z @WodyPolskie ora...  1834508231009325568
# 22677  Premier @donaldtusk : namierzono człowieka prz...  1836654233296244992
# 22676  Premier @donaldtusk : namierzono człowieka prz...  1836654233296244992
# 17012  Potwierdza się to o czym mówiliśmy już od dawn...  1838584923688444416
# 17011  Potwierdza się to o czym mówiliśmy już od dawn...  1838584923688444416
#
#        author_id                                      edit_controls  \
# 19626   61552404                                                NaN
# 19621   61552404                                                NaN
# 19620   61552404                                                NaN
# 19619   61552404                                                NaN
# 19624   61552404                                                NaN
# ...          ...                                                ...
# 25119  964017524  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 22677   52367150  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 22676   52367150  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 17012  138048156  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 17011  138048156  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings  \
# 19626                NaN       everyone
# 19621                NaN       everyone
# 19620                NaN       everyone
# 19619                NaN       everyone
# 19624                NaN       everyone
# ...                  ...            ...
# 25119                  0       everyone
# 22677                  0       everyone
# 22676                  0       everyone
# 17012              False       everyone
# 17011              False       everyone
#
#                                           public_metrics lang  \
# 19626  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19621  {'retweet_count': 1, 'reply_count': 0, 'like_c...   pl
# 19620  {'retweet_count': 1, 'reply_count': 1, 'like_c...   pl
# 19619  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19624  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# ...                                                  ...  ...
# 25119  {'retweet_count': 15, 'reply_count': 2, 'like_...   pl
# 22677  {'retweet_count': 567, 'reply_count': 221, 'li...   pl
# 22676  {'retweet_count': 568, 'reply_count': 221, 'li...   pl
# 17012  {'retweet_count': 141, 'reply_count': 125, 'li...   pl
# 17011  {'retweet_count': 141, 'reply_count': 125, 'li...   pl
#
#       edit_history_tweet_ids     conversation_id  category attachments  \
# 19626                    NaN                 NaN     Reply         NaN
# 19621                    NaN                 NaN     Reply         NaN
# 19620                    NaN                 NaN     Reply         NaN
# 19619                    NaN                 NaN     Reply         NaN
# 19624                    NaN                 NaN     Reply         NaN
# ...                      ...                 ...       ...         ...
# 25119  [1834508231009325542] 1834508231009325568  Original         NaN
# 22677  [1836654233296244914] 1836654233296244992  Original         NaN
# 22676  [1836654233296244914] 1836654233296244992  Original         NaN
# 17012  [1838584923688444342] 1838584923688444416     Quote         NaN
# 17011  [1838584923688444342] 1838584923688444416     Quote         NaN
#
#                                                 entities  \
# 19626                                                NaN
# 19621                                                NaN
# 19620                                                NaN
# 19619                                                NaN
# 19624                                                NaN
# ...                                                  ...
# 25119  {'mentions': [{'start': 30, 'end': 42, 'userna...
# 22677  {'mentions': [{'start': 8, 'end': 19, 'usernam...
# 22676  {'mentions': [{'start': 8, 'end': 19, 'usernam...
# 17012  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 17011  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
#
#                                          username party  in_reply_to_user_id  \
# 19626        Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19621        Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19620        Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19619        Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19624        Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# ...                                           ...   ...                  ...
# 25119  DariuszKlimczak_2023-10-16_2024-10-15.json   PSL                  NaN
# 22677   CTomczyk_2023-10-16_2024-10-15_ERROR.json    PO                  NaN
# 22676   CTomczyk_2023-10-16_2024-10-15_ERROR.json    PO                  NaN
# 17012       mblaszczak_2023-10-16_2024-10-15.json   PiS                  NaN
# 17011       mblaszczak_2023-10-16_2024-10-15.json   PiS                  NaN
#
#                                      context_annotations  \
# 19626                                                NaN
# 19621                                                NaN
# 19620                                                NaN
# 19619                                                NaN
# 19624                                                NaN
# ...                                                  ...
# 25119  [{'domain': {'id': '11', 'name': 'Sport', 'des...
# 22677  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 22676  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 17012                                                NaN
# 17011                                                NaN
#
#                                        referenced_tweets  geo
# 19626                                                NaN  NaN
# 19621                                                NaN  NaN
# 19620                                                NaN  NaN
# 19619                                                NaN  NaN
# 19624                                                NaN  NaN
# ...                                                  ...  ...
# 25119                                                NaN  NaN
# 22677                                                NaN  NaN
# 22676                                                NaN  NaN
# 17012  [{'type': 'quoted', 'id': '1838307356918071625'}]  NaN
# 17011  [{'type': 'quoted', 'id': '1838307356918071625'}]  NaN
#
# [243 rows x 20 columns]

# %%
for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, dict)).any():
        print(f"Column '{col}' contains dictionaries.")
    elif df[col].apply(lambda x: isinstance(x, list)).any():
        print(f"Column '{col}' contains lists.")
# Out:
# Column 'edit_controls' contains dictionaries.
# Column 'public_metrics' contains dictionaries.
# Column 'edit_history_tweet_ids' contains lists.
# Column 'attachments' contains dictionaries.
# Column 'entities' contains dictionaries.
# Column 'context_annotations' contains lists.
# Column 'referenced_tweets' contains lists.
# Column 'geo' contains dictionaries.

# %%
# Get all duplicate IDs
duplicate_ids = df[df['id'].duplicated(keep=False)]

# Exclude columns with unhashable (dict-like) values
columns_to_exclude = ['edit_controls', 'public_metrics', 'attachments', 'entities', 'geo', 'edit_history_tweet_ids', 'context_annotations','referenced_tweets']
valid_columns = [col for col in df.columns if col not in columns_to_exclude]

# Find differences across valid columns
diff_summary = duplicate_ids[valid_columns].groupby('id').nunique()

# Show columns where duplicates have different values
diff_summary = diff_summary[(diff_summary > 1).any(axis=1)]

# %%
diff_summary
# Out:
#                      created_at  text  author_id  possibly_sensitive  \
# id
# 0                             9    16          2                   0
# 1780108572161945856           1     1          1                   1
# 1780146130551996672           1     1          1                   1
# 1780171152914034944           1     1          1                   1
# 1780244011212485120           1     1          1                   1
# 1780309557610258688           1     1          1                   1
# 1780345695163047936           1     1          1                   1
# 1780345829615636480           1     1          1                   1
# 1780346025854603264           1     1          1                   1
# 1780346371888833024           1     1          1                   1
#
#                      reply_settings  lang  conversation_id  category  \
# id
# 0                                 1     1                0         2
# 1780108572161945856               1     1                1         1
# 1780146130551996672               1     1                1         1
# 1780171152914034944               1     1                1         1
# 1780244011212485120               1     1                1         1
# 1780309557610258688               1     1                1         1
# 1780345695163047936               1     1                1         1
# 1780345829615636480               1     1                1         1
# 1780346025854603264               1     1                1         1
# 1780346371888833024               1     1                1         1
#
#                      username  party  in_reply_to_user_id
# id
# 0                           2      2                    0
# 1780108572161945856         2      1                    0
# 1780146130551996672         2      1                    1
# 1780171152914034944         2      1                    1
# 1780244011212485120         2      1                    0
# 1780309557610258688         2      1                    0
# 1780345695163047936         2      1                    1
# 1780345829615636480         2      1                    1
# 1780346025854603264         2      1                    1
# 1780346371888833024         2      1                    1

# %%
duplicates = df[df.duplicated(subset=['id'], keep=False)]
duplicates
# Out:
#                      created_at  \
# 9     2024-02-26 13:35:28+00:00
# 10    2024-02-26 13:35:28+00:00
# 973   2023-10-17 08:22:19+00:00
# 974   2023-10-17 08:22:19+00:00
# 1974  2024-05-25 09:27:54+00:00
# ...                         ...
# 25856 2023-10-17 20:07:37+00:00
# 26266 2023-10-16 12:39:29+00:00
# 26267 2023-10-16 12:39:29+00:00
# 26675 2023-10-17 19:59:04+00:00
# 26676 2023-10-17 19:59:04+00:00
#
#                                                     text                   id  \
# 9      Nie ma takiej obietnicy, której polityk nie ob...  1762109123800293376
# 10     Nie ma takiej obietnicy, której polityk nie ob...  1762109123800293376
# 973    Serdeczne dzięki za każdy głos. 🤝\nDla mnie to...  1714195119706890496
# 974    Serdeczne dzięki za każdy głos. 🤝\nDla mnie to...  1714195119706890496
# 1974   @MKierwinski Za to Wy bronicie ambasadora kraj...  1794299341743829248
# ...                                                  ...                  ...
# 25856  Wszystkim Wam serdecznie dziekuję. Za wsparcie...  1714372612611060224
# 26266  .@TakJestTVN24 na antenie @tvn24📺. Zapraszam d...  1713897452430909952
# 26267  .@TakJestTVN24 na antenie @tvn24📺. Zapraszam d...  1713897452430909952
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
# 26676  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
#
#                 author_id                                      edit_controls  \
# 9     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 10    1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 973            1182211615  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 974            1182211615  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1974           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# ...                   ...                                                ...
# 25856          1201875318  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26266 1070635531447558144  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26267 1070635531447558144  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26675           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26676           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings  \
# 9                  False       everyone
# 10                 False       everyone
# 973                False       everyone
# 974                False       everyone
# 1974               False       everyone
# ...                  ...            ...
# 25856                  0       everyone
# 26266                  0       everyone
# 26267                  0       everyone
# 26675                  0       everyone
# 26676                  0       everyone
#
#                                           public_metrics lang  \
# 9      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 10     {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 973    {'retweet_count': 15, 'reply_count': 28, 'like...   pl
# 974    {'retweet_count': 15, 'reply_count': 28, 'like...   pl
# 1974   {'retweet_count': 104, 'reply_count': 26, 'lik...   pl
# ...                                                  ...  ...
# 25856  {'retweet_count': 10, 'reply_count': 6, 'like_...   pl
# 26266  {'retweet_count': 6, 'reply_count': 1, 'like_c...   pl
# 26267  {'retweet_count': 6, 'reply_count': 1, 'like_c...   pl
# 26675  {'retweet_count': 748, 'reply_count': 2136, 'l...   pl
# 26676  {'retweet_count': 748, 'reply_count': 2136, 'l...   pl
#
#       edit_history_tweet_ids     conversation_id  category  \
# 9      [1762109123800293457] 1762109123800293376  Original
# 10     [1762109123800293457] 1762109123800293376  Original
# 973    [1714195119706890463] 1714195119706890496  Original
# 974    [1714195119706890463] 1714195119706890496  Original
# 1974   [1794299341743829316] 1794294356570264064     Reply
# ...                      ...                 ...       ...
# 25856  [1714372612611060222] 1714372612611060224  Original
# 26266  [1713897452430909939] 1713897452430909952  Original
# 26267  [1713897452430909939] 1713897452430909952  Original
# 26675  [1714370461507748145] 1714370461507748096  Original
# 26676  [1714370461507748145] 1714370461507748096  Original
#
#                                      attachments  \
# 9      {'media_keys': ['3_1762109117865304064']}
# 10     {'media_keys': ['3_1762109117865304064']}
# 973    {'media_keys': ['3_1714195114472431617']}
# 974    {'media_keys': ['3_1714195114472431617']}
# 1974                                         NaN
# ...                                          ...
# 25856  {'media_keys': ['7_1714372479076954113']}
# 26266  {'media_keys': ['3_1713897440191885312']}
# 26267  {'media_keys': ['3_1713897440191885312']}
# 26675                                        NaN
# 26676                                        NaN
#
#                                                 entities  \
# 9      {'urls': [{'start': 80, 'end': 103, 'url': 'ht...
# 10     {'urls': [{'start': 80, 'end': 103, 'url': 'ht...
# 973    {'hashtags': [{'start': 251, 'end': 264, 'tag'...
# 974    {'urls': [{'start': 275, 'end': 298, 'url': 'h...
# 1974   {'mentions': [{'start': 0, 'end': 12, 'usernam...
# ...                                                  ...
# 25856  {'urls': [{'start': 81, 'end': 104, 'url': 'ht...
# 26266  {'urls': [{'start': 83, 'end': 106, 'url': 'ht...
# 26267  {'urls': [{'start': 83, 'end': 106, 'url': 'ht...
# 26675  {'mentions': [{'start': 59, 'end': 68, 'userna...
# 26676  {'mentions': [{'start': 59, 'end': 68, 'userna...
#
#                                               username         party  \
# 9           Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 10          Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 973          bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 974          bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1974   KonradBerkowicz_2024-04-16_2024-10-15_vol1.json  Konfederacja
# ...                                                ...           ...
# 25856       StefanKrajewski_2023-10-16_2024-10-15.json           PSL
# 26266          PZgorzelskiP_2023-10-16_2024-10-15.json           PSL
# 26267          PZgorzelskiP_2023-10-16_2024-10-15.json           PSL
# 26675        KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26676        KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
#
#        in_reply_to_user_id context_annotations  \
# 9                      NaN                 NaN
# 10                     NaN                 NaN
# 973                    NaN                 NaN
# 974                    NaN                 NaN
# 1974             308367619                 NaN
# ...                    ...                 ...
# 25856                  NaN                 NaN
# 26266                  NaN                 NaN
# 26267                  NaN                 NaN
# 26675                  NaN                 NaN
# 26676                  NaN                 NaN
#
#                                        referenced_tweets  \
# 9                                                    NaN
# 10                                                   NaN
# 973                                                  NaN
# 974                                                  NaN
# 1974   [{'type': 'replied_to', 'id': '179429435657026...
# ...                                                  ...
# 25856                                                NaN
# 26266                                                NaN
# 26267                                                NaN
# 26675                                                NaN
# 26676                                                NaN
#
#                                     geo
# 9                                   NaN
# 10                                  NaN
# 973    {'place_id': '535f0c2de0121451'}
# 974    {'place_id': '535f0c2de0121451'}
# 1974                                NaN
# ...                                 ...
# 25856  {'place_id': '47c001064da7125c'}
# 26266                               NaN
# 26267                               NaN
# 26675                               NaN
# 26676                               NaN
#
# [243 rows x 20 columns]

# %%
duplicate_text_count = df['text'].duplicated().sum()
print(f"Number of duplicate Text Entries: {duplicate_text_count}")
# Out:
# Number of duplicate Text Entries: 139

# %%
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]
print(f"Rows where BOTH `id` and `text` are duplicated: {len(duplicate_id_text_rows)}")
# Out:
# Rows where BOTH `id` and `text` are duplicated: 227

# %%
# Count occurrences of each ID
id_counts = df['id'].value_counts()
print("Distribution of duplicate IDs:")
print(id_counts.value_counts().sort_index())

# Count occurrences of each text
text_counts = df['text'].value_counts()
print("\nDistribution of duplicate Text Entries:")
print(text_counts.value_counts().sort_index())
# Out:
# Distribution of duplicate IDs:
# count
# 1     26434
# 2       112
# 3         1
# 16        1
# Name: count, dtype: int64
#
# Distribution of duplicate Text Entries:
# count
# 1    26404
# 2      130
# 3        3
# 4        1
# Name: count, dtype: int64

# %%
# Get all duplicate ID rows
duplicate_id_rows = df[df.duplicated(subset=['id'], keep=False)]

# Get all duplicate Text rows
duplicate_text_rows = df[df.duplicated(subset=['text'], keep=False)]

# Get rows where both ID and Text are duplicated
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]

# Compare overlaps
print(f"Rows where ID is duplicated: {len(duplicate_id_rows)}")
print(f"Rows where Text is duplicated: {len(duplicate_text_rows)}")
print(f"Rows where BOTH ID and Text are duplicated: {len(duplicate_id_text_rows)}")

# Find duplicate IDs that are NOT in the text duplicate set
id_not_in_text = duplicate_id_rows[~duplicate_id_rows['id'].isin(duplicate_text_rows['id'])]
print(f"\nDuplicate IDs NOT duplicated in Text: {len(id_not_in_text)}")

# Find duplicate Texts that are NOT in the ID duplicate set
text_not_in_id = duplicate_text_rows[~duplicate_text_rows['text'].isin(duplicate_id_rows['text'])]
print(f"Duplicate Texts NOT duplicated in ID: {len(text_not_in_id)}")
# Out:
# Rows where ID is duplicated: 243
# Rows where Text is duplicated: 273
# Rows where BOTH ID and Text are duplicated: 227
#
# Duplicate IDs NOT duplicated in Text: 16
# Duplicate Texts NOT duplicated in ID: 46

# %%
empty_id_rows = df[df['id'].isna()]
print(f"Rows where `id` is empty (NaN): {len(empty_id_rows)}")
#empty_id_rows

zero_id_rows = df[df['id'] == 0]
print(f"Rows where `id` is 0: {len(zero_id_rows)}")
zero_id_rows
# Out:
# Rows where `id` is empty (NaN): 0
# Rows where `id` is 0: 16
#                      created_at  \
# 19617 2023-10-16 00:00:00+00:00
# 19618 2023-10-16 00:00:00+00:00
# 19619 2023-10-16 00:00:00+00:00
# 19620 2023-10-16 00:00:00+00:00
# 19621 2023-10-16 00:00:00+00:00
# 19622 2023-10-16 00:00:00+00:00
# 19623 2023-10-16 00:00:00+00:00
# 19624 2023-10-16 21:57:00+00:00
# 19625 2023-10-16 22:27:00+00:00
# 19626 2023-10-16 22:41:00+00:00
# 19627 2023-10-16 23:15:00+00:00
# 19628 2023-10-16 23:17:00+00:00
# 19629 2023-10-16 23:18:00+00:00
# 19630 2023-10-16 23:18:00+00:00
# 25410 2024-10-17 18:49:00+00:00
# 25411 2023-10-18 12:46:00+00:00
#
#                                                     text  id  author_id  \
# 19617                                       @tomekbit ✌️   0   61552404
# 19618  @MaciejGdynia Maćku, czekam na oficjalne wynik...   0   61552404
# 19619      @MCichonAlicja Alu, czekamy jeszcze na wynik?   0   61552404
# 19620                                        @REL_76 🥰🥰🥰   0   61552404
# 19621                                      @Gidziela 🥰✌️   0   61552404
# 19622                              @WHaptar Gratulacje👏🥂   0   61552404
# 19623                       @KapenGenezyp Dziękuję❤️❤️❤️   0   61552404
# 19624                                     @jasinska_e ❤️   0   61552404
# 19625                            @BMikolajewska odpowie💪   0   61552404
# 19626                    @DorotaNiedziela ja Tobie też❣️   0   61552404
# 19627  @RGrupinski @StGawlowski i ode mnie Rafale, dl...   0   61552404
# 19628                                  @magosia_10_19 🤛🥰   0   61552404
# 19629                          @3Fritz1 @BMikolajewska 🫡   0   61552404
# 19630      @BernadettaK2 @otoWojciech @BMikolajewska 😂😂😂   0   61552404
# 25410                                       Dziękuję 🤝😀🍀   0 1119834276
# 25411                 @Maciej_ENZ0 Dziękuję i pozdrawiam   0   61552404
#
#       edit_controls possibly_sensitive reply_settings  \
# 19617           NaN                NaN       everyone
# 19618           NaN                NaN       everyone
# 19619           NaN                NaN       everyone
# 19620           NaN                NaN       everyone
# 19621           NaN                NaN       everyone
# 19622           NaN                NaN       everyone
# 19623           NaN                NaN       everyone
# 19624           NaN                NaN       everyone
# 19625           NaN                NaN       everyone
# 19626           NaN                NaN       everyone
# 19627           NaN                NaN       everyone
# 19628           NaN                NaN       everyone
# 19629           NaN                NaN       everyone
# 19630           NaN                NaN       everyone
# 25410           NaN                NaN       everyone
# 25411           NaN                NaN       everyone
#
#                                           public_metrics lang  \
# 19617  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19618  {'retweet_count': 0, 'reply_count': 2, 'like_c...   pl
# 19619  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19620  {'retweet_count': 1, 'reply_count': 1, 'like_c...   pl
# 19621  {'retweet_count': 1, 'reply_count': 0, 'like_c...   pl
# 19622  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19623  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19624  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19625  {'retweet_count': 18, 'reply_count': 31, 'like...   pl
# 19626  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19627  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19628  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19629  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19630  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 25410  {'retweet_count': 2, 'reply_count': 1, 'like_c...   pl
# 25411  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#       edit_history_tweet_ids  conversation_id category attachments entities  \
# 19617                    NaN              NaN    Reply         NaN      NaN
# 19618                    NaN              NaN    Reply         NaN      NaN
# 19619                    NaN              NaN    Reply         NaN      NaN
# 19620                    NaN              NaN    Reply         NaN      NaN
# 19621                    NaN              NaN    Reply         NaN      NaN
# 19622                    NaN              NaN    Reply         NaN      NaN
# 19623                    NaN              NaN    Reply         NaN      NaN
# 19624                    NaN              NaN    Reply         NaN      NaN
# 19625                    NaN              NaN    Reply         NaN      NaN
# 19626                    NaN              NaN    Reply         NaN      NaN
# 19627                    NaN              NaN    Reply         NaN      NaN
# 19628                    NaN              NaN    Reply         NaN      NaN
# 19629                    NaN              NaN    Reply         NaN      NaN
# 19630                    NaN              NaN    Reply         NaN      NaN
# 25410                    NaN              NaN    Quote         NaN      NaN
# 25411                    NaN              NaN    Reply         NaN      NaN
#
#                                       username party  in_reply_to_user_id  \
# 19617     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19618     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19619     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19620     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19621     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19622     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19623     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19624     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19625     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19626     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19627     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19628     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19629     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19630     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 25410  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL                  NaN
# 25411  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL                  NaN
#
#       context_annotations                                  referenced_tweets  \
# 19617                 NaN                                                NaN
# 19618                 NaN                                                NaN
# 19619                 NaN                                                NaN
# 19620                 NaN                                                NaN
# 19621                 NaN                                                NaN
# 19622                 NaN                                                NaN
# 19623                 NaN                                                NaN
# 19624                 NaN                                                NaN
# 19625                 NaN                                                NaN
# 19626                 NaN                                                NaN
# 19627                 NaN                                                NaN
# 19628                 NaN                                                NaN
# 19629                 NaN                                                NaN
# 19630                 NaN                                                NaN
# 25410                 NaN  [{'type': 'quoted', 'id': '1714320722481615223'}]
# 25411                 NaN                                                NaN
#
#        geo
# 19617  NaN
# 19618  NaN
# 19619  NaN
# 19620  NaN
# 19621  NaN
# 19622  NaN
# 19623  NaN
# 19624  NaN
# 19625  NaN
# 19626  NaN
# 19627  NaN
# 19628  NaN
# 19629  NaN
# 19630  NaN
# 25410  NaN
# 25411  NaN

# %% [markdown]
# id 0 of a tweet may mean, that the tweet was, changed, deleted, or that it is not a tweet but something else and was wrongly categorized as one

# %% [markdown]
# We need to remove duplicate tweets + delete the tweets that were 0; because our custom downloading loop occasionally downloads the same tweet two times to ensure completeness.

# %%
import pandas as pd
import numpy as np

# 1) Copy the original DataFrame before cleaning
df_before = df.copy()

# 2) Get the initial size
initial_size = len(df_before)
print(f"Initial number of tweets: {initial_size}")

# 3) Check and report issues with the 'id' column
print("\n--- ID QUALITY CHECK ---")

# Convert id to string for consistent checking
df_before['id'] = df_before['id'].astype(str)

# Check for various problems
missing_ids = df_before['id'].isna()
empty_ids = df_before['id'] == ''
zero_ids = df_before['id'] == '0'
very_short_ids = df_before['id'].str.len() < 5  # Twitter IDs are typically longer

# Report on ID issues
print(f"Missing IDs (NaN): {missing_ids.sum()} ({missing_ids.mean():.2%})")
print(f"Empty IDs: {empty_ids.sum()} ({empty_ids.mean():.2%})")
print(f"Zero IDs ('0'): {zero_ids.sum()} ({zero_ids.mean():.2%})")
print(f"Very short IDs (< 5 chars): {very_short_ids.sum()} ({very_short_ids.mean():.2%})")

# Create a mask for all problematic IDs
problematic_ids_mask = missing_ids | empty_ids | zero_ids | very_short_ids

# Report total problematic IDs
print(f"Total problematic IDs: {problematic_ids_mask.sum()} ({problematic_ids_mask.mean():.2%})")

# 4) First filter out problematic IDs from the original dataset
df_no_problems = df_before[~problematic_ids_mask].copy()
problematic_removed = initial_size - len(df_no_problems)

# 5) Then remove duplicates from the dataset without problematic IDs
df_after = df_no_problems.drop_duplicates(subset=['id'])
duplicates_removed = len(df_no_problems) - len(df_after)

# 6) Calculate removed counts and percentages
remaining_final = len(df_after)
total_removed = initial_size - remaining_final

duplicate_percentage = (duplicates_removed / initial_size) * 100
problematic_percentage = (problematic_removed / initial_size) * 100
total_removed_percentage = (total_removed / initial_size) * 100
remaining_percentage = (remaining_final / initial_size) * 100

# 7) Print comprehensive results
print("\n--- CLEANING SUMMARY ---")
print(f"Initial tweets: {initial_size}")
print(f"Problematic ID tweets removed: {problematic_removed} ({problematic_percentage:.2f}%)")
print(f"Duplicate tweets removed: {duplicates_removed} ({duplicate_percentage:.2f}%)")
print(f"Total tweets removed: {total_removed} ({total_removed_percentage:.2f}%)")
print(f"Tweets remaining: {remaining_final} ({remaining_percentage:.2f}%)")

# 8) Show sample of problematic IDs
if problematic_ids_mask.sum() > 0:
    print("\nSample of problematic IDs:")
    sample_problematic = df_before[problematic_ids_mask].head(5)
    for i, (idx, row) in enumerate(sample_problematic.iterrows()):
        print(f"  {i+1}. ID: '{row['id']}', Text: '{row['text'][:50]}...'")

# 9) Identify the actual duplicate IDs from the data without problematic IDs
duplicate_ids = df_no_problems[df_no_problems.duplicated(subset=['id'], keep='first')]['id'].unique().tolist()
print(f"\nNumber of unique duplicate IDs: {len(duplicate_ids)}")
if duplicate_ids:
    print("Sample of duplicate IDs (first 5):")
    for i, dup_id in enumerate(duplicate_ids[:5]):
        print(f"  {i+1}. {dup_id}")
else:
    print("No duplicates found")

# 10) Keep df_after as the new df
df = df_after
print(f"\nFinal clean dataframe shape: {df.shape}")

# 11) Verify no problematic IDs remain
if (df['id'] == '0').sum() > 0 or df['id'].isna().sum() > 0 or (df['id'] == '').sum() > 0 or (df['id'].str.len() < 5).sum() > 0:
    print("WARNING: Some problematic IDs still remain in the cleaned dataframe")
else:
    print("SUCCESS: All problematic IDs have been removed")
# Out:
# Initial number of tweets: 26677
#
# --- ID QUALITY CHECK ---
# Missing IDs (NaN): 0 (0.00%)
# Empty IDs: 0 (0.00%)
# Zero IDs ('0'): 16 (0.06%)
# Very short IDs (< 5 chars): 16 (0.06%)
# Total problematic IDs: 16 (0.06%)
#
# --- CLEANING SUMMARY ---
# Initial tweets: 26677
# Problematic ID tweets removed: 16 (0.06%)
# Duplicate tweets removed: 114 (0.43%)
# Total tweets removed: 130 (0.49%)
# Tweets remaining: 26547 (99.51%)
#
# Sample of problematic IDs:
#   1. ID: '0', Text: '@tomekbit ✌️...'
#   2. ID: '0', Text: '@MaciejGdynia Maćku, czekam na oficjalne wyniki, ż...'
#   3. ID: '0', Text: '@MCichonAlicja Alu, czekamy jeszcze na wynik?...'
#   4. ID: '0', Text: '@REL_76 🥰🥰🥰...'
#   5. ID: '0', Text: '@Gidziela 🥰✌️...'
#
# Number of unique duplicate IDs: 113
# Sample of duplicate IDs (first 5):
#   1. 1762109123800293376
#   2. 1714195119706890496
#   3. 1794299341743829248
#   4. 1780108572161945856
#   5. 1778400392470056960
#
# Final clean dataframe shape: (26547, 20)
# SUCCESS: All problematic IDs have been removed

# %%
# 1) How many total rows have a duplicate 'id' (including the first occurrence)?
total_dup_rows = df.duplicated(subset=['id'], keep=False).sum()
print(f"Total rows that share a duplicate ID (including the first occurrence): {total_dup_rows}")

# 2) How many rows are "extra" duplicates beyond the first?
extra_dup_rows = df.duplicated(subset=['id'], keep='first').sum()
print(f"Number of extra duplicates beyond the first occurrence: {extra_dup_rows}")

# 3) How many unique IDs appear more than once?
duplicate_ids = df[df.duplicated(subset=['id'], keep=False)]['id'].unique()
num_duplicate_ids = len(duplicate_ids)
print(f"Number of unique IDs that are duplicated: {num_duplicate_ids}")
# Out:
# Total rows that share a duplicate ID (including the first occurrence): 0
# Number of extra duplicates beyond the first occurrence: 0
# Number of unique IDs that are duplicated: 0

# %%
df.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings  \
# 0              False       everyone
# 1              False       everyone
# 2              False       everyone
# 3              False       everyone
# 4              False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids     conversation_id  category  \
# 0  [1765380709114409272] 1765380709114409216  Original
# 1  [1764245727646044196] 1764245727646044160  Original
# 2  [1763931255521857839] 1763931255521857792  Original
# 3  [1763576337078313201] 1763576337078313216  Original
# 4  [1763173358068281524] 1763173358068281600  Original
#
#                                  attachments  \
# 0                                        NaN
# 1  {'media_keys': ['3_1764245720805040128']}
# 2  {'media_keys': ['7_1763931103151202304']}
# 3  {'media_keys': ['3_1763576329385967617']}
# 4  {'media_keys': ['3_1763173351466401792']}
#
#                                             entities  \
# 0                                                NaN
# 1  {'urls': [{'start': 57, 'end': 80, 'url': 'htt...
# 2  {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 3  {'urls': [{'start': 64, 'end': 87, 'url': 'htt...
# 4  {'urls': [{'start': 128, 'end': 151, 'url': 'h...
#
#                                      username         party  \
# 0  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 1  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 2  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 3  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 4  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
#
#    in_reply_to_user_id context_annotations referenced_tweets  geo
# 0                  NaN                 NaN               NaN  NaN
# 1                  NaN                 NaN               NaN  NaN
# 2                  NaN                 NaN               NaN  NaN
# 3                  NaN                 NaN               NaN  NaN
# 4                  NaN                 NaN               NaN  NaN

# %%
# Get the value counts of the 'category' column
category_counts = df['category'].value_counts()

# Display the counts
print(category_counts)

# Get the number of unique categories
unique_category_count = category_counts.count()
print(f"Number of unique categories: {unique_category_count}")
# Out:
# category
# Original    17595
# Reply        5640
# Quote        2826
# Retweet       486
# Name: count, dtype: int64
# Number of unique categories: 4

# %% [markdown]
# We need to delete retweets because they are wrongly provided by the X API. We want to analyze only original tweets, replies, and quotes.

# %%
df = df[df['category'] != 'Retweet']

# %%
df
# Out:
#                      created_at  \
# 0     2024-03-06 14:15:34+00:00
# 1     2024-03-03 11:05:34+00:00
# 2     2024-03-02 14:15:58+00:00
# 3     2024-03-01 14:45:39+00:00
# 4     2024-02-29 12:04:21+00:00
# ...                         ...
# 26671 2023-10-24 10:46:22+00:00
# 26672 2023-10-19 18:05:26+00:00
# 26673 2023-10-19 08:52:05+00:00
# 26674 2023-10-18 16:12:37+00:00
# 26675 2023-10-17 19:59:04+00:00
#
#                                                     text                   id  \
# 0      Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2      Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3      Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
# ...                                                  ...                  ...
# 26671  Formacje demokratyczne będą tworzyć przyszły r...  1716768088052359424
# 26672  Żadne podchody, kłamstwa czy medialne wrzutki ...  1715066644018381312
# 26673  Polska potrzebuje nowego, demokratycznego rząd...  1714927388637696256
# 26674  95 lat temu zmarł generał Tadeusz Jordan Rozwa...  1714675864237924864
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
#
#                 author_id                                      edit_controls  \
# 0     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                   ...                                                ...
# 26671           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26672           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26673           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26674           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26675           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings  \
# 0                  False       everyone
# 1                  False       everyone
# 2                  False       everyone
# 3                  False       everyone
# 4                  False       everyone
# ...                  ...            ...
# 26671                  0       everyone
# 26672                  0       everyone
# 26673                  0       everyone
# 26674                  0       everyone
# 26675                  0       everyone
#
#                                           public_metrics lang  \
# 0      {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# ...                                                  ...  ...
# 26671  {'retweet_count': 344, 'reply_count': 2013, 'l...   pl
# 26672  {'retweet_count': 1149, 'reply_count': 2406, '...   pl
# 26673  {'retweet_count': 185, 'reply_count': 1108, 'l...   pl
# 26674  {'retweet_count': 110, 'reply_count': 354, 'li...   pl
# 26675  {'retweet_count': 748, 'reply_count': 2136, 'l...   pl
#
#       edit_history_tweet_ids     conversation_id  category  \
# 0      [1765380709114409272] 1765380709114409216  Original
# 1      [1764245727646044196] 1764245727646044160  Original
# 2      [1763931255521857839] 1763931255521857792  Original
# 3      [1763576337078313201] 1763576337078313216  Original
# 4      [1763173358068281524] 1763173358068281600  Original
# ...                      ...                 ...       ...
# 26671  [1716768088052359454] 1716768088052359424  Original
# 26672  [1715066644018381294] 1715066644018381312  Original
# 26673  [1714927388637696291] 1714927388637696256  Original
# 26674  [1714675864237924823] 1714675864237924864  Original
# 26675  [1714370461507748145] 1714370461507748096  Original
#
#                                      attachments  \
# 0                                            NaN
# 1      {'media_keys': ['3_1764245720805040128']}
# 2      {'media_keys': ['7_1763931103151202304']}
# 3      {'media_keys': ['3_1763576329385967617']}
# 4      {'media_keys': ['3_1763173351466401792']}
# ...                                          ...
# 26671  {'media_keys': ['3_1716768082402664449']}
# 26672                                        NaN
# 26673                                        NaN
# 26674  {'media_keys': ['3_1714675857548009473']}
# 26675                                        NaN
#
#                                                 entities  \
# 0                                                    NaN
# 1      {'urls': [{'start': 57, 'end': 80, 'url': 'htt...
# 2      {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 3      {'urls': [{'start': 64, 'end': 87, 'url': 'htt...
# 4      {'urls': [{'start': 128, 'end': 151, 'url': 'h...
# ...                                                  ...
# 26671  {'urls': [{'start': 145, 'end': 168, 'url': 'h...
# 26672                                                NaN
# 26673                                                NaN
# 26674  {'urls': [{'start': 264, 'end': 287, 'url': 'h...
# 26675  {'mentions': [{'start': 59, 'end': 68, 'userna...
#
#                                          username         party  \
# 0      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 1      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 2      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 3      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 4      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# ...                                           ...           ...
# 26671   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26672   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26673   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26674   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26675   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
#
#        in_reply_to_user_id                                context_annotations  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 26671                  NaN                                                NaN
# 26672                  NaN                                                NaN
# 26673                  NaN                                                NaN
# 26674                  NaN  [{'domain': {'id': '47', 'name': 'Brand', 'des...
# 26675                  NaN                                                NaN
#
#       referenced_tweets  geo
# 0                   NaN  NaN
# 1                   NaN  NaN
# 2                   NaN  NaN
# 3                   NaN  NaN
# 4                   NaN  NaN
# ...                 ...  ...
# 26671               NaN  NaN
# 26672               NaN  NaN
# 26673               NaN  NaN
# 26674               NaN  NaN
# 26675               NaN  NaN
#
# [26061 rows x 20 columns]

# %%
# Update the 'username' column to keep only the string until '_2' -> split to date range

#df['username'] = df['username'].str.split('_2').str[0].copy()
df.loc[:, 'username'] = df['username'].str.split('_2').str[0]

# %%
category_summary = df['category'].value_counts()
print(category_summary)
total_tweets = category_summary.sum()
print(f"Total tweets: {total_tweets}")
# Out:
# category
# Original    17595
# Reply        5640
# Quote        2826
# Name: count, dtype: int64
# Total tweets: 26061

# %%
# Ensure the created_at column is in datetime format

#df['created_at'] = pd.to_datetime(df['created_at'])
df.loc[:, 'created_at'] = pd.to_datetime(df['created_at'])

# %%
df.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings  \
# 0              False       everyone
# 1              False       everyone
# 2              False       everyone
# 3              False       everyone
# 4              False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids     conversation_id  category  \
# 0  [1765380709114409272] 1765380709114409216  Original
# 1  [1764245727646044196] 1764245727646044160  Original
# 2  [1763931255521857839] 1763931255521857792  Original
# 3  [1763576337078313201] 1763576337078313216  Original
# 4  [1763173358068281524] 1763173358068281600  Original
#
#                                  attachments  \
# 0                                        NaN
# 1  {'media_keys': ['3_1764245720805040128']}
# 2  {'media_keys': ['7_1763931103151202304']}
# 3  {'media_keys': ['3_1763576329385967617']}
# 4  {'media_keys': ['3_1763173351466401792']}
#
#                                             entities         username  \
# 0                                                NaN  Iwaszkiewicz_RJ
# 1  {'urls': [{'start': 57, 'end': 80, 'url': 'htt...  Iwaszkiewicz_RJ
# 2  {'urls': [{'start': 135, 'end': 158, 'url': 'h...  Iwaszkiewicz_RJ
# 3  {'urls': [{'start': 64, 'end': 87, 'url': 'htt...  Iwaszkiewicz_RJ
# 4  {'urls': [{'start': 128, 'end': 151, 'url': 'h...  Iwaszkiewicz_RJ
#
#           party  in_reply_to_user_id context_annotations referenced_tweets  \
# 0  Konfederacja                  NaN                 NaN               NaN
# 1  Konfederacja                  NaN                 NaN               NaN
# 2  Konfederacja                  NaN                 NaN               NaN
# 3  Konfederacja                  NaN                 NaN               NaN
# 4  Konfederacja                  NaN                 NaN               NaN
#
#    geo
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df.loc[1, 'text']
# Out:
# 'Zwróćcie uwagę na punkt 11.\nTu nie ma z czego się śmiać… https://t.co/I5KaMsUDzo'

# %% [markdown]
# Emojis handler

# %%
def add_space_around_emojis(text):
    return ''.join(f' {char} ' if char in emoji.EMOJI_DATA or re.match(r'[\U0001F1E6-\U0001F1FF]', char) else char for char in text)

df['text'] = df['text'].apply(add_space_around_emojis)

def clean_text(text):
    mentions = re.findall(r'@\w+', text)
    text = re.sub(r'@\w+', '', text)
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)
    hashtags = re.findall(r'#\w+', text)
    text = re.sub(r'(?<!\s)([\U0001F600-\U0001F64F])', r' \1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F])(?!\s)', r'\1 ', text)
    return [text, mentions, links, hashtags]

df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # Turn off the warning from lack of loc

# %%
df.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings  \
# 0              False       everyone
# 1              False       everyone
# 2              False       everyone
# 3              False       everyone
# 4              False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids  ...         username         party  \
# 0  [1765380709114409272]  ...  Iwaszkiewicz_RJ  Konfederacja
# 1  [1764245727646044196]  ...  Iwaszkiewicz_RJ  Konfederacja
# 2  [1763931255521857839]  ...  Iwaszkiewicz_RJ  Konfederacja
# 3  [1763576337078313201]  ...  Iwaszkiewicz_RJ  Konfederacja
# 4  [1763173358068281524]  ...  Iwaszkiewicz_RJ  Konfederacja
#
#   in_reply_to_user_id context_annotations referenced_tweets  geo  \
# 0                 NaN                 NaN               NaN  NaN
# 1                 NaN                 NaN               NaN  NaN
# 2                 NaN                 NaN               NaN  NaN
# 3                 NaN                 NaN               NaN  NaN
# 4                 NaN                 NaN               NaN  NaN
#
#                                           text_clean mentions  \
# 0  Policja rzucająca kostką brukową w rolników, p...       []
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...       []
# 2  Równość, ale nie dla wszystkich… \nPani „minis...       []
# 3  Pytanie za sto punktów! \nFirma jakiego państw...       []
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...       []
#
#                        links hashtags
# 0                         []       []
# 1  [https://t.co/I5KaMsUDzo]       []
# 2  [https://t.co/PyKYCMvSN3]       []
# 3  [https://t.co/g61Cb5BsIx]       []
# 4  [https://t.co/b0Q4Tt1FJW]       []
#
# [5 rows x 24 columns]

# %%
df.drop(columns=['entities'], inplace=True)

# %%
# Some additioanl numerical data from tweets is extracted and added to the dataframe as new variables, then the original column is dropped
df['retweet_count'] = df['public_metrics'].apply(lambda x: x['retweet_count'])
df['reply_count'] = df['public_metrics'].apply(lambda x: x['reply_count'])
df['like_count'] = df['public_metrics'].apply(lambda x: x['like_count'])
df['quote_count'] = df['public_metrics'].apply(lambda x: x['quote_count'])
df['impression_count'] = df['public_metrics'].apply(lambda x: x['impression_count'])

df.drop(columns=['public_metrics'], inplace=True)

# %%
df
# Out:
#                      created_at  \
# 0     2024-03-06 14:15:34+00:00
# 1     2024-03-03 11:05:34+00:00
# 2     2024-03-02 14:15:58+00:00
# 3     2024-03-01 14:45:39+00:00
# 4     2024-02-29 12:04:21+00:00
# ...                         ...
# 26671 2023-10-24 10:46:22+00:00
# 26672 2023-10-19 18:05:26+00:00
# 26673 2023-10-19 08:52:05+00:00
# 26674 2023-10-18 16:12:37+00:00
# 26675 2023-10-17 19:59:04+00:00
#
#                                                     text                   id  \
# 0      Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2      Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3      Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
# ...                                                  ...                  ...
# 26671  Formacje demokratyczne będą tworzyć przyszły r...  1716768088052359424
# 26672  Żadne podchody, kłamstwa czy medialne wrzutki ...  1715066644018381312
# 26673  Polska potrzebuje nowego, demokratycznego rząd...  1714927388637696256
# 26674  95 lat temu zmarł generał Tadeusz Jordan Rozwa...  1714675864237924864
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
#
#                 author_id                                      edit_controls  \
# 0     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                   ...                                                ...
# 26671           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26672           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26673           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26674           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26675           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0                  False       everyone   pl  [1765380709114409272]
# 1                  False       everyone   pl  [1764245727646044196]
# 2                  False       everyone   pl  [1763931255521857839]
# 3                  False       everyone   pl  [1763576337078313201]
# 4                  False       everyone   pl  [1763173358068281524]
# ...                  ...            ...  ...                    ...
# 26671                  0       everyone   pl  [1716768088052359454]
# 26672                  0       everyone   pl  [1715066644018381294]
# 26673                  0       everyone   pl  [1714927388637696291]
# 26674                  0       everyone   pl  [1714675864237924823]
# 26675                  0       everyone   pl  [1714370461507748145]
#
#           conversation_id  ...  geo  \
# 0     1765380709114409216  ...  NaN
# 1     1764245727646044160  ...  NaN
# 2     1763931255521857792  ...  NaN
# 3     1763576337078313216  ...  NaN
# 4     1763173358068281600  ...  NaN
# ...                   ...  ...  ...
# 26671 1716768088052359424  ...  NaN
# 26672 1715066644018381312  ...  NaN
# 26673 1714927388637696256  ...  NaN
# 26674 1714675864237924864  ...  NaN
# 26675 1714370461507748096  ...  NaN
#
#                                               text_clean     mentions  \
# 0      Policja rzucająca kostką brukową w rolników, p...           []
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...           []
# 2      Równość, ale nie dla wszystkich… \nPani „minis...           []
# 3      Pytanie za sto punktów! \nFirma jakiego państw...           []
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...           []
# ...                                                  ...          ...
# 26671  Formacje demokratyczne będą tworzyć przyszły r...           []
# 26672  Żadne podchody, kłamstwa czy medialne wrzutki ...           []
# 26673  Polska potrzebuje nowego, demokratycznego rząd...           []
# 26674  95 lat temu zmarł generał Tadeusz Jordan Rozwa...           []
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  [@pisorgpl]
#
#                            links         hashtags retweet_count reply_count  \
# 0                             []               []            17           4
# 1      [https://t.co/I5KaMsUDzo]               []             0           0
# 2      [https://t.co/PyKYCMvSN3]               []             0           0
# 3      [https://t.co/g61Cb5BsIx]               []             0           0
# 4      [https://t.co/b0Q4Tt1FJW]               []             0           0
# ...                          ...              ...           ...         ...
# 26671  [https://t.co/XFrtPBIMiv]               []           344        2013
# 26672                         []               []          1149        2406
# 26673                         []               []           185        1108
# 26674  [https://t.co/TZaorUiXQ1]               []           110         354
# 26675                         []  [#TrzeciaDroga]           748        2136
#
#       like_count quote_count impression_count
# 0            203           0            12028
# 1              2           0              275
# 2              0           0              188
# 3              1           0              170
# 4              0           0              124
# ...          ...         ...              ...
# 26671       4637         100           330379
# 26672      12760         182           689059
# 26673       3443          47           385751
# 26674       1568          21           205237
# 26675      11558         171           676180
#
# [26061 rows x 27 columns]

# %%
df.dtypes
# Out:
# created_at                datetime64[ns, UTC]
# text                                   object
# id                                     object
# author_id                             float64
# edit_controls                          object
# possibly_sensitive                     object
# reply_settings                         object
# lang                                   object
# edit_history_tweet_ids                 object
# conversation_id                       float64
# category                               object
# attachments                            object
# username                               object
# party                                  object
# in_reply_to_user_id                   float64
# context_annotations                    object
# referenced_tweets                      object
# geo                                    object
# text_clean                             object
# mentions                               object
# links                                  object
# hashtags                               object
# retweet_count                           int64
# reply_count                             int64
# like_count                              int64
# quote_count                             int64
# impression_count                        int64
# dtype: object

# %%
df.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0              False       everyone   pl  [1765380709114409272]
# 1              False       everyone   pl  [1764245727646044196]
# 2              False       everyone   pl  [1763931255521857839]
# 3              False       everyone   pl  [1763576337078313201]
# 4              False       everyone   pl  [1763173358068281524]
#
#       conversation_id  ...  geo  \
# 0 1765380709114409216  ...  NaN
# 1 1764245727646044160  ...  NaN
# 2 1763931255521857792  ...  NaN
# 3 1763576337078313216  ...  NaN
# 4 1763173358068281600  ...  NaN
#
#                                           text_clean mentions  \
# 0  Policja rzucająca kostką brukową w rolników, p...       []
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...       []
# 2  Równość, ale nie dla wszystkich… \nPani „minis...       []
# 3  Pytanie za sto punktów! \nFirma jakiego państw...       []
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...       []
#
#                        links  hashtags retweet_count reply_count like_count  \
# 0                         []        []            17           4        203
# 1  [https://t.co/I5KaMsUDzo]        []             0           0          2
# 2  [https://t.co/PyKYCMvSN3]        []             0           0          0
# 3  [https://t.co/g61Cb5BsIx]        []             0           0          1
# 4  [https://t.co/b0Q4Tt1FJW]        []             0           0          0
#
#   quote_count impression_count
# 0           0            12028
# 1           0              275
# 2           0              188
# 3           0              170
# 4           0              124
#
# [5 rows x 27 columns]

# %%
df.dtypes
# Out:
# created_at                datetime64[ns, UTC]
# text                                   object
# id                                     object
# author_id                             float64
# edit_controls                          object
# possibly_sensitive                     object
# reply_settings                         object
# lang                                   object
# edit_history_tweet_ids                 object
# conversation_id                       float64
# category                               object
# attachments                            object
# username                               object
# party                                  object
# in_reply_to_user_id                   float64
# context_annotations                    object
# referenced_tweets                      object
# geo                                    object
# text_clean                             object
# mentions                               object
# links                                  object
# hashtags                               object
# retweet_count                           int64
# reply_count                             int64
# like_count                              int64
# quote_count                             int64
# impression_count                        int64
# dtype: object

# %%
import pandas as pd

# Step 1: Check for duplicate columns and remove them
if df.columns.duplicated().any():
    print("Duplicate columns found! Removing them...")
    df_no_duplicates = df.loc[:, ~df.columns.duplicated()]  # Keep the first occurrence of each column
else:
    df_no_duplicates = df.copy()

# Step 2: Convert 'id' column to string (if needed)
df_no_duplicates['id'] = df_no_duplicates['id'].astype(str)

# Step 3: Check for missing or empty values in 'text' and 'text_clean'
empty_text = df_no_duplicates[df_no_duplicates['text'].isna() | (df_no_duplicates['text'].astype(str).str.strip() == '')]
empty_text_clean = df_no_duplicates[df_no_duplicates['text_clean'].isna() | (df_no_duplicates['text_clean'].astype(str).str.strip() == '')]

print(f"Rows where 'text' is empty or null: {empty_text.shape[0]}")
print(empty_text[['id', 'text', 'text_clean']].head())

print(f"\nRows where 'text_clean' is empty or null: {empty_text_clean.shape[0]}")
empty_text_clean[['id', 'text', 'text_clean']].head()
# Out:
# Rows where 'text' is empty or null: 0
# Empty DataFrame
# Columns: [id, text, text_clean]
# Index: []
#
# Rows where 'text_clean' is empty or null: 374
#                       id                                               text  \
# 27   1844711276577964544                     @Nowa_Nadzieja_ @KONFEDERACJA_
# 103  1838621761090285568                     @KONFEDERACJA_ @Nowa_Nadzieja_
# 265  1821520992629305600                            https://t.co/H9BQbYjylo
# 606  1768213892272959744  @MPerspektywa @AdamAbramowicz1 https://t.co/bz...
# 797  1733398115917402624                            https://t.co/uXKjbwD1DQ
#
#     text_clean
# 27
# 103
# 265
# 606
# 797

# %% [markdown]
# saving data used for translation

# %%
df_clean_text = df[['id', 'text', 'text_clean']]

df_clean_text.to_csv('data/02.processed/data_for_translation.csv', index=False)
df.to_csv('data/02.processed/whole_dataset_for_translation.csv', index=False)

# %%
df_clean_text.dtypes
# Out:
# id            object
# text          object
# text_clean    object
# dtype: object

# %% [markdown]
# reading data used for translation

# %%
# Read CSV with ID column as string (text)
df_clean_text = pd.read_csv('Data/02.processed/data_for_translation.csv', dtype={'id': str})

# Verify the column type
print("ID column type:", df_clean_text['id'].dtype)
print("Sample ID:", df_clean_text['id'].iloc[0], "of type", type(df_clean_text['id'].iloc[0]))
# Out:
# ID column type: object
# Sample ID: 1765380709114409216 of type <class 'str'>

# %%
df_clean_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26061 entries, 0 to 26060
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          26061 non-null  object
#  1   text        26061 non-null  object
#  2   text_clean  25848 non-null  object
# dtypes: object(3)
# memory usage: 610.9+ KB

# %%
df_clean_text
# Out:
#                         id                                               text  \
# 0      1765380709114409216  Policja rzucająca kostką brukową w rolników, p...
# 1      1764245727646044160  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...
# 2      1763931255521857792  Równość, ale nie dla wszystkich… \nPani „minis...
# 3      1763576337078313216  Pytanie za sto punktów! \nFirma jakiego państw...
# 4      1763173358068281600  Ukraina jeździ na polskim paliwie. \n\nPrzypom...
# ...                    ...                                                ...
# 26056  1716768088052359424  Formacje demokratyczne będą tworzyć przyszły r...
# 26057  1715066644018381312  Żadne podchody, kłamstwa czy medialne wrzutki ...
# 26058  1714927388637696256  Polska potrzebuje nowego, demokratycznego rząd...
# 26059  1714675864237924864  95 lat temu zmarł generał Tadeusz Jordan Rozwa...
# 26060  1714370461507748096  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...
#
#                                               text_clean
# 0      Policja rzucająca kostką brukową w rolników, p...
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...
# 2      Równość, ale nie dla wszystkich… \nPani „minis...
# 3      Pytanie za sto punktów! \nFirma jakiego państw...
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...
# ...                                                  ...
# 26056  Formacje demokratyczne będą tworzyć przyszły r...
# 26057  Żadne podchody, kłamstwa czy medialne wrzutki ...
# 26058  Polska potrzebuje nowego, demokratycznego rząd...
# 26059  95 lat temu zmarł generał Tadeusz Jordan Rozwa...
# 26060  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...
#
# [26061 rows x 3 columns]

# %%
# Filter rows where 'text_clean' is null OR empty (after stripping whitespace)
null_or_empty_text_clean = df_clean_text[
    df_clean_text['text_clean'].isna() | 
    (df_clean_text['text_clean'].astype(str).str.strip() == '')
]

# Display the number of problematic rows
print(f"Rows where 'text_clean' is null or empty: {null_or_empty_text_clean.shape[0]}")

# Show the affected rows
null_or_empty_text_clean[['id', 'text', 'text_clean']]
# Out:
# Rows where 'text_clean' is null or empty: 374
#                         id                                               text  \
# 26     1844711276577964544                     @Nowa_Nadzieja_ @KONFEDERACJA_
# 102    1838621761090285568                     @KONFEDERACJA_ @Nowa_Nadzieja_
# 264    1821520992629305600                            https://t.co/H9BQbYjylo
# 605    1768213892272959744  @MPerspektywa @AdamAbramowicz1 https://t.co/bz...
# 796    1733398115917402624                            https://t.co/uXKjbwD1DQ
# ...                    ...                                                ...
# 24206  1791516338030051840                            https://t.co/63YfThCg0s
# 24380  1725621854751047936  @bmarganiec @szymon_holownia https://t.co/5SI3...
# 24381  1725621750354923776  @MartaWitecka1 @szymon_holownia https://t.co/o...
# 24698  1846211673155162368                            https://t.co/fYTVm6hzqS
# 25730  1828937104459768064                            https://t.co/TBhHGPnnit
#
#       text_clean
# 26
# 102
# 264          NaN
# 605
# 796          NaN
# ...          ...
# 24206        NaN
# 24380
# 24381
# 24698        NaN
# 25730        NaN
#
# [374 rows x 3 columns]

# %%
# 1. Print the total number of rows in df_clean_text
print("Total rows in df_clean_text:", len(df_clean_text))

# 2. Filter out rows where 'text_clean' is null or an empty string (after stripping whitespace)
valid_rows = df_clean_text[
    ~(
        df_clean_text['text_clean'].isna() 
        | (df_clean_text['text_clean'].astype(str).str.strip() == '')
    )
]

# 3. Print the number of those valid (non-empty) rows
print("Rows with non-empty 'text_clean':", len(valid_rows))
# Out:
# Total rows in df_clean_text: 26061
# Rows with non-empty 'text_clean': 25687

# %% [markdown]
# reading translation dataset

# %%
df_en_text = pd.read_csv('data/02.processed/tweets_translation/text_clean_en1.csv')
df_en_text
# Out:
#                         id                                         text_clean  \
# 0      1846086999964283136   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1      1845748090461966592   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2      1845366606823657984   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3      1845006197847360000   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4      1844633149784891648   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
# ...                    ...                                                ...
# 25683  1717754912929435904   Gdyby coś się zmieniło, jestem do dyspozycji ...
# 25684  1717638951333245440  Zaświadczenie o wyborze na Posła na Sejm RP  🇵...
# 25685  1717063007988052224  Ceny paliw na stacjach Orlen rosną w szybkim t...
# 25686  1716417809469538560  Taki mandat to ja rozumiem 😃 \nDziękuję za każ...
# 25687  1714372612611060224  Wszystkim Wam serdecznie dziekuję. Za wsparcie...
#
#                                            text_clean_en
# 0       ❌ The Polish government intends to build 49 F...
# 1       ❌ The cesspool is breaking out and it's getti...
# 2       ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3       🆘 The pharmaceutical company GSK will pay ove...
# 4       ❌ WHAT IS GOING ON HERE? In October 2024, her...
# ...                                                  ...
# 25683    If anything changes, I am at your disposal 😄 👍
# 25684  I also have a certificate of election as a Mem...
# 25685  Fuel prices at Orlen stations are rising rapid...
# 25686  I understand this mandate 😃 \nThank you for ev...
# 25687  Thank you all very much. For your support, for...
#
# [25688 rows x 3 columns]

# %%
# to correction later on - delete it after correction
df_en_text_v2 = pd.read_csv('data/02.processed/tweets_translation/data-for-translation_v2.csv')
df_en_text_v2

df_en_text_v2['id'] = df_en_text_v2['id'].astype(str)
df_en_text_v2 = df_en_text_v2[['id', 'text_clean', 'text_clean_en']].copy()

# %%
print(df_en_text.shape[1])

print(df.shape[1])

print(df_en_text_v2.shape[1])
# Out:
# 3
# 27
# 3

# %%
df_en_text.dtypes
# Out:
# id               object
# text_clean       object
# text_clean_en    object
# dtype: object

# %%
df_en_text_v2.dtypes
# Out:
# id               object
# text_clean       object
# text_clean_en    object
# dtype: object

# %%
print(len(df_clean_text))
df_clean_text[df_clean_text["id"]=="1765380709114409216"]
# Out:
# 26061
#                     id                                               text  \
# 0  1765380709114409216  Policja rzucająca kostką brukową w rolników, p...
#
#                                           text_clean
# 0  Policja rzucająca kostką brukową w rolników, p...

# %%
print(len(df))
df[df["id"]=="1765380709114409216"]
# Out:
# 26061
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0              False       everyone   pl  [1765380709114409272]
#
#       conversation_id  ...  geo  \
# 0 1765380709114409216  ...  NaN
#
#                                           text_clean mentions links  hashtags  \
# 0  Policja rzucająca kostką brukową w rolników, p...       []    []        []
#
#   retweet_count reply_count like_count quote_count impression_count
# 0            17           4        203           0            12028
#
# [1 rows x 27 columns]

# %%
print(len(df_en_text_v2))
df_en_text_v2 #1765380709114409216 #1713706323672539392
# Out:
# 30
#                      id                                         text_clean  \
# 0   1807795860480160000   🇳  🇱  Holenderski klub NAC Breda przygotował ...
# 1   1729073656112800000  Serdecznie zapraszam na spotkanie z redaktorem...
# 2   1722289952547840000  Zapraszam na spotkanie członków i sympatyków #...
# 3   1820187117135520000  Jak podaje NASK: około 15 tysięcy „trolli”, od...
# 4   1783776678776320000                                               Tak.
# 5   1747645626219680000         Jeśli się boisz, już jesteś niewolnikiem!
# 6   1735658052001440000  Obrzydliwy list Episkopatu w sprawie krajowego...
# 7   1798344610043040000  Gdybym głosowała w okręgu łączącym województwo...
# 8   1757761149565600000  Zmiana definicji zgwałcenia wraca do  razem z ...
# 9   1788269097861440000                                     Powodzenia!!!!
# 10  1743718567692960000  Promować to można kurczaki w supermarkecie a n...
# 11  1767216706542240000   ❤ ️ Drogie Sołtyski, Drodzy Sołtysi  ❗ \n\n 🌹...
# 12  1748795393121440000   🗣 ️  funkcjonuje jak przed 15 października, w...
# 13  1764988413655040000  Jutro, kiedy ma być ogromny protest Rolników, ...
# 14  1745397214313120000  Postawili barierki przed parlamentem, nikogo n...
# 15  1841911914529440000  „Nasz dotychczasowy model jest skończony. Jest...
# 16  1775116997908480000                    #JesteśmyNaTAK 🇵  🇱  🇵  🇱  🇵  🇱
# 17  1730509309488800000  Panie , słuchał pan wywiadu pani  dziś?  stwie...
# 18  1797670872519680000  Jak mówią dużo o patriotyźmie, to znaczy będą ...
# 19  1805968829509440000  Stworzymy najnowocześniejsze lotnisko w Europi...
# 20  1794649250460320000   Dużo zdrowia dla wszystkich Mam 🌹 \n#DzienMatki
# 21  1746498006428320000  Zachęcam wszystkie Funkcjonariuszki, Funkcjona...
# 22  1719951364879520000  Proszę się nie martwić. To gwarantuje że w pre...
# 23  1788534655928480000  Stolica pracuje także nocą. Na przykład testuj...
# 24  1721119285148320000  Tak pracuje stolica. Bez przerwy! Zobaczcie, c...
# 25  1737029411151520000  No to zapinamy pasy. Nowi szefowie służb, w ty...
# 26  1842201835655840000  Nie ma szans ;) ścisła tajemnica obłożona klau...
# 27  1745721711478080000  Dziś (12.01) o godz. 18:45 będę gościem  i wez...
# 28  1727044221847360000                                  Gratuluję Jacku 👍
# 29  1841456934978720000  Spotkanie parlamentarzystów Ruchu Ludowego 🍀  ...
#
#                                         text_clean_en
# 0    🇳 🇱 The Dutch club NAC Breda has prepared spe...
# 1   I cordially invite you to a meeting with edito...
# 2   I invite you to a meeting of members and suppo...
# 3   According to NASK: about 15,000 "trolls" have ...
# 4     @DonBrajo @krzysztofbosak @szymon_holownia Yes.
# 5   If you are afraid, you are already a slave! ht...
# 6   A disgusting letter from the Episcopate regard...
# 7   If I voted in the district connecting the West...
# 8   Changing the definition of rape returns to @Se...
# 9   @magdadropek @__Lewica @fraczekkk @g_garbolins...
# 10  @PatrykJaki You can promote chicken in the sup...
# 11   ❤ ️ Dear Village Heads, Dear Village Heads ❗ ...
# 12   🗣 ️ @pisorgpl functions as before October 15,...
# 13  Tomorrow, when there is to be a huge protest b...
# 14  They put up barriers in front of the parliamen...
# 15  “Our current model is finished. We are overreg...
# 16    #We'reNaTAK 🇵 🇱 🇵 🇱 🇵 🇱 https://t.co/E5gjbNQ7jr
# 17  Mr. @KosiniakKamysz, did you listen to Ms. @he...
# 18  If they talk a lot about patriotism, it means ...
# 19  We will create the most modern airport in Euro...
# 20  Lots of health to all mothers 🌹 \n#Mother'sDay...
# 21  I encourage all Officers and Civilian Employee...
# 22  @BarbaraJar39036 @ANWac1 @NewsPlatforma Please...
# 23  The capital also works at night. For example, ...
# 24  This is how the capital works. Non-stop! See w...
# 25  Well, let's fasten our seat belts. New heads o...
# 26  @JaBozena No chance ;) top secret covered by t...
# 27  Today (12/01) at 18:45 I will be a guest of @T...
# 28              @jacek_protas Congratulations Jacek 👍
# 29  Meeting of parliamentarians of the People's Mo...

# %% [markdown]
# merging second version of translated dataset with original one

# %%
# Step 1: Make sure IDs are strings
df['id'] = df['id'].astype(str)
df_en_text['id'] = df_en_text['id'].astype(str)
df_en_text_v2['id'] = df_en_text_v2['id'].astype(str)

# Step 2: Combine the two translation sets (v1 + v2)
df_en_combined = pd.concat([df_en_text, df_en_text_v2], ignore_index=True)

# Step 3: Drop duplicates by 'id' to keep only the latest (e.g., if v2 is more up-to-date)
df_en_combined = df_en_combined.drop_duplicates(subset='id', keep='last')

# Step 4: Merge back into the full dataset to get a unified view
df_merged = df.merge(df_en_combined[['id', 'text_clean_en']], on='id', how='left')

print(f"Total rows after merge: {len(df_merged)} (should be 26061)")
# Out:
# Total rows after merge: 26061 (should be 26061)

# %% [markdown]
# check wether the data went correctly

# %%
df_merged[df_merged["id"]=="1807795860480160000"]
# Out:
#                    created_at  \
# 420 2024-07-01 15:18:15+00:00
#
#                                                   text                   id  \
# 420   🇳  🇱  Holenderski klub NAC Breda przygotował ...  1807795860480160000
#
#      author_id                                      edit_controls  \
# 420 1182211615  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#     possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 420              False       everyone   pl  [1807795860480159980]
#
#         conversation_id  ...  \
# 420 1807795860480160000  ...
#
#                                             text_clean mentions  \
# 420   🇳  🇱  Holenderski klub NAC Breda przygotował ...       []
#
#                                                  links hashtags  \
# 420  [https://t.co/WI736ocWQ7, https://t.co/ANX3x4e...       []
#
#      retweet_count reply_count like_count quote_count impression_count  \
# 420              5           1         24           0              603
#
#                                          text_clean_en
# 420   🇳 🇱 The Dutch club NAC Breda has prepared spe...
#
# [1 rows x 28 columns]

# %%
# Check how many rows still have missing or empty translations
missing_translation_mask = df_merged['text_clean_en'].isna() | (df_merged['text_clean_en'].str.strip() == '')

# Show some of them
df_missing_translation = df_merged[missing_translation_mask]
print(f"Rows without translation: {df_missing_translation.shape[0]}")
display(df_missing_translation[['id', 'text', 'text_clean', 'text_clean_en']].head())
# Out:
# Rows without translation: 374
#                       id                                               text  \
# 26   1844711276577964544                     @Nowa_Nadzieja_ @KONFEDERACJA_
# 102  1838621761090285568                     @KONFEDERACJA_ @Nowa_Nadzieja_
# 264  1821520992629305600                            https://t.co/H9BQbYjylo
# 605  1768213892272959744  @MPerspektywa @AdamAbramowicz1 https://t.co/bz...
# 796  1733398115917402624                            https://t.co/uXKjbwD1DQ
#
#     text_clean text_clean_en
# 26                       NaN
# 102                      NaN
# 264                      NaN
# 605                      NaN
# 796                      NaN

# %% [markdown]
# removing rows withtout translation due to possessing text that is not being analyzed by our research

# %%
# Remove them
df_clean_translated = df_merged[~missing_translation_mask].copy()

print(f"Remaining rows with proper translation: {df_clean_translated.shape[0]}")
# Out:
# Remaining rows with proper translation: 25687

# %%
df_clean_translated.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0              False       everyone   pl  [1765380709114409272]
# 1              False       everyone   pl  [1764245727646044196]
# 2              False       everyone   pl  [1763931255521857839]
# 3              False       everyone   pl  [1763576337078313201]
# 4              False       everyone   pl  [1763173358068281524]
#
#       conversation_id  ...                                         text_clean  \
# 0 1765380709114409216  ...  Policja rzucająca kostką brukową w rolników, p...
# 1 1764245727646044160  ...  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...
# 2 1763931255521857792  ...  Równość, ale nie dla wszystkich… \nPani „minis...
# 3 1763576337078313216  ...  Pytanie za sto punktów! \nFirma jakiego państw...
# 4 1763173358068281600  ...  Ukraina jeździ na polskim paliwie. \n\nPrzypom...
#
#   mentions                      links hashtags  retweet_count reply_count  \
# 0       []                         []       []             17           4
# 1       []  [https://t.co/I5KaMsUDzo]       []              0           0
# 2       []  [https://t.co/PyKYCMvSN3]       []              0           0
# 3       []  [https://t.co/g61Cb5BsIx]       []              0           0
# 4       []  [https://t.co/b0Q4Tt1FJW]       []              0           0
#
#   like_count quote_count impression_count  \
# 0        203           0            12028
# 1          2           0              275
# 2          0           0              188
# 3          1           0              170
# 4          0           0              124
#
#                                        text_clean_en
# 0  Police throwing paving stones at farmers, MP s...
# 1  Please pay attention to point 11.\nThere's not...
# 2  Equality, but not for everyone... \nThe "minis...
# 3  One hundred point question! \nWhich country's ...
# 4  Ukraine runs on Polish fuel. \n\nI would like ...
#
# [5 rows x 28 columns]

# %%
df_en_text['id'] = df_en_text['id'].astype(str)

# Try the merge with different suffixes
df_merged = df.merge(
    df_en_text, 
    on='id', 
    how='outer',
    suffixes=('_df', '_df_en')  # Use _orig and _en suffixes to avoid conflicts
)

# Check the merged dataframe
print("\nMerged dataframe shape:", df_merged.shape)
print("Merged dataframe columns:")
print(df_merged.columns.tolist())
# Out:
# Merged dataframe shape: (26671, 29)
# Merged dataframe columns:
# ['created_at', 'text', 'id', 'author_id', 'edit_controls', 'possibly_sensitive', 'reply_settings', 'lang', 'edit_history_tweet_ids', 'conversation_id', 'category', 'attachments', 'username', 'party', 'in_reply_to_user_id', 'context_annotations', 'referenced_tweets', 'geo', 'text_clean_df', 'mentions', 'links', 'hashtags', 'retweet_count', 'reply_count', 'like_count', 'quote_count', 'impression_count', 'text_clean_df_en', 'text_clean_en']

# %%
df_merged.columns
# Out:
# Index(['created_at', 'text', 'id', 'author_id', 'edit_controls',
#        'possibly_sensitive', 'reply_settings', 'lang',
#        'edit_history_tweet_ids', 'conversation_id', 'category', 'attachments',
#        'username', 'party', 'in_reply_to_user_id', 'context_annotations',
#        'referenced_tweets', 'geo', 'text_clean_df', 'mentions', 'links',
#        'hashtags', 'retweet_count', 'reply_count', 'like_count', 'quote_count',
#        'impression_count', 'text_clean_df_en', 'text_clean_en'],
#       dtype='object')

# %%
# First make sure text_clean columns have the same cleaning applied in both dataframes
# Rename the columns in advance
df = df.rename(columns={'text_clean': 'text_clean_orig'})
df_en_text = df_en_text.rename(columns={'text_clean': 'text_clean_orig_en', 'text_clean_en': 'text_clean_en'})

# Merge on the cleaned text
df_merged_by_text = df.merge(
    df_en_text, 
    left_on='text_clean_orig',
    right_on='text_clean_orig_en',
    how='outer',
    suffixes=('_orig', '_en')
)

# Check the results
print("Merged by text dataframe shape:", df_merged_by_text.shape)
print("Number of matched texts:", df_merged_by_text['text_clean_orig'].notna().sum())
# Out:
# Merged by text dataframe shape: (33863, 30)
# Number of matched texts: 26304

# %%
len(df_merged_by_text)
# Out:
# 33863

# %%
df_merged_by_text
# Out:
#                      created_at                     text              id_orig  \
# 0     2024-08-08 12:17:01+00:00  https://t.co/H9BQbYjylo  1821520992629305600
# 1     2023-12-09 08:08:10+00:00  https://t.co/uXKjbwD1DQ  1733398115917402624
# 2     2024-05-06 10:10:40+00:00  https://t.co/2Xy4VCJzgn  1787424735313231872
# 3     2024-08-22 15:39:00+00:00  https://t.co/E7RggSHg8n  1826645252612243968
# 4     2024-08-02 17:33:42+00:00  https://t.co/Rp636XGpCR  1819426362068758784
# ...                         ...                      ...                  ...
# 33858                       NaT                      NaN                  NaN
# 33859                       NaT                      NaN                  NaN
# 33860                       NaT                      NaN                  NaN
# 33861                       NaT                      NaN                  NaN
# 33862                       NaT                      NaN                  NaN
#
#                author_id                                      edit_controls  \
# 0             1182211615  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1             1182211615  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2             1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3     941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 4     941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# ...                  ...                                                ...
# 33858                NaN                                                NaN
# 33859                NaN                                                NaN
# 33860                NaN                                                NaN
# 33861                NaN                                                NaN
# 33862                NaN                                                NaN
#
#       possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0                  False       everyone  zxx  [1821520992629305694]
# 1                  False       everyone  zxx  [1733398115917402576]
# 2                  False       everyone  zxx  [1787424735313231995]
# 3                  False       everyone  zxx  [1826645252612243877]
# 4                  False       everyone  zxx  [1819426362068758830]
# ...                  ...            ...  ...                    ...
# 33858                NaN            NaN  NaN                    NaN
# 33859                NaN            NaN  NaN                    NaN
# 33860                NaN            NaN  NaN                    NaN
# 33861                NaN            NaN  NaN                    NaN
# 33862                NaN            NaN  NaN                    NaN
#
#           conversation_id  ...                      links hashtags  \
# 0     1821520944772350464  ...  [https://t.co/H9BQbYjylo]       []
# 1     1733397514844299264  ...  [https://t.co/uXKjbwD1DQ]       []
# 2     1787424647287349760  ...  [https://t.co/2Xy4VCJzgn]       []
# 3     1826645150149607680  ...  [https://t.co/E7RggSHg8n]       []
# 4     1819426313381277696  ...  [https://t.co/Rp636XGpCR]       []
# ...                   ...  ...                        ...      ...
# 33858                 NaN  ...                        NaN      NaN
# 33859                 NaN  ...                        NaN      NaN
# 33860                 NaN  ...                        NaN      NaN
# 33861                 NaN  ...                        NaN      NaN
# 33862                 NaN  ...                        NaN      NaN
#
#       retweet_count reply_count  like_count quote_count impression_count  \
# 0                 0           1          12           0              863
# 1                 0           0           1           0              418
# 2                 0           3          11           0             3409
# 3                 4           0          13           0              740
# 4                 1           1           8           0              487
# ...             ...         ...         ...         ...              ...
# 33858           NaN         NaN         NaN         NaN              NaN
# 33859           NaN         NaN         NaN         NaN              NaN
# 33860           NaN         NaN         NaN         NaN              NaN
# 33861           NaN         NaN         NaN         NaN              NaN
# 33862           NaN         NaN         NaN         NaN              NaN
#
#                      id_en    text_clean_orig_en    text_clean_en
# 0                      NaN                   NaN              NaN
# 1                      NaN                   NaN              NaN
# 2                      NaN                   NaN              NaN
# 3                      NaN                   NaN              NaN
# 4                      NaN                   NaN              NaN
# ...                    ...                   ...              ...
# 33858  1790254455390138368                🫶  ❤ ️            🫶 ❤ ️
# 33859  1808739852193534464                  🫶  🏻              🫶 🏻
# 33860  1778108858629488896                  🫶  🏻              🫶 🏻
# 33861  1773114732536316160        🫶  🤍  ❤ ️ 🥰  🥰      🫶 🤍 ❤ ️ 🥰 🥰
# 33862  1772753042229678592  🫶  🫶  🫶  🤍  ❤ ️ 🇵  🇱  🫶 🫶 🫶 🤍 ❤ ️ 🇵 🇱
#
# [33863 rows x 30 columns]

# %%
# Ensure IDs are strings in both dataframes
df['id'] = df['id'].astype(str)
df_en_text['id'] = df_en_text['id'].astype(str)

# First, rename the text_clean columns in both dataframes to avoid conflicts
df = df.rename(columns={'text_clean': 'text_clean_orig'})
df_en_text = df_en_text.rename(columns={'text_clean': 'text_clean_orig_en', 'text_clean_en': 'text_clean_en'})

# Now merge with suffixes for other potential column conflicts
df_merged = df.merge(
    df_en_text, 
    on='id', 
    how='outer',
    suffixes=('_orig', '_en')  # For any other columns with same names
)

# Check the merged dataframe
print("Merged dataframe shape:", df_merged.shape)
print("Merged dataframe columns:")
print(df_merged.columns.tolist())

# Check ID matching correctness
print("\nChecking ID matching correctness:")
# Create separate columns with IDs from both sources for comparison
df_merged['id_from_orig'] = df_merged['id']
df_merged['id_from_en'] = df_merged['id']

# Mark which rows came from which source
df_merged['in_orig_df'] = ~df_merged['text_clean_orig'].isna()
df_merged['in_en_df'] = ~df_merged['text_clean_en'].isna()

# Count matches and mismatches
both_sources = df_merged['in_orig_df'] & df_merged['in_en_df']
only_orig = df_merged['in_orig_df'] & ~df_merged['in_en_df']
only_en = ~df_merged['in_orig_df'] & df_merged['in_en_df']

print(f"Rows in both sources: {both_sources.sum()} ({both_sources.sum()/len(df_merged):.2%})")
print(f"Rows only in original df: {only_orig.sum()} ({only_orig.sum()/len(df_merged):.2%})")
print(f"Rows only in en_text df: {only_en.sum()} ({only_en.sum()/len(df_merged):.2%})")

# Display a few examples of the merged dataframe
print("\nSample rows from merged dataframe:")
print(df_merged[['id', 'text_clean_orig', 'text_clean_en']].head())

# Check for some mismatched pairs (if any)
if both_sources.sum() > 0:
    print("\nSample of matched pairs (text in both sources):")
    sample_matches = df_merged[both_sources][['id', 'text_clean_orig', 'text_clean_en']].head()
    for i, row in sample_matches.iterrows():
        print(f"\nID: {row['id']}")
        print(f"Original: {row['text_clean_orig']}")
        print(f"English:  {row['text_clean_en']}")
# Out:
# Merged dataframe shape: (26671, 29)
# Merged dataframe columns:
# ['created_at', 'text', 'id', 'author_id', 'edit_controls', 'possibly_sensitive', 'reply_settings', 'lang', 'edit_history_tweet_ids', 'conversation_id', 'category', 'attachments', 'username', 'party', 'in_reply_to_user_id', 'context_annotations', 'referenced_tweets', 'geo', 'text_clean_orig', 'mentions', 'links', 'hashtags', 'retweet_count', 'reply_count', 'like_count', 'quote_count', 'impression_count', 'text_clean_orig_en', 'text_clean_en']
#
# Checking ID matching correctness:
# Rows in both sources: 25078 (94.03%)
# Rows only in original df: 983 (3.69%)
# Rows only in en_text df: 610 (2.29%)
#
# Sample rows from merged dataframe:
#                     id                                    text_clean_orig  \
# 0  1713706323672539392  Obiecywałem i mówiłem od kilkunastu miesięcy, ...
# 1  1713710653582504448  Kochani :)) emocje jeszcze nie opadły, noc kró...
# 2  1713711170186522624                                  Ja będę o 7.00 💪
# 3  1713711915644424704                                 To widzimy się  💙
# 4  1713716477377892352  Przepięknie jest dostawać wyniki z kolejnych k...
#
#                                        text_clean_en
# 0  In this case it is difficult to disagree with ...
# 1           I see that nothing will be hidden here 😂
# 2                                      Totally agree
# 3         I'm really glad! This just motivates me!!!
# 4  A new MP must get to know the hosts in his or ...
#
# Sample of matched pairs (text in both sources):
#
# ID: 1713706323672539392
# Original: Obiecywałem i mówiłem od kilkunastu miesięcy, wygramy ze złodziejskim rządem . I tak się stało. Teraz spokój, rozsądek, współpraca, zmiana i rozliczenia. Tak będzie. #Trela2023
# English:  In this case it is difficult to disagree with Wolski. PiS propaganda worse than in the 1970s.
#
# ID: 1713710653582504448
# Original: Kochani :)) emocje jeszcze nie opadły, noc krótka, a ja Was zapraszam o 7:20 do   😊  wstańcie ze mną!
# English:  I see that nothing will be hidden here 😂
#
# ID: 1713711170186522624
# Original:   Ja będę o 7.00 💪
# English:  Totally agree
#
# ID: 1713711915644424704
# Original:   To widzimy się  💙
# English:  I'm really glad! This just motivates me!!!
#
# ID: 1713716477377892352
# Original: Przepięknie jest dostawać wyniki z kolejnych komisji, np. w Kielcach czy Skarżysku, w których dzięki Wam wygrałam z prezesem.
#
# W Świętokrzyskiem  ❤ ️ Symboliczne i niesamowite.
#
# I choć prezes w wielu miejscach na pewno mocno nadrobi, te małe cząstkowe wyniki i Wasza radość -  💙 .
# English:  A new MP must get to know the hosts in his or her constituency. That's why I'm starting my journey today and by the end of the year I will visit all mayors, commune heads and starostas of district 12, which I have the honor to represent in the Sejm of the 10th term.  The first stop is Andrychów and a meeting with the gentlemen…

# %%
df_en_text[df_en_text["id"]=="1713706323672539392"]
# Out:
#                         id                                 text_clean_orig_en  \
# 10569  1713706323672539392  Akurat w tym przypadku trudno się z Wolskim ni...
#
#                                            text_clean_en
# 10569  In this case it is difficult to disagree with ...

# %%
df[df["id"]=="1713706323672539392"]
# Out:
#                      created_at  \
# 10569 2023-10-16 00:00:01+00:00
#
#                                                     text                   id  \
# 10569  Obiecywałem i mówiłem od kilkunastu miesięcy, ...  1713706323672539392
#
#        author_id                                      edit_controls  \
# 10569  547089308  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 10569              False       everyone   pl  [1713706323672539456]
#
#           conversation_id  ...  geo  \
# 10569 1713706323672539392  ...  NaN
#
#                                          text_clean_orig     mentions links  \
# 10569  Obiecywałem i mówiłem od kilkunastu miesięcy, ...  [@pisorgpl]    []
#
#            hashtags retweet_count reply_count like_count quote_count  \
# 10569  [#Trela2023]            24          32        244           2
#
#       impression_count
# 10569             6545
#
# [1 rows x 27 columns]

# %%
df_merged
# Out:
#                      created_at  \
# 0     2023-10-16 00:00:01+00:00
# 1     2023-10-16 00:17:13+00:00
# 2     2023-10-16 00:19:16+00:00
# 3     2023-10-16 00:22:14+00:00
# 4     2023-10-16 00:40:22+00:00
# ...                         ...
# 26666                       NaT
# 26667                       NaT
# 26668                       NaT
# 26669                       NaT
# 26670                       NaT
#
#                                                     text                   id  \
# 0      Obiecywałem i mówiłem od kilkunastu miesięcy, ...  1713706323672539392
# 1      Kochani :)) emocje jeszcze nie opadły, noc kró...  1713710653582504448
# 2        @OklaDrewnowicz @Radio_TOK_FM Ja będę o 7.00 💪   1713711170186522624
# 3          @poselTTrela @Radio_TOK_FM To widzimy się  💙   1713711915644424704
# 4      Przepięknie jest dostawać wyniki z kolejnych k...  1713716477377892352
# ...                                                  ...                  ...
# 26666                                                NaN                  nan
# 26667                                                NaN                  nan
# 26668                                                NaN                  nan
# 26669                                                NaN                  nan
# 26670                                                NaN                  nan
#
#        author_id                                      edit_controls  \
# 0      547089308  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1     3305466189  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      547089308  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3     3305466189  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 4     3305466189  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...          ...                                                ...
# 26666        NaN                                                NaN
# 26667        NaN                                                NaN
# 26668        NaN                                                NaN
# 26669        NaN                                                NaN
# 26670        NaN                                                NaN
#
#       possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0                  False       everyone   pl  [1713706323672539456]
# 1                      0       everyone   pl  [1713710653582504333]
# 2                  False       everyone   pl  [1713711170186522695]
# 3                      0       everyone   pl  [1713711915644424683]
# 4                      0       everyone   pl  [1713716477377892441]
# ...                  ...            ...  ...                    ...
# 26666                NaN            NaN  NaN                    NaN
# 26667                NaN            NaN  NaN                    NaN
# 26668                NaN            NaN  NaN                    NaN
# 26669                NaN            NaN  NaN                    NaN
# 26670                NaN            NaN  NaN                    NaN
#
#           conversation_id  ...                          mentions links  \
# 0     1713706323672539392  ...                       [@pisorgpl]    []
# 1     1713710653582504448  ...                   [@Radio_TOK_FM]    []
# 2     1713710653582504448  ...  [@OklaDrewnowicz, @Radio_TOK_FM]    []
# 3     1713710653582504448  ...     [@poselTTrela, @Radio_TOK_FM]    []
# 4     1713716477377892352  ...                                []    []
# ...                   ...  ...                               ...   ...
# 26666                 NaN  ...                               NaN   NaN
# 26667                 NaN  ...                               NaN   NaN
# 26668                 NaN  ...                               NaN   NaN
# 26669                 NaN  ...                               NaN   NaN
# 26670                 NaN  ...                               NaN   NaN
#
#            hashtags retweet_count  reply_count like_count quote_count  \
# 0      [#Trela2023]            24           32        244           2
# 1                []            13           10        168           0
# 2                []             1            4         20           0
# 3                []             0            0          2           0
# 4                []           170           41       1737           2
# ...             ...           ...          ...        ...         ...
# 26666           NaN           NaN          NaN        NaN         NaN
# 26667           NaN           NaN          NaN        NaN         NaN
# 26668           NaN           NaN          NaN        NaN         NaN
# 26669           NaN           NaN          NaN        NaN         NaN
# 26670           NaN           NaN          NaN        NaN         NaN
#
#       impression_count                                   text_clean_df_en  \
# 0                 6545  Akurat w tym przypadku trudno się z Wolskim ni...
# 1                 3101               Ja tu widze ze nic sie nie ukryje  😂
# 2                 1415                                        Pełna zgoda
# 3                  151     Bardzo sie ciesze! To tylko mnie mobilizuje!!!
# 4                44491  Nowy poseł musi poznać gospodarzy w swoim okrę...
# ...                ...                                                ...
# 26666              NaN  W ramach roboczego kontaktu z  oraz  informuję...
# 26667              NaN  Dziękuję za dobrą współpracę na rzecz ochrony ...
# 26668              NaN  ❗ ️Aktualna sytuacja dotycząca budynku mieszka...
# 26669              NaN        Bo nie mogłem, przyjadę w innym terminie 👍
# 26670              NaN   Singapur otwarty dla Polskiego mięsa wołowego  👍
#
#                                            text_clean_en
# 0      In this case it is difficult to disagree with ...
# 1               I see that nothing will be hidden here 😂
# 2                                          Totally agree
# 3             I'm really glad! This just motivates me!!!
# 4      A new MP must get to know the hosts in his or ...
# ...                                                  ...
# 26666  As part of working contact with and I would li...
# 26667  Thank you for your good cooperation to protect...
# 26668  ❗ ️Current situation regarding the residential...
# 26669   Because I couldn't, I'll come at another time 👍
# 26670                    Singapore open to Polish beef 👍
#
# [26671 rows x 29 columns]

# %%
# Display merged dataframe info
print(f"\nTotal merged rows: {df_merged.shape[0]}")

# Show a sample of the merged data with both text columns
print("\nMerged DataFrame (showing both text columns where available):")
try:
    print(df_merged[['id', 'text_clean', 'text_clean_en']].head())
except KeyError as e:
    print(f"Error with column names: {e}")
    # Try to identify the actual column names
    text_cols = [col for col in df_merged.columns if 'text' in col.lower()]
    print(f"Available text-related columns: {text_cols}")
    if text_cols:
        print("Sample with available text columns:")
        print(df_merged[['id'] + text_cols].head())
# Out:
# Total merged rows: 26062
#
# Merged DataFrame (showing both text columns where available):
#                     id                                         text_clean  \
# 0                    0                                                ✌ ️
# 1  1713706323672539392  Obiecywałem i mówiłem od kilkunastu miesięcy, ...
# 2  1713710653582504448  Kochani :)) emocje jeszcze nie opadły, noc kró...
# 3  1713711170186522624                                  Ja będę o 7.00 💪
# 4  1713711915644424704                                 To widzimy się  💙
#
#                                        text_clean_en  \
# 0                                                 ✌️
# 1  I have been promising and saying for several m...
# 2  My dears :)) the emotions haven't subsided yet...
# 3                            I'll be there at 7.00 💪
# 4                                     See you then 💙
#
#                                        text_clean_en
# 0  Dzisiejszy atak B. Kempy na premiera w związku...
# 1   📢  Walczymy o ochronę autonomii seksualnej i ...
# 2             Brawo  bo kręgosłup ma sie jeden!! ☝ ️
# 3  Wczoraj zostałam wybrana na wiceprzewodniczącą...
# 4  Praca w Sejmie to także spotkania z dziennikar...

# %%
df_merged
# Out:
#                      created_at  \
# 0     2023-10-16 00:00:00+00:00
# 1     2023-10-16 00:00:01+00:00
# 2     2023-10-16 00:17:13+00:00
# 3     2023-10-16 00:19:16+00:00
# 4     2023-10-16 00:22:14+00:00
# ...                         ...
# 26057 2024-10-15 20:52:04+00:00
# 26058 2024-10-15 20:55:03+00:00
# 26059 2024-10-15 21:03:32+00:00
# 26060 2024-10-15 21:15:19+00:00
# 26061 2024-10-15 21:41:45+00:00
#
#                                                     text                   id  \
# 0                                         @tomekbit  ✌ ️                    0
# 1      Obiecywałem i mówiłem od kilkunastu miesięcy, ...  1713706323672539392
# 2      Kochani :)) emocje jeszcze nie opadły, noc kró...  1713710653582504448
# 3        @OklaDrewnowicz @Radio_TOK_FM Ja będę o 7.00 💪   1713711170186522624
# 4          @poselTTrela @Radio_TOK_FM To widzimy się  💙   1713711915644424704
# ...                                                  ...                  ...
# 26057  Nigdy nie tracić wiary i zawsze walczyć do koń...  1846292983219401216
# 26058  To był wyjątkowy dzień, 15 października 2023  ...  1846293735254249984
# 26059  To jest rok naszej pracy! https://t.co/3K1uo8N8xR  1846295871698129152
# 26060  W środę o 7.15 będę gościem programu #SygnałyD...  1846298832973307904
# 26061  @donaldtusk Cieszę się z tego wpisu. Będzie ba...  1846305485751787520
#
#                  author_id                                      edit_controls  \
# 0                 61552404                                                NaN
# 1                547089308  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2               3305466189  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3                547089308  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 4               3305466189  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# ...                    ...                                                ...
# 26057            375146901  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26058           1962004784  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26059  1226049381327044608  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26060            370112160  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26061           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
#
#        possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0                    True       everyone   pl                    NaN
# 1                   False       everyone   pl  [1713706323672539456]
# 2                   False       everyone   pl  [1713710653582504333]
# 3                   False       everyone   pl  [1713711170186522695]
# 4                   False       everyone   pl  [1713711915644424683]
# ...                   ...            ...  ...                    ...
# 26057               False       everyone   pl  [1846292983219401158]
# 26058               False       everyone   pl  [1846293735254249857]
# 26059               False       everyone   pl  [1846295871698129232]
# 26060               False       everyone   pl  [1846298832973307975]
# 26061               False       everyone   pl  [1846305485751787563]
#
#           conversation_id  ...        hashtags retweet_count reply_count  \
# 0                     NaN  ...              []             0           1
# 1     1713706323672539392  ...    [#Trela2023]            24          32
# 2     1713710653582504448  ...              []            13          10
# 3     1713710653582504448  ...              []             1           4
# 4     1713710653582504448  ...              []             0           0
# ...                   ...  ...             ...           ...         ...
# 26057 1846292983219401216  ...              []           549        1025
# 26058 1846293735254249984  ...              []             1           2
# 26059 1846295871698129152  ...              []             9          12
# 26060 1846298832973307904  ...  [#SygnałyDnia]            53          70
# 26061 1846292983219401216  ...              []            18          22
#
#       like_count  quote_count impression_count  \
# 0              1            0              104
# 1            244            2             6545
# 2            168            0             3101
# 3             20            0             1415
# 4              2            0              151
# ...          ...          ...              ...
# 26057       5997           36           253293
# 26058         31            0              507
# 26059         46            0             1872
# 26060        326            2            15812
# 26061        955            0            13853
#
#                                            text_clean_en  \
# 0                                                     ✌️
# 1      I have been promising and saying for several m...
# 2      My dears :)) the emotions haven't subsided yet...
# 3                                I'll be there at 7.00 💪
# 4                                         See you then 💙
# ...                                                  ...
# 26057  Never lose faith and always fight to the end. ...
# 26058  It was a special day, October 15, 2023 🤍 ❤ ️ 💪...
# 26059                          This is our year of work!
# 26060  On Wednesday at 7.15 I will be a guest of the ...
# 26061   I'm happy with this post. It will be very tre...
#
#                                  text_clean_en_demojized  \
# 0                                         :victory_hand:
# 1      I have been promising and saying for several m...
# 2      My dears :)) the emotions haven't subsided yet...
# 3                  I'll be there at 7.00 :flexed_biceps:
# 4                              See you then :blue_heart:
# ...                                                  ...
# 26057  Never lose faith and always fight to the end. ...
# 26058  It was a special day, October 15, 2023 :white_...
# 26059                          This is our year of work!
# 26060  On Wednesday at 7.15 I will be a guest of the ...
# 26061   I'm happy with this post. It will be very tre...
#
#                                            text_clean_en  \
# 0      Dzisiejszy atak B. Kempy na premiera w związku...
# 1       📢  Walczymy o ochronę autonomii seksualnej i ...
# 2                 Brawo  bo kręgosłup ma sie jeden!! ☝ ️
# 3      Wczoraj zostałam wybrana na wiceprzewodniczącą...
# 4      Praca w Sejmie to także spotkania z dziennikar...
# ...                                                  ...
# 26057  To nie jest  idziemy odbudować samorząd ✌ ️ 🤍 ...
# 26058  Sala wypełniona po brzegi na dzisiejszym spotk...
# 26059  Zupa z grilowanej  🌶 ️ i  🧅  z dodatkiem lekki...
# 26060  To co robił rząd PiS i jego kadry w SSP pokazu...
# 26061  Skoro według rządu wszystkie Izby i wyroki Sąd...
#
#                                         text_clean_en_en
# 0      Today's attack by B. Kempa on the Prime Minist...
# 1       📢 We fight to protect sexual autonomy and ind...
# 2            Bravo, because you only have one spine!! ☝️
# 3      Yesterday I was elected vice-chair of the Poli...
# 4      Working in the Sejm also involves meetings wit...
# ...                                                  ...
# 26057  This is not we are going to rebuild the local ...
# 26058  The room was filled to capacity at today's mee...
# 26059            Grilled soup 🌶 ️ and 🧅 with light 🎶 🍓 😍
# 26060  What the PiS government and its staff in the S...
# 26061  Since, according to the government, all Houses...
#
# [26062 rows x 31 columns]

# %%
# Find mismatched IDs:
missing_in_clean = df_merged[df_merged['text_clean'].isna()]  # IDs in df_en_text but not in df_clean_text
missing_in_en = df_merged[df_merged['text_clean_en'].isna()]  # IDs in df_clean_text but not in df_en_text

# Show mismatched statistics
print(f"\nRows present in df_en_text but NOT in df_clean_text: {missing_in_clean.shape[0]} ({missing_in_clean.shape[0]/df_merged.shape[0]:.2%})")
print(f"Rows present in df_clean_text but NOT in df_en_text: {missing_in_en.shape[0]} ({missing_in_en.shape[0]/df_merged.shape[0]:.2%})")
print(f"Rows present in BOTH dataframes: {df_merged.shape[0] - missing_in_clean.shape[0] - missing_in_en.shape[0]} ({(df_merged.shape[0] - missing_in_clean.shape[0] - missing_in_en.shape[0])/df_merged.shape[0]:.2%})")

# Show some examples of mismatches (if any exist)
if len(missing_in_clean) > 0:
    print("\nSample rows present in df_en_text but NOT in df_clean_text:")
    print(missing_in_clean[['id', 'text_clean_en']].head())

if len(missing_in_en) > 0:
    print("\nSample rows present in df_clean_text but NOT in df_en_text:")
    print(missing_in_en[['id', 'text_clean']].head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 3
#       1 # Find mismatched IDs:
#       2 missing_in_clean = df_merged[df_merged['text_clean'].isna()]  # IDs in df_en_text but not in df_clean_text
# ----> 3 missing_in_en = df_merged[df_merged['text_clean_en'].isna()]  # IDs in df_clean_text but not in df_en_text
#       5 # Show mismatched statistics
#       6 print(f"\nRows present in df_en_text but NOT in df_clean_text: {missing_in_clean.shape[0]} ({missing_in_clean.shape[0]/df_merged.shape[0]:.2%})")
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4089, in DataFrame.__getitem__(self, key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
# -> 4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:10984, in NDFrame.where(self, cond, other, inplace, axis, level)
#   10977             warnings.warn(
#   10978                 _chained_assignment_warning_method_msg,
#   10979                 FutureWarning,
#   10980                 stacklevel=2,
#   10981             )
#   10983 other = common.apply_if_callable(other, self)
# > 10984 return self._where(cond, other, inplace, axis, level)
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:10685, in NDFrame._where(self, cond, other, inplace, axis, level, warn)
#   10682     cond = cond.astype(bool)
#   10684 cond = -cond if inplace else cond
# > 10685 cond = cond.reindex(self._info_axis, axis=self._info_axis_number, copy=False)
#   10687 # try to align with other
#   10688 if isinstance(other, NDFrame):
#   10689     # align with me
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5378, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5359 @doc(
#    5360     NDFrame.reindex,
#    5361     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5376     tolerance=None,
#    5377 ) -> DataFrame:
# -> 5378     return super().reindex(
#    5379         labels=labels,
#    5380         index=index,
#    5381         columns=columns,
#    5382         axis=axis,
#    5383         method=method,
#    5384         copy=copy,
#    5385         level=level,
#    5386         fill_value=fill_value,
#    5387         limit=limit,
#    5388         tolerance=tolerance,
#    5389     )
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5610, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5607     return self._reindex_multi(axes, copy, fill_value)
#    5609 # perform the reindex on the axes
# -> 5610 return self._reindex_axes(
#    5611     axes, level, limit, tolerance, method, fill_value, copy
#    5612 ).__finalize__(self, method="reindex")
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5633, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5630     continue
#    5632 ax = self._get_axis(a)
# -> 5633 new_index, indexer = ax.reindex(
#    5634     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5635 )
#    5637 axis = self._get_axis_number(a)
#    5638 obj = obj._reindex_with_indexers(
#    5639     {axis: [new_index, indexer]},
#    5640     fill_value=fill_value,
#    5641     copy=copy,
#    5642     allow_dups=False,
#    5643 )
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:4429, in Index.reindex(self, target, method, level, limit, tolerance)
#    4426     raise ValueError("cannot handle a non-unique multi-index!")
#    4427 elif not self.is_unique:
#    4428     # GH#42568
# -> 4429     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4430 else:
#    4431     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
print("\nRows in df but NOT in df_en_text:")
missing_in_df_en_text
# Out:
# Rows in df but NOT in df_en_text:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 2
#       1 print("\nRows in df but NOT in df_en_text:")
# ----> 2 missing_in_df_en_text
#
# NameError: name 'missing_in_df_en_text' is not defined

# %%
df_en_text["id"] = df_en_text["id"].apply(lambda x: int(float(x.replace(',', ''))))

# %%
if 'text_clean_en' in df_en_text.columns:
    df = df.merge(df_en_text[['id', 'text_clean_en']], on='id', how='left')

    display(df.head())
else:
    print("Column 'text_clean_en' does not exist in df_clean_text")
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#              author_id                                      edit_controls  \
# 0  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0              False       everyone   pl  [1765380709114409272]
# 1              False       everyone   pl  [1764245727646044196]
# 2              False       everyone   pl  [1763931255521857839]
# 3              False       everyone   pl  [1763576337078313201]
# 4              False       everyone   pl  [1763173358068281524]
#
#       conversation_id  ...                                         text_clean  \
# 0 1765380709114409216  ...  Policja rzucająca kostką brukową w rolników, p...
# 1 1764245727646044160  ...  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...
# 2 1763931255521857792  ...  Równość, ale nie dla wszystkich… \nPani „minis...
# 3 1763576337078313216  ...  Pytanie za sto punktów! \nFirma jakiego państw...
# 4 1763173358068281600  ...  Ukraina jeździ na polskim paliwie. \n\nPrzypom...
#
#   mentions                      links hashtags  retweet_count reply_count  \
# 0       []                         []       []             17           4
# 1       []  [https://t.co/I5KaMsUDzo]       []              0           0
# 2       []  [https://t.co/PyKYCMvSN3]       []              0           0
# 3       []  [https://t.co/g61Cb5BsIx]       []              0           0
# 4       []  [https://t.co/b0Q4Tt1FJW]       []              0           0
#
#   like_count quote_count impression_count  \
# 0        203           0            12028
# 1          2           0              275
# 2          0           0              188
# 3          1           0              170
# 4          0           0              124
#
#                                        text_clean_en
# 0  Police throwing paving stones at farmers, MP s...
# 1  Please pay attention to point 11.\nThere's not...
# 2  Equality, but not for everyone... \nThe "minis...
# 3  One hundred point question! \nWhich country's ...
# 4  Ukraine runs on Polish fuel. \n\nI would like ...
#
# [5 rows x 28 columns]

# %%
# Replace '#VALUE!' with NaN in 'text_clean_en' column
df['text_clean_en'] = df['text_clean_en'].replace('#VALUE!', pd.NA)

# %%
df['text_clean_en_demojized'] = df['text_clean_en'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)

df[['text_clean_en', 'text_clean_en_demojized']].head()
# Out:
#                                        text_clean_en  \
# 0  Police throwing paving stones at farmers, MP s...
# 1  Please pay attention to point 11.\nThere's not...
# 2  Equality, but not for everyone... \nThe "minis...
# 3  One hundred point question! \nWhich country's ...
# 4  Ukraine runs on Polish fuel. \n\nI would like ...
#
#                              text_clean_en_demojized
# 0  Police throwing paving stones at farmers, MP s...
# 1  Please pay attention to point 11.\nThere's not...
# 2  Equality, but not for everyone... \nThe "minis...
# 3  One hundred point question! \nWhich country's ...
# 4  Ukraine runs on Polish fuel. \n\nI would like ...

# %%
df
# Out:
#                      created_at  \
# 0     2024-03-06 14:15:34+00:00
# 1     2024-03-03 11:05:34+00:00
# 2     2024-03-02 14:15:58+00:00
# 3     2024-03-01 14:45:39+00:00
# 4     2024-02-29 12:04:21+00:00
# ...                         ...
# 26057 2023-10-24 10:46:22+00:00
# 26058 2023-10-19 18:05:26+00:00
# 26059 2023-10-19 08:52:05+00:00
# 26060 2023-10-18 16:12:37+00:00
# 26061 2023-10-17 19:59:04+00:00
#
#                                                     text                   id  \
# 0      Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2      Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3      Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
# ...                                                  ...                  ...
# 26057  Formacje demokratyczne będą tworzyć przyszły r...  1716768088052359424
# 26058  Żadne podchody, kłamstwa czy medialne wrzutki ...  1715066644018381312
# 26059  Polska potrzebuje nowego, demokratycznego rząd...  1714927388637696256
# 26060  95 lat temu zmarł generał Tadeusz Jordan Rozwa...  1714675864237924864
# 26061  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
#
#                  author_id                                      edit_controls  \
# 0      1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1      1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3      1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                    ...                                                ...
# 26057            955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26058            955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26059            955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26060            955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26061            955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0                  False       everyone   pl  [1765380709114409272]
# 1                  False       everyone   pl  [1764245727646044196]
# 2                  False       everyone   pl  [1763931255521857839]
# 3                  False       everyone   pl  [1763576337078313201]
# 4                  False       everyone   pl  [1763173358068281524]
# ...                  ...            ...  ...                    ...
# 26057                  0       everyone   pl  [1716768088052359454]
# 26058                  0       everyone   pl  [1715066644018381294]
# 26059                  0       everyone   pl  [1714927388637696291]
# 26060                  0       everyone   pl  [1714675864237924823]
# 26061                  0       everyone   pl  [1714370461507748145]
#
#           conversation_id  ...     mentions                      links  \
# 0     1765380709114409216  ...           []                         []
# 1     1764245727646044160  ...           []  [https://t.co/I5KaMsUDzo]
# 2     1763931255521857792  ...           []  [https://t.co/PyKYCMvSN3]
# 3     1763576337078313216  ...           []  [https://t.co/g61Cb5BsIx]
# 4     1763173358068281600  ...           []  [https://t.co/b0Q4Tt1FJW]
# ...                   ...  ...          ...                        ...
# 26057 1716768088052359424  ...           []  [https://t.co/XFrtPBIMiv]
# 26058 1715066644018381312  ...           []                         []
# 26059 1714927388637696256  ...           []                         []
# 26060 1714675864237924864  ...           []  [https://t.co/TZaorUiXQ1]
# 26061 1714370461507748096  ...  [@pisorgpl]                         []
#
#               hashtags retweet_count  reply_count like_count quote_count  \
# 0                   []            17            4        203           0
# 1                   []             0            0          2           0
# 2                   []             0            0          0           0
# 3                   []             0            0          1           0
# 4                   []             0            0          0           0
# ...                ...           ...          ...        ...         ...
# 26057               []           344         2013       4637         100
# 26058               []          1149         2406      12760         182
# 26059               []           185         1108       3443          47
# 26060               []           110          354       1568          21
# 26061  [#TrzeciaDroga]           748         2136      11558         171
#
#       impression_count                                      text_clean_en  \
# 0                12028  Police throwing paving stones at farmers, MP s...
# 1                  275  Please pay attention to point 11.\nThere's not...
# 2                  188  Equality, but not for everyone... \nThe "minis...
# 3                  170  One hundred point question! \nWhich country's ...
# 4                  124  Ukraine runs on Polish fuel. \n\nI would like ...
# ...                ...                                                ...
# 26057           330379  Democratic formations will form the future gov...
# 26058           689059  No tricks, lies or media insertions from PiS w...
# 26059           385751  Poland needs a new, democratic government beca...
# 26060           205237  95 years ago, General Tadeusz Jordan Rozwadows...
# 26061           676180  We said clearly: either the #ThirdWay or a thi...
#
#                                  text_clean_en_demojized
# 0      Police throwing paving stones at farmers, MP s...
# 1      Please pay attention to point 11.\nThere's not...
# 2      Equality, but not for everyone... \nThe "minis...
# 3      One hundred point question! \nWhich country's ...
# 4      Ukraine runs on Polish fuel. \n\nI would like ...
# ...                                                  ...
# 26057  Democratic formations will form the future gov...
# 26058  No tricks, lies or media insertions from PiS w...
# 26059  Poland needs a new, democratic government beca...
# 26060  95 years ago, General Tadeusz Jordan Rozwadows...
# 26061  We said clearly: either the #ThirdWay or a thi...
#
# [26062 rows x 29 columns]

# %%
df['possibly_sensitive'] = df['possibly_sensitive'].astype(bool)

# %%
username_to_realname = {
    'bartlomiejpejo': 'Bartłomiej Pejo',
    'RobertBiedron': 'Robert Biedroń',
    'PatrykJaki': 'Patryk Jaki',
    'Kpelczynska': 'Katarzyna Pelczyńska',
    'OklaDrewnowicz': 'Agnieszka Okła-Drewnowicz',
    'KosiniakKamysz': 'Władysław Kosiniak-Kamysz',
    'mwojcik_': 'Michał Wójcik',
    'MorawieckiM': 'Mateusz Morawiecki',
    'SlawomirMentzen': 'Sławomir Mentzen',
    'Wlodek_Skalik': 'Włodzimierz Skalik',
    'BeataSzydlo': 'Beata Szydło',
    'WTumanowicz': 'Witold Tumanowicz',
    'KGawkowski': 'Krzysztof Gawkowski',
    'wlodekczarzasty': 'Włodzimierz Czarzasty',
    'Kaminski_M_': 'Mariusz Kamiński',
    'Macierewicz_A': 'Antoni Macierewicz',
    'elzbietawitek': 'Elżbieta Witek',
    'aga_buczynska': 'Agnieszka Buczyńska',
    'szymon_holownia': 'Szymon Hołownia',
    'DorotaNiedziela': 'Dorota Niedziela',
    'EwaKopacz': 'Ewa Kopacz',
    'Leszczyna': 'Izabela Leszczyna',
    'M_K_Blonska': 'Małgorzata Kidawa-Błońska',
    'bbudka': 'Borys Budka',
    'donaldtusk': 'Donald Tusk',
    'DariuszKlimczak': 'Dariusz Klimczak',
    'GrzybAndrzej': 'Andrzej Grzyb',
    'Hetman_K': 'Krzysztof Hetman',
    'JarubasAdam': 'Adam Jarubas',
    'Paslawska': 'Urszula Pasławska',
    'TudujKrzysztof': 'Krzysztof Tuduj',
    'ZalewskiPawel': 'Paweł Zalewski'
}

# Add the 'name' column to the dataframe
df['name'] = df['username'].map(username_to_realname)

# %%
# Delete next line sign from the 'text_clean_en' column
df['text_clean_en'] = df['text_clean_en'].str.replace('\n', ' ')

# %%
# Save the DataFrame to a Parquet file
df.to_parquet('cleaned_data/df_combined.parquet', index=False)

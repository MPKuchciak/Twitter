# %% [markdown]
# # Data cleaning

# %% [markdown]
# In this file, we cleaned the downloaded data:
# The main steps include:
# 1. Adding party affiliation to tweet rows
# 2. Deleting unnecessary downloaded Retweets.
# 3. Deleting links and mentions from the tweets text and saving them to separate columns
# 4. Expanding the column of public metrics
# 5. Encoding emojis in a unified format
# 6. Translating tweets using Google Translate in Google Sheets
# 7. Saving all downloaded tweets to one file

# %% [markdown]
# ### 1.  Used libraries

# %%
import os
import pandas as pd
import re
import emoji

# %% [markdown]
# ### 2. Reading JSON files and transforming them into party-specific pickle files

# %%
base_input_paths = ['data/PoWyborach', 'data/tweets_data_2022']
subfolders = ['Konfederacja', 'NL', 'PIS', 'PO', 'PL2050', 'PSL']
output_folder = 'data/tweets_data_combined'

for subfolder in subfolders:
    dataframes = []
    for base_input_path in base_input_paths:
        folder_path = os.path.join(base_input_path, subfolder)
        for filename in os.listdir(folder_path):
            if filename.endswith('.json'):
                file_path = os.path.join(folder_path, filename)
                politician = filename.split("_tweets.json")[0]
                try:
                    df = pd.read_json(file_path)  
                    df["username"] = politician  
                    df["party"] = subfolder
                    print(f"Read {len(df)} rows from {file_path}")  
                    dataframes.append(df)
                except ValueError as e:
                    print(f"Error reading {file_path}: {e}")
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        
        output_file_path = os.path.join(output_folder, f'{subfolder}_combined.pkl')
        combined_df.to_pickle(output_file_path) 
        
        print(f"Saved {subfolder} combined data to {output_file_path}")

print("Processing complete!")
# Out:
# Read 320 rows from data/PoWyborach/Konfederacja/placzekgrzegorz_2024-04-16_2024-10-15.json
# Read 597 rows from data/PoWyborach/Konfederacja/MichalWawer_2023-10-16_2024-10-15.json
# Read 1318 rows from data/PoWyborach/Konfederacja/KonradBerkowicz_2024-04-16_2024-10-15_vol1 (1).json
# Read 950 rows from data/PoWyborach/Konfederacja/Wlodek_Skalik_2023-10-16_2024-10-15.json
# Read 721 rows from data/PoWyborach/Konfederacja/SlawomirMentzen_2023-10-16_2024-10-15.json
# Read 889 rows from data/PoWyborach/Konfederacja/GrzegorzBraun__2023-10-16_2024-10-15.json
# Read 175 rows from data/PoWyborach/Konfederacja/TudujKrzysztof_2023-10-16_2024-10-15.json
# Read 964 rows from data/PoWyborach/Konfederacja/bartlomiejpejo_2023-10-16_2024-10-15.json
# Read 421 rows from data/PoWyborach/Konfederacja/placzekgrzegorz_2023-10-16_2024-04-15.json
# Read 772 rows from data/PoWyborach/Konfederacja/MarSypniewski_2023-10-16_2024-10-15.json
# Read 289 rows from data/PoWyborach/Konfederacja/KonradBerkowicz_2023-10-15_2024-04-16_vol2 (1).json
# Read 11 rows from data/PoWyborach/Konfederacja/Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json
# Read 750 rows from data/PoWyborach/Konfederacja/WTumanowicz_2023-10-16_2024-10-15.json
# Read 694 rows from data/tweets_data_2022/Konfederacja/WTumanowicz_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/Konfederacja/RJ_Iwaszkiewicz_2022-10-16_2023-10-15.json
# Read 758 rows from data/tweets_data_2022/Konfederacja/MarSypniewski_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/Konfederacja/KonradBerkowicz_2022-10-16_2023-10-15.json
# Read 213 rows from data/tweets_data_2022/Konfederacja/TudujKrzysztof_2022-10-16_2023-10-15.json
# Read 595 rows from data/tweets_data_2022/Konfederacja/bartlomiejpejo_2022-10-16_2023-10-15.json
# Read 592 rows from data/tweets_data_2022/Konfederacja/placzekgrzegorz_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/Konfederacja/JkmMikke_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/Konfederacja/GrzegorzBraun__2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/Konfederacja/krzysztofbosak_2022-10-16_2023-10-15.json
# Read 585 rows from data/tweets_data_2022/Konfederacja/Wlodek_Skalik_2022-10-16_2023-10-15.json
# Read 789 rows from data/tweets_data_2022/Konfederacja/SlawomirMentzen_2022-10-16_2023-10-15.json
# Read 248 rows from data/tweets_data_2022/Konfederacja/MichalWawer_2022-10-16_2023-10-15.json
# Saved Konfederacja combined data to data/tweets_data_combined/Konfederacja_combined.pkl
# Read 457 rows from data/PoWyborach/NL/RobertBiedron_2023-10-16_2024-10-15.json
# Read 247 rows from data/PoWyborach/NL/MoskwaWodnicka_2023-10-16_2024-10-15 (1).json
# Read 575 rows from data/PoWyborach/NL/poselTTrela_2024-04-16_2024-10-15.json
# Read 178 rows from data/PoWyborach/NL/KGawkowski_2023-10-16_2024-10-15.json
# Read 481 rows from data/PoWyborach/NL/AnitaKDZG_2023-10-16_2024-10-15 (1).json
# Read 787 rows from data/PoWyborach/NL/WandaNowicka_2023-10-16_2024-10-15 (1).json
# Read 142 rows from data/PoWyborach/NL/wieczorekdarek_2023-10-16_2024-10-15 (1).json
# Read 537 rows from data/PoWyborach/NL/PaulinaPW2024_2023-10-16_2024-10-15 (1).json
# Read 207 rows from data/PoWyborach/NL/AndrzejSzejna_2023-10-16_2024-10-15 (1).json
# Read 907 rows from data/PoWyborach/NL/poselTTrela_2023-10-16_2024-04-15.json
# Read 73 rows from data/PoWyborach/NL/wlodekczarzasty_2023-10-16_2024-10-15.json
# Read 1128 rows from data/PoWyborach/NL/MarcinKulasek_2023-10-16_2024-10-15.json
# Read 693 rows from data/PoWyborach/NL/K_Smiszek_2023-10-16_2024-10-15 (1).json
# Read 0 rows from data/PoWyborach/NL/DyduchMarek_2023-10-16_2024-10-15.json
# Read 103 rows from data/PoWyborach/NL/JoankaSW_2023-10-16_2024-10-15 (1).json
# Read 598 rows from data/tweets_data_2022/NL/B_Maciejewska_2022-10-16_2023-10-15.json
# Read 204 rows from data/tweets_data_2022/NL/MoskwaWodnicka_2022-10-16_2023-10-15.json
# Read 318 rows from data/tweets_data_2022/NL/wlodekczarzasty_2022-10-16_2023-10-15.json
# Read 379 rows from data/tweets_data_2022/NL/JoankaSW_2022-10-16_2023-10-15.json
# Read 1010 rows from data/tweets_data_2022/NL/MarcinKulasek_2022-10-16_2023-10-15.json
# Read 1073 rows from data/tweets_data_2022/NL/K_Smiszek_2022-10-16_2023-10-15.json
# Read 526 rows from data/tweets_data_2022/NL/PaulinaPW2024_2022-10-16_2023-10-15.json
# Read 91 rows from data/tweets_data_2022/NL/Arek_Iwaniak_2022-10-16_2023-10-15.json
# Read 889 rows from data/tweets_data_2022/NL/AnitaKDZG_2022-10-16_2023-10-15.json
# Read 265 rows from data/tweets_data_2022/NL/wieczorekdarek_2022-10-16_2023-10-15.json
# Read 227 rows from data/tweets_data_2022/NL/KGawkowski_2022-10-16_2023-10-15.json
# Read 293 rows from data/tweets_data_2022/NL/RobertBiedron_2022-10-16_2023-10-15.json
# Read 184 rows from data/tweets_data_2022/NL/AndrzejSzejna_2022-10-16_2023-10-15.json
# Read 859 rows from data/tweets_data_2022/NL/WandaNowicka_2022-10-16_2023-10-15.json
# Saved NL combined data to data/tweets_data_combined/NL_combined.pkl
# Read 249 rows from data/PoWyborach/PIS/mblaszczak_2023-10-16_2024-10-15 (1).json
# Read 647 rows from data/PoWyborach/PIS/MorawieckiM_2023-10-16_2024-10-15.json
# Read 35 rows from data/PoWyborach/PIS/Kowalczyk_H_2023-10-16_2024-10-15.json
# Read 77 rows from data/PoWyborach/PIS/elzbietawitek_2023-10-16_2024-10-15.json
# Read 556 rows from data/PoWyborach/PIS/BeataSzydlo_2023-10-16_2024-10-15.json
# Read 1025 rows from data/PoWyborach/PIS/PatrykJaki_2023-10-16_2024-10-15.json
# Read 782 rows from data/PoWyborach/PIS/mwojcik__2023-10-16_2024-10-15.json
# Read 189 rows from data/PoWyborach/PIS/Kaminski_M__2023-10-16_2024-10-15.json
# Read 236 rows from data/PoWyborach/PIS/Macierewicz_A_2023-10-16_2024-10-15.json
# Read 0 rows from data/tweets_data_2022/PIS/mblaszczak_2022-10-16_2023-10-15.json
# Read 391 rows from data/tweets_data_2022/PIS/Macierewicz_A_2022-10-16_2023-10-15.json
# Read 268 rows from data/tweets_data_2022/PIS/mwojcik__2022-10-16_2023-10-15.json
# Read 140 rows from data/tweets_data_2022/PIS/Kaminski_M__2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/PIS/jbrudzinski_2022-10-16_2023-10-15.json
# Read 333 rows from data/tweets_data_2022/PIS/BeataSzydlo_2022-10-16_2023-10-15.json
# Read 769 rows from data/tweets_data_2022/PIS/PatrykJaki_2022-10-16_2023-10-15.json
# Read 614 rows from data/tweets_data_2022/PIS/MorawieckiM_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/PIS/AC_Sobol_2022-10-16_2023-10-15.json
# Read 237 rows from data/tweets_data_2022/PIS/Kowalczyk_H_2022-10-16_2023-10-15.json
# Read 61 rows from data/tweets_data_2022/PIS/elzbietawitek_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/PIS/PMilowanski_2022-10-16_2023-10-15.json
# Saved PIS combined data to data/tweets_data_combined/PIS_combined.pkl
# Read 814 rows from data/PoWyborach/PO/trzaskowski__2023-10-16_2024-10-15 (1).json
# Read 165 rows from data/PoWyborach/PO/EwaKopacz_2023-10-16_2024-10-15.json
# Read 173 rows from data/PoWyborach/PO/Leszczyna_2024-04-01_2024-10-15.json
# Read 64 rows from data/PoWyborach/PO/M_K_Blonska_2024-04-01_2024-10-15.json
# Read 49 rows from data/PoWyborach/PO/bbudka_2024-04-01_2024-10-15.json
# Read 356 rows from data/PoWyborach/PO/Konwinski_PO_2023-10-16_2024-10-15.json
# Read 456 rows from data/PoWyborach/PO/OklaDrewnowicz_2023-10-16_2024-10-15.json
# Read 269 rows from data/PoWyborach/PO/CTomczyk_2023-10-16_2024-10-15_GUWNOMAMYZNIMPROBLEM (1).json
# Read 118 rows from data/PoWyborach/PO/Leszczyna_2023-10-16_2023-12-31.json
# Read 112 rows from data/PoWyborach/PO/Leszczyna_2024-01-01_2024-03-31.json
# Read 45 rows from data/PoWyborach/PO/bbudka_2023-10-16_2024-03-31.json
# Read 882 rows from data/PoWyborach/PO/MKierwinski_2023-10-16_2024-10-15.json
# Read 409 rows from data/PoWyborach/PO/DorotaNiedziela_2023-10-16_2024-10-15.json
# Read 62 rows from data/PoWyborach/PO/M_K_Blonska_2023-10-16_2024-03-31.json
# Read 102 rows from data/PoWyborach/PO/JanGrabiec_2023-10-16_2024-10-15.json
# Read 338 rows from data/PoWyborach/PO/donaldtusk_2023-10-16_2024-10-15.json
# Read 520 rows from data/tweets_data_2022/PO/JanGrabiec_2022-10-16_2023-10-15.json
# Read 178 rows from data/tweets_data_2022/PO/donaldtusk_2022-10-16_2023-10-15.json
# Read 513 rows from data/tweets_data_2022/PO/DorotaNiedziela_2022-10-16_2023-10-15.json
# Read 1081 rows from data/tweets_data_2022/PO/MKierwinski_2022-10-16_2023-10-15.json
# Read 851 rows from data/tweets_data_2022/PO/trzaskowski__2022-10-16_2023-10-15.json
# Read 264 rows from data/tweets_data_2022/PO/TomaszSiemoniak_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/PO/CTomczyk_2022-10-16_2023-10-15.json
# Read 56 rows from data/tweets_data_2022/PO/Konwinski_PO_2022-10-16_2023-10-15.json
# Read 395 rows from data/tweets_data_2022/PO/bbudka_2022-10-16_2023-10-15.json
# Read 766 rows from data/tweets_data_2022/PO/OklaDrewnowicz_2022-10-16_2023-10-15.json
# Read 0 rows from data/tweets_data_2022/PO/Arlukowicz_2022-10-16_2023-10-15.json
# Read 515 rows from data/tweets_data_2022/PO/M_K_Blonska_2022-10-16_2023-10-15.json
# Read 76 rows from data/tweets_data_2022/PO/EwaKopacz_2022-10-16_2023-10-15.json
# Read 370 rows from data/tweets_data_2022/PO/Leszczyna_2022-10-16_2023-10-15.json
# Saved PO combined data to data/tweets_data_combined/PO_combined.pkl
# Read 675 rows from data/PoWyborach/PL2050/SlizPawel_2023-10-16_2024-10-15.json
# Read 226 rows from data/PoWyborach/PL2050/Kpelczynska_2023-10-16_2024-10-15.json
# Read 73 rows from data/PoWyborach/PL2050/LukaszOsmalak_2023-10-16_2024-10-15.json
# Read 41 rows from data/PoWyborach/PL2050/AgaBaranowskaPL_2023-10-16_2024-10-15.json
# Read 389 rows from data/PoWyborach/PL2050/hennigkloska_2023-10-16_2024-10-15 (1).json
# Read 175 rows from data/PoWyborach/PL2050/ZalewskiPawel_2023-10-16_2024-10-15.json
# Read 319 rows from data/PoWyborach/PL2050/ZywnoMaciej_2023-10-16_2024-10-15 (1).json
# Read 8 rows from data/PoWyborach/PL2050/joannamucha_2023-10-16_2024-10-15 (1).json
# Read 167 rows from data/PoWyborach/PL2050/szymon_holownia_2023-10-16_2024-10-15.json
# Read 29 rows from data/PoWyborach/PL2050/aga_buczynska_2023-10-16_2024-10-15.json
# Read 339 rows from data/tweets_data_2022/PL2050/szymon_holownia_2022-10-16_2023-10-15.json
# Read 554 rows from data/tweets_data_2022/PL2050/michalkobosko_2022-10-16_2023-10-15.json
# Read 244 rows from data/tweets_data_2022/PL2050/aga_buczynska_2022-10-16_2023-10-15.json
# Read 514 rows from data/tweets_data_2022/PL2050/ZalewskiPawel_2022-10-16_2023-10-15.json
# Read 652 rows from data/tweets_data_2022/PL2050/hennigkloska_2022-10-16_2023-10-15.json
# Read 26 rows from data/tweets_data_2022/PL2050/JKozlowskiEu_2022-10-16_2023-10-15.json
# Read 127 rows from data/tweets_data_2022/PL2050/LukaszOsmalak_2022-10-16_2023-10-15.json
# Read 14 rows from data/tweets_data_2022/PL2050/AgaBaranowskaPL_2022-10-16_2023-10-15.json
# Read 51 rows from data/tweets_data_2022/PL2050/joannamucha_2022-10-16_2023-10-15.json
# Read 479 rows from data/tweets_data_2022/PL2050/ZywnoMaciej_2022-10-16_2023-10-15.json
# Read 74 rows from data/tweets_data_2022/PL2050/Kpelczynska_2022-10-16_2023-10-15.json
# Read 564 rows from data/tweets_data_2022/PL2050/SlizPawel_2022-10-16_2023-10-15.json
# Saved PL2050 combined data to data/tweets_data_combined/PL2050_combined.pkl
# Read 115 rows from data/PoWyborach/PSL/GrzybAndrzej_2023-10-16_2024-10-15.json
# Read 411 rows from data/PoWyborach/PSL/PZgorzelskiP_2023-10-16_2024-10-15.json
# Read 409 rows from data/PoWyborach/PSL/KosiniakKamysz_2023-10-16_2024-10-15.json
# Read 146 rows from data/PoWyborach/PSL/Paslawska_2023-10-16_2024-10-15.json
# Read 19 rows from data/PoWyborach/PSL/Hetman_K_2023-10-16_2024-10-15.json
# Read 192 rows from data/PoWyborach/PSL/JarubasAdam_2023-10-16_2024-10-15.json
# Read 274 rows from data/PoWyborach/PSL/DariuszKlimczak_2023-10-16_2024-10-15.json
# Read 107 rows from data/PoWyborach/PSL/StefanKrajewski_2023-10-16_2024-10-15.json
# Read 124 rows from data/tweets_data_2022/PSL/StruzikAdam_2022-10-16_2023-10-15.json
# Read 288 rows from data/tweets_data_2022/PSL/DariuszKlimczak_2022-10-16_2023-10-15.json
# Read 195 rows from data/tweets_data_2022/PSL/StefanKrajewski_2022-10-16_2023-10-15.json
# Read 280 rows from data/tweets_data_2022/PSL/JarubasAdam_2022-10-16_2023-10-15.json
# Read 199 rows from data/tweets_data_2022/PSL/Paslawska_2022-10-16_2023-10-15.json
# Read 400 rows from data/tweets_data_2022/PSL/KosiniakKamysz_2022-10-16_2023-10-15.json
# Read 162 rows from data/tweets_data_2022/PSL/Hetman_K_2022-10-16_2023-10-15.json
# Read 774 rows from data/tweets_data_2022/PSL/PZgorzelskiP_2022-10-16_2023-10-15.json
# Read 262 rows from data/tweets_data_2022/PSL/GrzybAndrzej_2022-10-16_2023-10-15.json
# Saved PSL combined data to data/tweets_data_combined/PSL_combined.pkl
# Processing complete!

# %% [markdown]
# ### 3. Data cleaning

# %%
df_konfederacja = pd.read_pickle(os.path.join(output_folder, 'Konfederacja_combined.pkl'))
df_NL = pd.read_pickle(os.path.join(output_folder, 'NL_combined.pkl'))
df_PIS = pd.read_pickle(os.path.join(output_folder, 'PIS_combined.pkl'))
df_PO = pd.read_pickle(os.path.join(output_folder, 'PO_combined.pkl'))
df_PL2050 = pd.read_pickle(os.path.join(output_folder, 'PL2050_combined.pkl'))
df_PSL = pd.read_pickle(os.path.join(output_folder, 'PSL_combined.pkl'))

# %%
df_konfederacja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12651 entries, 0 to 12650
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          12651 non-null  object
#  1   reply_settings          12651 non-null  object
#  2   entities                11407 non-null  object
#  3   created_at              12651 non-null  datetime64[ns, UTC]
#  4   attachments             6203 non-null   object
#  5   edit_controls           12651 non-null  object
#  6   author_id               12651 non-null  float64
#  7   edit_history_tweet_ids  12651 non-null  object
#  8   lang                    12651 non-null  object
#  9   possibly_sensitive      12651 non-null  object
#  10  id                      12651 non-null  float64
#  11  conversation_id         12651 non-null  float64
#  12  text                    12651 non-null  object
#  13  category                12651 non-null  object
#  14  context_annotations     1334 non-null   object
#  15  in_reply_to_user_id     3078 non-null   float64
#  16  referenced_tweets       4543 non-null   object
#  17  username                12651 non-null  object
#  18  party                   12651 non-null  object
#  19  geo                     295 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 1.9+ MB

# %%
df_konfederacja.head()
# Out:
#                                       public_metrics reply_settings  \
# 0  {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1  {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2  {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3  {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4  {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
#
#                                             entities  \
# 0  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1  {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
#
#                  created_at  \
# 0 2024-10-15 07:13:34+00:00
# 1 2024-10-14 08:46:51+00:00
# 2 2024-10-13 07:30:58+00:00
# 3 2024-10-12 07:38:50+00:00
# 4 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls     author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru...  1.284852e+18
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru...  1.284852e+18
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru...  1.284852e+18
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...  1.284852e+18
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...  1.284852e+18
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#              id  conversation_id  \
# 0  1.846087e+18     1.846087e+18
# 1  1.845748e+18     1.845748e+18
# 2  1.845367e+18     1.845367e+18
# 3  1.845006e+18     1.845006e+18
# 4  1.844633e+18     1.844633e+18
#
#                                                 text  category  \
# 0  ❌ Rząd polski zamierza budować w Polsce 49 Cen...  Original
# 1  ❌ Szambo wybija i robi się coraz ciekawiej. Na...  Original
# 2  ❌ NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SPOS...  Original
# 3  🆘  Firma farmaceutyczna GSK zapłaci ponad 2 ml...  Original
# 4  ❌ O CO TUTAJ CHODZI? W październiku 2024 r. sz...  Original
#
#                                  context_annotations  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   referenced_tweets                                    username         party  \
# 0               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 1               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 2               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 3               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 4               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
#
#    geo
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# Merge all dataframes into one
df = pd.concat([df_konfederacja, df_NL, df_PIS, df_PO, df_PL2050, df_PSL], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52787 entries, 0 to 52786
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   public_metrics          52787 non-null  object
#  1   reply_settings          52787 non-null  object
#  2   entities                46839 non-null  object
#  3   created_at              52787 non-null  datetime64[ns, UTC]
#  4   attachments             22966 non-null  object
#  5   edit_controls           52771 non-null  object
#  6   author_id               52787 non-null  float64
#  7   edit_history_tweet_ids  52771 non-null  object
#  8   lang                    52787 non-null  object
#  9   possibly_sensitive      52771 non-null  object
#  10  id                      52771 non-null  float64
#  11  conversation_id         52771 non-null  float64
#  12  text                    52787 non-null  object
#  13  category                52787 non-null  object
#  14  context_annotations     5948 non-null   object
#  15  in_reply_to_user_id     10972 non-null  float64
#  16  referenced_tweets       19691 non-null  object
#  17  username                52787 non-null  object
#  18  party                   52787 non-null  object
#  19  geo                     1459 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 8.1+ MB

# %%
len(df)
# Out:
# 52787

# %%
pd.options.display.float_format = '{:.0f}'.format
df['id'] = df['id'].fillna(0).astype('int64')
df['id']
# Out:
# 0        1846086999964283136
# 1        1845748090461966592
# 2        1845366606823657984
# 3        1845006197847360000
# 4        1844633149784891648
#                 ...
# 52782    1583494747536396288
# 52783    1583398153021104128
# 52784    1583360725958828032
# 52785    1581668593192034304
# 52786    1581668593192034304
# Name: id, Length: 52787, dtype: int64

# %%
# Get the value counts of 'id'
id_counts = df['id'].value_counts()

# Filter the counts to show only those greater than 1
id_counts_above_1 = id_counts[id_counts > 1]

# Display the counts
print(f"IDs with counts greater than 1:\n{id_counts_above_1}")
# Out:
# IDs with counts greater than 1:
# id
# 0                      16
# 1780108572161945856     3
# 1581668593192034304     2
# 1590377683367522304     2
# 1690321544608718848     2
#                        ..
# 1792117616804352256     2
# 1582569169882853376     2
# 1582320173482414080     2
# 1792169946169975296     2
# 1734231599116374272     2
# Name: count, Length: 229, dtype: int64

# %%
id_counts_above_1.sum()
# Out:
# 473

# %%
# Count unique IDs
non_duplicate_counts = df['id'].nunique()
print(f"Number of unique IDs: {non_duplicate_counts}")

# Count duplicate IDs
duplicate_counts = df['id'].duplicated().sum()
print(f"Number of duplicate IDs: {duplicate_counts}")

# Get the value counts of 'id'
id_counts = df['id'].value_counts()

# Filter the counts to show only those greater than 1
id_counts_above_1 = id_counts[id_counts > 1]

# Sum of counts of IDs that appear more than once
total_duplicate_rows = id_counts_above_1.sum()
print(f"Total number of duplicate rows based on 'id': {total_duplicate_rows}")

# Convert all columns to strings to avoid unhashable types
df_str = df.astype(str)

# Now check for exact duplicate rows across all columns
duplicates_all = df_str[df_str.duplicated(keep=False)]
print(f"Total duplicate rows (exact match across all columns): {duplicates_all.shape[0]}")
duplicates_all
# Out:
# Number of unique IDs: 52543
# Number of duplicate IDs: 244
# Total number of duplicate rows based on 'id': 473
# Total duplicate rows (exact match across all columns): 304
#                                           public_metrics reply_settings  \
# 318    {'retweet_count': 299, 'reply_count': 80, 'lik...       everyone
# 319    {'retweet_count': 299, 'reply_count': 80, 'lik...       everyone
# 915    {'retweet_count': 35, 'reply_count': 111, 'lik...       everyone
# 916    {'retweet_count': 35, 'reply_count': 111, 'lik...       everyone
# 2233   {'retweet_count': 5, 'reply_count': 1, 'like_c...       everyone
# ...                                                  ...            ...
# 52615  {'retweet_count': 9, 'reply_count': 1, 'like_c...       everyone
# 52766  {'retweet_count': 3, 'reply_count': 0, 'like_c...       everyone
# 52767  {'retweet_count': 3, 'reply_count': 0, 'like_c...       everyone
# 52785  {'retweet_count': 2, 'reply_count': 0, 'like_c...       everyone
# 52786  {'retweet_count': 2, 'reply_count': 0, 'like_c...       everyone
#
#                                                 entities  \
# 318    {'urls': [{'start': 274, 'end': 297, 'url': 'h...
# 319    {'urls': [{'start': 274, 'end': 297, 'url': 'h...
# 915    {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 916    {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 2233   {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# ...                                                  ...
# 52615  {'urls': [{'start': 231, 'end': 254, 'url': 'h...
# 52766  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# 52767  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# 52785  {'urls': [{'start': 49, 'end': 72, 'url': 'htt...
# 52786  {'urls': [{'start': 49, 'end': 72, 'url': 'htt...
#
#                       created_at                                attachments  \
# 318    2024-04-16 05:24:08+00:00                                        nan
# 319    2024-04-16 05:24:08+00:00                                        nan
# 915    2023-10-17 10:47:20+00:00  {'media_keys': ['3_1714231608536891392']}
# 916    2023-10-17 10:47:20+00:00  {'media_keys': ['3_1714231608536891392']}
# 2233   2024-04-16 05:38:51+00:00  {'media_keys': ['3_1780108567447560193']}
# ...                          ...                                        ...
# 52615  2023-07-03 21:13:30+00:00                                        nan
# 52766  2022-11-15 22:10:59+00:00                                        nan
# 52767  2022-11-15 22:10:59+00:00                                        nan
# 52785  2022-10-16 15:29:13+00:00  {'media_keys': ['3_1581668584501149697']}
# 52786  2022-10-16 15:29:13+00:00  {'media_keys': ['3_1581668584501149697']}
#
#                                            edit_controls  \
# 318    {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 319    {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 915    {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 916    {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2233   {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 52615  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52766  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52767  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 52785  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 52786  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                     author_id   edit_history_tweet_ids lang  \
# 318    1.2848522205934141e+18  ['1780104870302732443']   pl
# 319    1.2848522205934141e+18  ['1780104870302732443']   pl
# 915     9.417106438534472e+17  ['1714231616065708419']   pl
# 916     9.417106438534472e+17  ['1714231616065708419']   pl
# 2233             1420353350.0  ['1780108572161945969']   pl
# ...                       ...                      ...  ...
# 52615            1119834276.0  ['1675976082812461056']   pl
# 52766            1119834276.0  ['1592641337475870720']  qam
# 52767            1119834276.0  ['1592641337475870720']  qam
# 52785            1119834276.0  ['1581668593192034304']   pl
# 52786            1119834276.0  ['1581668593192034304']   pl
#
#       possibly_sensitive                   id         conversation_id  \
# 318                False  1780104870302732544  1.7801048703027325e+18
# 319                False  1780104870302732544  1.7801048703027325e+18
# 915                False  1714231616065708544  1.7142316160657085e+18
# 916                False  1714231616065708544  1.7142316160657085e+18
# 2233               False  1780108572161945856  1.7801085721619459e+18
# ...                  ...                  ...                     ...
# 52615                0.0  1675976082812461056   1.675976082812461e+18
# 52766                0.0  1592641337475870720  1.5926413374758707e+18
# 52767                0.0  1592641337475870720  1.5926413374758707e+18
# 52785                0.0  1581668593192034304  1.5816685931920343e+18
# 52786                0.0  1581668593192034304  1.5816685931920343e+18
#
#                                                     text  category  \
# 318    ❌ Od 1 września niemal 60 tys. ukraińskich 🇺🇦 ...  Original
# 319    ❌ Od 1 września niemal 60 tys. ukraińskich 🇺🇦 ...  Original
# 915    Ponad 43 tysiące wyborców oddało swoje głosy n...  Original
# 916    Ponad 43 tysiące wyborców oddało swoje głosy n...  Original
# 2233   ❗SPOTKANIE CZŁONKÓW I SYMPATYKÓW KLUBU KONFEDE...  Original
# ...                                                  ...       ...
# 52615  10 lat ma Europejska Fundacja na rzecz demokra...  Original
# 52766        RT @KleszczDaniel: @KosiniakKamysz @nowePSL   Retweet
# 52767        RT @KleszczDaniel: @KosiniakKamysz @nowePSL   Retweet
# 52785  16 październik 1978 rok pamiętamy #DzieńPapies...  Original
# 52786  16 październik 1978 rok pamiętamy #DzieńPapies...  Original
#
#                                      context_annotations in_reply_to_user_id  \
# 318                                                  nan                 nan
# 319                                                  nan                 nan
# 915    [{'domain': {'id': '47', 'name': 'Brand', 'des...                 nan
# 916    [{'domain': {'id': '47', 'name': 'Brand', 'des...                 nan
# 2233                                                 nan                 nan
# ...                                                  ...                 ...
# 52615                                                nan                 nan
# 52766                                                nan                 nan
# 52767                                                nan                 nan
# 52785                                                nan                 nan
# 52786                                                nan                 nan
#
#                                        referenced_tweets  \
# 318                                                  nan
# 319                                                  nan
# 915                                                  nan
# 916                                                  nan
# 2233                                                 nan
# ...                                                  ...
# 52615                                                nan
# 52766  [{'type': 'retweeted', 'id': '1592605909196632...
# 52767  [{'type': 'retweeted', 'id': '1592605909196632...
# 52785                                                nan
# 52786                                                nan
#
#                                                 username         party  geo
# 318           placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  nan
# 319           placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  nan
# 915               MichalWawer_2023-10-16_2024-10-15.json  Konfederacja  nan
# 916               MichalWawer_2023-10-16_2024-10-15.json  Konfederacja  nan
# 2233   KonradBerkowicz_2024-04-16_2024-10-15_vol1 (1)...  Konfederacja  nan
# ...                                                  ...           ...  ...
# 52615            GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  nan
# 52766            GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  nan
# 52767            GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  nan
# 52785            GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  nan
# 52786            GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  nan
#
# [304 rows x 20 columns]

# %% [markdown]
# brief insight into how do these duplicates look like

# %%
df[df['id'].duplicated(keep=False)].sort_values(by='id')
# Out:
#                                           public_metrics reply_settings  \
# 35149  {'retweet_count': 18, 'reply_count': 31, 'like...       everyone
# 35154  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 35153  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 48543  {'retweet_count': 2, 'reply_count': 1, 'like_c...       everyone
# 48544  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# ...                                                  ...            ...
# 49818  {'retweet_count': 15, 'reply_count': 2, 'like_...       everyone
# 34812  {'retweet_count': 567, 'reply_count': 221, 'li...       everyone
# 34811  {'retweet_count': 568, 'reply_count': 221, 'li...       everyone
# 26115  {'retweet_count': 141, 'reply_count': 125, 'li...       everyone
# 26116  {'retweet_count': 141, 'reply_count': 125, 'li...       everyone
#
#                                                 entities  \
# 35149                                                NaN
# 35154                                                NaN
# 35153                                                NaN
# 48543                                                NaN
# 48544                                                NaN
# ...                                                  ...
# 49818  {'mentions': [{'start': 30, 'end': 42, 'userna...
# 34812  {'mentions': [{'start': 8, 'end': 19, 'usernam...
# 34811  {'mentions': [{'start': 8, 'end': 19, 'usernam...
# 26115  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 26116  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
#
#                      created_at attachments  \
# 35149 2023-10-16 22:27:00+00:00         NaN
# 35154 2023-10-16 23:18:00+00:00         NaN
# 35153 2023-10-16 23:18:00+00:00         NaN
# 48543 2024-10-17 18:49:00+00:00         NaN
# 48544 2023-10-18 12:46:00+00:00         NaN
# ...                         ...         ...
# 49818 2024-09-13 08:23:40+00:00         NaN
# 34812 2024-09-19 06:31:07+00:00         NaN
# 34811 2024-09-19 06:31:07+00:00         NaN
# 26115 2024-09-24 14:22:59+00:00         NaN
# 26116 2024-09-24 14:22:59+00:00         NaN
#
#                                            edit_controls  author_id  \
# 35149                                                NaN   61552404
# 35154                                                NaN   61552404
# 35153                                                NaN   61552404
# 48543                                                NaN 1119834276
# 48544                                                NaN   61552404
# ...                                                  ...        ...
# 49818  {'edits_remaining': 5, 'is_edit_eligible': Fal...  964017524
# 34812  {'edits_remaining': 5, 'is_edit_eligible': Tru...   52367150
# 34811  {'edits_remaining': 5, 'is_edit_eligible': Tru...   52367150
# 26115  {'edits_remaining': 5, 'is_edit_eligible': Tru...  138048156
# 26116  {'edits_remaining': 5, 'is_edit_eligible': Tru...  138048156
#
#       edit_history_tweet_ids lang possibly_sensitive                   id  \
# 35149                    NaN   pl                NaN                    0
# 35154                    NaN   pl                NaN                    0
# 35153                    NaN   pl                NaN                    0
# 48543                    NaN   pl                NaN                    0
# 48544                    NaN   pl                NaN                    0
# ...                      ...  ...                ...                  ...
# 49818  [1834508231009325542]   pl                  0  1834508231009325568
# 34812  [1836654233296244914]   pl              False  1836654233296244992
# 34811  [1836654233296244914]   pl              False  1836654233296244992
# 26115  [1838584923688444342]   pl              False  1838584923688444416
# 26116  [1838584923688444342]   pl              False  1838584923688444416
#
#           conversation_id                                               text  \
# 35149                 NaN                            @BMikolajewska odpowie💪
# 35154                 NaN      @BernadettaK2 @otoWojciech @BMikolajewska 😂😂😂
# 35153                 NaN                          @3Fritz1 @BMikolajewska 🫡
# 48543                 NaN                                       Dziękuję 🤝😀🍀
# 48544                 NaN                 @Maciej_ENZ0 Dziękuję i pozdrawiam
# ...                   ...                                                ...
# 49818 1834508231009325568  W ramach roboczego kontaktu z @WodyPolskie ora...
# 34812 1836654233296244992  Premier @donaldtusk : namierzono człowieka prz...
# 34811 1836654233296244992  Premier @donaldtusk : namierzono człowieka prz...
# 26115 1838584923688444416  Potwierdza się to o czym mówiliśmy już od dawn...
# 26116 1838584923688444416  Potwierdza się to o czym mówiliśmy już od dawn...
#
#        category                                context_annotations  \
# 35149     Reply                                                NaN
# 35154     Reply                                                NaN
# 35153     Reply                                                NaN
# 48543     Quote                                                NaN
# 48544     Reply                                                NaN
# ...         ...                                                ...
# 49818  Original  [{'domain': {'id': '11', 'name': 'Sport', 'des...
# 34812  Original  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 34811  Original  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 26115     Quote                                                NaN
# 26116     Quote                                                NaN
#
#        in_reply_to_user_id                                  referenced_tweets  \
# 35149                  NaN                                                NaN
# 35154                  NaN                                                NaN
# 35153                  NaN                                                NaN
# 48543                  NaN  [{'type': 'quoted', 'id': '1714320722481615223'}]
# 48544                  NaN                                                NaN
# ...                    ...                                                ...
# 49818                  NaN                                                NaN
# 34812                  NaN                                                NaN
# 34811                  NaN                                                NaN
# 26115                  NaN  [{'type': 'quoted', 'id': '1838307356918071625'}]
# 26116                  NaN  [{'type': 'quoted', 'id': '1838307356918071625'}]
#
#                                                 username party  geo
# 35149               Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35154               Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35153               Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 48543            GrzybAndrzej_2023-10-16_2024-10-15.json   PSL  NaN
# 48544            GrzybAndrzej_2023-10-16_2024-10-15.json   PSL  NaN
# ...                                                  ...   ...  ...
# 49818         DariuszKlimczak_2023-10-16_2024-10-15.json   PSL  NaN
# 34812  CTomczyk_2023-10-16_2024-10-15_GUWNOMAMYZNIMPR...    PO  NaN
# 34811  CTomczyk_2023-10-16_2024-10-15_GUWNOMAMYZNIMPR...    PO  NaN
# 26115          mblaszczak_2023-10-16_2024-10-15 (1).json   PIS  NaN
# 26116          mblaszczak_2023-10-16_2024-10-15 (1).json   PIS  NaN
#
# [473 rows x 20 columns]

# %%
for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, dict)).any():
        print(f"Column '{col}' contains dictionaries.")
    elif df[col].apply(lambda x: isinstance(x, list)).any():
        print(f"Column '{col}' contains lists.")
# Out:
# Column 'public_metrics' contains dictionaries.
# Column 'entities' contains dictionaries.
# Column 'attachments' contains dictionaries.
# Column 'edit_controls' contains dictionaries.
# Column 'edit_history_tweet_ids' contains lists.
# Column 'context_annotations' contains lists.
# Column 'referenced_tweets' contains lists.
# Column 'geo' contains dictionaries.

# %%
# Get all duplicate IDs
duplicate_ids = df[df['id'].duplicated(keep=False)]

# Exclude columns with unhashable (dict-like) values
columns_to_exclude = ['edit_controls', 'public_metrics', 'attachments', 'entities', 'geo', 'edit_history_tweet_ids', 'context_annotations','referenced_tweets']
valid_columns = [col for col in df.columns if col not in columns_to_exclude]

# Find differences across valid columns
diff_summary = duplicate_ids[valid_columns].groupby('id').nunique()

# Show columns where duplicates have different values
diff_summary = diff_summary[(diff_summary > 1).any(axis=1)]

# %%
diff_summary
# Out:
#                      reply_settings  created_at  author_id  lang  \
# id
# 0                                 1           9          2     1
# 1780108572161945856               1           1          1     1
# 1780146130551996672               1           1          1     1
# 1780171152914034944               1           1          1     1
# 1780244011212485120               1           1          1     1
# 1780309557610258688               1           1          1     1
# 1780345695163047936               1           1          1     1
# 1780345829615636480               1           1          1     1
# 1780346025854603264               1           1          1     1
# 1780346371888833024               1           1          1     1
#
#                      possibly_sensitive  conversation_id  text  category  \
# id
# 0                                     0                0    16         2
# 1780108572161945856                   1                1     1         1
# 1780146130551996672                   1                1     1         1
# 1780171152914034944                   1                1     1         1
# 1780244011212485120                   1                1     1         1
# 1780309557610258688                   1                1     1         1
# 1780345695163047936                   1                1     1         1
# 1780345829615636480                   1                1     1         1
# 1780346025854603264                   1                1     1         1
# 1780346371888833024                   1                1     1         1
#
#                      in_reply_to_user_id  username  party
# id
# 0                                      0         2      2
# 1780108572161945856                    0         2      1
# 1780146130551996672                    1         2      1
# 1780171152914034944                    1         2      1
# 1780244011212485120                    0         2      1
# 1780309557610258688                    0         2      1
# 1780345695163047936                    1         2      1
# 1780345829615636480                    1         2      1
# 1780346025854603264                    1         2      1
# 1780346371888833024                    1         2      1

# %%
duplicates = df[df.duplicated(subset=['id'], keep=False)]
duplicates
# Out:
#                                           public_metrics reply_settings  \
# 318    {'retweet_count': 299, 'reply_count': 80, 'lik...       everyone
# 319    {'retweet_count': 299, 'reply_count': 80, 'lik...       everyone
# 608    {'retweet_count': 55, 'reply_count': 46, 'like...       everyone
# 609    {'retweet_count': 55, 'reply_count': 46, 'like...       everyone
# 915    {'retweet_count': 35, 'reply_count': 111, 'lik...       everyone
# ...                                                  ...            ...
# 52718  {'retweet_count': 3, 'reply_count': 0, 'like_c...       everyone
# 52766  {'retweet_count': 3, 'reply_count': 0, 'like_c...       everyone
# 52767  {'retweet_count': 3, 'reply_count': 0, 'like_c...       everyone
# 52785  {'retweet_count': 2, 'reply_count': 0, 'like_c...       everyone
# 52786  {'retweet_count': 2, 'reply_count': 0, 'like_c...       everyone
#
#                                                 entities  \
# 318    {'urls': [{'start': 274, 'end': 297, 'url': 'h...
# 319    {'urls': [{'start': 274, 'end': 297, 'url': 'h...
# 608    {'mentions': [{'start': 133, 'end': 142, 'user...
# 609    {'urls': [{'start': 281, 'end': 304, 'url': 'h...
# 915    {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# ...                                                  ...
# 52718  {'urls': [{'start': 90, 'end': 113, 'url': 'ht...
# 52766  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# 52767  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# 52785  {'urls': [{'start': 49, 'end': 72, 'url': 'htt...
# 52786  {'urls': [{'start': 49, 'end': 72, 'url': 'htt...
#
#                      created_at                                attachments  \
# 318   2024-04-16 05:24:08+00:00                                        NaN
# 319   2024-04-16 05:24:08+00:00                                        NaN
# 608   2024-04-11 12:31:09+00:00                                        NaN
# 609   2024-04-11 12:31:09+00:00                                        NaN
# 915   2023-10-17 10:47:20+00:00  {'media_keys': ['3_1714231608536891392']}
# ...                         ...                                        ...
# 52718 2023-02-25 00:45:56+00:00                                        NaN
# 52766 2022-11-15 22:10:59+00:00                                        NaN
# 52767 2022-11-15 22:10:59+00:00                                        NaN
# 52785 2022-10-16 15:29:13+00:00  {'media_keys': ['3_1581668584501149697']}
# 52786 2022-10-16 15:29:13+00:00  {'media_keys': ['3_1581668584501149697']}
#
#                                            edit_controls           author_id  \
# 318    {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 319    {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 608    {'edits_remaining': 5, 'is_edit_eligible': Tru...  941710643853447168
# 609    {'edits_remaining': 5, 'is_edit_eligible': Tru...  941710643853447168
# 915    {'edits_remaining': 5, 'is_edit_eligible': Tru...  941710643853447168
# ...                                                  ...                 ...
# 52718  {'edits_remaining': 5, 'is_edit_eligible': Fal...          1119834276
# 52766  {'edits_remaining': 5, 'is_edit_eligible': Fal...          1119834276
# 52767  {'edits_remaining': 5, 'is_edit_eligible': Fal...          1119834276
# 52785  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52786  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
#
#       edit_history_tweet_ids lang possibly_sensitive                   id  \
# 318    [1780104870302732443]   pl              False  1780104870302732544
# 319    [1780104870302732443]   pl              False  1780104870302732544
# 608    [1778400392470057027]   pl              False  1778400392470056960
# 609    [1778400392470057027]   pl              False  1778400392470056960
# 915    [1714231616065708419]   pl              False  1714231616065708544
# ...                      ...  ...                ...                  ...
# 52718  [1629281505804468226]   en                  0  1629281505804468224
# 52766  [1592641337475870720]  qam                  0  1592641337475870720
# 52767  [1592641337475870720]  qam                  0  1592641337475870720
# 52785  [1581668593192034304]   pl                  0  1581668593192034304
# 52786  [1581668593192034304]   pl                  0  1581668593192034304
#
#           conversation_id                                               text  \
# 318   1780104870302732544  ❌ Od 1 września niemal 60 tys. ukraińskich 🇺🇦 ...
# 319   1780104870302732544  ❌ Od 1 września niemal 60 tys. ukraińskich 🇺🇦 ...
# 608   1778400392470056960  PiS właśnie złożył w Sejmie wniosek o odrzucen...
# 609   1778400392470056960  PiS właśnie złożył w Sejmie wniosek o odrzucen...
# 915   1714231616065708544  Ponad 43 tysiące wyborców oddało swoje głosy n...
# ...                   ...                                                ...
# 52718 1629281505804468224  RT @bpaskal: The view from the highest tower o...
# 52766 1592641337475870720        RT @KleszczDaniel: @KosiniakKamysz @nowePSL
# 52767 1592641337475870720        RT @KleszczDaniel: @KosiniakKamysz @nowePSL
# 52785 1581668593192034304  16 październik 1978 rok pamiętamy #DzieńPapies...
# 52786 1581668593192034304  16 październik 1978 rok pamiętamy #DzieńPapies...
#
#        category                                context_annotations  \
# 318    Original                                                NaN
# 319    Original                                                NaN
# 608    Original                                                NaN
# 609    Original                                                NaN
# 915    Original  [{'domain': {'id': '47', 'name': 'Brand', 'des...
# ...         ...                                                ...
# 52718   Retweet                                                NaN
# 52766   Retweet                                                NaN
# 52767   Retweet                                                NaN
# 52785  Original                                                NaN
# 52786  Original                                                NaN
#
#        in_reply_to_user_id                                  referenced_tweets  \
# 318                    NaN                                                NaN
# 319                    NaN                                                NaN
# 608                    NaN                                                NaN
# 609                    NaN                                                NaN
# 915                    NaN                                                NaN
# ...                    ...                                                ...
# 52718                  NaN  [{'type': 'retweeted', 'id': '1629218162175623...
# 52766                  NaN  [{'type': 'retweeted', 'id': '1592605909196632...
# 52767                  NaN  [{'type': 'retweeted', 'id': '1592605909196632...
# 52785                  NaN                                                NaN
# 52786                  NaN                                                NaN
#
#                                          username         party  geo
# 318    placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  NaN
# 319    placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  NaN
# 608        MichalWawer_2023-10-16_2024-10-15.json  Konfederacja  NaN
# 609        MichalWawer_2023-10-16_2024-10-15.json  Konfederacja  NaN
# 915        MichalWawer_2023-10-16_2024-10-15.json  Konfederacja  NaN
# ...                                           ...           ...  ...
# 52718     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52766     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52767     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52785     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52786     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
#
# [473 rows x 20 columns]

# %%
duplicate_text_count = df['text'].duplicated().sum()
print(f"Number of duplicate Text Entries: {duplicate_text_count}")
# Out:
# Number of duplicate Text Entries: 320

# %%
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]
print(f"Rows where BOTH `id` and `text` are duplicated: {len(duplicate_id_text_rows)}")
# Out:
# Rows where BOTH `id` and `text` are duplicated: 457

# %%
# Count occurrences of each ID
id_counts = df['id'].value_counts()
print("Distribution of duplicate IDs:")
print(id_counts.value_counts().sort_index())

# Count occurrences of each text
text_counts = df['text'].value_counts()
print("\nDistribution of duplicate Text Entries:")
print(text_counts.value_counts().sort_index())
# Out:
# Distribution of duplicate IDs:
# count
# 1     52314
# 2       227
# 3         1
# 16        1
# Name: count, dtype: int64
#
# Distribution of duplicate Text Entries:
# count
# 1    52164
# 2      291
# 3        9
# 4        2
# 6        1
# Name: count, dtype: int64

# %%
# Get all duplicate ID rows
duplicate_id_rows = df[df.duplicated(subset=['id'], keep=False)]

# Get all duplicate Text rows
duplicate_text_rows = df[df.duplicated(subset=['text'], keep=False)]

# Get rows where both ID and Text are duplicated
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]

# Compare overlaps
print(f"Rows where ID is duplicated: {len(duplicate_id_rows)}")
print(f"Rows where Text is duplicated: {len(duplicate_text_rows)}")
print(f"Rows where BOTH ID and Text are duplicated: {len(duplicate_id_text_rows)}")

# Find duplicate IDs that are NOT in the text duplicate set
id_not_in_text = duplicate_id_rows[~duplicate_id_rows['id'].isin(duplicate_text_rows['id'])]
print(f"\nDuplicate IDs NOT duplicated in Text: {len(id_not_in_text)}")

# Find duplicate Texts that are NOT in the ID duplicate set
text_not_in_id = duplicate_text_rows[~duplicate_text_rows['text'].isin(duplicate_id_rows['text'])]
print(f"Duplicate Texts NOT duplicated in ID: {len(text_not_in_id)}")
# Out:
# Rows where ID is duplicated: 473
# Rows where Text is duplicated: 623
# Rows where BOTH ID and Text are duplicated: 457
#
# Duplicate IDs NOT duplicated in Text: 16
# Duplicate Texts NOT duplicated in ID: 165

# %%
empty_id_rows = df[df['id'].isna()]
print(f"Rows where `id` is empty (NaN): {len(empty_id_rows)}")
#empty_id_rows

zero_id_rows = df[df['id'] == 0]
print(f"Rows where `id` is 0: {len(zero_id_rows)}")
zero_id_rows
# Out:
# Rows where `id` is empty (NaN): 0
# Rows where `id` is 0: 16
#                                           public_metrics reply_settings  \
# 35141  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone
# 35142  {'retweet_count': 0, 'reply_count': 2, 'like_c...       everyone
# 35143  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone
# 35144  {'retweet_count': 1, 'reply_count': 1, 'like_c...       everyone
# 35145  {'retweet_count': 1, 'reply_count': 0, 'like_c...       everyone
# 35146  {'retweet_count': 0, 'reply_count': 1, 'like_c...       everyone
# 35147  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 35148  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 35149  {'retweet_count': 18, 'reply_count': 31, 'like...       everyone
# 35150  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 35151  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 35152  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 35153  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 35154  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
# 48543  {'retweet_count': 2, 'reply_count': 1, 'like_c...       everyone
# 48544  {'retweet_count': 0, 'reply_count': 0, 'like_c...       everyone
#
#       entities                created_at attachments edit_controls  author_id  \
# 35141      NaN 2023-10-16 00:00:00+00:00         NaN           NaN   61552404
# 35142      NaN 2023-10-16 00:00:00+00:00         NaN           NaN   61552404
# 35143      NaN 2023-10-16 00:00:00+00:00         NaN           NaN   61552404
# 35144      NaN 2023-10-16 00:00:00+00:00         NaN           NaN   61552404
# 35145      NaN 2023-10-16 00:00:00+00:00         NaN           NaN   61552404
# 35146      NaN 2023-10-16 00:00:00+00:00         NaN           NaN   61552404
# 35147      NaN 2023-10-16 00:00:00+00:00         NaN           NaN   61552404
# 35148      NaN 2023-10-16 21:57:00+00:00         NaN           NaN   61552404
# 35149      NaN 2023-10-16 22:27:00+00:00         NaN           NaN   61552404
# 35150      NaN 2023-10-16 22:41:00+00:00         NaN           NaN   61552404
# 35151      NaN 2023-10-16 23:15:00+00:00         NaN           NaN   61552404
# 35152      NaN 2023-10-16 23:17:00+00:00         NaN           NaN   61552404
# 35153      NaN 2023-10-16 23:18:00+00:00         NaN           NaN   61552404
# 35154      NaN 2023-10-16 23:18:00+00:00         NaN           NaN   61552404
# 48543      NaN 2024-10-17 18:49:00+00:00         NaN           NaN 1119834276
# 48544      NaN 2023-10-18 12:46:00+00:00         NaN           NaN   61552404
#
#       edit_history_tweet_ids lang possibly_sensitive  id  conversation_id  \
# 35141                    NaN   pl                NaN   0              NaN
# 35142                    NaN   pl                NaN   0              NaN
# 35143                    NaN   pl                NaN   0              NaN
# 35144                    NaN   pl                NaN   0              NaN
# 35145                    NaN   pl                NaN   0              NaN
# 35146                    NaN   pl                NaN   0              NaN
# 35147                    NaN   pl                NaN   0              NaN
# 35148                    NaN   pl                NaN   0              NaN
# 35149                    NaN   pl                NaN   0              NaN
# 35150                    NaN   pl                NaN   0              NaN
# 35151                    NaN   pl                NaN   0              NaN
# 35152                    NaN   pl                NaN   0              NaN
# 35153                    NaN   pl                NaN   0              NaN
# 35154                    NaN   pl                NaN   0              NaN
# 48543                    NaN   pl                NaN   0              NaN
# 48544                    NaN   pl                NaN   0              NaN
#
#                                                     text category  \
# 35141                                       @tomekbit ✌️    Reply
# 35142  @MaciejGdynia Maćku, czekam na oficjalne wynik...    Reply
# 35143      @MCichonAlicja Alu, czekamy jeszcze na wynik?    Reply
# 35144                                        @REL_76 🥰🥰🥰    Reply
# 35145                                      @Gidziela 🥰✌️    Reply
# 35146                              @WHaptar Gratulacje👏🥂    Reply
# 35147                       @KapenGenezyp Dziękuję❤️❤️❤️    Reply
# 35148                                     @jasinska_e ❤️    Reply
# 35149                            @BMikolajewska odpowie💪    Reply
# 35150                    @DorotaNiedziela ja Tobie też❣️    Reply
# 35151  @RGrupinski @StGawlowski i ode mnie Rafale, dl...    Reply
# 35152                                  @magosia_10_19 🤛🥰    Reply
# 35153                          @3Fritz1 @BMikolajewska 🫡    Reply
# 35154      @BernadettaK2 @otoWojciech @BMikolajewska 😂😂😂    Reply
# 48543                                       Dziękuję 🤝😀🍀    Quote
# 48544                 @Maciej_ENZ0 Dziękuję i pozdrawiam    Reply
#
#       context_annotations  in_reply_to_user_id  \
# 35141                 NaN                  NaN
# 35142                 NaN                  NaN
# 35143                 NaN                  NaN
# 35144                 NaN                  NaN
# 35145                 NaN                  NaN
# 35146                 NaN                  NaN
# 35147                 NaN                  NaN
# 35148                 NaN                  NaN
# 35149                 NaN                  NaN
# 35150                 NaN                  NaN
# 35151                 NaN                  NaN
# 35152                 NaN                  NaN
# 35153                 NaN                  NaN
# 35154                 NaN                  NaN
# 48543                 NaN                  NaN
# 48544                 NaN                  NaN
#
#                                        referenced_tweets  \
# 35141                                                NaN
# 35142                                                NaN
# 35143                                                NaN
# 35144                                                NaN
# 35145                                                NaN
# 35146                                                NaN
# 35147                                                NaN
# 35148                                                NaN
# 35149                                                NaN
# 35150                                                NaN
# 35151                                                NaN
# 35152                                                NaN
# 35153                                                NaN
# 35154                                                NaN
# 48543  [{'type': 'quoted', 'id': '1714320722481615223'}]
# 48544                                                NaN
#
#                                       username party  geo
# 35141     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35142     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35143     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35144     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35145     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35146     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35147     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35148     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35149     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35150     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35151     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35152     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35153     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 35154     Leszczyna_2023-10-16_2023-12-31.json    PO  NaN
# 48543  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL  NaN
# 48544  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL  NaN

# %%
tweets_by_author = df[df['author_id'] == 61552404.0].sort_values(by='created_at')
display(tweets_by_author)
# Out:
#                                           public_metrics reply_settings  \
# 42688  {'retweet_count': 482, 'reply_count': 0, 'like...       everyone
# 42689  {'retweet_count': 482, 'reply_count': 0, 'like...       everyone
# 42687  {'retweet_count': 376, 'reply_count': 0, 'like...       everyone
# 42686  {'retweet_count': 144, 'reply_count': 0, 'like...       everyone
# 42685  {'retweet_count': 167, 'reply_count': 0, 'like...       everyone
# ...                                                  ...            ...
# 33674  {'retweet_count': 0, 'reply_count': 2, 'like_c...       everyone
# 33673  {'retweet_count': 0, 'reply_count': 2, 'like_c...       everyone
# 33672  {'retweet_count': 47, 'reply_count': 116, 'lik...       everyone
# 33671  {'retweet_count': 0, 'reply_count': 5, 'like_c...       everyone
# 33670  {'retweet_count': 124, 'reply_count': 85, 'lik...       everyone
#
#                                                 entities  \
# 42688  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# 42689  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# 42687  {'hashtags': [{'start': 114, 'end': 127, 'tag'...
# 42686  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# 42685  {'mentions': [{'start': 3, 'end': 17, 'usernam...
# ...                                                  ...
# 33674  {'urls': [{'start': 85, 'end': 108, 'url': 'ht...
# 33673  {'urls': [{'start': 303, 'end': 326, 'url': 'h...
# 33672  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 33671  {'urls': [{'start': 296, 'end': 319, 'url': 'h...
# 33670  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
#
#                      created_at                                 attachments  \
# 42688 2023-09-09 15:22:42+00:00                                         NaN
# 42689 2023-09-09 15:22:42+00:00                                         NaN
# 42687 2023-09-09 15:23:08+00:00                                         NaN
# 42686 2023-09-09 15:23:20+00:00                                         NaN
# 42685 2023-09-09 15:23:36+00:00                                         NaN
# ...                         ...                                         ...
# 33674 2024-10-05 10:35:26+00:00                                         NaN
# 33673 2024-10-05 10:42:14+00:00                                         NaN
# 33672 2024-10-10 05:48:35+00:00                                         NaN
# 33671 2024-10-10 16:17:02+00:00                                         NaN
# 33670 2024-10-15 17:58:06+00:00  {'media_keys': ['13_1846249130529538048']}
#
#                                            edit_controls  author_id  \
# 42688  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# 42689  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# 42687  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# 42686  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# 42685  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# ...                                                  ...        ...
# 33674  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# 33673  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# 33672  {'edits_remaining': 4, 'is_edit_eligible': Tru...   61552404
# 33671  {'edits_remaining': 5, 'is_edit_eligible': Fal...   61552404
# 33670  {'edits_remaining': 5, 'is_edit_eligible': Tru...   61552404
#
#                            edit_history_tweet_ids lang possibly_sensitive  \
# 42688                       [1700530175337738371]   pl              False
# 42689                       [1700530175337738371]   pl              False
# 42687                       [1700530281784971545]   pl              False
# 42686                       [1700530331500085744]   pl              False
# 42685                       [1700530402610364779]   pl              False
# ...                                           ...  ...                ...
# 33674                       [1842513925612372262]   pl              False
# 33673                       [1842515633826627766]   pl              False
# 33672  [1844253222103380157, 1844253674584916327]   pl              False
# 33671                       [1844411831844036750]   pl              False
# 33670                       [1846249201925345310]   pl              False
#
#                         id     conversation_id  \
# 42688  1700530175337738496 1700530175337738496
# 42689  1700530175337738496 1700530175337738496
# 42687  1700530281784971520 1700530281784971520
# 42686  1700530331500085760 1700530331500085760
# 42685  1700530402610364672 1700530402610364672
# ...                    ...                 ...
# 33674  1842513925612372224 1842146757360169472
# 33673  1842515633826627840 1842146757360169472
# 33672  1844253674584916224 1844253674584916224
# 33671  1844411831844036864 1844253674584916224
# 33670  1846249201925345280 1846249201925345280
#
#                                                     text  category  \
# 42688  RT @Platforma_org: 💬 Przewodniczący @donaldtus...   Retweet
# 42689  RT @Platforma_org: 💬 Przewodniczący @donaldtus...   Retweet
# 42687  RT @MariaLe85219860: B U M‼️\n\nDuda, Ziobro, ...   Retweet
# 42686  RT @Platforma_org: 💬 Przewodniczący @donaldtus...   Retweet
# 42685  RT @Platforma_org: 💬 Przewodniczący @donaldtus...   Retweet
# ...                                                  ...       ...
# 33674  @arekpisarski @MZ_GOV_PL @NFZ_GOV_PL tak, @Rze...     Reply
# 33673  @ewa_esse @MZ_GOV_PL od 15. października, ale ...     Reply
# 33672  Ustawa o wychowaniu w trzeźwości trafi dopiero...     Quote
# 33671  @Mariusz32382943 nad zmianami systemowymi prac...     Reply
# 33670  #15października - Święto bezimiennych Bohatere...  Original
#
#                                      context_annotations  in_reply_to_user_id  \
# 42688  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 42689  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 42687                                                NaN                  NaN
# 42686  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 42685  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# ...                                                  ...                  ...
# 33674                                                NaN   713836895495696384
# 33673                                                NaN  1439610920175558656
# 33672                                                NaN                  NaN
# 33671                                                NaN  1217929501063155712
# 33670                                                NaN                  NaN
#
#                                        referenced_tweets  \
# 42688  [{'type': 'retweeted', 'id': '1700489605026340...
# 42689  [{'type': 'retweeted', 'id': '1700489605026340...
# 42687  [{'type': 'retweeted', 'id': '1700475689600696...
# 42686  [{'type': 'retweeted', 'id': '1700482994564186...
# 42685  [{'type': 'retweeted', 'id': '1700463357575221...
# ...                                                  ...
# 33674  [{'type': 'replied_to', 'id': '184214897941436...
# 33673  [{'type': 'replied_to', 'id': '184216083786941...
# 33672  [{'type': 'quoted', 'id': '1844091771900526777'}]
# 33671  [{'type': 'replied_to', 'id': '184427203001280...
# 33670                                                NaN
#
#                                    username party  geo
# 42688  Leszczyna_2022-10-16_2023-10-15.json    PO  NaN
# 42689  Leszczyna_2022-10-16_2023-10-15.json    PO  NaN
# 42687  Leszczyna_2022-10-16_2023-10-15.json    PO  NaN
# 42686  Leszczyna_2022-10-16_2023-10-15.json    PO  NaN
# 42685  Leszczyna_2022-10-16_2023-10-15.json    PO  NaN
# ...                                     ...   ...  ...
# 33674  Leszczyna_2024-04-01_2024-10-15.json    PO  NaN
# 33673  Leszczyna_2024-04-01_2024-10-15.json    PO  NaN
# 33672  Leszczyna_2024-04-01_2024-10-15.json    PO  NaN
# 33671  Leszczyna_2024-04-01_2024-10-15.json    PO  NaN
# 33670  Leszczyna_2024-04-01_2024-10-15.json    PO  NaN
#
# [774 rows x 20 columns]

# %% [markdown]
# id 0 of a tweet may mean, that the tweet was, changed, deleted, or that it is not a tweet but something else and was wrongly categorized as one

# %% [markdown]
# We need to remove duplicate tweets + delete the tweets that were 0; because our custom downloading loop occasionally downloads the same tweet two times to ensure completeness.

# %%
import pandas as pd
import numpy as np

# 1) Copy the original DataFrame before cleaning
df_before = df.copy()

# 2) Get the initial size
initial_size = len(df_before)
print(f"Initial number of tweets: {initial_size}")

# 3) Check and report issues with the 'id' column
print("\n--- ID QUALITY CHECK ---")

# Convert id to string for consistent checking
df_before['id'] = df_before['id'].astype(str)

# Check for various problems
missing_ids = df_before['id'].isna()
empty_ids = df_before['id'] == ''
zero_ids = df_before['id'] == '0'
very_short_ids = df_before['id'].str.len() < 5  # Twitter IDs are typically longer

# Report on ID issues
print(f"Missing IDs (NaN): {missing_ids.sum()} ({missing_ids.mean():.2%})")
print(f"Empty IDs: {empty_ids.sum()} ({empty_ids.mean():.2%})")
print(f"Zero IDs ('0'): {zero_ids.sum()} ({zero_ids.mean():.2%})")
print(f"Very short IDs (< 5 chars): {very_short_ids.sum()} ({very_short_ids.mean():.2%})")

# Create a mask for all problematic IDs
problematic_ids_mask = missing_ids | empty_ids | zero_ids | very_short_ids

# Report total problematic IDs
print(f"Total problematic IDs: {problematic_ids_mask.sum()} ({problematic_ids_mask.mean():.2%})")

# 4) First filter out problematic IDs from the original dataset
df_no_problems = df_before[~problematic_ids_mask].copy()
problematic_removed = initial_size - len(df_no_problems)

# 5) Then remove duplicates from the dataset without problematic IDs
df_after = df_no_problems.drop_duplicates(subset=['id'])
duplicates_removed = len(df_no_problems) - len(df_after)

# 6) Calculate removed counts and percentages
remaining_final = len(df_after)
total_removed = initial_size - remaining_final

duplicate_percentage = (duplicates_removed / initial_size) * 100
problematic_percentage = (problematic_removed / initial_size) * 100
total_removed_percentage = (total_removed / initial_size) * 100
remaining_percentage = (remaining_final / initial_size) * 100

# 7) Print comprehensive results
print("\n--- CLEANING SUMMARY ---")
print(f"Initial tweets: {initial_size}")
print(f"Problematic ID tweets removed: {problematic_removed} ({problematic_percentage:.2f}%)")
print(f"Duplicate tweets removed: {duplicates_removed} ({duplicate_percentage:.2f}%)")
print(f"Total tweets removed: {total_removed} ({total_removed_percentage:.2f}%)")
print(f"Tweets remaining: {remaining_final} ({remaining_percentage:.2f}%)")

# 8) Show sample of problematic IDs
if problematic_ids_mask.sum() > 0:
    print("\nSample of problematic IDs:")
    sample_problematic = df_before[problematic_ids_mask].head(5)
    for i, (idx, row) in enumerate(sample_problematic.iterrows()):
        print(f"  {i+1}. ID: '{row['id']}', Text: '{row['text'][:50]}...'")

# 9) Identify the actual duplicate IDs from the data without problematic IDs
duplicate_ids = df_no_problems[df_no_problems.duplicated(subset=['id'], keep='first')]['id'].unique().tolist()
print(f"\nNumber of unique duplicate IDs: {len(duplicate_ids)}")
if duplicate_ids:
    print("Sample of duplicate IDs (first 5):")
    for i, dup_id in enumerate(duplicate_ids[:5]):
        print(f"  {i+1}. {dup_id}")
else:
    print("No duplicates found")

# 10) Keep df_after as the new df
df = df_after
print(f"\nFinal clean dataframe shape: {df.shape}")

# 11) Verify no problematic IDs remain
if (df['id'] == '0').sum() > 0 or df['id'].isna().sum() > 0 or (df['id'] == '').sum() > 0 or (df['id'].str.len() < 5).sum() > 0:
    print("WARNING: Some problematic IDs still remain in the cleaned dataframe")
else:
    print("SUCCESS: All problematic IDs have been removed")
# Out:
# Initial number of tweets: 52787
#
# --- ID QUALITY CHECK ---
# Missing IDs (NaN): 0 (0.00%)
# Empty IDs: 0 (0.00%)
# Zero IDs ('0'): 16 (0.03%)
# Very short IDs (< 5 chars): 16 (0.03%)
# Total problematic IDs: 16 (0.03%)
#
# --- CLEANING SUMMARY ---
# Initial tweets: 52787
# Problematic ID tweets removed: 16 (0.03%)
# Duplicate tweets removed: 229 (0.43%)
# Total tweets removed: 245 (0.46%)
# Tweets remaining: 52542 (99.54%)
#
# Sample of problematic IDs:
#   1. ID: '0', Text: '@tomekbit ✌️...'
#   2. ID: '0', Text: '@MaciejGdynia Maćku, czekam na oficjalne wyniki, ż...'
#   3. ID: '0', Text: '@MCichonAlicja Alu, czekamy jeszcze na wynik?...'
#   4. ID: '0', Text: '@REL_76 🥰🥰🥰...'
#   5. ID: '0', Text: '@Gidziela 🥰✌️...'
#
# Number of unique duplicate IDs: 228
# Sample of duplicate IDs (first 5):
#   1. 1780104870302732544
#   2. 1778400392470056960
#   3. 1714231616065708544
#   4. 1794299341743829248
#   5. 1780108572161945856
#
# Final clean dataframe shape: (52542, 20)
# SUCCESS: All problematic IDs have been removed

# %%
# 1) How many total rows have a duplicate 'id' (including the first occurrence)?
total_dup_rows = df.duplicated(subset=['id'], keep=False).sum()
print(f"Total rows that share a duplicate ID (including the first occurrence): {total_dup_rows}")

# 2) How many rows are "extra" duplicates beyond the first?
extra_dup_rows = df.duplicated(subset=['id'], keep='first').sum()
print(f"Number of extra duplicates beyond the first occurrence: {extra_dup_rows}")

# 3) How many unique IDs appear more than once?
duplicate_ids = df[df.duplicated(subset=['id'], keep=False)]['id'].unique()
num_duplicate_ids = len(duplicate_ids)
print(f"Number of unique IDs that are duplicated: {num_duplicate_ids}")
# Out:
# Total rows that share a duplicate ID (including the first occurrence): 0
# Number of extra duplicates beyond the first occurrence: 0
# Number of unique IDs that are duplicated: 0

# %%
df.head()
# Out:
#                                       public_metrics reply_settings  \
# 0  {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1  {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2  {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3  {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4  {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
#
#                                             entities  \
# 0  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1  {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
#
#                  created_at  \
# 0 2024-10-15 07:13:34+00:00
# 1 2024-10-14 08:46:51+00:00
# 2 2024-10-13 07:30:58+00:00
# 3 2024-10-12 07:38:50+00:00
# 4 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#                     id     conversation_id  \
# 0  1846086999964283136 1846086999964283136
# 1  1845748090461966592 1845748090461966592
# 2  1845366606823657984 1845366606823657984
# 3  1845006197847360000 1845006197847360000
# 4  1844633149784891648 1844633149784891648
#
#                                                 text  category  \
# 0  ❌ Rząd polski zamierza budować w Polsce 49 Cen...  Original
# 1  ❌ Szambo wybija i robi się coraz ciekawiej. Na...  Original
# 2  ❌ NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SPOS...  Original
# 3  🆘  Firma farmaceutyczna GSK zapłaci ponad 2 ml...  Original
# 4  ❌ O CO TUTAJ CHODZI? W październiku 2024 r. sz...  Original
#
#                                  context_annotations  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   referenced_tweets                                    username         party  \
# 0               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 1               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 2               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 3               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
# 4               NaN  placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja
#
#    geo
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# Get the value counts of the 'category' column
category_counts = df['category'].value_counts()

# Display the counts
print(category_counts)

# Get the number of unique categories
unique_category_count = category_counts.count()
print(f"Number of unique categories: {unique_category_count}")
# Out:
# category
# Original    32794
# Reply       10790
# Quote        5478
# Retweet      3480
# Name: count, dtype: int64
# Number of unique categories: 4

# %% [markdown]
# We need to delete retweets because they are wrongly provided by the X API. We want to analyze only original tweets, replies, and quotes.

# %%
df = df[df['category'] != 'Retweet']

# %%
df
# Out:
#                                           public_metrics reply_settings  \
# 0      {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1      {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2      {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3      {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4      {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
# ...                                                  ...            ...
# 52770  {'retweet_count': 3, 'reply_count': 0, 'like_c...       everyone
# 52774  {'retweet_count': 1, 'reply_count': 0, 'like_c...       everyone
# 52779  {'retweet_count': 3, 'reply_count': 0, 'like_c...       everyone
# 52784  {'retweet_count': 4, 'reply_count': 0, 'like_c...       everyone
# 52785  {'retweet_count': 2, 'reply_count': 0, 'like_c...       everyone
#
#                                                 entities  \
# 0      {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1      {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2      {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3      {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4      {'urls': [{'start': 281, 'end': 304, 'url': 'h...
# ...                                                  ...
# 52770  {'urls': [{'start': 120, 'end': 143, 'url': 'h...
# 52774  {'urls': [{'start': 163, 'end': 186, 'url': 'h...
# 52779  {'urls': [{'start': 243, 'end': 266, 'url': 'h...
# 52784  {'urls': [{'start': 117, 'end': 140, 'url': 'h...
# 52785  {'urls': [{'start': 49, 'end': 72, 'url': 'htt...
#
#                      created_at  \
# 0     2024-10-15 07:13:34+00:00
# 1     2024-10-14 08:46:51+00:00
# 2     2024-10-13 07:30:58+00:00
# 3     2024-10-12 07:38:50+00:00
# 4     2024-10-11 06:56:29+00:00
# ...                         ...
# 52770 2022-11-04 17:02:07+00:00
# 52774 2022-11-04 07:02:07+00:00
# 52779 2022-10-29 12:23:28+00:00
# 52784 2022-10-21 07:33:09+00:00
# 52785 2022-10-16 15:29:13+00:00
#
#                                              attachments  \
# 0      {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52770                                                NaN
# 52774                                                NaN
# 52779                                                NaN
# 52784                                                NaN
# 52785          {'media_keys': ['3_1581668584501149697']}
#
#                                            edit_controls           author_id  \
# 0      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# ...                                                  ...                 ...
# 52770  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52774  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52779  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52784  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52785  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
#
#                            edit_history_tweet_ids lang possibly_sensitive  \
# 0      [1846086770229694583, 1846086999964283214]   pl              False
# 1      [1845747336862961872, 1845748090461966651]   pl              False
# 2                           [1845366606823657982]   pl              False
# 3                           [1845006197847359885]   pl              False
# 4                           [1844633149784891665]   pl              False
# ...                                           ...  ...                ...
# 52770                       [1588577342594482176]   pl                  0
# 52774                       [1588426347646533634]   pl                  0
# 52779                       [1586332889444237312]   pl                  0
# 52784                       [1583360725958828034]   pl                  0
# 52785                       [1581668593192034304]   pl                  0
#
#                         id     conversation_id  \
# 0      1846086999964283136 1846086999964283136
# 1      1845748090461966592 1845748090461966592
# 2      1845366606823657984 1845366606823657984
# 3      1845006197847360000 1845006197847360000
# 4      1844633149784891648 1844633149784891648
# ...                    ...                 ...
# 52770  1588577342594482176 1588577342594482176
# 52774  1588426347646533632 1588426347646533632
# 52779  1586332889444237312 1586332889444237312
# 52784  1583360725958828032 1583360725958828032
# 52785  1581668593192034304 1581668593192034304
#
#                                                     text  category  \
# 0      ❌ Rząd polski zamierza budować w Polsce 49 Cen...  Original
# 1      ❌ Szambo wybija i robi się coraz ciekawiej. Na...  Original
# 2      ❌ NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SPOS...  Original
# 3      🆘  Firma farmaceutyczna GSK zapłaci ponad 2 ml...  Original
# 4      ❌ O CO TUTAJ CHODZI? W październiku 2024 r. sz...  Original
# ...                                                  ...       ...
# 52770  Rozporządzenie o zakazie rejestracji nowych sa...     Quote
# 52774  Wojna gazowa Putina. Europa przełamała szantaż...  Original
# 52779  Naukowcy wiedzą jak sprawić, by OZE nie zależa...  Original
# 52784  Chaos na rynku energii. Zrywane umowy i zamroż...  Original
# 52785  16 październik 1978 rok pamiętamy #DzieńPapies...  Original
#
#                                      context_annotations  in_reply_to_user_id  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2      [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 52770  [{'domain': {'id': '46', 'name': 'Business Tax...                  NaN
# 52774                                                NaN                  NaN
# 52779                                                NaN                  NaN
# 52784                                                NaN                  NaN
# 52785                                                NaN                  NaN
#
#                                        referenced_tweets  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52770  [{'type': 'quoted', 'id': '1586802685587738629'}]
# 52774                                                NaN
# 52779                                                NaN
# 52784                                                NaN
# 52785                                                NaN
#
#                                          username         party  geo
# 0      placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  NaN
# 1      placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  NaN
# 2      placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  NaN
# 3      placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  NaN
# 4      placzekgrzegorz_2024-04-16_2024-10-15.json  Konfederacja  NaN
# ...                                           ...           ...  ...
# 52770     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52774     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52779     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52784     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
# 52785     GrzybAndrzej_2022-10-16_2023-10-15.json           PSL  NaN
#
# [49062 rows x 20 columns]

# %%
# Update the 'username' column to keep only the string until '_2' -> split to date range

#df['username'] = df['username'].str.split('_2').str[0].copy()
df.loc[:, 'username'] = df['username'].str.split('_2').str[0]

# %%
category_summary = df['category'].value_counts()
print(category_summary)
total_tweets = category_summary.sum()
print(f"Total tweets: {total_tweets}")
# Out:
# category
# Original    32794
# Reply       10790
# Quote        5478
# Name: count, dtype: int64
# Total tweets: 49062

# %%
# Ensure the created_at column is in datetime format

#df['created_at'] = pd.to_datetime(df['created_at'])
df.loc[:, 'created_at'] = pd.to_datetime(df['created_at'])

# %%
df.head()
# Out:
#                                       public_metrics reply_settings  \
# 0  {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1  {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2  {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3  {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4  {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
#
#                                             entities  \
# 0  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1  {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
#
#                  created_at  \
# 0 2024-10-15 07:13:34+00:00
# 1 2024-10-14 08:46:51+00:00
# 2 2024-10-13 07:30:58+00:00
# 3 2024-10-12 07:38:50+00:00
# 4 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#                     id     conversation_id  \
# 0  1846086999964283136 1846086999964283136
# 1  1845748090461966592 1845748090461966592
# 2  1845366606823657984 1845366606823657984
# 3  1845006197847360000 1845006197847360000
# 4  1844633149784891648 1844633149784891648
#
#                                                 text  category  \
# 0  ❌ Rząd polski zamierza budować w Polsce 49 Cen...  Original
# 1  ❌ Szambo wybija i robi się coraz ciekawiej. Na...  Original
# 2  ❌ NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SPOS...  Original
# 3  🆘  Firma farmaceutyczna GSK zapłaci ponad 2 ml...  Original
# 4  ❌ O CO TUTAJ CHODZI? W październiku 2024 r. sz...  Original
#
#                                  context_annotations  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   referenced_tweets         username         party  geo
# 0               NaN  placzekgrzegorz  Konfederacja  NaN
# 1               NaN  placzekgrzegorz  Konfederacja  NaN
# 2               NaN  placzekgrzegorz  Konfederacja  NaN
# 3               NaN  placzekgrzegorz  Konfederacja  NaN
# 4               NaN  placzekgrzegorz  Konfederacja  NaN

# %%
df.loc[1, 'text']
# Out:
# '❌ Szambo wybija i robi się coraz ciekawiej. Na światło dzienne wychodzą bowiem coraz to nowe fakty. Otóż wytyczne funkcjonowania 49 Centrów Integracji Cudzoziemców (CIC) przewidują dla cudzoziemców w całej Polsce między innymi… zatrudnianie OSOBISTYCH ASYSTENTÓW w urzędach,… https://t.co/OZyTSwcMAb'

# %% [markdown]
# Emojis handler

# %%
def add_space_around_emojis(text):
    return ''.join(f' {char} ' if char in emoji.EMOJI_DATA or re.match(r'[\U0001F1E6-\U0001F1FF]', char) else char for char in text)

df['text'] = df['text'].apply(add_space_around_emojis)

def clean_text(text):
    mentions = re.findall(r'@\w+', text)
    text = re.sub(r'@\w+', '', text)
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)
    hashtags = re.findall(r'#\w+', text)
    text = re.sub(r'(?<!\s)([\U0001F600-\U0001F64F])', r' \1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F])(?!\s)', r'\1 ', text)
    return [text, mentions, links, hashtags]

df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# Out:
# /var/folders/4y/59z3xr0d24q8s85gv4mfxhc00000gn/T/ipykernel_17976/331721625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(add_space_around_emojis)
# /var/folders/4y/59z3xr0d24q8s85gv4mfxhc00000gn/T/ipykernel_17976/331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# /var/folders/4y/59z3xr0d24q8s85gv4mfxhc00000gn/T/ipykernel_17976/331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# /var/folders/4y/59z3xr0d24q8s85gv4mfxhc00000gn/T/ipykernel_17976/331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)
# /var/folders/4y/59z3xr0d24q8s85gv4mfxhc00000gn/T/ipykernel_17976/331721625.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # Turn off the warning from lack of loc

# %%
df.head()
# Out:
#                                       public_metrics reply_settings  \
# 0  {'retweet_count': 230, 'reply_count': 61, 'lik...       everyone
# 1  {'retweet_count': 1301, 'reply_count': 169, 'l...       everyone
# 2  {'retweet_count': 682, 'reply_count': 145, 'li...       everyone
# 3  {'retweet_count': 271, 'reply_count': 56, 'lik...       everyone
# 4  {'retweet_count': 214, 'reply_count': 56, 'lik...       everyone
#
#                                             entities  \
# 0  {'urls': [{'start': 277, 'end': 300, 'url': 'h...
# 1  {'urls': [{'start': 276, 'end': 299, 'url': 'h...
# 2  {'urls': [{'start': 279, 'end': 302, 'url': 'h...
# 3  {'urls': [{'start': 278, 'end': 301, 'url': 'h...
# 4  {'urls': [{'start': 281, 'end': 304, 'url': 'h...
#
#                  created_at  \
# 0 2024-10-15 07:13:34+00:00
# 1 2024-10-14 08:46:51+00:00
# 2 2024-10-13 07:30:58+00:00
# 3 2024-10-12 07:38:50+00:00
# 4 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  ...  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False  ...
# 1  [1845747336862961872, 1845748090461966651]   pl              False  ...
# 2                       [1845366606823657982]   pl              False  ...
# 3                       [1845006197847359885]   pl              False  ...
# 4                       [1844633149784891665]   pl              False  ...
#
#                                  context_annotations  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   referenced_tweets         username         party  geo  \
# 0               NaN  placzekgrzegorz  Konfederacja  NaN
# 1               NaN  placzekgrzegorz  Konfederacja  NaN
# 2               NaN  placzekgrzegorz  Konfederacja  NaN
# 3               NaN  placzekgrzegorz  Konfederacja  NaN
# 4               NaN  placzekgrzegorz  Konfederacja  NaN
#
#                                           text_clean  \
# 0   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                 mentions  \
# 0                                     []
# 1                                     []
# 2                          [@donaldtusk]
# 3                                     []
# 4  [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
#
#                                                links          hashtags
# 0  [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                          [https://t.co/OZyTSwcMAb]                []
# 2                          [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                          [https://t.co/cwusG1221F]                []
# 4                          [https://t.co/RkylDcUHbo]                []
#
# [5 rows x 24 columns]

# %%
df.drop(columns=['entities'], inplace=True)

# %%
# Some additioanl numerical data from tweets is extracted and added to the dataframe as new variables, then the original column is dropped
df['retweet_count'] = df['public_metrics'].apply(lambda x: x['retweet_count'])
df['reply_count'] = df['public_metrics'].apply(lambda x: x['reply_count'])
df['like_count'] = df['public_metrics'].apply(lambda x: x['like_count'])
df['quote_count'] = df['public_metrics'].apply(lambda x: x['quote_count'])
df['impression_count'] = df['public_metrics'].apply(lambda x: x['impression_count'])

df.drop(columns=['public_metrics'], inplace=True)

# %%
df
# Out:
#       reply_settings                created_at  \
# 0           everyone 2024-10-15 07:13:34+00:00
# 1           everyone 2024-10-14 08:46:51+00:00
# 2           everyone 2024-10-13 07:30:58+00:00
# 3           everyone 2024-10-12 07:38:50+00:00
# 4           everyone 2024-10-11 06:56:29+00:00
# ...              ...                       ...
# 52770       everyone 2022-11-04 17:02:07+00:00
# 52774       everyone 2022-11-04 07:02:07+00:00
# 52779       everyone 2022-10-29 12:23:28+00:00
# 52784       everyone 2022-10-21 07:33:09+00:00
# 52785       everyone 2022-10-16 15:29:13+00:00
#
#                                              attachments  \
# 0      {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52770                                                NaN
# 52774                                                NaN
# 52779                                                NaN
# 52784                                                NaN
# 52785          {'media_keys': ['3_1581668584501149697']}
#
#                                            edit_controls           author_id  \
# 0      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# ...                                                  ...                 ...
# 52770  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52774  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52779  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52784  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 52785  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
#
#                            edit_history_tweet_ids lang possibly_sensitive  \
# 0      [1846086770229694583, 1846086999964283214]   pl              False
# 1      [1845747336862961872, 1845748090461966651]   pl              False
# 2                           [1845366606823657982]   pl              False
# 3                           [1845006197847359885]   pl              False
# 4                           [1844633149784891665]   pl              False
# ...                                           ...  ...                ...
# 52770                       [1588577342594482176]   pl                  0
# 52774                       [1588426347646533634]   pl                  0
# 52779                       [1586332889444237312]   pl                  0
# 52784                       [1583360725958828034]   pl                  0
# 52785                       [1581668593192034304]   pl                  0
#
#                         id     conversation_id  ...  geo  \
# 0      1846086999964283136 1846086999964283136  ...  NaN
# 1      1845748090461966592 1845748090461966592  ...  NaN
# 2      1845366606823657984 1845366606823657984  ...  NaN
# 3      1845006197847360000 1845006197847360000  ...  NaN
# 4      1844633149784891648 1844633149784891648  ...  NaN
# ...                    ...                 ...  ...  ...
# 52770  1588577342594482176 1588577342594482176  ...  NaN
# 52774  1588426347646533632 1588426347646533632  ...  NaN
# 52779  1586332889444237312 1586332889444237312  ...  NaN
# 52784  1583360725958828032 1583360725958828032  ...  NaN
# 52785  1581668593192034304 1581668593192034304  ...  NaN
#
#                                               text_clean  \
# 0       ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1       ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2       ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3       🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4       ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
# ...                                                  ...
# 52770  Rozporządzenie o zakazie rejestracji nowych sa...
# 52774  Wojna gazowa Putina. Europa przełamała szantaż...
# 52779  Naukowcy wiedzą jak sprawić, by OZE nie zależa...
# 52784  Chaos na rynku energii. Zrywane umowy i zamroż...
# 52785  16 październik 1978 rok pamiętamy #DzieńPapieski
#
#                                     mentions  \
# 0                                         []
# 1                                         []
# 2                              [@donaldtusk]
# 3                                         []
# 4      [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
# ...                                      ...
# 52770                            [@EPPGroup]
# 52774                            [@Money_pl]
# 52779                                     []
# 52784                           [@BOksinska]
# 52785                                     []
#
#                                                    links          hashtags  \
# 0      [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                              [https://t.co/OZyTSwcMAb]                []
# 2                              [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                              [https://t.co/cwusG1221F]                []
# 4                              [https://t.co/RkylDcUHbo]                []
# ...                                                  ...               ...
# 52770                          [https://t.co/zjdg6y5yH8]                []
# 52774                          [https://t.co/UP6coX7Ukj]                []
# 52779                          [https://t.co/rS6OtqX4wc]                []
# 52784                          [https://t.co/XMl5UjJLwb]                []
# 52785                          [https://t.co/vGdsQWNdMl]  [#DzieńPapieski]
#
#       retweet_count reply_count like_count quote_count impression_count
# 0               230          61        644           7            11648
# 1              1301         169       3845          57           146584
# 2               682         145       2061          28           100757
# 3               271          56        989           8            30769
# 4               214          56        678           9            17432
# ...             ...         ...        ...         ...              ...
# 52770             3           0          3           1                0
# 52774             1           0          2           1                0
# 52779             3           0          2           1                0
# 52784             4           0          2           1                0
# 52785             2           0          7           0                0
#
# [49062 rows x 27 columns]

# %%
df.dtypes
# Out:
# reply_settings                         object
# created_at                datetime64[ns, UTC]
# attachments                            object
# edit_controls                          object
# author_id                             float64
# edit_history_tweet_ids                 object
# lang                                   object
# possibly_sensitive                     object
# id                                     object
# conversation_id                       float64
# text                                   object
# category                               object
# context_annotations                    object
# in_reply_to_user_id                   float64
# referenced_tweets                      object
# username                               object
# party                                  object
# geo                                    object
# text_clean                             object
# mentions                               object
# links                                  object
# hashtags                               object
# retweet_count                           int64
# reply_count                             int64
# like_count                              int64
# quote_count                             int64
# impression_count                        int64
# dtype: object

# %%
df.head()
# Out:
#   reply_settings                created_at  \
# 0       everyone 2024-10-15 07:13:34+00:00
# 1       everyone 2024-10-14 08:46:51+00:00
# 2       everyone 2024-10-13 07:30:58+00:00
# 3       everyone 2024-10-12 07:38:50+00:00
# 4       everyone 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#                     id     conversation_id  ...  geo  \
# 0  1846086999964283136 1846086999964283136  ...  NaN
# 1  1845748090461966592 1845748090461966592  ...  NaN
# 2  1845366606823657984 1845366606823657984  ...  NaN
# 3  1845006197847360000 1845006197847360000  ...  NaN
# 4  1844633149784891648 1844633149784891648  ...  NaN
#
#                                           text_clean  \
# 0   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                 mentions  \
# 0                                     []
# 1                                     []
# 2                          [@donaldtusk]
# 3                                     []
# 4  [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
#
#                                                links          hashtags  \
# 0  [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                          [https://t.co/OZyTSwcMAb]                []
# 2                          [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                          [https://t.co/cwusG1221F]                []
# 4                          [https://t.co/RkylDcUHbo]                []
#
#   retweet_count reply_count like_count quote_count impression_count
# 0           230          61        644           7            11648
# 1          1301         169       3845          57           146584
# 2           682         145       2061          28           100757
# 3           271          56        989           8            30769
# 4           214          56        678           9            17432
#
# [5 rows x 27 columns]

# %%
df.dtypes
# Out:
# reply_settings                         object
# created_at                datetime64[ns, UTC]
# attachments                            object
# edit_controls                          object
# author_id                             float64
# edit_history_tweet_ids                 object
# lang                                   object
# possibly_sensitive                     object
# id                                     object
# conversation_id                       float64
# text                                   object
# category                               object
# context_annotations                    object
# in_reply_to_user_id                   float64
# referenced_tweets                      object
# username                               object
# party                                  object
# geo                                    object
# text_clean                             object
# mentions                               object
# links                                  object
# hashtags                               object
# retweet_count                           int64
# reply_count                             int64
# like_count                              int64
# quote_count                             int64
# impression_count                        int64
# dtype: object

# %%
import pandas as pd

# Step 1: Check for duplicate columns and remove them
if df.columns.duplicated().any():
    print("Duplicate columns found! Removing them...")
    df_no_duplicates = df.loc[:, ~df.columns.duplicated()]  # Keep the first occurrence of each column
else:
    df_no_duplicates = df.copy()

# Step 2: Convert 'id' column to string (if needed)
df_no_duplicates['id'] = df_no_duplicates['id'].astype(str)

# Step 3: Check for missing or empty values in 'text' and 'text_clean'
empty_text = df_no_duplicates[df_no_duplicates['text'].isna() | (df_no_duplicates['text'].astype(str).str.strip() == '')]
empty_text_clean = df_no_duplicates[df_no_duplicates['text_clean'].isna() | (df_no_duplicates['text_clean'].astype(str).str.strip() == '')]

print(f"Rows where 'text' is empty or null: {empty_text.shape[0]}")
print(empty_text[['id', 'text', 'text_clean']].head())

print(f"\nRows where 'text_clean' is empty or null: {empty_text_clean.shape[0]}")
empty_text_clean[['id', 'text', 'text_clean']].head()
# Out:
# Rows where 'text' is empty or null: 0
# Empty DataFrame
# Columns: [id, text, text_clean]
# Index: []
#
# Rows where 'text_clean' is empty or null: 731
#                      id                                               text  \
# 41  1830335798408884480    @DOganaw @KONFEDERACJA_ https://t.co/XyFM1k7j7d
# 46  1830203038419591168     @PremierRP @donaldtusk https://t.co/2cp9NKe0U4
# 49  1829244931577098240                 @Leszczyna https://t.co/RrGcwaedOx
# 57  1827578129142943744                 @PremierRP https://t.co/Vf4FzG1iX0
# 58  1827374206306099200  @PlaOb_StalWola @donaldtusk https://t.co/tyTl9...
#
#    text_clean
# 41
# 46
# 49
# 57
# 58

# %%
false_count = (df['text_clean'].str.strip().astype(bool))
print(f"Number of False values: {false_count}")
# Out:
# Number of False values: 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 52770    True
# 52774    True
# 52779    True
# 52784    True
# 52785    True
# Name: text_clean, Length: 49062, dtype: bool

# %%
#Delete empty tweets
df = df[false_count]

# %%
len(df)
# Out:
# 48331

# %% [markdown]
# saving data used for translation

# %%
df_clean_text = df[['id', 'text', 'text_clean']]

df_clean_text.to_csv('data/02.processed/data_for_translation.csv', index=False)
df.to_csv('data/02.processed/whole_dataset_for_translation.csv', index=False)

# %%
len(df)
# Out:
# 48331

# %%
df_clean_text.dtypes
# Out:
# id            object
# text          object
# text_clean    object
# dtype: object

# %% [markdown]
# reading data used for translation

# %%
# Read CSV with ID column as string (text)
df_clean_text = pd.read_csv('Data/02.processed/data_for_translation.csv', dtype={'id': str})

# Verify the column type
print("ID column type:", df_clean_text['id'].dtype)
print("Sample ID:", df_clean_text['id'].iloc[0], "of type", type(df_clean_text['id'].iloc[0]))
# Out:
# ID column type: object
# Sample ID: 1846086999964283136 of type <class 'str'>

# %%
df_clean_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48331 entries, 0 to 48330
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          48331 non-null  object
#  1   text        48331 non-null  object
#  2   text_clean  48331 non-null  object
# dtypes: object(3)
# memory usage: 1.1+ MB

# %%
df_clean_text
# Out:
#                         id                                               text  \
# 0      1846086999964283136   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1      1845748090461966592   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2      1845366606823657984   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3      1845006197847360000   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4      1844633149784891648   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
# ...                    ...                                                ...
# 48326  1588577342594482176  Rozporządzenie o zakazie rejestracji nowych sa...
# 48327  1588426347646533632  Wojna gazowa Putina. Europa przełamała szantaż...
# 48328  1586332889444237312  Naukowcy wiedzą jak sprawić, by OZE nie zależa...
# 48329  1583360725958828032  Chaos na rynku energii. Zrywane umowy i zamroż...
# 48330  1581668593192034304  16 październik 1978 rok pamiętamy #DzieńPapies...
#
#                                               text_clean
# 0       ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1       ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2       ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3       🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4       ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
# ...                                                  ...
# 48326  Rozporządzenie o zakazie rejestracji nowych sa...
# 48327  Wojna gazowa Putina. Europa przełamała szantaż...
# 48328  Naukowcy wiedzą jak sprawić, by OZE nie zależa...
# 48329  Chaos na rynku energii. Zrywane umowy i zamroż...
# 48330  16 październik 1978 rok pamiętamy #DzieńPapieski
#
# [48331 rows x 3 columns]

# %%
# Filter rows where 'text_clean' is null OR empty (after stripping whitespace)
null_or_empty_text_clean = df_clean_text[
    df_clean_text['text_clean'].isna() | 
    (df_clean_text['text_clean'].astype(str).str.strip() == '')
]

# Display the number of problematic rows
print(f"Rows where 'text_clean' is null or empty: {null_or_empty_text_clean.shape[0]}")

# Show the affected rows
null_or_empty_text_clean[['id', 'text', 'text_clean']]
# Out:
# Rows where 'text_clean' is null or empty: 0
# Empty DataFrame
# Columns: [id, text, text_clean]
# Index: []

# %%
# 1. Print the total number of rows in df_clean_text
print("Total rows in df_clean_text:", len(df_clean_text))

# 2. Filter out rows where 'text_clean' is null or an empty string (after stripping whitespace)
valid_rows = df_clean_text[
    ~(
        df_clean_text['text_clean'].isna() 
        | (df_clean_text['text_clean'].astype(str).str.strip() == '')
    )
]

# 3. Print the number of those valid (non-empty) rows
print("Rows with non-empty 'text_clean':", len(valid_rows))
# Out:
# Total rows in df_clean_text: 48331
# Rows with non-empty 'text_clean': 48331

# %% [markdown]
# reading translation dataset

# %%
df_en_text = pd.read_parquet('data/przetłumaczone przed i po/df_combined.parquet')
df_en_text
# Out:
#        in_reply_to_user_id reply_settings  author_id  \
# 0                375146901       everyone 1182211615
# 1                      NaN       everyone 1182211615
# 2                      NaN       everyone 1182211615
# 3                      NaN       everyone 1182211615
# 4                      NaN       everyone 1182211615
# ...                    ...            ...        ...
# 48326                  NaN       everyone  961181894
# 48327                  NaN       everyone  961181894
# 48328                  NaN       everyone  961181894
# 48329                  NaN       everyone  961181894
# 48330                  NaN       everyone  961181894
#
#                                      context_annotations                   id  \
# 0      [{'domain': {'description': 'Named people in t...  1846277256509116672
# 1      [{'domain': {'description': 'Named people in t...  1846222583898784000
# 2                                                   None  1846161400328028160
# 3                                                   None  1846091824101769472
# 4                                                   None  1846075343188144128
# ...                                                  ...                  ...
# 48326                                               None  1707719554355380480
# 48327                                               None  1704120323023454464
# 48328                                               None  1702668459576786944
# 48329                                               None  1701960909369868544
# 48330                                               None  1701606379709198336
#
#                                                     text  \
# 0      @donaldtusk Niezrealizowanie większości ze "10...
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...
# 2       ❌ Mamy rok po wyborach, a Polska pogrąża się ...
# 3      Mija rok od wyborów parlamentarnych. W kampani...
# 4                  #Idę11  🇵  🇱  https://t.co/KiCe5ATOpX
# ...                                                  ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...
# 48327  Za nami posiedzenie @SejmikMaz. I kolejne wspa...
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...
# 48329  To jedna z największych inwestycji drogowych @...
# 48330  Powiaty mają 25 lat ❗ ️Na @Zamek_Krolewski odb...
#
#                                            edit_controls  \
# 0      {'editable_until': '2024-10-15 20:49:34+00:00'...
# 1      {'editable_until': '2024-10-15 17:12:19+00:00'...
# 2      {'editable_until': '2024-10-15 13:09:12+00:00'...
# 3      {'editable_until': '2024-10-15 08:32:44+00:00'...
# 4      {'editable_until': '2024-10-15 07:27:14+00:00'...
# ...                                                  ...
# 48326  {'editable_until': '2023-09-29 12:30:44+00:00'...
# 48327  {'editable_until': '2023-09-19 14:08:40+00:00'...
# 48328  {'editable_until': '2023-09-15 13:59:29+00:00'...
# 48329  {'editable_until': '2023-09-13 15:07:56+00:00'...
# 48330  {'editable_until': '2023-09-12 15:39:09+00:00'...
#
#                                        referenced_tweets  \
# 0      [{'id': '1846091776269963695', 'type': 'replie...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 48326                                               None
# 48327                                               None
# 48328                                               None
# 48329                                               None
# 48330                                               None
#
#                      created_at edit_history_tweet_ids  ... reply_count  \
# 0     2024-10-15 19:49:34+00:00  [1846277256509116623]  ...           1
# 1     2024-10-15 16:12:19+00:00  [1846222583898784025]  ...           2
# 2     2024-10-15 12:09:12+00:00  [1846161400328028272]  ...           3
# 3     2024-10-15 07:32:44+00:00  [1846091824101769490]  ...           2
# 4     2024-10-15 06:27:14+00:00  [1846075343188144153]  ...          18
# ...                         ...                    ...  ...         ...
# 48326 2023-09-29 11:30:44+00:00  [1707719554355380484]  ...           0
# 48327 2023-09-19 13:08:40+00:00  [1704120323023454339]  ...           0
# 48328 2023-09-15 12:59:29+00:00  [1702668459576787064]  ...           0
# 48329 2023-09-13 14:07:56+00:00  [1701960909369868437]  ...           0
# 48330 2023-09-12 14:39:09+00:00  [1701606379709198357]  ...           2
#
#        like_count  quote_count impression_count  \
# 0              33            0             1555
# 1              72            0             3031
# 2              33            2             8636
# 3              38            0             2441
# 4             616            2             8634
# ...           ...          ...              ...
# 48326           6            0             2154
# 48327          15            0              649
# 48328          16            0              581
# 48329          13            0              621
# 48330          16            0             2444
#
#                                            text_clean_en  \
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       ❌ We are a year after the elections, and Pola...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 48326  Are you studying medicine, nursing or emergenc...
# 48327  The meeting is over. And further support for t...
# 48328  The Płock Oncology Center is ready! It will ac...
# 48329  This is one of the largest road investments   ...
# 48330  The counties are 25 years old ❗ ️The anniversa...
#
#                                  text_clean_en_demojized  \
# 0       Failure to implement most of the "100 specifi...
# 1      A year after the elections, one thing must be ...
# 2       :cross_mark: We are a year after the election...
# 3      A year has passed since the parliamentary elec...
# 4                                       #I'm going11 🇵 🇱
# ...                                                  ...
# 48326  Are you studying medicine, nursing or emergenc...
# 48327  The meeting is over. And further support for t...
# 48328  The Płock Oncology Center is ready! It will ac...
# 48329  This is one of the largest road investments  \...
# 48330  The counties are 25 years old :red_exclamation...
#
#                                     text_clean_demojized emoji_count_en  \
# 0       Niezrealizowanie większości ze "100 konkretów...              0
# 1      Rok po wyborach trzeba powiedzieć jedno - nie ...              0
# 2       :cross_mark: Mamy rok po wyborach, a Polska p...              1
# 3      Mija rok od wyborów parlamentarnych. W kampani...              0
# 4                                         #Idę11  🇵  🇱                2
# ...                                                  ...            ...
# 48326  Studiujesz na kierunku lekarskim, pielęgniarst...              0
# 48327  Za nami posiedzenie . I kolejne wsparcie dla m...              0
# 48328  Płockie Centrum Onkologii gotowe! Już na począ...              0
# 48329  To jedna z największych inwestycji drogowych  ...              0
# 48330  Powiaty mają 25 lat :red_exclamation_mark: Na ...              3
#
#       emoji_count             name
# 0               0  Bartłomiej Pejo
# 1               0  Bartłomiej Pejo
# 2               1  Bartłomiej Pejo
# 3               0  Bartłomiej Pejo
# 4               2  Bartłomiej Pejo
# ...           ...              ...
# 48326           0     Adam Struzik
# 48327           0     Adam Struzik
# 48328           0     Adam Struzik
# 48329           0     Adam Struzik
# 48330           3     Adam Struzik
#
# [48331 rows x 33 columns]

# %%
missing_translation_mask = df_en_text['text_clean_en'].isna() | (df_en_text['text_clean_en'].str.strip() == '')
df_en_text[missing_translation_mask]
# Out:
# Empty DataFrame
# Columns: [in_reply_to_user_id, reply_settings, author_id, context_annotations, id, text, edit_controls, referenced_tweets, created_at, edit_history_tweet_ids, lang, conversation_id, possibly_sensitive, category, attachments, geo, username, party, text_clean, mentions, links, hashtags, retweet_count, reply_count, like_count, quote_count, impression_count, text_clean_en, text_clean_en_demojized, text_clean_demojized, emoji_count_en, emoji_count, name]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# merging second version of translated dataset with original one

# %%
# Step 1: Make sure IDs are strings
df['id'] = df['id'].astype(str)
df_en_text['id'] = df_en_text['id'].astype(str)

df_en_combined = pd.concat([df_en_text], ignore_index=True)

# Step 3: Drop duplicates by 'id' to keep only the latest 
df_en_combined = df_en_combined.drop_duplicates(subset='id', keep='last')

# Step 4: Merge back into the full dataset to get a unified view
df_merged = df.merge(df_en_text[['id', 'text_clean_en']], on='id')

print(f"Total rows after merge: {len(df_merged)} ")
# Out:
# Total rows after merge: 48331

# %%
# Find the IDs present in df but not in df_merged
missing_ids = df[~df['id'].isin(df_merged['id'])]['id']

# Display the missing rows
missing_rows = df[df['id'].isin(missing_ids)]
print(missing_rows)
# Out:
# Empty DataFrame
# Columns: [reply_settings, created_at, attachments, edit_controls, author_id, edit_history_tweet_ids, lang, possibly_sensitive, id, conversation_id, text, category, context_annotations, in_reply_to_user_id, referenced_tweets, username, party, geo, text_clean, mentions, links, hashtags, retweet_count, reply_count, like_count, quote_count, impression_count]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_merged
# Out:
#       reply_settings                created_at  \
# 0           everyone 2024-10-15 07:13:34+00:00
# 1           everyone 2024-10-14 08:46:51+00:00
# 2           everyone 2024-10-13 07:30:58+00:00
# 3           everyone 2024-10-12 07:38:50+00:00
# 4           everyone 2024-10-11 06:56:29+00:00
# ...              ...                       ...
# 48326       everyone 2022-11-04 17:02:07+00:00
# 48327       everyone 2022-11-04 07:02:07+00:00
# 48328       everyone 2022-10-29 12:23:28+00:00
# 48329       everyone 2022-10-21 07:33:09+00:00
# 48330       everyone 2022-10-16 15:29:13+00:00
#
#                                              attachments  \
# 0      {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 48326                                                NaN
# 48327                                                NaN
# 48328                                                NaN
# 48329                                                NaN
# 48330          {'media_keys': ['3_1581668584501149697']}
#
#                                            edit_controls           author_id  \
# 0      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# ...                                                  ...                 ...
# 48326  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48327  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48328  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48329  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48330  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
#
#                            edit_history_tweet_ids lang possibly_sensitive  \
# 0      [1846086770229694583, 1846086999964283214]   pl              False
# 1      [1845747336862961872, 1845748090461966651]   pl              False
# 2                           [1845366606823657982]   pl              False
# 3                           [1845006197847359885]   pl              False
# 4                           [1844633149784891665]   pl              False
# ...                                           ...  ...                ...
# 48326                       [1588577342594482176]   pl                  0
# 48327                       [1588426347646533634]   pl                  0
# 48328                       [1586332889444237312]   pl                  0
# 48329                       [1583360725958828034]   pl                  0
# 48330                       [1581668593192034304]   pl                  0
#
#                         id     conversation_id  ...  \
# 0      1846086999964283136 1846086999964283136  ...
# 1      1845748090461966592 1845748090461966592  ...
# 2      1845366606823657984 1845366606823657984  ...
# 3      1845006197847360000 1845006197847360000  ...
# 4      1844633149784891648 1844633149784891648  ...
# ...                    ...                 ...  ...
# 48326  1588577342594482176 1588577342594482176  ...
# 48327  1588426347646533632 1588426347646533632  ...
# 48328  1586332889444237312 1586332889444237312  ...
# 48329  1583360725958828032 1583360725958828032  ...
# 48330  1581668593192034304 1581668593192034304  ...
#
#                                               text_clean  \
# 0       ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1       ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2       ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3       🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4       ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
# ...                                                  ...
# 48326  Rozporządzenie o zakazie rejestracji nowych sa...
# 48327  Wojna gazowa Putina. Europa przełamała szantaż...
# 48328  Naukowcy wiedzą jak sprawić, by OZE nie zależa...
# 48329  Chaos na rynku energii. Zrywane umowy i zamroż...
# 48330  16 październik 1978 rok pamiętamy #DzieńPapieski
#
#                                     mentions  \
# 0                                         []
# 1                                         []
# 2                              [@donaldtusk]
# 3                                         []
# 4      [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
# ...                                      ...
# 48326                            [@EPPGroup]
# 48327                            [@Money_pl]
# 48328                                     []
# 48329                           [@BOksinska]
# 48330                                     []
#
#                                                    links          hashtags  \
# 0      [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                              [https://t.co/OZyTSwcMAb]                []
# 2                              [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                              [https://t.co/cwusG1221F]                []
# 4                              [https://t.co/RkylDcUHbo]                []
# ...                                                  ...               ...
# 48326                          [https://t.co/zjdg6y5yH8]                []
# 48327                          [https://t.co/UP6coX7Ukj]                []
# 48328                          [https://t.co/rS6OtqX4wc]                []
# 48329                          [https://t.co/XMl5UjJLwb]                []
# 48330                          [https://t.co/vGdsQWNdMl]  [#DzieńPapieski]
#
#       retweet_count reply_count like_count quote_count impression_count  \
# 0               230          61        644           7            11648
# 1              1301         169       3845          57           146584
# 2               682         145       2061          28           100757
# 3               271          56        989           8            30769
# 4               214          56        678           9            17432
# ...             ...         ...        ...         ...              ...
# 48326             3           0          3           1                0
# 48327             1           0          2           1                0
# 48328             3           0          2           1                0
# 48329             4           0          2           1                0
# 48330             2           0          7           0                0
#
#                                            text_clean_en
# 0       ❌ The Polish government intends to build 49 F...
# 1       ❌ The cesspool is breaking out and it's getti...
# 2       ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3       🆘 The pharmaceutical company GSK will pay ove...
# 4       ❌ WHAT IS GOING ON HERE? In October 2024, her...
# ...                                                  ...
# 48326  Regulation banning the registration of new car...
# 48327  Putin's gas war. Europe has broken the blackma...
# 48328  Scientists know how to ensure that renewable e...
# 48329  Chaos on the energy market. Terminated contrac...
# 48330             October 16, 1978 we remember #PapalDay
#
# [48331 rows x 28 columns]

# %% [markdown]
# check wether the data went correctly

# %%
df_merged[df_merged["id"]=="1807795860480160000"]
# Out:
#      reply_settings                created_at  \
# 5163       everyone 2024-07-01 15:18:15+00:00
#
#                                             attachments  \
# 5163  {'media_keys': ['3_1807795856101212161', '3_18...
#
#                                           edit_controls  author_id  \
# 5163  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1182211615
#
#      edit_history_tweet_ids lang possibly_sensitive                   id  \
# 5163  [1807795860480159980]   pl              False  1807795860480160000
#
#          conversation_id  ...  \
# 5163 1807795860480160000  ...
#
#                                              text_clean mentions  \
# 5163   🇳  🇱  Holenderski klub NAC Breda przygotował ...       []
#
#                                                   links  hashtags  \
# 5163  [https://t.co/WI736ocWQ7, https://t.co/ANX3x4e...        []
#
#      retweet_count reply_count like_count quote_count impression_count  \
# 5163             5           1         24           0              603
#
#                                           text_clean_en
# 5163   🇳 🇱 The Dutch club NAC Breda has prepared spe...
#
# [1 rows x 28 columns]

# %%
# Check how many rows still have missing or empty translations
missing_translation_mask = df_merged['text_clean_en'].isna() | (df_merged['text_clean_en'].str.strip() == '')

# Show some of them
df_missing_translation = df_merged[missing_translation_mask]
print(f"Rows without translation: {df_missing_translation.shape[0]}")
display(df_missing_translation[['id', 'text', 'text_clean', 'text_clean_en']].head())
# Out:
# Rows without translation: 0
# Empty DataFrame
# Columns: [id, text, text_clean, text_clean_en]
# Index: []

# %% [markdown]
# removing rows withtout translation due to possessing text that is not being analyzed by our research

# %%
# Remove them
df_clean_translated = df_merged[~missing_translation_mask].copy()

print(f"Remaining rows with proper translation: {df_clean_translated.shape[0]}")
# Out:
# Remaining rows with proper translation: 48331

# %%
df_clean_translated.head()
# Out:
#   reply_settings                created_at  \
# 0       everyone 2024-10-15 07:13:34+00:00
# 1       everyone 2024-10-14 08:46:51+00:00
# 2       everyone 2024-10-13 07:30:58+00:00
# 3       everyone 2024-10-12 07:38:50+00:00
# 4       everyone 2024-10-11 06:56:29+00:00
#
#                                          attachments  \
# 0  {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        edit_controls           author_id  \
# 0  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1  {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
#
#                        edit_history_tweet_ids lang possibly_sensitive  \
# 0  [1846086770229694583, 1846086999964283214]   pl              False
# 1  [1845747336862961872, 1845748090461966651]   pl              False
# 2                       [1845366606823657982]   pl              False
# 3                       [1845006197847359885]   pl              False
# 4                       [1844633149784891665]   pl              False
#
#                     id     conversation_id  ...  \
# 0  1846086999964283136 1846086999964283136  ...
# 1  1845748090461966592 1845748090461966592  ...
# 2  1845366606823657984 1845366606823657984  ...
# 3  1845006197847360000 1845006197847360000  ...
# 4  1844633149784891648 1844633149784891648  ...
#
#                                           text_clean  \
# 0   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                 mentions  \
# 0                                     []
# 1                                     []
# 2                          [@donaldtusk]
# 3                                     []
# 4  [@MZ_GOV_PL, @Leszczyna, @NFZ_GOV_PL]
#
#                                                links          hashtags  \
# 0  [https://t.co/gL3O8F0ITB, https://t.co/cay37TX...                []
# 1                          [https://t.co/OZyTSwcMAb]                []
# 2                          [https://t.co/rIGkIpR8sw]  [#RadaKrajowaKO]
# 3                          [https://t.co/cwusG1221F]                []
# 4                          [https://t.co/RkylDcUHbo]                []
#
#   retweet_count reply_count like_count quote_count impression_count  \
# 0           230          61        644           7            11648
# 1          1301         169       3845          57           146584
# 2           682         145       2061          28           100757
# 3           271          56        989           8            30769
# 4           214          56        678           9            17432
#
#                                        text_clean_en
# 0   ❌ The Polish government intends to build 49 F...
# 1   ❌ The cesspool is breaking out and it's getti...
# 2   ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3   🆘 The pharmaceutical company GSK will pay ove...
# 4   ❌ WHAT IS GOING ON HERE? In October 2024, her...
#
# [5 rows x 28 columns]

# %%
df_clean_translated.to_csv('data/02.processed/df_clean_translated_further_analalysis.csv', index=False)

# %%
def count_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols & pictographs
        "\U0001F680-\U0001F6FF"  # Transport & map symbols
        "\U0001F700-\U0001F77F"  # Alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric shapes
        "\U0001F800-\U0001F8FF"  # Supplemental arrows
        "\U0001F900-\U0001F9FF"  # Supplemental symbols and pictographs
        "\U0001FA00-\U0001FA6F"  # Chess symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and pictographs extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"  # Enclosed characters
        "]+",
        flags=re.UNICODE,
    )
    return len(emoji_pattern.findall(text))

# %%
# Demojize text columns
df_clean_translated['text_clean_en_demojized'] = df_clean_translated['text_clean_en'].apply(
    lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x
)
df_clean_translated['text_clean_demojized'] = df_clean_translated['text_clean'].apply(
    lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x
)

# Count emojis in original text columns
df_clean_translated['emoji_count_en'] = df_clean_translated['text_clean_en'].apply(
    lambda x: count_emojis(str(x)) if pd.notnull(x) else 0
)
df_clean_translated['emoji_count'] = df_clean_translated['text_clean'].apply(
    lambda x: count_emojis(str(x)) if pd.notnull(x) else 0
)

# %%
# Total number of rows
total_rows = len(df_clean_translated)

# Rows with emojis in 'text_clean_en'
rows_with_emojis_en = df_clean_translated[df_clean_translated['emoji_count_en'] > 0].shape[0]

# Rows with emojis in 'text_clean'
rows_with_emojis = df_clean_translated[df_clean_translated['emoji_count'] > 0].shape[0]

# Display statistics
print(f"Total number of rows: {total_rows}")
print(f"Rows with emojis in 'text_clean_en': {rows_with_emojis_en} ({(rows_with_emojis_en/total_rows)*100:.2f}%)")
print(f"Rows with emojis in 'text_clean': {rows_with_emojis} ({(rows_with_emojis/total_rows)*100:.2f}%)")
# Out:
# Total number of rows: 48331
# Rows with emojis in 'text_clean_en': 17994 (37.23%)
# Rows with emojis in 'text_clean': 18289 (37.84%)

# %%
df_clean_translated[['text_clean_en', 'text_clean_en_demojized', 'emoji_count_en', 'text_clean', 'text_clean_demojized', 'emoji_count']].head()
# Out:
#                                        text_clean_en  \
# 0   ❌ The Polish government intends to build 49 F...
# 1   ❌ The cesspool is breaking out and it's getti...
# 2   ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3   🆘 The pharmaceutical company GSK will pay ove...
# 4   ❌ WHAT IS GOING ON HERE? In October 2024, her...
#
#                              text_clean_en_demojized  emoji_count_en  \
# 0   :cross_mark: The Polish government intends to...               2
# 1   :cross_mark: The cesspool is breaking out and...               1
# 2   :cross_mark: I DON'T UNDERSTAND HOW YOU CAN H...               1
# 3   :SOS_button: The pharmaceutical company GSK w...               2
# 4   :cross_mark: WHAT IS GOING ON HERE? In Octobe...               2
#
#                                           text_clean  \
# 0   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                 text_clean_demojized  emoji_count
# 0   :cross_mark:  Rząd polski zamierza budować w ...            3
# 1   :cross_mark:  Szambo wybija i robi się coraz ...            1
# 2   :cross_mark:  NIE ROZUMIEM, JAK MOŻNA KRZYWDZ...            1
# 3   :SOS_button:   Firma farmaceutyczna GSK zapła...            3
# 4   :cross_mark:  O CO TUTAJ CHODZI? W październi...            3

# %%
# Filter rows
rows_with_emojis_in_text_clean_only = df_clean_translated[
    (df_clean_translated['emoji_count'] > 0) & (df_clean_translated['emoji_count_en'] == 0)
]

# Display the number of such rows
print(f"Number of rows with emojis in 'text_clean' but not in 'text_clean_en': {len(rows_with_emojis_in_text_clean_only)}")

# Display the affected rows
rows_with_emojis_in_text_clean_only[['text_clean', 'text_clean_en']]
# Out:
# Number of rows with emojis in 'text_clean' but not in 'text_clean_en': 295
#                                               text_clean  \
# 472    Recepta na problemy na polskiej granicy jest b...
# 536    Unia Europejska mówi Polakom: wasze domy i mie...
# 633    Unia Europejska planuje wprowadzać kolejne ogr...
# 651    Poseł Adam Gomoła z Polski 2050 Szymona Hołown...
# 686    Premier Tusk oświadczył, że zamierza wprowadzi...
# ...                                                  ...
# 45637  W niedzielę będę gościem . Serdecznie zachęcam...
# 45654           I 10 razy tyle, co na mieszkalnictwo  🙂
# 46684  Intensywny tydzień misji Komisji Budżetu PE w ...
# 46926               Może być  🙂  Dziękuję i ściskam dłoń
# 47011  Dbanie o bezpieczeństwo żywnościowe i ochrona ...
#
#                                            text_clean_en
# 472    The solution to problems at the Polish border ...
# 536    The European Union tells Poles: your houses an...
# 633    The European Union plans to introduce further ...
# 651    MP Adam Gomoła from Szymon Hołownia's Poland 2...
# 686    Prime Minister Tusk stated that he intends to ...
# ...                                                  ...
# 45637  I will be a guest on Sunday. I encourage you t...
# 45654            And 10 times as much as for housing :)
# 46684  An intense week of mission of the EP Budget Co...
# 46926           Maybe :) Thank you and I shake your hand
# 47011  Taking care of food security and protecting th...
#
# [295 rows x 2 columns]

# %%
df_clean_translated['text_clean_en_demojized'] = df_clean_translated['text_clean_en'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)
df_clean_translated['text_clean_demojized'] = df_clean_translated['text_clean'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)

df_clean_translated[['text_clean_en', 'text_clean_en_demojized', 'text_clean', 'text_clean_demojized']].head()
# Out:
#                                        text_clean_en  \
# 0   ❌ The Polish government intends to build 49 F...
# 1   ❌ The cesspool is breaking out and it's getti...
# 2   ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3   🆘 The pharmaceutical company GSK will pay ove...
# 4   ❌ WHAT IS GOING ON HERE? In October 2024, her...
#
#                              text_clean_en_demojized  \
# 0   :cross_mark: The Polish government intends to...
# 1   :cross_mark: The cesspool is breaking out and...
# 2   :cross_mark: I DON'T UNDERSTAND HOW YOU CAN H...
# 3   :SOS_button: The pharmaceutical company GSK w...
# 4   :cross_mark: WHAT IS GOING ON HERE? In Octobe...
#
#                                           text_clean  \
# 0   ❌  Rząd polski zamierza budować w Polsce 49 C...
# 1   ❌  Szambo wybija i robi się coraz ciekawiej. ...
# 2   ❌  NIE ROZUMIEM, JAK MOŻNA KRZYWDZIĆ W TEN SP...
# 3   🆘   Firma farmaceutyczna GSK zapłaci ponad 2 ...
# 4   ❌  O CO TUTAJ CHODZI? W październiku 2024 r. ...
#
#                                 text_clean_demojized
# 0   :cross_mark:  Rząd polski zamierza budować w ...
# 1   :cross_mark:  Szambo wybija i robi się coraz ...
# 2   :cross_mark:  NIE ROZUMIEM, JAK MOŻNA KRZYWDZ...
# 3   :SOS_button:   Firma farmaceutyczna GSK zapła...
# 4   :cross_mark:  O CO TUTAJ CHODZI? W październi...

# %%
df_clean_translated['possibly_sensitive'] = df_clean_translated['possibly_sensitive'].astype(bool)

# %%
username_to_realname = {
    'bartlomiejpejo': 'Bartłomiej Pejo',
    'GrzegorzBraun_': 'Grzegorz Braun',
    'Iwaszkiewicz_RJ': 'Robert Iwaszkiewicz',
    'KonradBerkowicz': 'Konrad Berkowicz',
    'MarSypniewski': 'Marcin Sypniewski',
    'MichalWawer': 'Michał Wawer',
    'placzekgrzegorz': 'Grzegorz Płaczek',
    'SlawomirMentzen': 'Sławomir Mentzen',
    'TudujKrzysztof': 'Krzysztof Tuduj',
    'Wlodek_Skalik': 'Włodzimierz Skalik',
    'WTumanowicz': 'Witold Tumanowicz',
    'AndrzejSzejna': 'Andrzej Szejna',
    'AnitaKDZG': 'Anita Kucharska-Dziedzic',
    'JoankaSW': 'Joanna Scheuring-Wielgus',
    'KGawkowski': 'Krzysztof Gawkowski',
    'K_Smiszek': 'Krzysztof Śmiszek',
    'MarcinKulasek': 'Marcin Kulasek',
    'MoskwaWodnicka': 'Małgorzata Moskwa-Wodnicka',
    'PaulinaPW2024': 'Paulina Piechna-Więckiewicz',
    'poselTTrela': 'Tomasz Trela',
    'RobertBiedron': 'Robert Biedroń',
    'WandaNowicka': 'Wanda Nowicka',
    'wieczorekdarek': 'Dariusz Wieczorek',
    'wlodekczarzasty': 'Włodzimierz Czarzasty',
    'Arek_Iwaniak': 'Arkadiusz Iwaniak',
    'B_Maciejewska': 'Beata Maciejewska',
    'BeataSzydlo': 'Beata Szydło',
    'elzbietawitek': 'Elżbieta Witek',
    'Kaminski_M_': 'Mariusz Kamiński',
    'Kowalczyk_H': 'Henryk Kowalczyk',
    'Macierewicz_A': 'Antoni Macierewicz',
    'mblaszczak': 'Mariusz Błaszczak',
    'MorawieckiM': 'Mateusz Morawiecki',
    'mwojcik_': 'Michał Wójcik',
    'PatrykJaki': 'Patryk Jaki',
    'bbudka': 'Borys Budka',
    'CTomczyk': 'Cezary Tomczyk',
    'donaldtusk': 'Donald Tusk',
    'DorotaNiedziela': 'Dorota Niedziela',
    'EwaKopacz': 'Ewa Kopacz',
    'JanGrabiec': 'Jan Grabiec',
    'Konwinski_PO': 'Zbigniew Konwiński',
    'Leszczyna': 'Izabela Leszczyna',
    'MKierwinski': 'Marcin Kierwiński',
    'M_K_Blonska': 'Małgorzata Kidawa-Błońska',
    'OklaDrewnowicz': 'Agnieszka Okła-Drewnowicz',
    'trzaskowski_': 'Rafał Trzaskowski',
    'TomaszSiemoniak': 'Tomasz Siemoniak',
    'AgaBaranowskaPL': 'Agnieszka Baranowska',
    'aga_buczynska': 'Agnieszka Buczyńska',
    'hennigkloska': 'Paulina Hennig-Kloska',
    'joannamucha': 'Joanna Mucha',
    'Kpelczynska': 'Katarzyna Pełczyńska-Nałęcz',
    'LukaszOsmalak': 'Łukasz Osmalak',
    'SlizPawel': 'Paweł Śliz',
    'szymon_holownia': 'Szymon Hołownia',
    'ZalewskiPawel': 'Paweł Zalewski',
    'ZywnoMaciej': 'Maciej Żywno',
    'JKozlowskiEu': 'Jacek Kozłowski',
    'michalkobosko': 'Michał Kobosko',
    'DariuszKlimczak': 'Dariusz Klimczak',
    'GrzybAndrzej': 'Andrzej Grzyb',
    'Hetman_K': 'Krzysztof Hetman',
    'JarubasAdam': 'Adam Jarubas',
    'KosiniakKamysz': 'Władysław Kosiniak-Kamysz',
    'Paslawska': 'Urszula Pasławska',
    'PZgorzelskiP': 'Piotr Zgorzelski',
    'StefanKrajewski': 'Stefan Krajewski',
    'StruzikAdam': 'Adam Struzik'
}

# Add the 'name' column to the dataframe
df_clean_translated['name'] = df_clean_translated['username'].map(username_to_realname)

# %%
# Delete next line sign from the 'text_clean_en' column
df_clean_translated['text_clean_en'] = df_clean_translated['text_clean_en'].str.replace('\n', ' ')

# %%
# Save the DataFrame to a Parquet file
df_clean_translated.to_parquet('data/03.cleaned/df_combined.parquet', index=False)

# %%
df_clean_translated
# Out:
#       reply_settings                created_at  \
# 0           everyone 2024-10-15 07:13:34+00:00
# 1           everyone 2024-10-14 08:46:51+00:00
# 2           everyone 2024-10-13 07:30:58+00:00
# 3           everyone 2024-10-12 07:38:50+00:00
# 4           everyone 2024-10-11 06:56:29+00:00
# ...              ...                       ...
# 48326       everyone 2022-11-04 17:02:07+00:00
# 48327       everyone 2022-11-04 07:02:07+00:00
# 48328       everyone 2022-10-29 12:23:28+00:00
# 48329       everyone 2022-10-21 07:33:09+00:00
# 48330       everyone 2022-10-16 15:29:13+00:00
#
#                                              attachments  \
# 0      {'media_keys': ['3_1846083966849159168', '3_18...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 48326                                                NaN
# 48327                                                NaN
# 48328                                                NaN
# 48329                                                NaN
# 48330          {'media_keys': ['3_1581668584501149697']}
#
#                                            edit_controls           author_id  \
# 0      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 1      {'edits_remaining': 4, 'is_edit_eligible': Tru... 1284852220593414144
# 2      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru... 1284852220593414144
# ...                                                  ...                 ...
# 48326  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48327  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48328  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48329  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
# 48330  {'edits_remaining': 5, 'is_edit_eligible': Tru...          1119834276
#
#                            edit_history_tweet_ids lang  possibly_sensitive  \
# 0      [1846086770229694583, 1846086999964283214]   pl               False
# 1      [1845747336862961872, 1845748090461966651]   pl               False
# 2                           [1845366606823657982]   pl               False
# 3                           [1845006197847359885]   pl               False
# 4                           [1844633149784891665]   pl               False
# ...                                           ...  ...                 ...
# 48326                       [1588577342594482176]   pl               False
# 48327                       [1588426347646533634]   pl               False
# 48328                       [1586332889444237312]   pl               False
# 48329                       [1583360725958828034]   pl               False
# 48330                       [1581668593192034304]   pl               False
#
#                         id     conversation_id  ... reply_count like_count  \
# 0      1846086999964283136 1846086999964283136  ...          61        644
# 1      1845748090461966592 1845748090461966592  ...         169       3845
# 2      1845366606823657984 1845366606823657984  ...         145       2061
# 3      1845006197847360000 1845006197847360000  ...          56        989
# 4      1844633149784891648 1844633149784891648  ...          56        678
# ...                    ...                 ...  ...         ...        ...
# 48326  1588577342594482176 1588577342594482176  ...           0          3
# 48327  1588426347646533632 1588426347646533632  ...           0          2
# 48328  1586332889444237312 1586332889444237312  ...           0          2
# 48329  1583360725958828032 1583360725958828032  ...           0          2
# 48330  1581668593192034304 1581668593192034304  ...           0          7
#
#       quote_count  impression_count  \
# 0               7             11648
# 1              57            146584
# 2              28            100757
# 3               8             30769
# 4               9             17432
# ...           ...               ...
# 48326           1                 0
# 48327           1                 0
# 48328           1                 0
# 48329           1                 0
# 48330           0                 0
#
#                                            text_clean_en  \
# 0       ❌ The Polish government intends to build 49 F...
# 1       ❌ The cesspool is breaking out and it's getti...
# 2       ❌ I DON'T UNDERSTAND HOW YOU CAN HURT YOUR OW...
# 3       🆘 The pharmaceutical company GSK will pay ove...
# 4       ❌ WHAT IS GOING ON HERE? In October 2024, her...
# ...                                                  ...
# 48326  Regulation banning the registration of new car...
# 48327  Putin's gas war. Europe has broken the blackma...
# 48328  Scientists know how to ensure that renewable e...
# 48329  Chaos on the energy market. Terminated contrac...
# 48330             October 16, 1978 we remember #PapalDay
#
#                                  text_clean_en_demojized  \
# 0       :cross_mark: The Polish government intends to...
# 1       :cross_mark: The cesspool is breaking out and...
# 2       :cross_mark: I DON'T UNDERSTAND HOW YOU CAN H...
# 3       :SOS_button: The pharmaceutical company GSK w...
# 4       :cross_mark: WHAT IS GOING ON HERE? In Octobe...
# ...                                                  ...
# 48326  Regulation banning the registration of new car...
# 48327  Putin's gas war. Europe has broken the blackma...
# 48328  Scientists know how to ensure that renewable e...
# 48329  Chaos on the energy market. Terminated contrac...
# 48330             October 16, 1978 we remember #PapalDay
#
#                                     text_clean_demojized emoji_count_en  \
# 0       :cross_mark:  Rząd polski zamierza budować w ...              2
# 1       :cross_mark:  Szambo wybija i robi się coraz ...              1
# 2       :cross_mark:  NIE ROZUMIEM, JAK MOŻNA KRZYWDZ...              1
# 3       :SOS_button:   Firma farmaceutyczna GSK zapła...              2
# 4       :cross_mark:  O CO TUTAJ CHODZI? W październi...              2
# ...                                                  ...            ...
# 48326  Rozporządzenie o zakazie rejestracji nowych sa...              0
# 48327  Wojna gazowa Putina. Europa przełamała szantaż...              0
# 48328  Naukowcy wiedzą jak sprawić, by OZE nie zależa...              0
# 48329  Chaos na rynku energii. Zrywane umowy i zamroż...              0
# 48330  16 październik 1978 rok pamiętamy #DzieńPapieski               0
#
#       emoji_count              name
# 0               3  Grzegorz Płaczek
# 1               1  Grzegorz Płaczek
# 2               1  Grzegorz Płaczek
# 3               3  Grzegorz Płaczek
# 4               3  Grzegorz Płaczek
# ...           ...               ...
# 48326           0     Andrzej Grzyb
# 48327           0     Andrzej Grzyb
# 48328           0     Andrzej Grzyb
# 48329           0     Andrzej Grzyb
# 48330           0     Andrzej Grzyb
#
# [48331 rows x 33 columns]

# %% [markdown]
# ,=-# Data cleaning

# %% [markdown]
# In this file, we cleaned the downloaded data:
# The main steps include:
# 1. Adding party affiliation to tweet rows
# 2. Deleting unnecessary downloaded Retweets.
# 3. Deleting links and mentions from the tweets text and saving them to separate columns
# 4. Expanding the column of public metrics
# 5. Encoding emojis in a unified format
# 6. Translating tweets using Google Translate in Google Sheets
# 7. Saving all downloaded tweets to one file

# %% [markdown]
# ### 1.  Used libraries

# %%
import os
import pandas as pd
import re
import emoji

# %% [markdown]
# ### 2. Reading JSON files and transforming them into party-specific pickle files

# %%
base_input_path = 'Data/tweets_data_final' # change folder if needed
subfolders = ['Konfederacja', 'NL', 'PiS', 'PO', 'PL2050', 'PSL']
output_folder = 'data/tweets_data_combined'

os.makedirs(output_folder, exist_ok=True)

for subfolder in subfolders:
    folder_path = os.path.join(base_input_path, subfolder)
    dataframes = []
    
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            politician = filename.split("_tweets.json")[0]
            try:
                df = pd.read_json(file_path)  
                df["username"] = politician  
                df["party"] = subfolder
                print(f"Read {len(df)} rows from {file_path}")  
                dataframes.append(df)
            except ValueError as e:
                print(f"Error reading {file_path}: {e}")
    
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        
        output_file_path = os.path.join(output_folder, f'{subfolder}_combined.pkl')
        combined_df.to_pickle(output_file_path) 
        
        print(f"Saved {subfolder} combined data to {output_file_path}")

print("Processing complete!")
# Out:
# Read 11 rows from Data/tweets_data_final\Konfederacja\Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json
# Read 964 rows from Data/tweets_data_final\Konfederacja\bartlomiejpejo_2023-10-16_2024-10-15.json
# Read 1318 rows from Data/tweets_data_final\Konfederacja\KonradBerkowicz_2024-04-16_2024-10-15_vol1.json
# Read 597 rows from Data/tweets_data_final\Konfederacja\MichalWawer_2023-10-16_2024-10-15.json
# Read 772 rows from Data/tweets_data_final\Konfederacja\MarSypniewski_2023-10-16_2024-10-15.json
# Read 175 rows from Data/tweets_data_final\Konfederacja\TudujKrzysztof_2023-10-16_2024-10-15.json
# Read 721 rows from Data/tweets_data_final\Konfederacja\SlawomirMentzen_2023-10-16_2024-10-15.json
# Read 750 rows from Data/tweets_data_final\Konfederacja\WTumanowicz_2023-10-16_2024-10-15.json
# Read 950 rows from Data/tweets_data_final\Konfederacja\Wlodek_Skalik_2023-10-16_2024-10-15.json
# Read 289 rows from Data/tweets_data_final\Konfederacja\KonradBerkowicz_2023-10-15_2024-04-16_vol2.json
# Read 421 rows from Data/tweets_data_final\Konfederacja\placzekgrzegorz_2023-10-16_2024-04-15.json
# Read 320 rows from Data/tweets_data_final\Konfederacja\placzekgrzegorz_2024-04-16_2024-10-15.json
# Read 889 rows from Data/tweets_data_final\Konfederacja\GrzegorzBraun__2023-10-16_2024-10-15.json
# Saved Konfederacja combined data to data/tweets_data_combined\Konfederacja_combined.pkl
# Read 0 rows from Data/tweets_data_final\NL\DyduchMarek_2023-10-16_2024-10-15.json
# Read 207 rows from Data/tweets_data_final\NL\AndrzejSzejna_2023-10-16_2024-10-15.json
# Read 73 rows from Data/tweets_data_final\NL\wlodekczarzasty_2023-10-16_2024-10-15.json
# Read 103 rows from Data/tweets_data_final\NL\JoankaSW_2023-10-16_2024-10-15.json
# Read 142 rows from Data/tweets_data_final\NL\wieczorekdarek_2023-10-16_2024-10-15.json
# Read 247 rows from Data/tweets_data_final\NL\MoskwaWodnicka_2023-10-16_2024-10-15.json
# Read 178 rows from Data/tweets_data_final\NL\KGawkowski_2023-10-16_2024-10-15.json
# Read 537 rows from Data/tweets_data_final\NL\PaulinaPW2024_2023-10-16_2024-10-15.json
# Read 907 rows from Data/tweets_data_final\NL\poselTTrela_2023-10-16_2024-04-15.json
# Read 575 rows from Data/tweets_data_final\NL\poselTTrela_2024-04-16_2024-10-15.json
# Read 787 rows from Data/tweets_data_final\NL\WandaNowicka_2023-10-16_2024-10-15.json
# Read 457 rows from Data/tweets_data_final\NL\RobertBiedron_2023-10-16_2024-10-15.json
# Read 481 rows from Data/tweets_data_final\NL\AnitaKDZG_2023-10-16_2024-10-15.json
# Read 693 rows from Data/tweets_data_final\NL\K_Smiszek_2023-10-16_2024-10-15.json
# Read 1128 rows from Data/tweets_data_final\NL\MarcinKulasek_2023-10-16_2024-10-15.json
# Saved NL combined data to data/tweets_data_combined\NL_combined.pkl
# Read 189 rows from Data/tweets_data_final\PiS\Kaminski_M__2023-10-16_2024-10-15.json
# Read 782 rows from Data/tweets_data_final\PiS\mwojcik__2023-10-16_2024-10-15.json
# Read 556 rows from Data/tweets_data_final\PiS\BeataSzydlo_2023-10-16_2024-10-15.json
# Read 77 rows from Data/tweets_data_final\PiS\elzbietawitek_2023-10-16_2024-10-15.json
# Read 35 rows from Data/tweets_data_final\PiS\Kowalczyk_H_2023-10-16_2024-10-15.json
# Read 647 rows from Data/tweets_data_final\PiS\MorawieckiM_2023-10-16_2024-10-15.json
# Read 249 rows from Data/tweets_data_final\PiS\mblaszczak_2023-10-16_2024-10-15.json
# Read 236 rows from Data/tweets_data_final\PiS\Macierewicz_A_2023-10-16_2024-10-15.json
# Read 1025 rows from Data/tweets_data_final\PiS\PatrykJaki_2023-10-16_2024-10-15.json
# Saved PiS combined data to data/tweets_data_combined\PiS_combined.pkl
# Read 102 rows from Data/tweets_data_final\PO\JanGrabiec_2023-10-16_2024-10-15.json
# Read 356 rows from Data/tweets_data_final\PO\Konwinski_PO_2023-10-16_2024-10-15.json
# Read 409 rows from Data/tweets_data_final\PO\DorotaNiedziela_2023-10-16_2024-10-15.json
# Read 49 rows from Data/tweets_data_final\PO\bbudka_2024-04-01_2024-10-15.json
# Read 45 rows from Data/tweets_data_final\PO\bbudka_2023-10-16_2024-03-31.json
# Read 64 rows from Data/tweets_data_final\PO\M_K_Blonska_2024-04-01_2024-10-15.json
# Read 118 rows from Data/tweets_data_final\PO\Leszczyna_2023-10-16_2023-12-31.json
# Read 112 rows from Data/tweets_data_final\PO\Leszczyna_2024-01-01_2024-03-31.json
# Read 62 rows from Data/tweets_data_final\PO\M_K_Blonska_2023-10-16_2024-03-31.json
# Read 165 rows from Data/tweets_data_final\PO\EwaKopacz_2023-10-16_2024-10-15.json
# Read 173 rows from Data/tweets_data_final\PO\Leszczyna_2024-04-01_2024-10-15.json
# Read 882 rows from Data/tweets_data_final\PO\MKierwinski_2023-10-16_2024-10-15.json
# Read 814 rows from Data/tweets_data_final\PO\trzaskowski__2023-10-16_2024-10-15.json
# Read 338 rows from Data/tweets_data_final\PO\donaldtusk_2023-10-16_2024-10-15.json
# Read 456 rows from Data/tweets_data_final\PO\OklaDrewnowicz_2023-10-16_2024-10-15.json
# Read 269 rows from Data/tweets_data_final\PO\CTomczyk_2023-10-16_2024-10-15_ERROR.json
# Saved PO combined data to data/tweets_data_combined\PO_combined.pkl
# Read 675 rows from Data/tweets_data_final\PL2050\SlizPawel_2023-10-16_2024-10-15.json
# Read 8 rows from Data/tweets_data_final\PL2050\joannamucha_2023-10-16_2024-10-15.json
# Read 167 rows from Data/tweets_data_final\PL2050\szymon_holownia_2023-10-16_2024-10-15.json
# Read 41 rows from Data/tweets_data_final\PL2050\AgaBaranowskaPL_2023-10-16_2024-10-15.json
# Read 29 rows from Data/tweets_data_final\PL2050\aga_buczynska_2023-10-16_2024-10-15.json
# Read 73 rows from Data/tweets_data_final\PL2050\LukaszOsmalak_2023-10-16_2024-10-15.json
# Read 175 rows from Data/tweets_data_final\PL2050\ZalewskiPawel_2023-10-16_2024-10-15.json
# Read 226 rows from Data/tweets_data_final\PL2050\Kpelczynska_2023-10-16_2024-10-15.json
# Read 319 rows from Data/tweets_data_final\PL2050\ZywnoMaciej_2023-10-16_2024-10-15.json
# Read 389 rows from Data/tweets_data_final\PL2050\hennigkloska_2023-10-16_2024-10-15.json
# Saved PL2050 combined data to data/tweets_data_combined\PL2050_combined.pkl
# Read 19 rows from Data/tweets_data_final\PSL\Hetman_K_2023-10-16_2024-10-15.json
# Read 274 rows from Data/tweets_data_final\PSL\DariuszKlimczak_2023-10-16_2024-10-15.json
# Read 115 rows from Data/tweets_data_final\PSL\GrzybAndrzej_2023-10-16_2024-10-15.json
# Read 192 rows from Data/tweets_data_final\PSL\JarubasAdam_2023-10-16_2024-10-15.json
# Read 146 rows from Data/tweets_data_final\PSL\Paslawska_2023-10-16_2024-10-15.json
# Read 107 rows from Data/tweets_data_final\PSL\StefanKrajewski_2023-10-16_2024-10-15.json
# Read 411 rows from Data/tweets_data_final\PSL\PZgorzelskiP_2023-10-16_2024-10-15.json
# Read 409 rows from Data/tweets_data_final\PSL\KosiniakKamysz_2023-10-16_2024-10-15.json
# Saved PSL combined data to data/tweets_data_combined\PSL_combined.pkl
# Processing complete!

# %% [markdown]
# ### 3. Data cleaning

# %%
df_konf = pd.read_pickle(os.path.join(output_folder, 'Konfederacja_combined.pkl'))
df_NL = pd.read_pickle(os.path.join(output_folder, 'NL_combined.pkl'))
df_PIS = pd.read_pickle(os.path.join(output_folder, 'PIS_combined.pkl'))
df_PO = pd.read_pickle(os.path.join(output_folder, 'PO_combined.pkl'))
df_PL2050 = pd.read_pickle(os.path.join(output_folder, 'PL2050_combined.pkl'))
df_PSL = pd.read_pickle(os.path.join(output_folder, 'PSL_combined.pkl'))

# %%
df_konf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8177 entries, 0 to 8176
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   created_at              8177 non-null   datetime64[ns, UTC]
#  1   text                    8177 non-null   object
#  2   id                      8177 non-null   int64
#  3   author_id               8177 non-null   int64
#  4   edit_controls           8177 non-null   object
#  5   possibly_sensitive      8177 non-null   bool
#  6   reply_settings          8177 non-null   object
#  7   public_metrics          8177 non-null   object
#  8   lang                    8177 non-null   object
#  9   edit_history_tweet_ids  8177 non-null   object
#  10  conversation_id         8177 non-null   int64
#  11  category                8177 non-null   object
#  12  attachments             4073 non-null   object
#  13  entities                7489 non-null   object
#  14  username                8177 non-null   object
#  15  party                   8177 non-null   object
#  16  in_reply_to_user_id     1949 non-null   float64
#  17  context_annotations     986 non-null    object
#  18  referenced_tweets       2848 non-null   object
#  19  geo                     138 non-null    object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(3), object(14)
# memory usage: 1.2+ MB

# %%
df_konf.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#              author_id                                      edit_controls  \
# 0  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#    possibly_sensitive reply_settings  \
# 0               False       everyone
# 1               False       everyone
# 2               False       everyone
# 3               False       everyone
# 4               False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids      conversation_id  category  \
# 0  [1765380709114409272]  1765380709114409216  Original
# 1  [1764245727646044196]  1764245727646044160  Original
# 2  [1763931255521857839]  1763931255521857792  Original
# 3  [1763576337078313201]  1763576337078313216  Original
# 4  [1763173358068281524]  1763173358068281600  Original
#
#                                  attachments  \
# 0                                        NaN
# 1  {'media_keys': ['3_1764245720805040128']}
# 2  {'media_keys': ['7_1763931103151202304']}
# 3  {'media_keys': ['3_1763576329385967617']}
# 4  {'media_keys': ['3_1763173351466401792']}
#
#                                             entities  \
# 0                                                NaN
# 1  {'urls': [{'start': 57, 'end': 80, 'url': 'htt...
# 2  {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 3  {'urls': [{'start': 64, 'end': 87, 'url': 'htt...
# 4  {'urls': [{'start': 128, 'end': 151, 'url': 'h...
#
#                                      username         party  \
# 0  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 1  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 2  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 3  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 4  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
#
#    in_reply_to_user_id context_annotations referenced_tweets  geo
# 0                  NaN                 NaN               NaN  NaN
# 1                  NaN                 NaN               NaN  NaN
# 2                  NaN                 NaN               NaN  NaN
# 3                  NaN                 NaN               NaN  NaN
# 4                  NaN                 NaN               NaN  NaN

# %%
# Merge all dataframes into one
df = pd.concat([df_konf, df_NL, df_PIS, df_PO, df_PL2050, df_PSL], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26677 entries, 0 to 26676
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   created_at              26677 non-null  datetime64[ns, UTC]
#  1   text                    26677 non-null  object
#  2   id                      26661 non-null  float64
#  3   author_id               26677 non-null  float64
#  4   edit_controls           26661 non-null  object
#  5   possibly_sensitive      26661 non-null  object
#  6   reply_settings          26677 non-null  object
#  7   public_metrics          26677 non-null  object
#  8   lang                    26677 non-null  object
#  9   edit_history_tweet_ids  26661 non-null  object
#  10  conversation_id         26661 non-null  float64
#  11  category                26677 non-null  object
#  12  attachments             11931 non-null  object
#  13  entities                23437 non-null  object
#  14  username                26677 non-null  object
#  15  party                   26677 non-null  object
#  16  in_reply_to_user_id     5743 non-null   float64
#  17  context_annotations     3335 non-null   object
#  18  referenced_tweets       8896 non-null   object
#  19  geo                     668 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(4), object(15)
# memory usage: 4.1+ MB

# %%
len(df)
# Out:
# 26677

# %%
pd.options.display.float_format = '{:.0f}'.format
df['id'] = df['id'].fillna(0).astype('int64')
df['id']
# Out:
# 0        1765380709114409216
# 1        1764245727646044160
# 2        1763931255521857792
# 3        1763576337078313216
# 4        1763173358068281600
#                 ...
# 26672    1715066644018381312
# 26673    1714927388637696256
# 26674    1714675864237924864
# 26675    1714370461507748096
# 26676    1714370461507748096
# Name: id, Length: 26677, dtype: int64

# %%
non_duplicate_counts = df['id'].nunique()
print(f"Number of duplicate IDs: {non_duplicate_counts}")

duplicate_counts = df['id'].duplicated().sum()
print(f"Number of duplicate IDs: {duplicate_counts}")
# Out:
# Number of duplicate IDs: 26548
# Number of duplicate IDs: 129

# %% [markdown]
# brief insight into how do these duplicates look like

# %%
duplicates = df[df.duplicated(subset=['id'], keep=False)]
duplicates
# Out:
#                      created_at  \
# 9     2024-02-26 13:35:28+00:00
# 10    2024-02-26 13:35:28+00:00
# 973   2023-10-17 08:22:19+00:00
# 974   2023-10-17 08:22:19+00:00
# 1974  2024-05-25 09:27:54+00:00
# ...                         ...
# 25856 2023-10-17 20:07:37+00:00
# 26266 2023-10-16 12:39:29+00:00
# 26267 2023-10-16 12:39:29+00:00
# 26675 2023-10-17 19:59:04+00:00
# 26676 2023-10-17 19:59:04+00:00
#
#                                                     text                   id  \
# 9      Nie ma takiej obietnicy, której polityk nie ob...  1762109123800293376
# 10     Nie ma takiej obietnicy, której polityk nie ob...  1762109123800293376
# 973    Serdeczne dzięki za każdy głos. 🤝\nDla mnie to...  1714195119706890496
# 974    Serdeczne dzięki za każdy głos. 🤝\nDla mnie to...  1714195119706890496
# 1974   @MKierwinski Za to Wy bronicie ambasadora kraj...  1794299341743829248
# ...                                                  ...                  ...
# 25856  Wszystkim Wam serdecznie dziekuję. Za wsparcie...  1714372612611060224
# 26266  .@TakJestTVN24 na antenie @tvn24📺. Zapraszam d...  1713897452430909952
# 26267  .@TakJestTVN24 na antenie @tvn24📺. Zapraszam d...  1713897452430909952
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
# 26676  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
#
#                 author_id                                      edit_controls  \
# 9     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 10    1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 973            1182211615  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 974            1182211615  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1974           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# ...                   ...                                                ...
# 25856          1201875318  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26266 1070635531447558144  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26267 1070635531447558144  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26675           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26676           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings  \
# 9                  False       everyone
# 10                 False       everyone
# 973                False       everyone
# 974                False       everyone
# 1974               False       everyone
# ...                  ...            ...
# 25856                  0       everyone
# 26266                  0       everyone
# 26267                  0       everyone
# 26675                  0       everyone
# 26676                  0       everyone
#
#                                           public_metrics lang  \
# 9      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 10     {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 973    {'retweet_count': 15, 'reply_count': 28, 'like...   pl
# 974    {'retweet_count': 15, 'reply_count': 28, 'like...   pl
# 1974   {'retweet_count': 104, 'reply_count': 26, 'lik...   pl
# ...                                                  ...  ...
# 25856  {'retweet_count': 10, 'reply_count': 6, 'like_...   pl
# 26266  {'retweet_count': 6, 'reply_count': 1, 'like_c...   pl
# 26267  {'retweet_count': 6, 'reply_count': 1, 'like_c...   pl
# 26675  {'retweet_count': 748, 'reply_count': 2136, 'l...   pl
# 26676  {'retweet_count': 748, 'reply_count': 2136, 'l...   pl
#
#       edit_history_tweet_ids     conversation_id  category  \
# 9      [1762109123800293457] 1762109123800293376  Original
# 10     [1762109123800293457] 1762109123800293376  Original
# 973    [1714195119706890463] 1714195119706890496  Original
# 974    [1714195119706890463] 1714195119706890496  Original
# 1974   [1794299341743829316] 1794294356570264064     Reply
# ...                      ...                 ...       ...
# 25856  [1714372612611060222] 1714372612611060224  Original
# 26266  [1713897452430909939] 1713897452430909952  Original
# 26267  [1713897452430909939] 1713897452430909952  Original
# 26675  [1714370461507748145] 1714370461507748096  Original
# 26676  [1714370461507748145] 1714370461507748096  Original
#
#                                      attachments  \
# 9      {'media_keys': ['3_1762109117865304064']}
# 10     {'media_keys': ['3_1762109117865304064']}
# 973    {'media_keys': ['3_1714195114472431617']}
# 974    {'media_keys': ['3_1714195114472431617']}
# 1974                                         NaN
# ...                                          ...
# 25856  {'media_keys': ['7_1714372479076954113']}
# 26266  {'media_keys': ['3_1713897440191885312']}
# 26267  {'media_keys': ['3_1713897440191885312']}
# 26675                                        NaN
# 26676                                        NaN
#
#                                                 entities  \
# 9      {'urls': [{'start': 80, 'end': 103, 'url': 'ht...
# 10     {'urls': [{'start': 80, 'end': 103, 'url': 'ht...
# 973    {'hashtags': [{'start': 251, 'end': 264, 'tag'...
# 974    {'urls': [{'start': 275, 'end': 298, 'url': 'h...
# 1974   {'mentions': [{'start': 0, 'end': 12, 'usernam...
# ...                                                  ...
# 25856  {'urls': [{'start': 81, 'end': 104, 'url': 'ht...
# 26266  {'urls': [{'start': 83, 'end': 106, 'url': 'ht...
# 26267  {'urls': [{'start': 83, 'end': 106, 'url': 'ht...
# 26675  {'mentions': [{'start': 59, 'end': 68, 'userna...
# 26676  {'mentions': [{'start': 59, 'end': 68, 'userna...
#
#                                               username         party  \
# 9           Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 10          Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 973          bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 974          bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1974   KonradBerkowicz_2024-04-16_2024-10-15_vol1.json  Konfederacja
# ...                                                ...           ...
# 25856       StefanKrajewski_2023-10-16_2024-10-15.json           PSL
# 26266          PZgorzelskiP_2023-10-16_2024-10-15.json           PSL
# 26267          PZgorzelskiP_2023-10-16_2024-10-15.json           PSL
# 26675        KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26676        KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
#
#        in_reply_to_user_id context_annotations  \
# 9                      NaN                 NaN
# 10                     NaN                 NaN
# 973                    NaN                 NaN
# 974                    NaN                 NaN
# 1974             308367619                 NaN
# ...                    ...                 ...
# 25856                  NaN                 NaN
# 26266                  NaN                 NaN
# 26267                  NaN                 NaN
# 26675                  NaN                 NaN
# 26676                  NaN                 NaN
#
#                                        referenced_tweets  \
# 9                                                    NaN
# 10                                                   NaN
# 973                                                  NaN
# 974                                                  NaN
# 1974   [{'type': 'replied_to', 'id': '179429435657026...
# ...                                                  ...
# 25856                                                NaN
# 26266                                                NaN
# 26267                                                NaN
# 26675                                                NaN
# 26676                                                NaN
#
#                                     geo
# 9                                   NaN
# 10                                  NaN
# 973    {'place_id': '535f0c2de0121451'}
# 974    {'place_id': '535f0c2de0121451'}
# 1974                                NaN
# ...                                 ...
# 25856  {'place_id': '47c001064da7125c'}
# 26266                               NaN
# 26267                               NaN
# 26675                               NaN
# 26676                               NaN
#
# [243 rows x 20 columns]

# %%
duplicate_text_count = df['text'].duplicated().sum()
print(f"Number of duplicate Text Entries: {duplicate_text_count}")
# Out:
# Number of duplicate Text Entries: 139

# %%
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]
print(f"Rows where BOTH `id` and `text` are duplicated: {len(duplicate_id_text_rows)}")
# Out:
# Rows where BOTH `id` and `text` are duplicated: 227

# %%
# Count occurrences of each ID
id_counts = df['id'].value_counts()
print("Distribution of duplicate IDs:")
print(id_counts.value_counts().sort_index())

# Count occurrences of each text
text_counts = df['text'].value_counts()
print("\nDistribution of duplicate Text Entries:")
print(text_counts.value_counts().sort_index())
# Out:
# Distribution of duplicate IDs:
# count
# 1     26434
# 2       112
# 3         1
# 16        1
# Name: count, dtype: int64
#
# Distribution of duplicate Text Entries:
# count
# 1    26404
# 2      130
# 3        3
# 4        1
# Name: count, dtype: int64

# %%
# Get all duplicate ID rows
duplicate_id_rows = df[df.duplicated(subset=['id'], keep=False)]

# Get all duplicate Text rows
duplicate_text_rows = df[df.duplicated(subset=['text'], keep=False)]

# Get rows where both ID and Text are duplicated
duplicate_id_text_rows = df[df.duplicated(subset=['id', 'text'], keep=False)]

# Compare overlaps
print(f"Rows where ID is duplicated: {len(duplicate_id_rows)}")
print(f"Rows where Text is duplicated: {len(duplicate_text_rows)}")
print(f"Rows where BOTH ID and Text are duplicated: {len(duplicate_id_text_rows)}")

# Find duplicate IDs that are NOT in the text duplicate set
id_not_in_text = duplicate_id_rows[~duplicate_id_rows['id'].isin(duplicate_text_rows['id'])]
print(f"\nDuplicate IDs NOT duplicated in Text: {len(id_not_in_text)}")

# Find duplicate Texts that are NOT in the ID duplicate set
text_not_in_id = duplicate_text_rows[~duplicate_text_rows['text'].isin(duplicate_id_rows['text'])]
print(f"Duplicate Texts NOT duplicated in ID: {len(text_not_in_id)}")
# Out:
# Rows where ID is duplicated: 243
# Rows where Text is duplicated: 273
# Rows where BOTH ID and Text are duplicated: 227
#
# Duplicate IDs NOT duplicated in Text: 16
# Duplicate Texts NOT duplicated in ID: 46

# %%
id_duplicate_but_different_text = duplicate_id_rows.drop_duplicates(subset=['text'], keep=False)
print(f"Rows where the same `id` has different `text`: {len(id_duplicate_but_different_text)}")
id_duplicate_but_different_text
# Out:
# Rows where the same `id` has different `text`: 16
#                      created_at  \
# 19617 2023-10-16 00:00:00+00:00
# 19618 2023-10-16 00:00:00+00:00
# 19619 2023-10-16 00:00:00+00:00
# 19620 2023-10-16 00:00:00+00:00
# 19621 2023-10-16 00:00:00+00:00
# 19622 2023-10-16 00:00:00+00:00
# 19623 2023-10-16 00:00:00+00:00
# 19624 2023-10-16 21:57:00+00:00
# 19625 2023-10-16 22:27:00+00:00
# 19626 2023-10-16 22:41:00+00:00
# 19627 2023-10-16 23:15:00+00:00
# 19628 2023-10-16 23:17:00+00:00
# 19629 2023-10-16 23:18:00+00:00
# 19630 2023-10-16 23:18:00+00:00
# 25410 2024-10-17 18:49:00+00:00
# 25411 2023-10-18 12:46:00+00:00
#
#                                                     text  id  author_id  \
# 19617                                       @tomekbit ✌️   0   61552404
# 19618  @MaciejGdynia Maćku, czekam na oficjalne wynik...   0   61552404
# 19619      @MCichonAlicja Alu, czekamy jeszcze na wynik?   0   61552404
# 19620                                        @REL_76 🥰🥰🥰   0   61552404
# 19621                                      @Gidziela 🥰✌️   0   61552404
# 19622                              @WHaptar Gratulacje👏🥂   0   61552404
# 19623                       @KapenGenezyp Dziękuję❤️❤️❤️   0   61552404
# 19624                                     @jasinska_e ❤️   0   61552404
# 19625                            @BMikolajewska odpowie💪   0   61552404
# 19626                    @DorotaNiedziela ja Tobie też❣️   0   61552404
# 19627  @RGrupinski @StGawlowski i ode mnie Rafale, dl...   0   61552404
# 19628                                  @magosia_10_19 🤛🥰   0   61552404
# 19629                          @3Fritz1 @BMikolajewska 🫡   0   61552404
# 19630      @BernadettaK2 @otoWojciech @BMikolajewska 😂😂😂   0   61552404
# 25410                                       Dziękuję 🤝😀🍀   0 1119834276
# 25411                 @Maciej_ENZ0 Dziękuję i pozdrawiam   0   61552404
#
#       edit_controls possibly_sensitive reply_settings  \
# 19617           NaN                NaN       everyone
# 19618           NaN                NaN       everyone
# 19619           NaN                NaN       everyone
# 19620           NaN                NaN       everyone
# 19621           NaN                NaN       everyone
# 19622           NaN                NaN       everyone
# 19623           NaN                NaN       everyone
# 19624           NaN                NaN       everyone
# 19625           NaN                NaN       everyone
# 19626           NaN                NaN       everyone
# 19627           NaN                NaN       everyone
# 19628           NaN                NaN       everyone
# 19629           NaN                NaN       everyone
# 19630           NaN                NaN       everyone
# 25410           NaN                NaN       everyone
# 25411           NaN                NaN       everyone
#
#                                           public_metrics lang  \
# 19617  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19618  {'retweet_count': 0, 'reply_count': 2, 'like_c...   pl
# 19619  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19620  {'retweet_count': 1, 'reply_count': 1, 'like_c...   pl
# 19621  {'retweet_count': 1, 'reply_count': 0, 'like_c...   pl
# 19622  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19623  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19624  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19625  {'retweet_count': 18, 'reply_count': 31, 'like...   pl
# 19626  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19627  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19628  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19629  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19630  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 25410  {'retweet_count': 2, 'reply_count': 1, 'like_c...   pl
# 25411  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#       edit_history_tweet_ids  conversation_id category attachments entities  \
# 19617                    NaN              NaN    Reply         NaN      NaN
# 19618                    NaN              NaN    Reply         NaN      NaN
# 19619                    NaN              NaN    Reply         NaN      NaN
# 19620                    NaN              NaN    Reply         NaN      NaN
# 19621                    NaN              NaN    Reply         NaN      NaN
# 19622                    NaN              NaN    Reply         NaN      NaN
# 19623                    NaN              NaN    Reply         NaN      NaN
# 19624                    NaN              NaN    Reply         NaN      NaN
# 19625                    NaN              NaN    Reply         NaN      NaN
# 19626                    NaN              NaN    Reply         NaN      NaN
# 19627                    NaN              NaN    Reply         NaN      NaN
# 19628                    NaN              NaN    Reply         NaN      NaN
# 19629                    NaN              NaN    Reply         NaN      NaN
# 19630                    NaN              NaN    Reply         NaN      NaN
# 25410                    NaN              NaN    Quote         NaN      NaN
# 25411                    NaN              NaN    Reply         NaN      NaN
#
#                                       username party  in_reply_to_user_id  \
# 19617     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19618     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19619     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19620     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19621     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19622     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19623     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19624     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19625     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19626     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19627     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19628     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19629     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19630     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 25410  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL                  NaN
# 25411  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL                  NaN
#
#       context_annotations                                  referenced_tweets  \
# 19617                 NaN                                                NaN
# 19618                 NaN                                                NaN
# 19619                 NaN                                                NaN
# 19620                 NaN                                                NaN
# 19621                 NaN                                                NaN
# 19622                 NaN                                                NaN
# 19623                 NaN                                                NaN
# 19624                 NaN                                                NaN
# 19625                 NaN                                                NaN
# 19626                 NaN                                                NaN
# 19627                 NaN                                                NaN
# 19628                 NaN                                                NaN
# 19629                 NaN                                                NaN
# 19630                 NaN                                                NaN
# 25410                 NaN  [{'type': 'quoted', 'id': '1714320722481615223'}]
# 25411                 NaN                                                NaN
#
#        geo
# 19617  NaN
# 19618  NaN
# 19619  NaN
# 19620  NaN
# 19621  NaN
# 19622  NaN
# 19623  NaN
# 19624  NaN
# 19625  NaN
# 19626  NaN
# 19627  NaN
# 19628  NaN
# 19629  NaN
# 19630  NaN
# 25410  NaN
# 25411  NaN

# %%
text_duplicate_but_different_id = duplicate_text_rows.drop_duplicates(subset=['id'], keep=False)
print(f"Rows where the same `text` has different `id`: {len(text_duplicate_but_different_id)}")
text_duplicate_but_different_id
# Out:
# Rows where the same `text` has different `id`: 46
#                      created_at  \
# 103   2024-09-24 16:49:22+00:00
# 1802  2024-07-02 13:04:45+00:00
# 1803  2024-07-02 13:02:57+00:00
# 2058  2024-05-17 07:19:36+00:00
# 2731  2024-01-21 20:27:16+00:00
# 2733  2024-01-20 18:19:48+00:00
# 2735  2024-01-19 17:29:22+00:00
# 2765  2024-01-05 19:33:21+00:00
# 2767  2024-01-04 17:45:19+00:00
# 2774  2023-12-30 12:59:30+00:00
# 2780  2023-12-27 05:44:14+00:00
# 2783  2023-12-23 22:12:23+00:00
# 2785  2023-12-22 19:12:18+00:00
# 3393  2024-04-28 16:47:57+00:00
# 3394  2024-04-28 16:45:49+00:00
# 3919  2024-09-17 12:14:44+00:00
# 3923  2024-09-16 06:28:46+00:00
# 6069  2023-12-13 16:47:13+00:00
# 6070  2023-12-13 16:46:58+00:00
# 6139  2023-11-16 17:20:18+00:00
# 6151  2023-11-14 19:57:17+00:00
# 6328  2024-03-30 14:40:40+00:00
# 6379  2024-03-07 17:10:05+00:00
# 6384  2024-03-06 16:17:43+00:00
# 7666  2024-05-29 09:24:40+00:00
# 7679  2024-05-28 16:11:29+00:00
# 7979  2024-03-17 11:18:46+00:00
# 7988  2024-03-15 15:45:28+00:00
# 8913  2023-12-12 11:41:37+00:00
# 8945  2023-10-17 08:40:56+00:00
# 12918 2024-09-12 07:33:33+00:00
# 12920 2024-09-12 07:31:54+00:00
# 12966 2024-07-23 09:43:07+00:00
# 13239 2024-04-07 08:18:37+00:00
# 13488 2023-11-13 18:13:29+00:00
# 13544 2023-10-21 20:42:32+00:00
# 16428 2024-09-12 16:01:22+00:00
# 16435 2024-09-11 08:23:01+00:00
# 17456 2023-10-16 16:16:48+00:00
# 17457 2023-10-16 16:16:37+00:00
# 20161 2024-10-07 09:55:18+00:00
# 20615 2024-04-10 17:49:53+00:00
# 22489 2023-12-12 22:13:39+00:00
# 22582 2023-10-17 21:19:35+00:00
# 24557 2023-12-19 16:47:35+00:00
# 24582 2023-11-21 19:20:04+00:00
#
#                                                     text                   id  \
# 103                       @KONFEDERACJA_ @Nowa_Nadzieja_  1838621761090285568
# 1802   @Bundeskanzler @donaldtusk Jesteście ostatnim ...  1808124655041236992
# 1803   @Bundeskanzler @donaldtusk Jesteście ostatnim ...  1808124200399356416
# 2058                      @KONFEDERACJA_ @Nowa_Nadzieja_  1791367951259406336
# 2731                             https://t.co/a07zxVsZ7B  1749166794684653568
# 2733                             https://t.co/a07zxVsZ7B  1748772328115155200
# 2735                             https://t.co/a07zxVsZ7B  1748397249602699520
# 2765                             https://t.co/osFnIRXwaB  1743355020580405760
# 2767                             https://t.co/osFnIRXwaB  1742965447044076032
# 2774                             https://t.co/plR4HvmYku  1741081578942427136
# 2780                             https://t.co/plR4HvmYku  1739884875291717888
# 2783                             https://t.co/plR4HvmYku  1738683998983921920
# 2785                             https://t.co/plR4HvmYku  1738276293022519808
# 3393   @KONFEDERACJA_ Zachęcam do głosowania na mnie ...  1784625614130970880
# 3394   @KONFEDERACJA_ Zachęcam do głosowania na mnie ...  1784625077637533952
# 3919            Link do zbiórki: https://t.co/BDegxjK8A2  1836015931245383936
# 3923            Link do zbiórki: https://t.co/BDegxjK8A2  1835566477841137920
# 6069            @wirtualnapolska https://t.co/MsvGTUaWev  1734978288932536832
# 6070            @wirtualnapolska https://t.co/MsvGTUaWev  1734978227070763520
# 6139                             https://t.co/9SdNgXiQsB  1725202142795862272
# 6151                             https://t.co/9SdNgXiQsB  1724516875806081024
# 6328                      @KONFEDERACJA_ @Nowa_Nadzieja_  1774084334867136768
# 6379   Kto wygrał krakowską debatę prezydencką? Zagło...  1765787014371160320
# 6384   Kto wygrał krakowską debatę prezydencką? Zagło...  1765411445812994304
# 7666   Spotkanie posła Konfederacji Grzegorza Brauna ...  1795748082572751360
# 7679   Spotkanie posła Konfederacji Grzegorza Brauna ...  1795488069786755072
# 7979              Do zobaczenia👇 https://t.co/gq7Hp7CYOC  1769322482404618496
# 7988              Do zobaczenia👇 https://t.co/gq7Hp7CYOC  1768664820377637120
# 8913                               @KotulaKat Gratulacje  1734538994539454720
# 8945                               @KotulaKat Gratulacje  1714199805407134208
# 12918  📲📲📲 Ważne telefony:\n👉Całodobowy nr Centrum Za...  1834133231492272384
# 12920  📲📲📲 Ważne telefony:\n👉Całodobowy nr Centrum Za...  1834132816830886400
# 12966                                  @RobertBiedron ✌️  1815684054814953472
# 13239                                  @RobertBiedron ✌️  1776887289659998720
# 13488                                 @Arek_Sikora_SLD 💪  1724128364040954112
# 13544                                 @Arek_Sikora_SLD 💪  1715830954395070464
# 16428             Zapraszam tu➡️ https://t.co/pl74dR24m6  1834261025639497984
# 16435             Zapraszam tu➡️ https://t.co/pl74dR24m6  1833783293549973504
# 17456                            https://t.co/Y7SjOjKObP  1713952141725900800
# 17457                            https://t.co/Y7SjOjKObP  1713952091788509440
# 20161                          @MarianRebeliant Dziękuję  1843228600201564672
# 20615                          @MarianRebeliant Dziękuję  1778118217308745984
# 22489                             @AnnaLisowska6 Dzięki!  1734698052206661888
# 22582                             @AnnaLisowska6 Dzięki!  1714390725909983232
# 24557                     @jacek_protas Gratuluję Jacku👍  1737152710556664064
# 24582                     @jacek_protas Gratuluję Jacku👍  1727044221847360000
#
#                 author_id                                      edit_controls  \
# 103            1182211615  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1802           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1803           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2058           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2731   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2733   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2735   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2765   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2767   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2774   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2780   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2783   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 2785   941710643853447168  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3393           2909714375  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3394           2909714375  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3919           3242182113  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3923           3242182113  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 6069  1187748790863839232  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 6070  1187748790863839232  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 6139  1187748790863839232  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 6151  1187748790863839232  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 6328           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 6379           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 6384           1420353350  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 7666  1186367483546165248  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 7679  1186367483546165248  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 7979  1186367483546165248  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 7988  1186367483546165248  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 8913   790898627971543040  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 8945   790898627971543040  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 12918          3025432383  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 12920          3025432383  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 12966          3025432383  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 13239          3025432383  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 13488          3025432383  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 13544          3025432383  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 16428  939053934232195072  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 16435  939053934232195072  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 17456  703533129252925440  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 17457  703533129252925440  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 20161           308367619  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 20615           308367619  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 22489          3305466189  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 22582          3305466189  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 24557           323848699  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 24582           323848699  {'edits_remaining': 5, 'is_edit_eligible': Fal...
#
#       possibly_sensitive reply_settings  \
# 103                False       everyone
# 1802               False       everyone
# 1803               False       everyone
# 2058               False       everyone
# 2731               False       everyone
# 2733               False       everyone
# 2735               False       everyone
# 2765               False       everyone
# 2767               False       everyone
# 2774               False       everyone
# 2780               False       everyone
# 2783               False       everyone
# 2785               False       everyone
# 3393               False       everyone
# 3394               False       everyone
# 3919               False       everyone
# 3923               False       everyone
# 6069               False       everyone
# 6070               False       everyone
# 6139               False       everyone
# 6151               False       everyone
# 6328               False       everyone
# 6379               False       everyone
# 6384               False       everyone
# 7666               False       everyone
# 7679               False       everyone
# 7979               False       everyone
# 7988               False       everyone
# 8913               False       everyone
# 8945               False       everyone
# 12918              False       everyone
# 12920              False       everyone
# 12966              False       everyone
# 13239              False       everyone
# 13488              False       everyone
# 13544              False       everyone
# 16428              False       everyone
# 16435              False       everyone
# 17456              False       everyone
# 17457              False       everyone
# 20161                  0       everyone
# 20615                  0       everyone
# 22489                  0       everyone
# 22582                  0       everyone
# 24557              False       everyone
# 24582              False       everyone
#
#                                           public_metrics lang  \
# 103    {'retweet_count': 1, 'reply_count': 1, 'like_c...  qam
# 1802   {'retweet_count': 45, 'reply_count': 34, 'like...   pl
# 1803   {'retweet_count': 20, 'reply_count': 20, 'like...   pl
# 2058   {'retweet_count': 0, 'reply_count': 2, 'like_c...  qam
# 2731   {'retweet_count': 1, 'reply_count': 0, 'like_c...  zxx
# 2733   {'retweet_count': 0, 'reply_count': 1, 'like_c...  zxx
# 2735   {'retweet_count': 0, 'reply_count': 0, 'like_c...  zxx
# 2765   {'retweet_count': 1, 'reply_count': 0, 'like_c...  zxx
# 2767   {'retweet_count': 0, 'reply_count': 0, 'like_c...  zxx
# 2774   {'retweet_count': 1, 'reply_count': 0, 'like_c...  zxx
# 2780   {'retweet_count': 2, 'reply_count': 0, 'like_c...  zxx
# 2783   {'retweet_count': 1, 'reply_count': 0, 'like_c...  zxx
# 2785   {'retweet_count': 1, 'reply_count': 0, 'like_c...  zxx
# 3393   {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 3394   {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 3919   {'retweet_count': 3, 'reply_count': 6, 'like_c...   pl
# 3923   {'retweet_count': 38, 'reply_count': 11, 'like...   pl
# 6069   {'retweet_count': 0, 'reply_count': 1, 'like_c...  qme
# 6070   {'retweet_count': 0, 'reply_count': 1, 'like_c...  qme
# 6139   {'retweet_count': 1, 'reply_count': 1, 'like_c...  zxx
# 6151   {'retweet_count': 1, 'reply_count': 0, 'like_c...  zxx
# 6328   {'retweet_count': 1, 'reply_count': 2, 'like_c...  qam
# 6379   {'retweet_count': 1, 'reply_count': 2, 'like_c...   pl
# 6384   {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 7666   {'retweet_count': 19, 'reply_count': 2, 'like_...   pl
# 7679   {'retweet_count': 29, 'reply_count': 12, 'like...   pl
# 7979   {'retweet_count': 21, 'reply_count': 18, 'like...   pl
# 7988   {'retweet_count': 24, 'reply_count': 11, 'like...   pl
# 8913   {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 8945   {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 12918  {'retweet_count': 0, 'reply_count': 2, 'like_c...   pl
# 12920  {'retweet_count': 0, 'reply_count': 2, 'like_c...   pl
# 12966  {'retweet_count': 0, 'reply_count': 0, 'like_c...  qme
# 13239  {'retweet_count': 0, 'reply_count': 1, 'like_c...  qme
# 13488  {'retweet_count': 0, 'reply_count': 0, 'like_c...  qme
# 13544  {'retweet_count': 0, 'reply_count': 0, 'like_c...  qme
# 16428  {'retweet_count': 10, 'reply_count': 5, 'like_...   pl
# 16435  {'retweet_count': 17, 'reply_count': 12, 'like...   pl
# 17456  {'retweet_count': 6, 'reply_count': 25, 'like_...  zxx
# 17457  {'retweet_count': 7, 'reply_count': 18, 'like_...  zxx
# 20161  {'retweet_count': 10, 'reply_count': 19, 'like...   pl
# 20615  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 22489  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 22582  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 24557  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 24582  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#       edit_history_tweet_ids     conversation_id  category attachments  \
# 103    [1838621761090285637] 1838621418218561536     Reply         NaN
# 1802   [1808124655041236995] 1808110506722394368     Reply         NaN
# 1803   [1808124200399356382] 1808088070870233344     Reply         NaN
# 2058   [1791367951259406344] 1791367605858550272     Reply         NaN
# 2731   [1749166794684653580] 1749166791673168384     Reply         NaN
# 2733   [1748772328115155198] 1748772325653139712     Reply         NaN
# 2735   [1748397249602699397] 1748397247413305344     Reply         NaN
# 2765   [1743355020580405656] 1743355018181263616     Reply         NaN
# 2767   [1742965447044076026] 1742965444732965120     Reply         NaN
# 2774   [1741081578942427186] 1741081576308453632     Reply         NaN
# 2780   [1739884875291717886] 1739884872594801152     Reply         NaN
# 2783   [1738683998983921801] 1738683976473026816     Reply         NaN
# 2785   [1738276293022519700] 1738276290711494912     Reply         NaN
# 3393   [1784625614130970785] 1784618463023018240     Reply         NaN
# 3394   [1784625077637533898] 1784622667418554880     Reply         NaN
# 3919   [1836015931245383887] 1836015840488980736     Reply         NaN
# 3923   [1835566477841138031] 1835566401831997696     Reply         NaN
# 6069   [1734978288932536757] 1734972492647899136     Reply         NaN
# 6070   [1734978227070763404] 1734961091954786560     Reply         NaN
# 6139   [1725202142795862309] 1725202139885035776     Reply         NaN
# 6151   [1724516875806081088] 1724516871863423232     Reply         NaN
# 6328   [1774084334867136784] 1774082538497011968     Reply         NaN
# 6379   [1765787014371160285] 1765786633641550080     Reply         NaN
# 6384   [1765411445812994317] 1765405691068485888     Reply         NaN
# 7666   [1795748082572751303] 1795748082572751360  Original         NaN
# 7679   [1795488069786755171] 1795488069786755072  Original         NaN
# 7979   [1769322482404618401] 1769322482404618496     Quote         NaN
# 7988   [1768664820377637074] 1768664820377637120     Quote         NaN
# 8913   [1734538994539454778] 1734531508482756864     Reply         NaN
# 8945   [1714199805407134166] 1714197415249481984     Reply         NaN
# 12918  [1834133231492272304] 1834133227734188288     Reply         NaN
# 12920  [1834132816830886338] 1834132812972048640     Reply         NaN
# 12966  [1815684054814953474] 1815683881493778944     Reply         NaN
# 13239  [1776887289659998629] 1776882692451123712     Reply         NaN
# 13488  [1724128364040954098] 1724080852743655680     Reply         NaN
# 13544  [1715830954395070559] 1715782340369076736     Reply         NaN
# 16428  [1834261025639498078] 1834260686538768896     Reply         NaN
# 16435  [1833783293549973536] 1833782937030123520     Reply         NaN
# 17456  [1713952141725900828] 1713948521940861440     Reply         NaN
# 17457  [1713952091788509432] 1713933987473735936     Reply         NaN
# 20161  [1843228600201564594] 1843222499812835584     Reply         NaN
# 20615  [1778118217308745879] 1778082888333787648     Reply         NaN
# 22489  [1734698052206661877] 1734540623435243776     Reply         NaN
# 22582  [1714390725909983305] 1714373610096194048     Reply         NaN
# 24557  [1737152710556664034] 1737131637320675328     Reply         NaN
# 24582  [1727044221847359967] 1727040451599909376     Reply         NaN
#
#                                                 entities  \
# 103    {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 1802   {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 1803   {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 2058   {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 2731   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2733   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2735   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2765   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2767   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2774   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2780   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2783   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 2785   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 3393   {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 3394   {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 3919   {'urls': [{'start': 17, 'end': 40, 'url': 'htt...
# 3923   {'urls': [{'start': 17, 'end': 40, 'url': 'htt...
# 6069   {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 6070   {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 6139   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 6151   {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 6328   {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 6379   {'urls': [{'start': 62, 'end': 85, 'url': 'htt...
# 6384   {'urls': [{'start': 62, 'end': 85, 'url': 'htt...
# 7666   {'urls': [{'start': 130, 'end': 153, 'url': 'h...
# 7679   {'urls': [{'start': 130, 'end': 153, 'url': 'h...
# 7979   {'urls': [{'start': 15, 'end': 38, 'url': 'htt...
# 7988   {'urls': [{'start': 15, 'end': 38, 'url': 'htt...
# 8913   {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 8945   {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 12918                                                NaN
# 12920                                                NaN
# 12966  {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 13239  {'mentions': [{'start': 0, 'end': 14, 'usernam...
# 13488  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 13544  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 16428  {'urls': [{'start': 15, 'end': 38, 'url': 'htt...
# 16435  {'urls': [{'start': 15, 'end': 38, 'url': 'htt...
# 17456  {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 17457  {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# 20161  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 20615  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 22489                                                NaN
# 22582                                                NaN
# 24557  {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 24582  {'mentions': [{'start': 0, 'end': 13, 'usernam...
#
#                                               username         party  \
# 103          bartlomiejpejo_2023-10-16_2024-10-15.json  Konfederacja
# 1802   KonradBerkowicz_2024-04-16_2024-10-15_vol1.json  Konfederacja
# 1803   KonradBerkowicz_2024-04-16_2024-10-15_vol1.json  Konfederacja
# 2058   KonradBerkowicz_2024-04-16_2024-10-15_vol1.json  Konfederacja
# 2731            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2733            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2735            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2765            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2767            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2774            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2780            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2783            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 2785            MichalWawer_2023-10-16_2024-10-15.json  Konfederacja
# 3393          MarSypniewski_2023-10-16_2024-10-15.json  Konfederacja
# 3394          MarSypniewski_2023-10-16_2024-10-15.json  Konfederacja
# 3919        SlawomirMentzen_2023-10-16_2024-10-15.json  Konfederacja
# 3923        SlawomirMentzen_2023-10-16_2024-10-15.json  Konfederacja
# 6069          Wlodek_Skalik_2023-10-16_2024-10-15.json  Konfederacja
# 6070          Wlodek_Skalik_2023-10-16_2024-10-15.json  Konfederacja
# 6139          Wlodek_Skalik_2023-10-16_2024-10-15.json  Konfederacja
# 6151          Wlodek_Skalik_2023-10-16_2024-10-15.json  Konfederacja
# 6328   KonradBerkowicz_2023-10-15_2024-04-16_vol2.json  Konfederacja
# 6379   KonradBerkowicz_2023-10-15_2024-04-16_vol2.json  Konfederacja
# 6384   KonradBerkowicz_2023-10-15_2024-04-16_vol2.json  Konfederacja
# 7666         GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 7679         GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 7979         GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 7988         GrzegorzBraun__2023-10-16_2024-10-15.json  Konfederacja
# 8913         MoskwaWodnicka_2023-10-16_2024-10-15.json            NL
# 8945         MoskwaWodnicka_2023-10-16_2024-10-15.json            NL
# 12918             K_Smiszek_2023-10-16_2024-10-15.json            NL
# 12920             K_Smiszek_2023-10-16_2024-10-15.json            NL
# 12966             K_Smiszek_2023-10-16_2024-10-15.json            NL
# 13239             K_Smiszek_2023-10-16_2024-10-15.json            NL
# 13488             K_Smiszek_2023-10-16_2024-10-15.json            NL
# 13544             K_Smiszek_2023-10-16_2024-10-15.json            NL
# 16428           MorawieckiM_2023-10-16_2024-10-15.json           PiS
# 16435           MorawieckiM_2023-10-16_2024-10-15.json           PiS
# 17456         Macierewicz_A_2023-10-16_2024-10-15.json           PiS
# 17457         Macierewicz_A_2023-10-16_2024-10-15.json           PiS
# 20161           MKierwinski_2023-10-16_2024-10-15.json            PO
# 20615           MKierwinski_2023-10-16_2024-10-15.json            PO
# 22489        OklaDrewnowicz_2023-10-16_2024-10-15.json            PO
# 22582        OklaDrewnowicz_2023-10-16_2024-10-15.json            PO
# 24557           ZywnoMaciej_2023-10-16_2024-10-15.json        PL2050
# 24582           ZywnoMaciej_2023-10-16_2024-10-15.json        PL2050
#
#        in_reply_to_user_id                                context_annotations  \
# 103             1182211615                                                NaN
# 1802   1489164711652466688  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1803   1489164711652466688  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 2058            1420353350                                                NaN
# 2731    941710643853447168                                                NaN
# 2733    941710643853447168                                                NaN
# 2735    941710643853447168                                                NaN
# 2765    941710643853447168                                                NaN
# 2767    941710643853447168                                                NaN
# 2774    941710643853447168                                                NaN
# 2780    941710643853447168                                                NaN
# 2783    941710643853447168                                                NaN
# 2785    941710643853447168                                                NaN
# 3393   1093510047605374976                                                NaN
# 3394   1093510047605374976                                                NaN
# 3919            3242182113                                                NaN
# 3923            3242182113                                                NaN
# 6069              68277403                                                NaN
# 6070              68277403                                                NaN
# 6139   1187748790863839232                                                NaN
# 6151   1187748790863839232                                                NaN
# 6328            1420353350                                                NaN
# 6379            1420353350                                                NaN
# 6384            1420353350                                                NaN
# 7666                   NaN                                                NaN
# 7679                   NaN                                                NaN
# 7979                   NaN                                                NaN
# 7988                   NaN                                                NaN
# 8913            3889514427                                                NaN
# 8945            3889514427                                                NaN
# 12918           3025432383                                                NaN
# 12920           3025432383                                                NaN
# 12966            466781777                                                NaN
# 13239            466781777                                                NaN
# 13488   982246012851896320                                                NaN
# 13544   982246012851896320                                                NaN
# 16428   939053934232195072                                                NaN
# 16435   939053934232195072                                                NaN
# 17456   703533129252925440                                                NaN
# 17457   703533129252925440                                                NaN
# 20161  1777047682986528768                                                NaN
# 20615  1777047682986528768                                                NaN
# 22489   839871691086004224                                                NaN
# 22582   839871691086004224                                                NaN
# 24557           4894818729                                                NaN
# 24582           4894818729                                                NaN
#
#                                        referenced_tweets  geo
# 103    [{'type': 'replied_to', 'id': '183862141821856...  NaN
# 1802   [{'type': 'replied_to', 'id': '180811050672239...  NaN
# 1803   [{'type': 'replied_to', 'id': '180808807087023...  NaN
# 2058   [{'type': 'replied_to', 'id': '179136760585855...  NaN
# 2731   [{'type': 'replied_to', 'id': '174916679167316...  NaN
# 2733   [{'type': 'replied_to', 'id': '174877232565313...  NaN
# 2735   [{'type': 'replied_to', 'id': '174839724741330...  NaN
# 2765   [{'type': 'replied_to', 'id': '174335501818126...  NaN
# 2767   [{'type': 'replied_to', 'id': '174296544473296...  NaN
# 2774   [{'type': 'replied_to', 'id': '174108157630845...  NaN
# 2780   [{'type': 'replied_to', 'id': '173988487259480...  NaN
# 2783   [{'type': 'replied_to', 'id': '173868397647302...  NaN
# 2785   [{'type': 'replied_to', 'id': '173827629071149...  NaN
# 3393   [{'type': 'replied_to', 'id': '178461846302301...  NaN
# 3394   [{'type': 'replied_to', 'id': '178462266741855...  NaN
# 3919   [{'type': 'replied_to', 'id': '183601584048898...  NaN
# 3923   [{'type': 'replied_to', 'id': '183556640183199...  NaN
# 6069   [{'type': 'replied_to', 'id': '173497249264789...  NaN
# 6070   [{'type': 'replied_to', 'id': '173496109195478...  NaN
# 6139   [{'type': 'replied_to', 'id': '172520213988503...  NaN
# 6151   [{'type': 'replied_to', 'id': '172451687186342...  NaN
# 6328   [{'type': 'replied_to', 'id': '177408253849701...  NaN
# 6379   [{'type': 'replied_to', 'id': '176578663364155...  NaN
# 6384   [{'type': 'replied_to', 'id': '176540569106848...  NaN
# 7666                                                 NaN  NaN
# 7679                                                 NaN  NaN
# 7979   [{'type': 'quoted', 'id': '1768614944344359065'}]  NaN
# 7988   [{'type': 'quoted', 'id': '1768614944344359065'}]  NaN
# 8913   [{'type': 'replied_to', 'id': '173453150848275...  NaN
# 8945   [{'type': 'replied_to', 'id': '171419741524948...  NaN
# 12918  [{'type': 'replied_to', 'id': '183413322773418...  NaN
# 12920  [{'type': 'replied_to', 'id': '183413281297204...  NaN
# 12966  [{'type': 'replied_to', 'id': '181568388149377...  NaN
# 13239  [{'type': 'replied_to', 'id': '177688269245112...  NaN
# 13488  [{'type': 'replied_to', 'id': '172408085274365...  NaN
# 13544  [{'type': 'replied_to', 'id': '171578234036907...  NaN
# 16428  [{'type': 'replied_to', 'id': '183426068653876...  NaN
# 16435  [{'type': 'replied_to', 'id': '183378293703012...  NaN
# 17456  [{'type': 'replied_to', 'id': '171394852194086...  NaN
# 17457  [{'type': 'replied_to', 'id': '171393398747373...  NaN
# 20161  [{'type': 'replied_to', 'id': '184322249981283...  NaN
# 20615  [{'type': 'replied_to', 'id': '177808288833378...  NaN
# 22489  [{'type': 'replied_to', 'id': '173468833511573...  NaN
# 22582  [{'type': 'replied_to', 'id': '171437649368440...  NaN
# 24557  [{'type': 'replied_to', 'id': '173713163732067...  NaN
# 24582  [{'type': 'replied_to', 'id': '172704045159990...  NaN

# %%
id_duplicate_but_different_text[['id', 'text', 'created_at', 'author_id']]
# Out:
#        id                                               text  \
# 19617   0                                       @tomekbit ✌️
# 19618   0  @MaciejGdynia Maćku, czekam na oficjalne wynik...
# 19619   0      @MCichonAlicja Alu, czekamy jeszcze na wynik?
# 19620   0                                        @REL_76 🥰🥰🥰
# 19621   0                                      @Gidziela 🥰✌️
# 19622   0                              @WHaptar Gratulacje👏🥂
# 19623   0                       @KapenGenezyp Dziękuję❤️❤️❤️
# 19624   0                                     @jasinska_e ❤️
# 19625   0                            @BMikolajewska odpowie💪
# 19626   0                    @DorotaNiedziela ja Tobie też❣️
# 19627   0  @RGrupinski @StGawlowski i ode mnie Rafale, dl...
# 19628   0                                  @magosia_10_19 🤛🥰
# 19629   0                          @3Fritz1 @BMikolajewska 🫡
# 19630   0      @BernadettaK2 @otoWojciech @BMikolajewska 😂😂😂
# 25410   0                                       Dziękuję 🤝😀🍀
# 25411   0                 @Maciej_ENZ0 Dziękuję i pozdrawiam
#
#                      created_at  author_id
# 19617 2023-10-16 00:00:00+00:00   61552404
# 19618 2023-10-16 00:00:00+00:00   61552404
# 19619 2023-10-16 00:00:00+00:00   61552404
# 19620 2023-10-16 00:00:00+00:00   61552404
# 19621 2023-10-16 00:00:00+00:00   61552404
# 19622 2023-10-16 00:00:00+00:00   61552404
# 19623 2023-10-16 00:00:00+00:00   61552404
# 19624 2023-10-16 21:57:00+00:00   61552404
# 19625 2023-10-16 22:27:00+00:00   61552404
# 19626 2023-10-16 22:41:00+00:00   61552404
# 19627 2023-10-16 23:15:00+00:00   61552404
# 19628 2023-10-16 23:17:00+00:00   61552404
# 19629 2023-10-16 23:18:00+00:00   61552404
# 19630 2023-10-16 23:18:00+00:00   61552404
# 25410 2024-10-17 18:49:00+00:00 1119834276
# 25411 2023-10-18 12:46:00+00:00   61552404

# %%
empty_id_rows = df[df['id'].isna()]
print(f"Rows where `id` is empty (NaN): {len(empty_id_rows)}")
#empty_id_rows
# Out:
# Rows where `id` is empty (NaN): 0
# Empty DataFrame
# Columns: [created_at, text, id, author_id, edit_controls, possibly_sensitive, reply_settings, public_metrics, lang, edit_history_tweet_ids, conversation_id, category, attachments, entities, username, party, in_reply_to_user_id, context_annotations, referenced_tweets, geo]
# Index: []

# %%
zero_id_rows = df[df['id'] == 0]
print(f"Rows where `id` is 0: {len(zero_id_rows)}")
zero_id_rows
# Out:
# Rows where `id` is 0: 16
#                      created_at  \
# 19617 2023-10-16 00:00:00+00:00
# 19618 2023-10-16 00:00:00+00:00
# 19619 2023-10-16 00:00:00+00:00
# 19620 2023-10-16 00:00:00+00:00
# 19621 2023-10-16 00:00:00+00:00
# 19622 2023-10-16 00:00:00+00:00
# 19623 2023-10-16 00:00:00+00:00
# 19624 2023-10-16 21:57:00+00:00
# 19625 2023-10-16 22:27:00+00:00
# 19626 2023-10-16 22:41:00+00:00
# 19627 2023-10-16 23:15:00+00:00
# 19628 2023-10-16 23:17:00+00:00
# 19629 2023-10-16 23:18:00+00:00
# 19630 2023-10-16 23:18:00+00:00
# 25410 2024-10-17 18:49:00+00:00
# 25411 2023-10-18 12:46:00+00:00
#
#                                                     text  id  author_id  \
# 19617                                       @tomekbit ✌️   0   61552404
# 19618  @MaciejGdynia Maćku, czekam na oficjalne wynik...   0   61552404
# 19619      @MCichonAlicja Alu, czekamy jeszcze na wynik?   0   61552404
# 19620                                        @REL_76 🥰🥰🥰   0   61552404
# 19621                                      @Gidziela 🥰✌️   0   61552404
# 19622                              @WHaptar Gratulacje👏🥂   0   61552404
# 19623                       @KapenGenezyp Dziękuję❤️❤️❤️   0   61552404
# 19624                                     @jasinska_e ❤️   0   61552404
# 19625                            @BMikolajewska odpowie💪   0   61552404
# 19626                    @DorotaNiedziela ja Tobie też❣️   0   61552404
# 19627  @RGrupinski @StGawlowski i ode mnie Rafale, dl...   0   61552404
# 19628                                  @magosia_10_19 🤛🥰   0   61552404
# 19629                          @3Fritz1 @BMikolajewska 🫡   0   61552404
# 19630      @BernadettaK2 @otoWojciech @BMikolajewska 😂😂😂   0   61552404
# 25410                                       Dziękuję 🤝😀🍀   0 1119834276
# 25411                 @Maciej_ENZ0 Dziękuję i pozdrawiam   0   61552404
#
#       edit_controls possibly_sensitive reply_settings  \
# 19617           NaN                NaN       everyone
# 19618           NaN                NaN       everyone
# 19619           NaN                NaN       everyone
# 19620           NaN                NaN       everyone
# 19621           NaN                NaN       everyone
# 19622           NaN                NaN       everyone
# 19623           NaN                NaN       everyone
# 19624           NaN                NaN       everyone
# 19625           NaN                NaN       everyone
# 19626           NaN                NaN       everyone
# 19627           NaN                NaN       everyone
# 19628           NaN                NaN       everyone
# 19629           NaN                NaN       everyone
# 19630           NaN                NaN       everyone
# 25410           NaN                NaN       everyone
# 25411           NaN                NaN       everyone
#
#                                           public_metrics lang  \
# 19617  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19618  {'retweet_count': 0, 'reply_count': 2, 'like_c...   pl
# 19619  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19620  {'retweet_count': 1, 'reply_count': 1, 'like_c...   pl
# 19621  {'retweet_count': 1, 'reply_count': 0, 'like_c...   pl
# 19622  {'retweet_count': 0, 'reply_count': 1, 'like_c...   pl
# 19623  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19624  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19625  {'retweet_count': 18, 'reply_count': 31, 'like...   pl
# 19626  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19627  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19628  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19629  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 19630  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 25410  {'retweet_count': 2, 'reply_count': 1, 'like_c...   pl
# 25411  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#       edit_history_tweet_ids  conversation_id category attachments entities  \
# 19617                    NaN              NaN    Reply         NaN      NaN
# 19618                    NaN              NaN    Reply         NaN      NaN
# 19619                    NaN              NaN    Reply         NaN      NaN
# 19620                    NaN              NaN    Reply         NaN      NaN
# 19621                    NaN              NaN    Reply         NaN      NaN
# 19622                    NaN              NaN    Reply         NaN      NaN
# 19623                    NaN              NaN    Reply         NaN      NaN
# 19624                    NaN              NaN    Reply         NaN      NaN
# 19625                    NaN              NaN    Reply         NaN      NaN
# 19626                    NaN              NaN    Reply         NaN      NaN
# 19627                    NaN              NaN    Reply         NaN      NaN
# 19628                    NaN              NaN    Reply         NaN      NaN
# 19629                    NaN              NaN    Reply         NaN      NaN
# 19630                    NaN              NaN    Reply         NaN      NaN
# 25410                    NaN              NaN    Quote         NaN      NaN
# 25411                    NaN              NaN    Reply         NaN      NaN
#
#                                       username party  in_reply_to_user_id  \
# 19617     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19618     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19619     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19620     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19621     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19622     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19623     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19624     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19625     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19626     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19627     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19628     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19629     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 19630     Leszczyna_2023-10-16_2023-12-31.json    PO                  NaN
# 25410  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL                  NaN
# 25411  GrzybAndrzej_2023-10-16_2024-10-15.json   PSL                  NaN
#
#       context_annotations                                  referenced_tweets  \
# 19617                 NaN                                                NaN
# 19618                 NaN                                                NaN
# 19619                 NaN                                                NaN
# 19620                 NaN                                                NaN
# 19621                 NaN                                                NaN
# 19622                 NaN                                                NaN
# 19623                 NaN                                                NaN
# 19624                 NaN                                                NaN
# 19625                 NaN                                                NaN
# 19626                 NaN                                                NaN
# 19627                 NaN                                                NaN
# 19628                 NaN                                                NaN
# 19629                 NaN                                                NaN
# 19630                 NaN                                                NaN
# 25410                 NaN  [{'type': 'quoted', 'id': '1714320722481615223'}]
# 25411                 NaN                                                NaN
#
#        geo
# 19617  NaN
# 19618  NaN
# 19619  NaN
# 19620  NaN
# 19621  NaN
# 19622  NaN
# 19623  NaN
# 19624  NaN
# 19625  NaN
# 19626  NaN
# 19627  NaN
# 19628  NaN
# 19629  NaN
# 19630  NaN
# 25410  NaN
# 25411  NaN

# %% [markdown]
# id 0 of a tweet may mean, that the tweet was, changed, deleted, or that it is not a tweet but something else and was wrongly categorized as one

# %% [markdown]
# We need to remove duplicate tweets because our custom downloading loop occasionally downloads the same tweet two times to ensure completeness.

# %%
# Remove duplicates from the dataframe based on specific columns
df.drop_duplicates(subset=['id'], inplace=True)

# %%
df.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings  \
# 0              False       everyone
# 1              False       everyone
# 2              False       everyone
# 3              False       everyone
# 4              False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids     conversation_id  category  \
# 0  [1765380709114409272] 1765380709114409216  Original
# 1  [1764245727646044196] 1764245727646044160  Original
# 2  [1763931255521857839] 1763931255521857792  Original
# 3  [1763576337078313201] 1763576337078313216  Original
# 4  [1763173358068281524] 1763173358068281600  Original
#
#                                  attachments  \
# 0                                        NaN
# 1  {'media_keys': ['3_1764245720805040128']}
# 2  {'media_keys': ['7_1763931103151202304']}
# 3  {'media_keys': ['3_1763576329385967617']}
# 4  {'media_keys': ['3_1763173351466401792']}
#
#                                             entities  \
# 0                                                NaN
# 1  {'urls': [{'start': 57, 'end': 80, 'url': 'htt...
# 2  {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 3  {'urls': [{'start': 64, 'end': 87, 'url': 'htt...
# 4  {'urls': [{'start': 128, 'end': 151, 'url': 'h...
#
#                                      username         party  \
# 0  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 1  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 2  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 3  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 4  Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
#
#    in_reply_to_user_id context_annotations referenced_tweets  geo
# 0                  NaN                 NaN               NaN  NaN
# 1                  NaN                 NaN               NaN  NaN
# 2                  NaN                 NaN               NaN  NaN
# 3                  NaN                 NaN               NaN  NaN
# 4                  NaN                 NaN               NaN  NaN

# %% [markdown]
# We need to delete retweets because they are wrongly provided by the X API. We want to analyze only original tweets, replies, and quotes.

# %%
df = df[df['category'] != 'Retweet']

# %%
df
# Out:
#                      created_at  \
# 0     2024-03-06 14:15:34+00:00
# 1     2024-03-03 11:05:34+00:00
# 2     2024-03-02 14:15:58+00:00
# 3     2024-03-01 14:45:39+00:00
# 4     2024-02-29 12:04:21+00:00
# ...                         ...
# 26671 2023-10-24 10:46:22+00:00
# 26672 2023-10-19 18:05:26+00:00
# 26673 2023-10-19 08:52:05+00:00
# 26674 2023-10-18 16:12:37+00:00
# 26675 2023-10-17 19:59:04+00:00
#
#                                                     text                   id  \
# 0      Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2      Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3      Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
# ...                                                  ...                  ...
# 26671  Formacje demokratyczne będą tworzyć przyszły r...  1716768088052359424
# 26672  Żadne podchody, kłamstwa czy medialne wrzutki ...  1715066644018381312
# 26673  Polska potrzebuje nowego, demokratycznego rząd...  1714927388637696256
# 26674  95 lat temu zmarł generał Tadeusz Jordan Rozwa...  1714675864237924864
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
#
#                 author_id                                      edit_controls  \
# 0     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                   ...                                                ...
# 26671           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26672           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26673           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26674           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26675           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings  \
# 0                  False       everyone
# 1                  False       everyone
# 2                  False       everyone
# 3                  False       everyone
# 4                  False       everyone
# ...                  ...            ...
# 26671                  0       everyone
# 26672                  0       everyone
# 26673                  0       everyone
# 26674                  0       everyone
# 26675                  0       everyone
#
#                                           public_metrics lang  \
# 0      {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4      {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# ...                                                  ...  ...
# 26671  {'retweet_count': 344, 'reply_count': 2013, 'l...   pl
# 26672  {'retweet_count': 1149, 'reply_count': 2406, '...   pl
# 26673  {'retweet_count': 185, 'reply_count': 1108, 'l...   pl
# 26674  {'retweet_count': 110, 'reply_count': 354, 'li...   pl
# 26675  {'retweet_count': 748, 'reply_count': 2136, 'l...   pl
#
#       edit_history_tweet_ids     conversation_id  category  \
# 0      [1765380709114409272] 1765380709114409216  Original
# 1      [1764245727646044196] 1764245727646044160  Original
# 2      [1763931255521857839] 1763931255521857792  Original
# 3      [1763576337078313201] 1763576337078313216  Original
# 4      [1763173358068281524] 1763173358068281600  Original
# ...                      ...                 ...       ...
# 26671  [1716768088052359454] 1716768088052359424  Original
# 26672  [1715066644018381294] 1715066644018381312  Original
# 26673  [1714927388637696291] 1714927388637696256  Original
# 26674  [1714675864237924823] 1714675864237924864  Original
# 26675  [1714370461507748145] 1714370461507748096  Original
#
#                                      attachments  \
# 0                                            NaN
# 1      {'media_keys': ['3_1764245720805040128']}
# 2      {'media_keys': ['7_1763931103151202304']}
# 3      {'media_keys': ['3_1763576329385967617']}
# 4      {'media_keys': ['3_1763173351466401792']}
# ...                                          ...
# 26671  {'media_keys': ['3_1716768082402664449']}
# 26672                                        NaN
# 26673                                        NaN
# 26674  {'media_keys': ['3_1714675857548009473']}
# 26675                                        NaN
#
#                                                 entities  \
# 0                                                    NaN
# 1      {'urls': [{'start': 57, 'end': 80, 'url': 'htt...
# 2      {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 3      {'urls': [{'start': 64, 'end': 87, 'url': 'htt...
# 4      {'urls': [{'start': 128, 'end': 151, 'url': 'h...
# ...                                                  ...
# 26671  {'urls': [{'start': 145, 'end': 168, 'url': 'h...
# 26672                                                NaN
# 26673                                                NaN
# 26674  {'urls': [{'start': 264, 'end': 287, 'url': 'h...
# 26675  {'mentions': [{'start': 59, 'end': 68, 'userna...
#
#                                          username         party  \
# 0      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 1      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 2      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 3      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# 4      Iwaszkiewicz_RJ_2023-10-16_2024-10-15.json  Konfederacja
# ...                                           ...           ...
# 26671   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26672   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26673   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26674   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
# 26675   KosiniakKamysz_2023-10-16_2024-10-15.json           PSL
#
#        in_reply_to_user_id                                context_annotations  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 26671                  NaN                                                NaN
# 26672                  NaN                                                NaN
# 26673                  NaN                                                NaN
# 26674                  NaN  [{'domain': {'id': '47', 'name': 'Brand', 'des...
# 26675                  NaN                                                NaN
#
#       referenced_tweets  geo
# 0                   NaN  NaN
# 1                   NaN  NaN
# 2                   NaN  NaN
# 3                   NaN  NaN
# 4                   NaN  NaN
# ...                 ...  ...
# 26671               NaN  NaN
# 26672               NaN  NaN
# 26673               NaN  NaN
# 26674               NaN  NaN
# 26675               NaN  NaN
#
# [26062 rows x 20 columns]

# %%
# Update the 'username' column to keep only the string until '_2' -> split to date range

#df['username'] = df['username'].str.split('_2').str[0].copy()
df.loc[:, 'username'] = df['username'].str.split('_2').str[0]

# %%
category_summary = df['category'].value_counts()
print(category_summary)
total_tweets = category_summary.sum()
print(f"Total tweets: {total_tweets}")
# Out:
# category
# Original    17595
# Reply        5641
# Quote        2826
# Name: count, dtype: int64
# Total tweets: 26062

# %%
# Ensure the created_at column is in datetime format

#df['created_at'] = pd.to_datetime(df['created_at'])
df.loc[:, 'created_at'] = pd.to_datetime(df['created_at'])

# %%
df.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings  \
# 0              False       everyone
# 1              False       everyone
# 2              False       everyone
# 3              False       everyone
# 4              False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids     conversation_id  category  \
# 0  [1765380709114409272] 1765380709114409216  Original
# 1  [1764245727646044196] 1764245727646044160  Original
# 2  [1763931255521857839] 1763931255521857792  Original
# 3  [1763576337078313201] 1763576337078313216  Original
# 4  [1763173358068281524] 1763173358068281600  Original
#
#                                  attachments  \
# 0                                        NaN
# 1  {'media_keys': ['3_1764245720805040128']}
# 2  {'media_keys': ['7_1763931103151202304']}
# 3  {'media_keys': ['3_1763576329385967617']}
# 4  {'media_keys': ['3_1763173351466401792']}
#
#                                             entities         username  \
# 0                                                NaN  Iwaszkiewicz_RJ
# 1  {'urls': [{'start': 57, 'end': 80, 'url': 'htt...  Iwaszkiewicz_RJ
# 2  {'urls': [{'start': 135, 'end': 158, 'url': 'h...  Iwaszkiewicz_RJ
# 3  {'urls': [{'start': 64, 'end': 87, 'url': 'htt...  Iwaszkiewicz_RJ
# 4  {'urls': [{'start': 128, 'end': 151, 'url': 'h...  Iwaszkiewicz_RJ
#
#           party  in_reply_to_user_id context_annotations referenced_tweets  \
# 0  Konfederacja                  NaN                 NaN               NaN
# 1  Konfederacja                  NaN                 NaN               NaN
# 2  Konfederacja                  NaN                 NaN               NaN
# 3  Konfederacja                  NaN                 NaN               NaN
# 4  Konfederacja                  NaN                 NaN               NaN
#
#    geo
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
print(df.loc[1, 'text'])
# Out:
# Zwróćcie uwagę na punkt 11.
# Tu nie ma z czego się śmiać… https://t.co/I5KaMsUDzo

# %%
def add_space_around_emojis(text):
    return ''.join(f' {char} ' if char in emoji.EMOJI_DATA or re.match(r'[\U0001F1E6-\U0001F1FF]', char) else char for char in text)

df['text'] = df['text'].apply(add_space_around_emojis)

def clean_text(text):
    mentions = re.findall(r'@\w+', text)
    text = re.sub(r'@\w+', '', text)
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)
    hashtags = re.findall(r'#\w+', text)
    text = re.sub(r'(?<!\s)([\U0001F600-\U0001F64F])', r' \1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F])(?!\s)', r'\1 ', text)
    return [text, mentions, links, hashtags]

df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text'].apply(clean_text).tolist(), index=df.index)

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # Turn off the warning from lack of loc

# %%
def add_space_around_emojis(text):
    return ''.join(f' {char} ' if char in emoji.EMOJI_DATA or re.match(r'[\U0001F1E6-\U0001F1FF]', char) else char for char in text)

def clean_text(text):
    mentions = re.findall(r'@\w+', text)
    text = re.sub(r'@\w+', '', text)  # Remove mentions
    
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)  # Remove links
    
    hashtags = re.findall(r'#\w+', text)
    
    # Add spaces around emojis
    text = re.sub(r'(?<!\s)([\U0001F600-\U0001F64F])', r' \1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F])(?!\s)', r'\1 ', text)
    
    return [text.strip(), mentions, links, hashtags]

# Apply functions
df['text_clean'] = df['text'].apply(add_space_around_emojis)
#df.loc[:, 'text_clean'] = df['text'].apply(add_space_around_emojis)

df[['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text_clean'].apply(clean_text).tolist(), index=df.index)
#df.loc[:, ['text_clean', 'mentions', 'links', 'hashtags']] = pd.DataFrame(df['text_clean'].apply(clean_text).tolist(), index=df.index)

# %%
df.head()
# Out:
#                  created_at  \
# 0 2024-03-06 14:15:34+00:00
# 1 2024-03-03 11:05:34+00:00
# 2 2024-03-02 14:15:58+00:00
# 3 2024-03-01 14:45:39+00:00
# 4 2024-02-29 12:04:21+00:00
#
#                                                 text                   id  \
# 0  Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2  Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3  Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
#
#             author_id                                      edit_controls  \
# 0 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4 1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#   possibly_sensitive reply_settings  \
# 0              False       everyone
# 1              False       everyone
# 2              False       everyone
# 3              False       everyone
# 4              False       everyone
#
#                                       public_metrics lang  \
# 0  {'retweet_count': 17, 'reply_count': 4, 'like_...   pl
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pl
#
#   edit_history_tweet_ids  ...         username         party  \
# 0  [1765380709114409272]  ...  Iwaszkiewicz_RJ  Konfederacja
# 1  [1764245727646044196]  ...  Iwaszkiewicz_RJ  Konfederacja
# 2  [1763931255521857839]  ...  Iwaszkiewicz_RJ  Konfederacja
# 3  [1763576337078313201]  ...  Iwaszkiewicz_RJ  Konfederacja
# 4  [1763173358068281524]  ...  Iwaszkiewicz_RJ  Konfederacja
#
#   in_reply_to_user_id context_annotations referenced_tweets  geo  \
# 0                 NaN                 NaN               NaN  NaN
# 1                 NaN                 NaN               NaN  NaN
# 2                 NaN                 NaN               NaN  NaN
# 3                 NaN                 NaN               NaN  NaN
# 4                 NaN                 NaN               NaN  NaN
#
#                                           text_clean mentions  \
# 0  Policja rzucająca kostką brukową w rolników, p...       []
# 1  Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...       []
# 2  Równość, ale nie dla wszystkich… \nPani „minis...       []
# 3  Pytanie za sto punktów! \nFirma jakiego państw...       []
# 4  Ukraina jeździ na polskim paliwie. \n\nPrzypom...       []
#
#                        links hashtags
# 0                         []       []
# 1  [https://t.co/I5KaMsUDzo]       []
# 2  [https://t.co/PyKYCMvSN3]       []
# 3  [https://t.co/g61Cb5BsIx]       []
# 4  [https://t.co/b0Q4Tt1FJW]       []
#
# [5 rows x 24 columns]

# %%
df.drop(columns=['entities'], inplace=True)

# %%
# Some additioanl numerical data from tweets is extracted and added to the dataframe as new variables, then the original column is dropped
df['retweet_count'] = df['public_metrics'].apply(lambda x: x['retweet_count'])
df['reply_count'] = df['public_metrics'].apply(lambda x: x['reply_count'])
df['like_count'] = df['public_metrics'].apply(lambda x: x['like_count'])
df['quote_count'] = df['public_metrics'].apply(lambda x: x['quote_count'])
df['impression_count'] = df['public_metrics'].apply(lambda x: x['impression_count'])

df.drop(columns=['public_metrics'], inplace=True)

# %%
df
# Out:
#                      created_at  \
# 0     2024-03-06 14:15:34+00:00
# 1     2024-03-03 11:05:34+00:00
# 2     2024-03-02 14:15:58+00:00
# 3     2024-03-01 14:45:39+00:00
# 4     2024-02-29 12:04:21+00:00
# ...                         ...
# 26671 2023-10-24 10:46:22+00:00
# 26672 2023-10-19 18:05:26+00:00
# 26673 2023-10-19 08:52:05+00:00
# 26674 2023-10-18 16:12:37+00:00
# 26675 2023-10-17 19:59:04+00:00
#
#                                                     text                   id  \
# 0      Policja rzucająca kostką brukową w rolników, p...  1765380709114409216
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...  1764245727646044160
# 2      Równość, ale nie dla wszystkich… \nPani „minis...  1763931255521857792
# 3      Pytanie za sto punktów! \nFirma jakiego państw...  1763576337078313216
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...  1763173358068281600
# ...                                                  ...                  ...
# 26671  Formacje demokratyczne będą tworzyć przyszły r...  1716768088052359424
# 26672  Żadne podchody, kłamstwa czy medialne wrzutki ...  1715066644018381312
# 26673  Polska potrzebuje nowego, demokratycznego rząd...  1714927388637696256
# 26674  95 lat temu zmarł generał Tadeusz Jordan Rozwa...  1714675864237924864
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  1714370461507748096
#
#                 author_id                                      edit_controls  \
# 0     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 1     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 3     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4     1554483991511703552  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                   ...                                                ...
# 26671           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26672           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26673           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26674           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 26675           955239446  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#       possibly_sensitive reply_settings lang edit_history_tweet_ids  \
# 0                  False       everyone   pl  [1765380709114409272]
# 1                  False       everyone   pl  [1764245727646044196]
# 2                  False       everyone   pl  [1763931255521857839]
# 3                  False       everyone   pl  [1763576337078313201]
# 4                  False       everyone   pl  [1763173358068281524]
# ...                  ...            ...  ...                    ...
# 26671                  0       everyone   pl  [1716768088052359454]
# 26672                  0       everyone   pl  [1715066644018381294]
# 26673                  0       everyone   pl  [1714927388637696291]
# 26674                  0       everyone   pl  [1714675864237924823]
# 26675                  0       everyone   pl  [1714370461507748145]
#
#           conversation_id  ...  geo  \
# 0     1765380709114409216  ...  NaN
# 1     1764245727646044160  ...  NaN
# 2     1763931255521857792  ...  NaN
# 3     1763576337078313216  ...  NaN
# 4     1763173358068281600  ...  NaN
# ...                   ...  ...  ...
# 26671 1716768088052359424  ...  NaN
# 26672 1715066644018381312  ...  NaN
# 26673 1714927388637696256  ...  NaN
# 26674 1714675864237924864  ...  NaN
# 26675 1714370461507748096  ...  NaN
#
#                                               text_clean     mentions  \
# 0      Policja rzucająca kostką brukową w rolników, p...           []
# 1      Zwróćcie uwagę na punkt 11.\nTu nie ma z czego...           []
# 2      Równość, ale nie dla wszystkich… \nPani „minis...           []
# 3      Pytanie za sto punktów! \nFirma jakiego państw...           []
# 4      Ukraina jeździ na polskim paliwie. \n\nPrzypom...           []
# ...                                                  ...          ...
# 26671  Formacje demokratyczne będą tworzyć przyszły r...           []
# 26672  Żadne podchody, kłamstwa czy medialne wrzutki ...           []
# 26673  Polska potrzebuje nowego, demokratycznego rząd...           []
# 26674  95 lat temu zmarł generał Tadeusz Jordan Rozwa...           []
# 26675  Mówiliśmy jasno: albo #TrzeciaDroga, albo trze...  [@pisorgpl]
#
#                            links         hashtags retweet_count reply_count  \
# 0                             []               []            17           4
# 1      [https://t.co/I5KaMsUDzo]               []             0           0
# 2      [https://t.co/PyKYCMvSN3]               []             0           0
# 3      [https://t.co/g61Cb5BsIx]               []             0           0
# 4      [https://t.co/b0Q4Tt1FJW]               []             0           0
# ...                          ...              ...           ...         ...
# 26671  [https://t.co/XFrtPBIMiv]               []           344        2013
# 26672                         []               []          1149        2406
# 26673                         []               []           185        1108
# 26674  [https://t.co/TZaorUiXQ1]               []           110         354
# 26675                         []  [#TrzeciaDroga]           748        2136
#
#       like_count quote_count impression_count
# 0            203           0            12028
# 1              2           0              275
# 2              0           0              188
# 3              1           0              170
# 4              0           0              124
# ...          ...         ...              ...
# 26671       4637         100           330379
# 26672      12760         182           689059
# 26673       3443          47           385751
# 26674       1568          21           205237
# 26675      11558         171           676180
#
# [26062 rows x 27 columns]

# %%
# changing id from float to int
df['id'] = df['id'].astype('int64')

# %%
df_clean_text = df[['id', 'text_clean']]

df_clean_text.to_csv('data_for_translation.csv', index=False)

# %% [markdown]
# # TO JEST DO OGARNIĘCIA -> OCZEKIWUJE NA DANE

# %%
df_en_text = pd.read_csv('Data/tweets_translation/translated_tweets.csv')
df_en_text.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df_en_text = pd.read_csv('Data/tweets_translation/translated_tweets.csv')
#       2 df_en_text.head()
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\macie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/tweets_translation/translated_tweets.csv'

# %%
df_en_text["id"] = df_en_text["id"].apply(lambda x: int(float(x.replace(',', ''))))

# %%
if 'text_clean_en' in df_en_text.columns:
    df = df.merge(df_en_text[['id', 'text_clean_en']], on='id', how='left')

    display(df.head())
else:
    print("Column 'text_clean_en' does not exist in df_clean_text")
# Out:
#                     id possibly_sensitive  in_reply_to_user_id  \
# 0  1846267743022330112              False            509272614
# 1  1846264777347117568              False                  NaN
# 2  1846262693394588160              False            955239446
# 3  1846261341327446272              False                  NaN
# 4  1846104865829015552              False                  NaN
#
#                  created_at  \
# 0 2024-10-15 19:11:46+00:00
# 1 2024-10-15 18:59:59+00:00
# 2 2024-10-15 18:51:42+00:00
# 3 2024-10-15 18:46:20+00:00
# 4 2024-10-15 08:24:33+00:00
#
#                                    referenced_tweets  \
# 0  [{'type': 'replied_to', 'id': '184615588116918...
# 1                                                NaN
# 2  [{'type': 'replied_to', 'id': '184612763211236...
# 3  [{'type': 'quoted', 'id': '1846159669573689602'}]
# 4                                                NaN
#
#                                        edit_controls  \
# 0  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4  {'edits_remaining': 5, 'is_edit_eligible': Tru...
#
#                                                 text edit_history_tweet_ids  \
# 0  @Dariusz_Jonski "Ani kroku wstecz!" - w przód ...  [1846267743022330183]
# 1  Właśnie zadzwonił do mnie nieznany numer. Już ...  [1846264777347117471]
# 2  @KosiniakKamysz Czy "jeszcze cięższa praca" pr...  [1846262693394588154]
# 3  Polecam się zapoznać z treścią konferencji  👇 ...  [1846261341327446163]
# 4   ❌ Kilka dni temu zagłosowałem za odwołaniem K...  [1846104865829015639]
#
#   reply_settings           author_id  ...  \
# 0       everyone 1187748790863839232  ...
# 1       everyone 1187748790863839232  ...
# 2       everyone 1187748790863839232  ...
# 3       everyone 1187748790863839232  ...
# 4       everyone 1187748790863839232  ...
#
#                                           text_clean           mentions  \
# 0   "Ani kroku wstecz!" - w przód też żadnego jak...  [@Dariusz_Jonski]
# 1  Właśnie zadzwonił do mnie nieznany numer. Już ...                 []
# 2   Czy "jeszcze cięższa praca" przełoży się na r...  [@KosiniakKamysz]
# 3    Polecam się zapoznać z treścią konferencji  👇                   []
# 4   ❌ Kilka dni temu zagłosowałem za odwołaniem K...                 []
#
#                                                links hashtags retweet_count  \
# 0                                                 []       []             0
# 1                                                 []       []            28
# 2                                                 []       []             4
# 3                          [https://t.co/U7LAeL2cqP]       []             9
# 4  [https://t.co/JQAQMEKjEs, https://t.co/4qtpUJO...       []            30
#
#   reply_count like_count quote_count impression_count  \
# 0           1         13           0              219
# 1           9        418           0             6449
# 2           1         38           0              443
# 3           2         48           0              687
# 4           0        141           0             3354
#
#                                        text_clean_en
# 0   "Not a step back!" - you haven't put any forw...
# 1  An unknown number just called me. I thought it...
# 2   Will "even harder work" translate into the fu...
# 3  I recommend reading the content of the confere...
# 4   ❌ A few days ago, I voted to dismiss Krzyszto...
#
# [5 rows x 28 columns]

# %%
# Replace '#VALUE!' with NaN in 'text_clean_en' column
df['text_clean_en'] = df['text_clean_en'].replace('#VALUE!', pd.NA)

# %%
df['text_clean_en_demojized'] = df['text_clean_en'].apply(lambda x: emoji.demojize(str(x)) if pd.notnull(x) else x)

df[['text_clean_en', 'text_clean_en_demojized']].head()
# Out:
#                                        text_clean_en  \
# 0   "Not a step back!" - you haven't put any forw...
# 1  An unknown number just called me. I thought it...
# 2   Will "even harder work" translate into the fu...
# 3  I recommend reading the content of the confere...
# 4   ❌ A few days ago, I voted to dismiss Krzyszto...
#
#                              text_clean_en_demojized
# 0   "Not a step back!" - you haven't put any forw...
# 1  An unknown number just called me. I thought it...
# 2   Will "even harder work" translate into the fu...
# 3  I recommend reading the content of the confere...
# 4   :cross_mark: A few days ago, I voted to dismi...

# %%
df
# Out:
#                         id possibly_sensitive  in_reply_to_user_id  \
# 0      1846267743022330112              False            509272614
# 1      1846264777347117568              False                  NaN
# 2      1846262693394588160              False            955239446
# 3      1846261341327446272              False                  NaN
# 4      1846104865829015552              False                  NaN
# ...                    ...                ...                  ...
# 11452  1721611648257921024                  0                  NaN
# 11453  1720163035048706304                  0                  NaN
# 11454  1716897815400792320                  0                  NaN
# 11455  1714387831425052928                  0           3370515933
# 11456  1714364905619431680                  0  1134033817105313792
#
#                      created_at  \
# 0     2024-10-15 19:11:46+00:00
# 1     2024-10-15 18:59:59+00:00
# 2     2024-10-15 18:51:42+00:00
# 3     2024-10-15 18:46:20+00:00
# 4     2024-10-15 08:24:33+00:00
# ...                         ...
# 11452 2023-11-06 19:32:57+00:00
# 11453 2023-11-02 19:36:41+00:00
# 11454 2023-10-24 19:21:52+00:00
# 11455 2023-10-17 21:08:05+00:00
# 11456 2023-10-17 19:36:59+00:00
#
#                                        referenced_tweets  \
# 0      [{'type': 'replied_to', 'id': '184615588116918...
# 1                                                    NaN
# 2      [{'type': 'replied_to', 'id': '184612763211236...
# 3      [{'type': 'quoted', 'id': '1846159669573689602'}]
# 4                                                    NaN
# ...                                                  ...
# 11452                                                NaN
# 11453  [{'type': 'quoted', 'id': '1720122294914187659'}]
# 11454                                                NaN
# 11455  [{'type': 'replied_to', 'id': '171438631727710...
# 11456  [{'type': 'replied_to', 'id': '171420049865020...
#
#                                            edit_controls  \
# 0      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 1      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 2      {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 3      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 4      {'edits_remaining': 5, 'is_edit_eligible': Tru...
# ...                                                  ...
# 11452  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 11453  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11454  {'edits_remaining': 5, 'is_edit_eligible': Tru...
# 11455  {'edits_remaining': 5, 'is_edit_eligible': Fal...
# 11456  {'edits_remaining': 5, 'is_edit_eligible': Fal...
#
#                                                     text  \
# 0      @Dariusz_Jonski "Ani kroku wstecz!" - w przód ...
# 1      Właśnie zadzwonił do mnie nieznany numer. Już ...
# 2      @KosiniakKamysz Czy "jeszcze cięższa praca" pr...
# 3      Polecam się zapoznać z treścią konferencji  👇 ...
# 4       ❌ Kilka dni temu zagłosowałem za odwołaniem K...
# ...                                                  ...
# 11452  Prezydent RP jest gwarantem ciągłości władzy p...
# 11453  W państwach o ustabilizowanej demokracji siła ...
# 11454  Piękny epilog kampanii wyborczej:\n ✅ ️ @Rober...
# 11455  @motykamilosz Jak widać nie tylko w piosenkach...
# 11456  @kamil_marc Oprócz korekty dotyczącej zmian de...
#
#       edit_history_tweet_ids reply_settings           author_id  ...  \
# 0      [1846267743022330183]       everyone 1187748790863839232  ...
# 1      [1846264777347117471]       everyone 1187748790863839232  ...
# 2      [1846262693394588154]       everyone 1187748790863839232  ...
# 3      [1846261341327446163]       everyone 1187748790863839232  ...
# 4      [1846104865829015639]       everyone 1187748790863839232  ...
# ...                      ...            ...                 ...  ...
# 11452  [1721611648257921084]       everyone           964017524  ...
# 11453  [1720163035048706306]       everyone           964017524  ...
# 11454  [1716897815400792400]       everyone           964017524  ...
# 11455  [1714387831425052856]       everyone           964017524  ...
# 11456  [1714364905619431647]       everyone           964017524  ...
#
#                               mentions  \
# 0                    [@Dariusz_Jonski]
# 1                                   []
# 2                    [@KosiniakKamysz]
# 3                                   []
# 4                                   []
# ...                                ...
# 11452                               []
# 11453                               []
# 11454  [@RobertTelus, @KosiniakKamysz]
# 11455                  [@motykamilosz]
# 11456                    [@kamil_marc]
#
#                                                    links         hashtags  \
# 0                                                     []               []
# 1                                                     []               []
# 2                                                     []               []
# 3                              [https://t.co/U7LAeL2cqP]               []
# 4      [https://t.co/JQAQMEKjEs, https://t.co/4qtpUJO...               []
# ...                                                  ...              ...
# 11452                                                 []               []
# 11453                          [https://t.co/u1vzB6ImaB]               []
# 11454                          [https://t.co/MGuhesegb2]  [#TrzeciaDroga]
# 11455                                                 []               []
# 11456                                                 []               []
#
#       retweet_count reply_count like_count quote_count impression_count  \
# 0                 0           1         13           0              219
# 1                28           9        418           0             6449
# 2                 4           1         38           0              443
# 3                 9           2         48           0              687
# 4                30           0        141           0             3354
# ...             ...         ...        ...         ...              ...
# 11452            17           6         53           1             4871
# 11453            18           2         41           2             3152
# 11454            26           7         97           1             5674
# 11455             1           2         50           0             1301
# 11456             2           2          9           0              595
#
#                                            text_clean_en  \
# 0       "Not a step back!" - you haven't put any forw...
# 1      An unknown number just called me. I thought it...
# 2       Will "even harder work" translate into the fu...
# 3      I recommend reading the content of the confere...
# 4       ❌ A few days ago, I voted to dismiss Krzyszto...
# ...                                                  ...
# 11452  The President of the Republic of Poland is the...
# 11453  In countries with stable democracy, the streng...
# 11454  A beautiful epilogue of the election campaign:...
# 11455   As you can see, not only in Eleni's songs "Lo...
# 11456  In addition to corrections related to demograp...
#
#                                  text_clean_en_demojized
# 0       "Not a step back!" - you haven't put any forw...
# 1      An unknown number just called me. I thought it...
# 2       Will "even harder work" translate into the fu...
# 3      I recommend reading the content of the confere...
# 4       :cross_mark: A few days ago, I voted to dismi...
# ...                                                  ...
# 11452  The President of the Republic of Poland is the...
# 11453  In countries with stable democracy, the streng...
# 11454  A beautiful epilogue of the election campaign:...
# 11455   As you can see, not only in Eleni's songs "Lo...
# 11456  In addition to corrections related to demograp...
#
# [11457 rows x 29 columns]

# %%
df['possibly_sensitive'] = df['possibly_sensitive'].astype(bool)

# %%
username_to_realname = {
    'bartlomiejpejo': 'Bartłomiej Pejo',
    'RobertBiedron': 'Robert Biedroń',
    'PatrykJaki': 'Patryk Jaki',
    'Kpelczynska': 'Katarzyna Pelczyńska',
    'OklaDrewnowicz': 'Agnieszka Okła-Drewnowicz',
    'KosiniakKamysz': 'Władysław Kosiniak-Kamysz',
    'mwojcik_': 'Michał Wójcik',
    'MorawieckiM': 'Mateusz Morawiecki',
    'SlawomirMentzen': 'Sławomir Mentzen',
    'Wlodek_Skalik': 'Włodzimierz Skalik',
    'BeataSzydlo': 'Beata Szydło',
    'WTumanowicz': 'Witold Tumanowicz',
    'KGawkowski': 'Krzysztof Gawkowski',
    'wlodekczarzasty': 'Włodzimierz Czarzasty',
    'Kaminski_M_': 'Mariusz Kamiński',
    'Macierewicz_A': 'Antoni Macierewicz',
    'elzbietawitek': 'Elżbieta Witek',
    'aga_buczynska': 'Agnieszka Buczyńska',
    'szymon_holownia': 'Szymon Hołownia',
    'DorotaNiedziela': 'Dorota Niedziela',
    'EwaKopacz': 'Ewa Kopacz',
    'Leszczyna': 'Izabela Leszczyna',
    'M_K_Blonska': 'Małgorzata Kidawa-Błońska',
    'bbudka': 'Borys Budka',
    'donaldtusk': 'Donald Tusk',
    'DariuszKlimczak': 'Dariusz Klimczak',
    'GrzybAndrzej': 'Andrzej Grzyb',
    'Hetman_K': 'Krzysztof Hetman',
    'JarubasAdam': 'Adam Jarubas',
    'Paslawska': 'Urszula Pasławska',
    'TudujKrzysztof': 'Krzysztof Tuduj',
    'ZalewskiPawel': 'Paweł Zalewski'
}

# Add the 'name' column to the dataframe
df['name'] = df['username'].map(username_to_realname)

# %%
# Delete next line sign from the 'text_clean_en' column
df['text_clean_en'] = df['text_clean_en'].str.replace('\n', ' ')

# %%
# Save the DataFrame to a Parquet file
df.to_parquet('cleaned_data/df_combined.parquet', index=False)
